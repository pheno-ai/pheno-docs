# %% [raw]
# ---
# output-file: 13-gut_microbiome.html
# title: 13-gut_microbiome
#
# ---

# %% [markdown]
# # 13 - gut microbiome
#
# Metagenomics is the study of genetic material from environmental samples, including microbial communities. It involves sequencing the DNA of all microorganisms in the sample, rather than isolating individual organisms. Metagenomics enables the identification and functional analysis of microorganisms in diverse environments, including soil, water, and the human body.
#
# This dataset maps out the human gut microbiota per participant via shotgun metagenomic sequencing given stool samples. It is then compared to known references of gut flora to measure prevalence of specific microbes.
#
# Gut microbiome metagenomics can be used to identify potential biomarkers of disease, develop personalized treatment strategies, and better understand the complex relationship between the gut microbiota and human physiology. It has already been providing insights into the role of gut microbes in various diseases such as obesity, diabetes and IBD.
#
# To measure the genetic makeup of the human gut flora given stool samples via metagenomics, the following steps done:
#
# 1. Collection of stool sample: For each visit, a stool sample is collected from the individual and stored appropriately to preserve the microbial community.
# 2. DNA extraction: DNA is extracted from the stool sample using specialized techniques to isolate the microbial DNA from other materials present in the sample.
# 3. DNA fragmentation and sequencing: The extracted DNA is then fragmented into small pieces and sequenced using high-throughput sequencing technologies.
# 4. Quality control: The resulting raw sequencing data is then pre-processed, removing low-quality reads and artifacts of the sequencing methodology.
# 5. Taxonomic classification: The processed sequencing data is then compared to databases of known microbial sequences to identify and classify the microbial species presence and their respective abundances in the sample.
#
# The information is stored in multiple parquet files:
#
# - `metadata`: Sequencing and QC statistics.
# - `urs`: Segal Lab relative abundance.
# - `metaphlan_*`: 8 tables with MetaPhlAn 4 relative abundances, separated by taxonomic levels.

# %%
#| hide
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('gut_microbiome', age_sex_dataset=None)
dl
# Out:
# DataLoader for gut_microbiome with
# 9903 fields
# 10 tables: ['metadata', 'urs', 'metaphlan_kingdom', 'metaphlan_phylum', 'metaphlan_class', 'metaphlan_order', 'metaphlan_family', 'metaphlan_genus', 'metaphlan_species', 'metaphlan_strain']

# %%
dl.dict
# Out:
#                                                            field_string  \
# tabular_field_name
# collection_timestamp                                  Sampled Timestamp
# collection_date                                            Sampled Date
# SampleName                                                  Sample Name
# raw_read_count                                          Raw Reads Count
# trimmed_read_count                                  Post QC Reads Count
# ...                                                                 ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...              SGB9222
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...              EUK4932
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...             EUK46681
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...            EUK944036
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...              EUK5741
#
#                                                               description_string  \
# tabular_field_name
# collection_timestamp                                       Time sample was given
# collection_date                                            Date sample was given
# SampleName                                                           Sample Name
# raw_read_count                                      #Reads in the original FASTQ
# trimmed_read_count                                   #Reads in the Post QC FASTQ
# ...                                                                          ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...                       SGB9222
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...                       EUK4932
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                      EUK46681
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                     EUK944036
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                       EUK5741
#
#                                                     parent_dataframe  \
# tabular_field_name
# collection_timestamp                                             NaN
# collection_date                                                  NaN
# SampleName                                                       NaN
# raw_read_count                                                   NaN
# trimmed_read_count                                               NaN
# ...                                                              ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...               NaN
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...               NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...               NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...               NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...               NaN
#
#                                                            relative_location  \
# tabular_field_name
# collection_timestamp                                        metadata.parquet
# collection_date                                             metadata.parquet
# SampleName                                                  metadata.parquet
# raw_read_count                                              metadata.parquet
# trimmed_read_count                                          metadata.parquet
# ...                                                                      ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...  metaphlan_strain.parquet
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...  metaphlan_strain.parquet
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  metaphlan_strain.parquet
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  metaphlan_strain.parquet
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  metaphlan_strain.parquet
#
#                                                     value_type    units  \
# tabular_field_name
# collection_timestamp                                      Date     Time
# collection_date                                           Date     Time
# SampleName                                                Text      NaN
# raw_read_count                                         Integer      NaN
# trimmed_read_count                                     Integer      NaN
# ...                                                        ...      ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...  Continuous  Percent
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...  Continuous  Percent
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  Continuous  Percent
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  Continuous  Percent
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  Continuous  Percent
#
#                                                     sampling_rate item_type  \
# tabular_field_name
# collection_timestamp                                          NaN      Data
# collection_date                                               NaN      Data
# SampleName                                                    NaN      Data
# raw_read_count                                                NaN      Data
# trimmed_read_count                                            NaN      Data
# ...                                                           ...       ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...            NaN      Data
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...            NaN      Data
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...            NaN      Data
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...            NaN      Data
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...            NaN      Data
#
#                                                      array cohorts data_type  \
# tabular_field_name
# collection_timestamp                                Single     10K  Metadata
# collection_date                                     Single     10K  Metadata
# SampleName                                          Single     10K  Metadata
# raw_read_count                                      Single     10K  Metadata
# trimmed_read_count                                  Single     10K  Metadata
# ...                                                    ...     ...       ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...  single     10K   Tabular
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...  single     10K   Tabular
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  single     10K   Tabular
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  single     10K   Tabular
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  single     10K   Tabular
#
#                                                          debut    pandas_dtype
# tabular_field_name
# collection_timestamp                                2019-02-14  datetime64[ns]
# collection_date                                     2019-02-14  datetime64[ns]
# SampleName                                          2019-02-14          object
# raw_read_count                                      2019-02-14           int64
# trimmed_read_count                                  2019-02-14           int64
# ...                                                        ...             ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...  2019-02-14         float64
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...  2019-02-14         float64
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  2019-02-14         float64
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  2019-02-14         float64
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  2019-02-14         float64
#
# [9903 rows x 13 columns]
