# %% [raw]
# ---
# output-file: 14-human_genetics.html
# title: 14-human_genetics
#
# ---

# %% [markdown]
# # 14 - human genetics
#
# The Human Phenotype Project collects genomic variation data on all its participants. The genomic data together with the Human Phenotype Project  deep-phenotypes allows to investigate the progression of disease, and to explore personalized treatments. We genotype millions of positions by low-pass sequencing combined with imputation using gencove platform technologies. Genotype imputation is a process of statistically inferring unobserved genotypes using known haplotypes in a population. The performance of Gencove genotype imputation is very high ( accuracy > 98% ) (Wasik et al. 2021).
#
# The information is stored in a number of statistics parquet files:
# - `main.parquet`: sample metadata, including QC statistics, paths to PLINK variant files (raw and post-QC), and principal components (PCs).
# - `variant_qc.parquet`: variant QC statistics.
# - `relatives/plink_ibs.parquet`: IBS calculated by PLINK for pairs of participants.
# - `relatives/king_kinship.parquet`: King kinship coefficients for pairs of participants.
#
# And a PLINK text file `pca/eigenvec.var` containing the principal component loadings.

# %%
#| hide
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('human_genetics', age_sex_dataset=None)
dl
# Out:
# DataLoader for human_genetics with
# 119 fields
# 1 tables: ['main']

# %%
dl.dict
# Out:
#                                                                                field_string  \
# tabular_field_name
# collection_date                                                             Collection date
# version                                                                    Gencove version
# genecov_qc_bases                                                           Bases sequenced
# genecov_qc_bases_dedup                                                   Deduplicated bases
# gencove_qc_bases_dedup_mapped                                    Deduplicated bases aligned
# genecov_qc_effective_coverage                                            Effective coverage
# genecov_qc_fraction_contamination                                         DNA contamination
# genecov_qc_snps                                                                SNPs covered
# genecov_qc_format_passed                                       Passed FASTQ format validity
# genecov_qc_r1_eq_r2_passed                                         Passed paired-end count
# genecov_qc_r1_r2_ids_match_passed                                   Passed paired-end match
# genecov_qc_bases_passed                                             Passed Bases sequenced
# genecov_qc_bases_dedup_passed                                     Passed Deduplicated bases
# genecov_qc_bases_dedup_mapped_passed                      Passed Deduplicated bases aligned
# genecov_qc_effective_coverage_passed                              Passed Effective coverage
# genecov_qc_fraction_contamination_passed                           Passed DNA contamination
# genecov_qc_snps_passed                                                  Passed SNPs covered
# heterozygosity_proportion                                         Heterozygosity proportion
# pass_het_check                                             Passed Heterozygosity proportion
# sample_qc_gp_pass_rate                                    Genotype Probabilities pass rate
# sample_qc_gp_pass_check                                       Passed Genotype Probabilities
# genetic_sex                                                                         DNA sex
# chr_x_proportion                                    Proportion of alignment to chromosome X
# chr_y_proportion                                    Proportion of alignment to chromosome Y
# sample_qc_gender_match_check                                            Passed gender check
# relatives                                                 Relatives based on IBD estimation
# self_report_ashkenaz_proportion                 Self-reported ashkenazi descent proportion
# self_report_middleeastern_proportion       Self-reported Middle-Eastern descent proportion
# self_report_northafrican_proportion         Self-reported North-African descent proportion
# self_report_sephardi_proportion                  Self-reported Sephardi descent proportion
# self_report_yemen_proportion                        Self-reported Yemen descent proportion
# self_report_unknownother_proportion       Self-reported unknown or other descent proport...
# pc1                                                                   Principal component 1
# pc2                                                                   Principal component 2
# pc3                                                                   Principal component 3
# pc4                                                                   Principal component 4
# pc5                                                                   Principal component 5
# pc6                                                                   Principal component 6
# pc7                                                                   Principal component 7
# pc8                                                                   Principal component 8
# pc9                                                                   Principal component 9
# pc10                                                                 Principal component 10
# pc11                                                                 Principal component 11
# pc12                                                                 Principal component 12
# pc13                                                                 Principal component 13
# pc14                                                                 Principal component 14
# pc15                                                                 Principal component 15
# pc16                                                                 Principal component 16
# pc17                                                                 Principal component 17
# pc18                                                                 Principal component 18
# pc19                                                                 Principal component 19
# pc20                                                                 Principal component 20
# used_in_pca_calculation                            Included in principal component analysis
# postqc_bed_chr_1                              PLINK BED file for post QC genotype data chr1
# postqc_fam_chr_1                                   PLINK FAM file accompanying QC .bed chr1
# postqc_bim_chr_1                          PLINK BIM file for the post QC genotype data chr1
# postqc_bed_chr_2                              PLINK BED file for post QC genotype data chr2
# postqc_fam_chr_2                                   PLINK FAM file accompanying QC .bed chr2
# postqc_bim_chr_2                          PLINK BIM file for the post QC genotype data chr2
# postqc_bed_chr_3                              PLINK BED file for post QC genotype data chr3
# postqc_fam_chr_3                                   PLINK FAM file accompanying QC .bed chr3
# postqc_bim_chr_3                          PLINK BIM file for the post QC genotype data chr3
# postqc_bed_chr_4                              PLINK BED file for post QC genotype data chr4
# postqc_fam_chr_4                                   PLINK FAM file accompanying QC .bed chr4
# postqc_bim_chr_4                          PLINK BIM file for the post QC genotype data chr4
# postqc_bed_chr_5                              PLINK BED file for post QC genotype data chr5
# postqc_fam_chr_5                                   PLINK FAM file accompanying QC .bed chr5
# postqc_bim_chr_5                          PLINK BIM file for the post QC genotype data chr5
# postqc_bed_chr_6                              PLINK BED file for post QC genotype data chr6
# postqc_fam_chr_6                                   PLINK FAM file accompanying QC .bed chr6
# postqc_bim_chr_6                          PLINK BIM file for the post QC genotype data chr6
# postqc_bed_chr_7                              PLINK BED file for post QC genotype data chr7
# postqc_fam_chr_7                                   PLINK FAM file accompanying QC .bed chr7
# postqc_bim_chr_7                          PLINK BIM file for the post QC genotype data chr7
# postqc_bed_chr_8                              PLINK BED file for post QC genotype data chr8
# postqc_fam_chr_8                                   PLINK FAM file accompanying QC .bed chr8
# postqc_bim_chr_8                          PLINK BIM file for the post QC genotype data chr8
# postqc_bed_chr_9                              PLINK BED file for post QC genotype data chr9
# postqc_fam_chr_9                                   PLINK FAM file accompanying QC .bed chr9
# postqc_bim_chr_9                          PLINK BIM file for the post QC genotype data chr9
# postqc_bed_chr_10                            PLINK BED file for post QC genotype data chr10
# postqc_fam_chr_10                                 PLINK FAM file accompanying QC .bed chr10
# postqc_bim_chr_10                         PLINK BIM file for the post QC genotype data c...
# postqc_bed_chr_11                            PLINK BED file for post QC genotype data chr11
# postqc_fam_chr_11                                 PLINK FAM file accompanying QC .bed chr11
# postqc_bim_chr_11                         PLINK BIM file for the post QC genotype data c...
# postqc_bed_chr_12                            PLINK BED file for post QC genotype data chr12
# postqc_fam_chr_12                                 PLINK FAM file accompanying QC .bed chr12
# postqc_bim_chr_12                         PLINK BIM file for the post QC genotype data c...
# postqc_bed_chr_13                            PLINK BED file for post QC genotype data chr13
# postqc_fam_chr_13                                 PLINK FAM file accompanying QC .bed chr13
# postqc_bim_chr_13                         PLINK BIM file for the post QC genotype data c...
# postqc_bed_chr_14                            PLINK BED file for post QC genotype data chr14
# postqc_fam_chr_14                                 PLINK FAM file accompanying QC .bed chr14
# postqc_bim_chr_14                         PLINK BIM file for the post QC genotype data c...
# postqc_bed_chr_15                            PLINK BED file for post QC genotype data chr15
# postqc_fam_chr_15                                 PLINK FAM file accompanying QC .bed chr15
# postqc_bim_chr_15                         PLINK BIM file for the post QC genotype data c...
# postqc_bed_chr_16                            PLINK BED file for post QC genotype data chr16
# postqc_fam_chr_16                                 PLINK FAM file accompanying QC .bed chr16
# postqc_bim_chr_16                         PLINK BIM file for the post QC genotype data c...
# postqc_bed_chr_17                            PLINK BED file for post QC genotype data chr17
# postqc_fam_chr_17                                 PLINK FAM file accompanying QC .bed chr17
# postqc_bim_chr_17                         PLINK BIM file for the post QC genotype data c...
# postqc_bed_chr_18                            PLINK BED file for post QC genotype data chr18
# postqc_fam_chr_18                                 PLINK FAM file accompanying QC .bed chr18
# postqc_bim_chr_18                         PLINK BIM file for the post QC genotype data c...
# postqc_bed_chr_19                            PLINK BED file for post QC genotype data chr19
# postqc_fam_chr_19                                 PLINK FAM file accompanying QC .bed chr19
# postqc_bim_chr_19                         PLINK BIM file for the post QC genotype data c...
# postqc_bed_chr_20                            PLINK BED file for post QC genotype data chr20
# postqc_fam_chr_20                                 PLINK FAM file accompanying QC .bed chr20
# postqc_bim_chr_20                         PLINK BIM file for the post QC genotype data c...
# postqc_bed_chr_21                            PLINK BED file for post QC genotype data chr21
# postqc_fam_chr_21                                 PLINK FAM file accompanying QC .bed chr21
# postqc_bim_chr_21                         PLINK BIM file for the post QC genotype data c...
# postqc_bed_chr_22                            PLINK BED file for post QC genotype data chr22
# postqc_fam_chr_22                                 PLINK FAM file accompanying QC .bed chr22
# postqc_bim_chr_22                         PLINK BIM file for the post QC genotype data c...
#
#                                                                          description_string  \
# tabular_field_name
# collection_date                           The date of downloading Gencove results from t...
# version                                                          Gencove API version 1 or 2
# genecov_qc_bases                          number of total bases sequenced. from genecov ...
# genecov_qc_bases_dedup                    number of deduplicated bases. from genecov qc ...
# gencove_qc_bases_dedup_mapped             number of deduplicated bases that have aligned...
# genecov_qc_effective_coverage                      effective coverage. from genecov qc file
# genecov_qc_fraction_contamination         contamination by DNA from another sample of th...
# genecov_qc_snps                           number of variants in reference panel that are...
# genecov_qc_format_passed                  Indicates proper formatting of the input FASTQ...
# genecov_qc_r1_eq_r2_passed                Indicates number of bases in R1 file equal to ...
# genecov_qc_r1_r2_ids_match_passed         Indicates R1 read identifiers match R2 read id...
# genecov_qc_bases_passed                   Indicates number of total bases sequenced grea...
# genecov_qc_bases_dedup_passed             Indicates number of deduplicated bases greater...
# genecov_qc_bases_dedup_mapped_passed      Indicates number of deduplicated bases aligned...
# genecov_qc_effective_coverage_passed      Indicates effective coverage greater than 0. f...
# genecov_qc_fraction_contamination_passed  Indicates contamination by DNA less than 0.06....
# genecov_qc_snps_passed                    Indicates number of variants covered by at lea...
# heterozygosity_proportion                 Estimated heterozygosity proportion across a s...
# pass_het_check                            Indicates heterozygosity proportion is less th...
# sample_qc_gp_pass_rate                    Proportion of genotypes with maximum GP greate...
# sample_qc_gp_pass_check                   Indicates proportion of GP greater than 0.9 is...
# genetic_sex                               Sex as determined by the percentage of read-al...
# chr_x_proportion                                percentage of reads aligned to chromosome X
# chr_y_proportion                                percentage of reads aligned to chromosome Y
# sample_qc_gender_match_check              Indicates inferred_gender and submitted_gender...
# relatives                                 List of second and first degree relatives acco...
# self_report_ashkenaz_proportion           Proportion of great-grandparents with ashkenaz...
# self_report_middleeastern_proportion      Proportion of great-grandparents with Middle-E...
# self_report_northafrican_proportion       Proportion of great-grandparents with ashkenaz...
# self_report_sephardi_proportion           Proportion of great-grandparents with North-Af...
# self_report_yemen_proportion              Proportion of great-grandparents with Yemen de...
# self_report_unknownother_proportion       Proportion of great-grandparents with unknown ...
# pc1                                               Score for projected principal component 1
# pc2                                               Score for projected principal component 2
# pc3                                               Score for projected principal component 3
# pc4                                               Score for projected principal component 4
# pc5                                               Score for projected principal component 5
# pc6                                               Score for projected principal component 6
# pc7                                               Score for projected principal component 7
# pc8                                               Score for projected principal component 8
# pc9                                               Score for projected principal component 9
# pc10                                             Score for projected principal component 10
# pc11                                             Score for projected principal component 11
# pc12                                             Score for projected principal component 12
# pc13                                             Score for projected principal component 13
# pc14                                             Score for projected principal component 14
# pc15                                             Score for projected principal component 15
# pc16                                             Score for projected principal component 16
# pc17                                             Score for projected principal component 17
# pc18                                             Score for projected principal component 18
# pc19                                             Score for projected principal component 19
# pc20                                             Score for projected principal component 20
# used_in_pca_calculation                   Indicates samples was in the input for princip...
# postqc_bed_chr_1                          Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_1                          PLINK sample information file accompanying a ....
# postqc_bim_chr_1                          PLINK variant information file (per chromosome...
# postqc_bed_chr_2                          Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_2                          PLINK sample information file accompanying a ....
# postqc_bim_chr_2                          PLINK variant information file (per chromosome...
# postqc_bed_chr_3                          Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_3                          PLINK sample information file accompanying a ....
# postqc_bim_chr_3                          PLINK variant information file (per chromosome...
# postqc_bed_chr_4                          Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_4                          PLINK sample information file accompanying a ....
# postqc_bim_chr_4                          PLINK variant information file (per chromosome...
# postqc_bed_chr_5                          Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_5                          PLINK sample information file accompanying a ....
# postqc_bim_chr_5                          PLINK variant information file (per chromosome...
# postqc_bed_chr_6                          Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_6                          PLINK sample information file accompanying a ....
# postqc_bim_chr_6                          PLINK variant information file (per chromosome...
# postqc_bed_chr_7                          Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_7                          PLINK sample information file accompanying a ....
# postqc_bim_chr_7                          PLINK variant information file (per chromosome...
# postqc_bed_chr_8                          Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_8                          PLINK sample information file accompanying a ....
# postqc_bim_chr_8                          PLINK variant information file (per chromosome...
# postqc_bed_chr_9                          Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_9                          PLINK sample information file accompanying a ....
# postqc_bim_chr_9                          PLINK variant information file (per chromosome...
# postqc_bed_chr_10                         Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_10                         PLINK sample information file accompanying a ....
# postqc_bim_chr_10                         PLINK variant information file (per chromosome...
# postqc_bed_chr_11                         Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_11                         PLINK sample information file accompanying a ....
# postqc_bim_chr_11                         PLINK variant information file (per chromosome...
# postqc_bed_chr_12                         Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_12                         PLINK sample information file accompanying a ....
# postqc_bim_chr_12                         PLINK variant information file (per chromosome...
# postqc_bed_chr_13                         Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_13                         PLINK sample information file accompanying a ....
# postqc_bim_chr_13                         PLINK variant information file (per chromosome...
# postqc_bed_chr_14                         Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_14                         PLINK sample information file accompanying a ....
# postqc_bim_chr_14                         PLINK variant information file (per chromosome...
# postqc_bed_chr_15                         Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_15                         PLINK sample information file accompanying a ....
# postqc_bim_chr_15                         PLINK variant information file (per chromosome...
# postqc_bed_chr_16                         Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_16                         PLINK sample information file accompanying a ....
# postqc_bim_chr_16                         PLINK variant information file (per chromosome...
# postqc_bed_chr_17                         Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_17                         PLINK sample information file accompanying a ....
# postqc_bim_chr_17                         PLINK variant information file (per chromosome...
# postqc_bed_chr_18                         Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_18                         PLINK sample information file accompanying a ....
# postqc_bim_chr_18                         PLINK variant information file (per chromosome...
# postqc_bed_chr_19                         Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_19                         PLINK sample information file accompanying a ....
# postqc_bim_chr_19                         PLINK variant information file (per chromosome...
# postqc_bed_chr_20                         Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_20                         PLINK sample information file accompanying a ....
# postqc_bim_chr_20                         PLINK variant information file (per chromosome...
# postqc_bed_chr_21                         Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_21                         PLINK sample information file accompanying a ....
# postqc_bim_chr_21                         PLINK variant information file (per chromosome...
# postqc_bed_chr_22                         Raw genotype calls (per chromosome) in binary ...
# postqc_fam_chr_22                         PLINK sample information file accompanying a ....
# postqc_bim_chr_22                         PLINK variant information file (per chromosome...
#
#                                           parent_dataframe relative_location  \
# tabular_field_name
# collection_date                                        NaN      main.parquet
# version                                                NaN      main.parquet
# genecov_qc_bases                                       NaN      main.parquet
# genecov_qc_bases_dedup                                 NaN      main.parquet
# gencove_qc_bases_dedup_mapped                          NaN      main.parquet
# genecov_qc_effective_coverage                          NaN      main.parquet
# genecov_qc_fraction_contamination                      NaN      main.parquet
# genecov_qc_snps                                        NaN      main.parquet
# genecov_qc_format_passed                               NaN      main.parquet
# genecov_qc_r1_eq_r2_passed                             NaN      main.parquet
# genecov_qc_r1_r2_ids_match_passed                      NaN      main.parquet
# genecov_qc_bases_passed                                NaN      main.parquet
# genecov_qc_bases_dedup_passed                          NaN      main.parquet
# genecov_qc_bases_dedup_mapped_passed                   NaN      main.parquet
# genecov_qc_effective_coverage_passed                   NaN      main.parquet
# genecov_qc_fraction_contamination_passed               NaN      main.parquet
# genecov_qc_snps_passed                                 NaN      main.parquet
# heterozygosity_proportion                              NaN      main.parquet
# pass_het_check                                         NaN      main.parquet
# sample_qc_gp_pass_rate                                 NaN      main.parquet
# sample_qc_gp_pass_check                                NaN      main.parquet
# genetic_sex                                            NaN      main.parquet
# chr_x_proportion                                       NaN      main.parquet
# chr_y_proportion                                       NaN      main.parquet
# sample_qc_gender_match_check                           NaN      main.parquet
# relatives                                              NaN      main.parquet
# self_report_ashkenaz_proportion                        NaN      main.parquet
# self_report_middleeastern_proportion                   NaN      main.parquet
# self_report_northafrican_proportion                    NaN      main.parquet
# self_report_sephardi_proportion                        NaN      main.parquet
# self_report_yemen_proportion                           NaN      main.parquet
# self_report_unknownother_proportion                    NaN      main.parquet
# pc1                                                    NaN      main.parquet
# pc2                                                    NaN      main.parquet
# pc3                                                    NaN      main.parquet
# pc4                                                    NaN      main.parquet
# pc5                                                    NaN      main.parquet
# pc6                                                    NaN      main.parquet
# pc7                                                    NaN      main.parquet
# pc8                                                    NaN      main.parquet
# pc9                                                    NaN      main.parquet
# pc10                                                   NaN      main.parquet
# pc11                                                   NaN      main.parquet
# pc12                                                   NaN      main.parquet
# pc13                                                   NaN      main.parquet
# pc14                                                   NaN      main.parquet
# pc15                                                   NaN      main.parquet
# pc16                                                   NaN      main.parquet
# pc17                                                   NaN      main.parquet
# pc18                                                   NaN      main.parquet
# pc19                                                   NaN      main.parquet
# pc20                                                   NaN      main.parquet
# used_in_pca_calculation                                NaN      main.parquet
# postqc_bed_chr_1                                       NaN      main.parquet
# postqc_fam_chr_1                                       NaN      main.parquet
# postqc_bim_chr_1                                       NaN      main.parquet
# postqc_bed_chr_2                                       NaN      main.parquet
# postqc_fam_chr_2                                       NaN      main.parquet
# postqc_bim_chr_2                                       NaN      main.parquet
# postqc_bed_chr_3                                       NaN      main.parquet
# postqc_fam_chr_3                                       NaN      main.parquet
# postqc_bim_chr_3                                       NaN      main.parquet
# postqc_bed_chr_4                                       NaN      main.parquet
# postqc_fam_chr_4                                       NaN      main.parquet
# postqc_bim_chr_4                                       NaN      main.parquet
# postqc_bed_chr_5                                       NaN      main.parquet
# postqc_fam_chr_5                                       NaN      main.parquet
# postqc_bim_chr_5                                       NaN      main.parquet
# postqc_bed_chr_6                                       NaN      main.parquet
# postqc_fam_chr_6                                       NaN      main.parquet
# postqc_bim_chr_6                                       NaN      main.parquet
# postqc_bed_chr_7                                       NaN      main.parquet
# postqc_fam_chr_7                                       NaN      main.parquet
# postqc_bim_chr_7                                       NaN      main.parquet
# postqc_bed_chr_8                                       NaN      main.parquet
# postqc_fam_chr_8                                       NaN      main.parquet
# postqc_bim_chr_8                                       NaN      main.parquet
# postqc_bed_chr_9                                       NaN      main.parquet
# postqc_fam_chr_9                                       NaN      main.parquet
# postqc_bim_chr_9                                       NaN      main.parquet
# postqc_bed_chr_10                                      NaN      main.parquet
# postqc_fam_chr_10                                      NaN      main.parquet
# postqc_bim_chr_10                                      NaN      main.parquet
# postqc_bed_chr_11                                      NaN      main.parquet
# postqc_fam_chr_11                                      NaN      main.parquet
# postqc_bim_chr_11                                      NaN      main.parquet
# postqc_bed_chr_12                                      NaN      main.parquet
# postqc_fam_chr_12                                      NaN      main.parquet
# postqc_bim_chr_12                                      NaN      main.parquet
# postqc_bed_chr_13                                      NaN      main.parquet
# postqc_fam_chr_13                                      NaN      main.parquet
# postqc_bim_chr_13                                      NaN      main.parquet
# postqc_bed_chr_14                                      NaN      main.parquet
# postqc_fam_chr_14                                      NaN      main.parquet
# postqc_bim_chr_14                                      NaN      main.parquet
# postqc_bed_chr_15                                      NaN      main.parquet
# postqc_fam_chr_15                                      NaN      main.parquet
# postqc_bim_chr_15                                      NaN      main.parquet
# postqc_bed_chr_16                                      NaN      main.parquet
# postqc_fam_chr_16                                      NaN      main.parquet
# postqc_bim_chr_16                                      NaN      main.parquet
# postqc_bed_chr_17                                      NaN      main.parquet
# postqc_fam_chr_17                                      NaN      main.parquet
# postqc_bim_chr_17                                      NaN      main.parquet
# postqc_bed_chr_18                                      NaN      main.parquet
# postqc_fam_chr_18                                      NaN      main.parquet
# postqc_bim_chr_18                                      NaN      main.parquet
# postqc_bed_chr_19                                      NaN      main.parquet
# postqc_fam_chr_19                                      NaN      main.parquet
# postqc_bim_chr_19                                      NaN      main.parquet
# postqc_bed_chr_20                                      NaN      main.parquet
# postqc_fam_chr_20                                      NaN      main.parquet
# postqc_bim_chr_20                                      NaN      main.parquet
# postqc_bed_chr_21                                      NaN      main.parquet
# postqc_fam_chr_21                                      NaN      main.parquet
# postqc_bim_chr_21                                      NaN      main.parquet
# postqc_bed_chr_22                                      NaN      main.parquet
# postqc_fam_chr_22                                      NaN      main.parquet
# postqc_bim_chr_22                                      NaN      main.parquet
#
#                                                       value_type    units  \
# tabular_field_name
# collection_date                                             Time     Time
# version                                   Categorical (multiple)      NaN
# genecov_qc_bases                                         Integer    Count
# genecov_qc_bases_dedup                                   Integer    Count
# gencove_qc_bases_dedup_mapped                            Integer    Count
# genecov_qc_effective_coverage                         Continuous  Precent
# genecov_qc_fraction_contamination                     Continuous  Precent
# genecov_qc_snps                                          Integer    Count
# genecov_qc_format_passed                    Categorical (single)  Boolean
# genecov_qc_r1_eq_r2_passed                  Categorical (single)  Boolean
# genecov_qc_r1_r2_ids_match_passed           Categorical (single)  Boolean
# genecov_qc_bases_passed                     Categorical (single)  Boolean
# genecov_qc_bases_dedup_passed               Categorical (single)  Boolean
# genecov_qc_bases_dedup_mapped_passed        Categorical (single)  Boolean
# genecov_qc_effective_coverage_passed        Categorical (single)  Boolean
# genecov_qc_fraction_contamination_passed    Categorical (single)  Boolean
# genecov_qc_snps_passed                      Categorical (single)  Boolean
# heterozygosity_proportion                             Continuous  Precent
# pass_het_check                              Categorical (single)  Boolean
# sample_qc_gp_pass_rate                                Continuous  Precent
# sample_qc_gp_pass_check                     Categorical (single)  Boolean
# genetic_sex                                 Categorical (single)  Boolean
# chr_x_proportion                                      Continuous  Precent
# chr_y_proportion                                      Continuous  Precent
# sample_qc_gender_match_check                Categorical (single)  Boolean
# relatives                                                 String     Text
# self_report_ashkenaz_proportion                       Continuous  Precent
# self_report_middleeastern_proportion                  Continuous  Precent
# self_report_northafrican_proportion                   Continuous  Precent
# self_report_sephardi_proportion                       Continuous  Precent
# self_report_yemen_proportion                          Continuous  Precent
# self_report_unknownother_proportion                   Continuous  Precent
# pc1                                                   Continuous     None
# pc2                                                   Continuous     None
# pc3                                                   Continuous     None
# pc4                                                   Continuous     None
# pc5                                                   Continuous     None
# pc6                                                   Continuous     None
# pc7                                                   Continuous     None
# pc8                                                   Continuous     None
# pc9                                                   Continuous     None
# pc10                                                  Continuous     None
# pc11                                                  Continuous     None
# pc12                                                  Continuous     None
# pc13                                                  Continuous     None
# pc14                                                  Continuous     None
# pc15                                                  Continuous     None
# pc16                                                  Continuous     None
# pc17                                                  Continuous     None
# pc18                                                  Continuous     None
# pc19                                                  Continuous     None
# pc20                                                  Continuous     None
# used_in_pca_calculation                     Categorical (single)  Boolean
# postqc_bed_chr_1                                             NaN      NaN
# postqc_fam_chr_1                                             NaN      NaN
# postqc_bim_chr_1                                             NaN      NaN
# postqc_bed_chr_2                                             NaN      NaN
# postqc_fam_chr_2                                             NaN      NaN
# postqc_bim_chr_2                                             NaN      NaN
# postqc_bed_chr_3                                             NaN      NaN
# postqc_fam_chr_3                                             NaN      NaN
# postqc_bim_chr_3                                             NaN      NaN
# postqc_bed_chr_4                                             NaN      NaN
# postqc_fam_chr_4                                             NaN      NaN
# postqc_bim_chr_4                                             NaN      NaN
# postqc_bed_chr_5                                             NaN      NaN
# postqc_fam_chr_5                                             NaN      NaN
# postqc_bim_chr_5                                             NaN      NaN
# postqc_bed_chr_6                                             NaN      NaN
# postqc_fam_chr_6                                             NaN      NaN
# postqc_bim_chr_6                                             NaN      NaN
# postqc_bed_chr_7                                             NaN      NaN
# postqc_fam_chr_7                                             NaN      NaN
# postqc_bim_chr_7                                             NaN      NaN
# postqc_bed_chr_8                                             NaN      NaN
# postqc_fam_chr_8                                             NaN      NaN
# postqc_bim_chr_8                                             NaN      NaN
# postqc_bed_chr_9                                             NaN      NaN
# postqc_fam_chr_9                                             NaN      NaN
# postqc_bim_chr_9                                             NaN      NaN
# postqc_bed_chr_10                                            NaN      NaN
# postqc_fam_chr_10                                            NaN      NaN
# postqc_bim_chr_10                                            NaN      NaN
# postqc_bed_chr_11                                            NaN      NaN
# postqc_fam_chr_11                                            NaN      NaN
# postqc_bim_chr_11                                            NaN      NaN
# postqc_bed_chr_12                                            NaN      NaN
# postqc_fam_chr_12                                            NaN      NaN
# postqc_bim_chr_12                                            NaN      NaN
# postqc_bed_chr_13                                            NaN      NaN
# postqc_fam_chr_13                                            NaN      NaN
# postqc_bim_chr_13                                            NaN      NaN
# postqc_bed_chr_14                                            NaN      NaN
# postqc_fam_chr_14                                            NaN      NaN
# postqc_bim_chr_14                                            NaN      NaN
# postqc_bed_chr_15                                            NaN      NaN
# postqc_fam_chr_15                                            NaN      NaN
# postqc_bim_chr_15                                            NaN      NaN
# postqc_bed_chr_16                                            NaN      NaN
# postqc_fam_chr_16                                            NaN      NaN
# postqc_bim_chr_16                                            NaN      NaN
# postqc_bed_chr_17                                            NaN      NaN
# postqc_fam_chr_17                                            NaN      NaN
# postqc_bim_chr_17                                            NaN      NaN
# postqc_bed_chr_18                                            NaN      NaN
# postqc_fam_chr_18                                            NaN      NaN
# postqc_bim_chr_18                                            NaN      NaN
# postqc_bed_chr_19                                            NaN      NaN
# postqc_fam_chr_19                                            NaN      NaN
# postqc_bim_chr_19                                            NaN      NaN
# postqc_bed_chr_20                                            NaN      NaN
# postqc_fam_chr_20                                            NaN      NaN
# postqc_bim_chr_20                                            NaN      NaN
# postqc_bed_chr_21                                            NaN      NaN
# postqc_fam_chr_21                                            NaN      NaN
# postqc_bim_chr_21                                            NaN      NaN
# postqc_bed_chr_22                                            NaN      NaN
# postqc_fam_chr_22                                            NaN      NaN
# postqc_bim_chr_22                                            NaN      NaN
#
#                                           sampling_rate item_type    array  \
# tabular_field_name
# collection_date                                     NaN      Data  Single
# version                                             NaN      Data  Single
# genecov_qc_bases                                    NaN      Data  Single
# genecov_qc_bases_dedup                              NaN      Data  Single
# gencove_qc_bases_dedup_mapped                       NaN      Data  Single
# genecov_qc_effective_coverage                       NaN      Data  Single
# genecov_qc_fraction_contamination                   NaN      Data  Single
# genecov_qc_snps                                     NaN      Data  Single
# genecov_qc_format_passed                            NaN      Data  Single
# genecov_qc_r1_eq_r2_passed                          NaN      Data  Single
# genecov_qc_r1_r2_ids_match_passed                   NaN      Data  Single
# genecov_qc_bases_passed                             NaN      Data  Single
# genecov_qc_bases_dedup_passed                       NaN      Data  Single
# genecov_qc_bases_dedup_mapped_passed                NaN      Data  Single
# genecov_qc_effective_coverage_passed                NaN      Data  Single
# genecov_qc_fraction_contamination_passed            NaN      Data  Single
# genecov_qc_snps_passed                              NaN      Data  Single
# heterozygosity_proportion                           NaN      Data  Single
# pass_het_check                                      NaN      Data  Single
# sample_qc_gp_pass_rate                              NaN      Data  Single
# sample_qc_gp_pass_check                             NaN      Data  Single
# genetic_sex                                         NaN      Data  Single
# chr_x_proportion                                    NaN      Data  Single
# chr_y_proportion                                    NaN      Data  Single
# sample_qc_gender_match_check                        NaN      Data  Single
# relatives                                           NaN      Data  Single
# self_report_ashkenaz_proportion                     NaN      Data  Single
# self_report_middleeastern_proportion                NaN      Data  Single
# self_report_northafrican_proportion                 NaN      Data  Single
# self_report_sephardi_proportion                     NaN      Data  Single
# self_report_yemen_proportion                        NaN      Data  Single
# self_report_unknownother_proportion                 NaN      Data  Single
# pc1                                                 NaN      Data  Single
# pc2                                                 NaN      Data  Single
# pc3                                                 NaN      Data  Single
# pc4                                                 NaN      Data  Single
# pc5                                                 NaN      Data  Single
# pc6                                                 NaN      Data  Single
# pc7                                                 NaN      Data  Single
# pc8                                                 NaN      Data  Single
# pc9                                                 NaN      Data  Single
# pc10                                                NaN      Data  Single
# pc11                                                NaN      Data  Single
# pc12                                                NaN      Data  Single
# pc13                                                NaN      Data  Single
# pc14                                                NaN      Data  Single
# pc15                                                NaN      Data  Single
# pc16                                                NaN      Data  Single
# pc17                                                NaN      Data  Single
# pc18                                                NaN      Data  Single
# pc19                                                NaN      Data  Single
# pc20                                                NaN      Data  Single
# used_in_pca_calculation                             NaN      Data  Single
# postqc_bed_chr_1                                    NaN      Bulk  Single
# postqc_fam_chr_1                                    NaN      Bulk  Single
# postqc_bim_chr_1                                    NaN      Bulk  Single
# postqc_bed_chr_2                                    NaN      Bulk  Single
# postqc_fam_chr_2                                    NaN      Bulk  Single
# postqc_bim_chr_2                                    NaN      Bulk  Single
# postqc_bed_chr_3                                    NaN      Bulk  Single
# postqc_fam_chr_3                                    NaN      Bulk  Single
# postqc_bim_chr_3                                    NaN      Bulk  Single
# postqc_bed_chr_4                                    NaN      Bulk  Single
# postqc_fam_chr_4                                    NaN      Bulk  Single
# postqc_bim_chr_4                                    NaN      Bulk  Single
# postqc_bed_chr_5                                    NaN      Bulk  Single
# postqc_fam_chr_5                                    NaN      Bulk  Single
# postqc_bim_chr_5                                    NaN      Bulk  Single
# postqc_bed_chr_6                                    NaN      Bulk  Single
# postqc_fam_chr_6                                    NaN      Bulk  Single
# postqc_bim_chr_6                                    NaN      Bulk  Single
# postqc_bed_chr_7                                    NaN      Bulk  Single
# postqc_fam_chr_7                                    NaN      Bulk  Single
# postqc_bim_chr_7                                    NaN      Bulk  Single
# postqc_bed_chr_8                                    NaN      Bulk  Single
# ...
# chr_x_proportion                             10K                 Tabular
# chr_y_proportion                             10K                 Tabular
# sample_qc_gender_match_check                 10K                 Tabular
# relatives                                    10K                 Tabular
# self_report_ashkenaz_proportion              10K                 Tabular
# self_report_middleeastern_proportion         10K                 Tabular
# self_report_northafrican_proportion          10K                 Tabular
# self_report_sephardi_proportion              10K                 Tabular
# self_report_yemen_proportion                 10K                 Tabular
# self_report_unknownother_proportion          10K                 Tabular
# pc1                                          10K                 Tabular
# pc2                                          10K                 Tabular
# pc3                                          10K                 Tabular
# pc4                                          10K                 Tabular
# pc5                                          10K                 Tabular
# pc6                                          10K                 Tabular
# pc7                                          10K                 Tabular
# pc8                                          10K                 Tabular
# pc9                                          10K                 Tabular
# pc10                                         10K                 Tabular
# pc11                                         10K                 Tabular
# pc12                                         10K                 Tabular
# pc13                                         10K                 Tabular
# pc14                                         10K                 Tabular
# pc15                                         10K                 Tabular
# pc16                                         10K                 Tabular
# pc17                                         10K                 Tabular
# pc18                                         10K                 Tabular
# pc19                                         10K                 Tabular
# pc20                                         10K                 Tabular
# used_in_pca_calculation                      10K                 Tabular
# postqc_bed_chr_1                             10K  Compressed binary file
# postqc_fam_chr_1                             10K               Text file
# postqc_bim_chr_1                             10K               Text file
# postqc_bed_chr_2                             10K  Compressed binary file
# postqc_fam_chr_2                             10K               Text file
# postqc_bim_chr_2                             10K               Text file
# postqc_bed_chr_3                             10K  Compressed binary file
# postqc_fam_chr_3                             10K               Text file
# postqc_bim_chr_3                             10K               Text file
# postqc_bed_chr_4                             10K  Compressed binary file
# postqc_fam_chr_4                             10K               Text file
# postqc_bim_chr_4                             10K               Text file
# postqc_bed_chr_5                             10K  Compressed binary file
# postqc_fam_chr_5                             10K               Text file
# postqc_bim_chr_5                             10K               Text file
# postqc_bed_chr_6                             10K  Compressed binary file
# postqc_fam_chr_6                             10K               Text file
# postqc_bim_chr_6                             10K               Text file
# postqc_bed_chr_7                             10K  Compressed binary file
# postqc_fam_chr_7                             10K               Text file
# postqc_bim_chr_7                             10K               Text file
# postqc_bed_chr_8                             10K  Compressed binary file
# postqc_fam_chr_8                             10K               Text file
# postqc_bim_chr_8                             10K               Text file
# postqc_bed_chr_9                             10K  Compressed binary file
# postqc_fam_chr_9                             10K               Text file
# postqc_bim_chr_9                             10K               Text file
# postqc_bed_chr_10                            10K  Compressed binary file
# postqc_fam_chr_10                            10K               Text file
# postqc_bim_chr_10                            10K               Text file
# postqc_bed_chr_11                            10K  Compressed binary file
# postqc_fam_chr_11                            10K               Text file
# postqc_bim_chr_11                            10K               Text file
# postqc_bed_chr_12                            10K  Compressed binary file
# postqc_fam_chr_12                            10K               Text file
# postqc_bim_chr_12                            10K               Text file
# postqc_bed_chr_13                            10K  Compressed binary file
# postqc_fam_chr_13                            10K               Text file
# postqc_bim_chr_13                            10K               Text file
# postqc_bed_chr_14                            10K  Compressed binary file
# postqc_fam_chr_14                            10K               Text file
# postqc_bim_chr_14                            10K               Text file
# postqc_bed_chr_15                            10K  Compressed binary file
# postqc_fam_chr_15                            10K               Text file
# postqc_bim_chr_15                            10K               Text file
# postqc_bed_chr_16                            10K  Compressed binary file
# postqc_fam_chr_16                            10K               Text file
# postqc_bim_chr_16                            10K               Text file
# postqc_bed_chr_17                            10K  Compressed binary file
# postqc_fam_chr_17                            10K               Text file
# postqc_bim_chr_17                            10K               Text file
# postqc_bed_chr_18                            10K  Compressed binary file
# postqc_fam_chr_18                            10K               Text file
# postqc_bim_chr_18                            10K               Text file
# postqc_bed_chr_19                            10K  Compressed binary file
# postqc_fam_chr_19                            10K               Text file
# postqc_bim_chr_19                            10K               Text file
# postqc_bed_chr_20                            10K  Compressed binary file
# postqc_fam_chr_20                            10K               Text file
# postqc_bim_chr_20                            10K               Text file
# postqc_bed_chr_21                            10K  Compressed binary file
# postqc_fam_chr_21                            10K               Text file
# postqc_bim_chr_21                            10K               Text file
# postqc_bed_chr_22                            10K  Compressed binary file
# postqc_fam_chr_22                            10K               Text file
# postqc_bim_chr_22                            10K               Text file
#
#                                                debut    pandas_dtype
# tabular_field_name
# collection_date                           2019-03-11  datetime64[ns]
# version                                   2019-03-11          object
# genecov_qc_bases                          2019-03-11         float64
# genecov_qc_bases_dedup                    2019-03-11         float64
# gencove_qc_bases_dedup_mapped             2019-03-11         float64
# genecov_qc_effective_coverage             2019-03-11         float64
# genecov_qc_fraction_contamination         2019-03-11         float64
# genecov_qc_snps                           2019-03-11         float64
# genecov_qc_format_passed                  2019-03-11          object
# genecov_qc_r1_eq_r2_passed                2019-03-11          object
# genecov_qc_r1_r2_ids_match_passed         2019-03-11          object
# genecov_qc_bases_passed                   2019-03-11          object
# genecov_qc_bases_dedup_passed             2019-03-11          object
# genecov_qc_bases_dedup_mapped_passed      2019-03-11          object
# genecov_qc_effective_coverage_passed      2019-03-11          object
# genecov_qc_fraction_contamination_passed  2019-03-11          object
# genecov_qc_snps_passed                    2019-03-11          object
# heterozygosity_proportion                 2019-03-11         float64
# pass_het_check                            2019-03-11            bool
# sample_qc_gp_pass_rate                    2019-03-11         float64
# sample_qc_gp_pass_check                   2019-03-11            bool
# genetic_sex                               2019-03-11         float64
# chr_x_proportion                          2019-03-11         float64
# chr_y_proportion                          2019-03-11         float64
# sample_qc_gender_match_check              2019-03-11            bool
# relatives                                 2019-03-11          object
# self_report_ashkenaz_proportion           2019-03-11         float64
# self_report_middleeastern_proportion      2019-03-11         float64
# self_report_northafrican_proportion       2019-03-11         float64
# self_report_sephardi_proportion           2019-03-11         float64
# self_report_yemen_proportion              2019-03-11         float64
# self_report_unknownother_proportion       2019-03-11         float64
# pc1                                       2019-03-11         float64
# pc2                                       2019-03-11         float64
# pc3                                       2019-03-11         float64
# pc4                                       2019-03-11         float64
# pc5                                       2019-03-11         float64
# pc6                                       2019-03-11         float64
# pc7                                       2019-03-11         float64
# pc8                                       2019-03-11         float64
# pc9                                       2019-03-11         float64
# pc10                                      2019-03-11         float64
# pc11                                      2019-03-11         float64
# pc12                                      2019-03-11         float64
# pc13                                      2019-03-11         float64
# pc14                                      2019-03-11         float64
# pc15                                      2019-03-11         float64
# pc16                                      2019-03-11         float64
# pc17                                      2019-03-11         float64
# pc18                                      2019-03-11         float64
# pc19                                      2019-03-11         float64
# pc20                                      2019-03-11         float64
# used_in_pca_calculation                   2019-03-11            bool
# postqc_bed_chr_1                          2019-03-11          object
# postqc_fam_chr_1                          2019-03-11          object
# postqc_bim_chr_1                          2019-03-11          object
# postqc_bed_chr_2                          2019-03-11          object
# postqc_fam_chr_2                          2019-03-11          object
# postqc_bim_chr_2                          2019-03-11          object
# postqc_bed_chr_3                          2019-03-11          object
# postqc_fam_chr_3                          2019-03-11          object
# postqc_bim_chr_3                          2019-03-11          object
# postqc_bed_chr_4                          2019-03-11          object
# postqc_fam_chr_4                          2019-03-11          object
# postqc_bim_chr_4                          2019-03-11          object
# postqc_bed_chr_5                          2019-03-11          object
# postqc_fam_chr_5                          2019-03-11          object
# postqc_bim_chr_5                          2019-03-11          object
# postqc_bed_chr_6                          2019-03-11          object
# postqc_fam_chr_6                          2019-03-11          object
# postqc_bim_chr_6                          2019-03-11          object
# postqc_bed_chr_7                          2019-03-11          object
# postqc_fam_chr_7                          2019-03-11          object
# postqc_bim_chr_7                          2019-03-11          object
# postqc_bed_chr_8                          2019-03-11          object
# postqc_fam_chr_8                          2019-03-11          object
# postqc_bim_chr_8                          2019-03-11          object
# postqc_bed_chr_9                          2019-03-11          object
# postqc_fam_chr_9                          2019-03-11          object
# postqc_bim_chr_9                          2019-03-11          object
# postqc_bed_chr_10                         2019-03-11          object
# postqc_fam_chr_10                         2019-03-11          object
# postqc_bim_chr_10                         2019-03-11          object
# postqc_bed_chr_11                         2019-03-11          object
# postqc_fam_chr_11                         2019-03-11          object
# postqc_bim_chr_11                         2019-03-11          object
# postqc_bed_chr_12                         2019-03-11          object
# postqc_fam_chr_12                         2019-03-11          object
# postqc_bim_chr_12                         2019-03-11          object
# postqc_bed_chr_13                         2019-03-11          object
# postqc_fam_chr_13                         2019-03-11          object
# postqc_bim_chr_13                         2019-03-11          object
# postqc_bed_chr_14                         2019-03-11          object
# postqc_fam_chr_14                         2019-03-11          object
# postqc_bim_chr_14                         2019-03-11          object
# postqc_bed_chr_15                         2019-03-11          object
# postqc_fam_chr_15                         2019-03-11          object
# postqc_bim_chr_15                         2019-03-11          object
# postqc_bed_chr_16                         2019-03-11          object
# postqc_fam_chr_16                         2019-03-11          object
# postqc_bim_chr_16                         2019-03-11          object
# postqc_bed_chr_17                         2019-03-11          object
# postqc_fam_chr_17                         2019-03-11          object
# postqc_bim_chr_17                         2019-03-11          object
# postqc_bed_chr_18                         2019-03-11          object
# postqc_fam_chr_18                         2019-03-11          object
# postqc_bim_chr_18                         2019-03-11          object
# postqc_bed_chr_19                         2019-03-11          object
# postqc_fam_chr_19                         2019-03-11          object
# postqc_bim_chr_19                         2019-03-11          object
# postqc_bed_chr_20                         2019-03-11          object
# postqc_fam_chr_20                         2019-03-11          object
# postqc_bim_chr_20                         2019-03-11          object
# postqc_bed_chr_21                         2019-03-11          object
# postqc_fam_chr_21                         2019-03-11          object
# postqc_bim_chr_21                         2019-03-11          object
# postqc_bed_chr_22                         2019-03-11          object
# postqc_fam_chr_22                         2019-03-11          object
# postqc_bim_chr_22                         2019-03-11          object
