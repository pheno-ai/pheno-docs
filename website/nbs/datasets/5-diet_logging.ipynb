# %% [raw]
# ---
# output-file: 5-diet_logging.html
# title: 5-diet_logging
#
# ---

# %% [markdown]
# # 5 - diet logging
#
# Diet logging using a smartphone app involves collecting data on food and drink consumption through a mobile application. These data include information such as types of food, serving sizes, nutritional information and the times of consumption. The data is used to track dietary habits and can be used in scientific research to gain insights into the dietary habits of a population and to correlate to other temporal measurements and events.
#
# The information is stored in 2 parquet file: `diet_logging.parquet`, `raw_diet_logging.parquet` which contain the processed and raw diet logging data respectively.

# %%
#| hide
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('diet_logging', age_sex_dataset=None)
dl
# Out:
# Warning: index is not unique for diet_logging.parquet
# Warning: index is not unique for raw_diet_logging.parquet
# DataLoader for diet_logging with
# 15 fields
# 2 tables: ['diet_logging', 'raw_diet_logging']

# %%
dl.dict
# Out:
#                                                 field_string  \
# tabular_field_name
# collection_timestamp                    Collection timestamp
# collection_date                                         Date
# food_id                                              Food ID
# logging_day                      Logging day per participant
# weight                                                Weight
# short_food_name                              Short food name
# food_category                                  Food category
# product_name                                   Product name
# calories                                            Calories
# carbohydrate_g           Carbohydrate intake per food logged
# llipid_g                          Fat intake per food logged
# protein_g                     Protein intake per food logged
# sodium_mg                      Sodium intake per food logged
# alcohol_g                     Alcohol intake per food logged
# dietary_fiber_g         Dietary fiber intake per food logged
# local_timestamp                              Local timestamp
# eaten_in_restaurant           Eaten at restaurant indication
# total_logging_days               Total number of days logged
#
#                                                        description_string  \
# tabular_field_name
# collection_timestamp                                 Collection timestamp
# collection_date         Datetime column relecting the time food item w...
# food_id                 IDs in the diet logging app representing speci...
# logging_day               Integer indicating which day of logging period
# weight                                         Weight of food item logged
# short_food_name         Classifcation of food item logged into a short...
# food_category           Classifcation of food item logged into a food ...
# product_name                                  Product name of food logged
# calories                                     Calories of food item logged
# carbohydrate_g                        Carbohydrate intake per food logged
# llipid_g                                       Fat intake per food logged
# protein_g                                  Protein intake per food logged
# sodium_mg                                   Sodium intake per food logged
# alcohol_g                                  Alcohol intake per food logged
# dietary_fiber_g                      Dietary fiber intake per food logged
# local_timestamp                           Local timestamp of food logging
# eaten_in_restaurant     Indication if food was eatn at home or at a re...
# total_logging_days      Total number of days diet was logged per resea...
#
#                         parent_dataframe         relative_location  \
# tabular_field_name
# collection_timestamp                 NaN      diet_logging.parquet
# collection_date                      NaN      diet_logging.parquet
# food_id                              NaN      diet_logging.parquet
# logging_day                          NaN      diet_logging.parquet
# weight                               NaN      diet_logging.parquet
# short_food_name                      NaN      diet_logging.parquet
# food_category                        NaN      diet_logging.parquet
# product_name                         NaN      diet_logging.parquet
# calories                             NaN      diet_logging.parquet
# carbohydrate_g                       NaN      diet_logging.parquet
# llipid_g                             NaN      diet_logging.parquet
# protein_g                            NaN      diet_logging.parquet
# sodium_mg                            NaN      diet_logging.parquet
# alcohol_g                            NaN      diet_logging.parquet
# dietary_fiber_g                      NaN      diet_logging.parquet
# local_timestamp                      NaN      diet_logging.parquet
# eaten_in_restaurant                  NaN      diet_logging.parquet
# total_logging_days                   NaN  raw_diet_logging.parquet
#
#                                    value_type  units item_type   array  \
# tabular_field_name
# collection_timestamp                     Time   Time      Data  Single
# collection_date                          Time   Time      Data  Single
# food_id                 Categorical (single)    None      Data  Single
# logging_day                           Integer  None       Data  Single
# weight                             Continuous      g      Data  Single
# short_food_name         Categorical (single)    None      Data  Single
# food_category           Categorical (single)    None      Data  Single
# product_name            Categorical (single)    None      Data  Single
# calories                           Continuous   kcal      Data  Single
# carbohydrate_g                     Continuous      g      Data  Single
# llipid_g                           Continuous      g      Data  Single
# protein_g                          Continuous      g      Data  Single
# sodium_mg                          Continuous     mg      Data  Single
# alcohol_g                          Continuous      g      Data  Single
# dietary_fiber_g                    Continuous      g      Data  Single
# local_timestamp                          Time   Time      Data  Single
# eaten_in_restaurant                   Boolean   None      Data  Single
# total_logging_days                    Integer   None      Data  Single
#
#                        cohorts    data_type       debut  \
# tabular_field_name
# collection_timestamp       10K  Time Series  2019-01-29
# collection_date            10K  Time Series  2019-09-01
# food_id                    10K  Time Series  2019-09-01
# logging_day                10K  Time Series  2019-09-01
# weight                     10K  Time Series  2019-09-01
# short_food_name            10K  Time Series  2019-09-01
# food_category              10K  Time Series  2019-09-01
# product_name               10K  Time Series  2019-09-01
# calories                   10K  Time Series  2019-09-01
# carbohydrate_g             10K  Time Series  2019-09-01
# llipid_g                   10K  Time Series  2019-09-01
# protein_g                  10K  Time Series  2019-09-01
# sodium_mg                  10K  Time Series  2019-09-01
# alcohol_g                  10K  Time Series  2019-09-01
# dietary_fiber_g            10K  Time Series  2019-09-01
# local_timestamp            10K  Time Series  2019-09-01
# eaten_in_restaurant        10K  Time Series  2019-09-01
# total_logging_days         10K  Time Series  2019-09-01
#
#                                           pandas_dtype  sampling_rate
# tabular_field_name
# collection_timestamp    datetime64[ns, Asia/Jerusalem]            NaN
# collection_date                         datetime64[ns]            NaN
# food_id                                        integer            NaN
# logging_day                                      float            NaN
# weight                                           float            NaN
# short_food_name                                 object            NaN
# food_category                                   object            NaN
# product_name                                    object            NaN
# calories                                         float            NaN
# carbohydrate_g                                   float            NaN
# llipid_g                                         float            NaN
# protein_g                                        float            NaN
# sodium_mg                                        float            NaN
# alcohol_g                                        float            NaN
# dietary_fiber_g                                  float            NaN
# local_timestamp                         datetime64[ns]            NaN
# eaten_in_restaurant                               bool            NaN
# total_logging_days                             integer            NaN
