# %% [raw]
# ---
# output-file: 12-carotid_ultrasound.html
# title: 12-carotid_ultrasound
#
# ---

# %% [markdown]
# # 12 - carotid ultrasound
#
# Carotid intima-media thickness (CIMT) measurement is an ultrasound-based technique used to assess the thickness of the innermost two layers of the carotid artery, known as the intima and media. These layers can become thickened due to atherosclerotic processes or due to age. The thickening of the intima-media layer can be throughout the length of the artery (increased IMT) or as local accumulation of fatty deposits that penetrate into the vessel interior known  as plaques. Advanced plaques can cause stenosis of the artery. . Carotid IMT is increasingly used as an indicator of early atherosclerosis and a predictor for cardiovascular events and can be used for identifying asymptomatic patients at high risk who might be candidates for more intensive medical interventions. Measurement of CIMT with B-mode ultrasound is a noninvasive, sensitive, and reproducible technique for identifying and quantifying subclinical vascular disease and for evaluating CVD risk.
#
# The ultrasound probe is placed on the skin over the carotid artery and high-frequency sound waves are used to produce images of the artery. These images are then analyzed using an automatic detection algorithm to measure the thickness of the intima and media layers.
#
# Measurement protocol: Carotid US was performed using the Supersonic Aixplorer MACH 30 (Hologic, USA). Carotid Intima Media (CIMT) was measured using the L10-2 transducer from both carotid arteries while the subject in supine position with head rotated to the opposite side of the measured artery. Evaluation was performed using an automatic computerized system (Aixplorer Mach 30). The intima and media are automatically traced within the box of interest. Mean CIMT was recorded over a length of 1 cm at the far wall of each carotid artery. One measurement was obtained from each carotid artery. Only parts of the carotid artery without plaques were included in the IMT analysis.
#
#
# The information is stored in 1 parquet file: `carotid_us.parquet`

# %%
#| hide
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('carotid_ultrasound', age_sex_dataset=None)
dl
# Out:
# DataLoader for carotid_ultrasound with
# 9 fields
# 1 tables: ['carotid_us']

# %%
dl.dict
# Out:
#                                               field_string  \
# tabular_field_name
# timezone                                          Timezone
# collection_date               Collection date (YYYY-MM-DD)
# collection_timestamp                  Collection timestamp
# imt_left                     Intima media thickness (left)
# imt_right                   Intima media thickness (right)
# imt_window_width_left              IMT window width (left)
# imt_window_width_right            IMT window width (right)
# imt_fit_left             Intima media thickness Fit (left)
# imt_fit_right           Intima media thickness Fit (right)
#
#                                                        description_string  \
# tabular_field_name
# timezone                                                         Timezone
# collection_date                              Collection date (YYYY-MM-DD)
# collection_timestamp                                 Collection timestamp
# imt_left                                           Intima Media Thickness
# imt_right                                          Intima Media Thickness
# imt_window_width_left          Indicates the width if the box of interest
# imt_window_width_right         Indicates the width if the box of interest
# imt_fit_left            Percentage of the box of interest for which th...
# imt_fit_right           Percentage of the box of interest for which th...
#
#                         parent_dataframe   relative_location  value_type  \
# tabular_field_name
# timezone                             NaN  carotid_us.parquet        Text
# collection_date                      NaN  carotid_us.parquet        Date
# collection_timestamp                 NaN  carotid_us.parquet        Time
# imt_left                             NaN  carotid_us.parquet  Continuous
# imt_right                            NaN  carotid_us.parquet  Continuous
# imt_window_width_left                NaN  carotid_us.parquet  Continuous
# imt_window_width_right               NaN  carotid_us.parquet  Continuous
# imt_fit_left                         NaN  carotid_us.parquet  Continuous
# imt_fit_right                        NaN  carotid_us.parquet  Continuous
#
#                        units sampling_rate item_type   array cohorts  \
# tabular_field_name
# timezone                 NaN           NaN      Data  Single     10k
# collection_date         None           NaN      Data  Single     10k
# collection_timestamp     NaN          Data      Data  Single     10k
# imt_left                  mm           NaN      Data  Single     10k
# imt_right                 mm           NaN      Data  Single     10k
# imt_window_width_left     mm           NaN      Data  Single     10k
# imt_window_width_right    mm           NaN      Data  Single     10k
# imt_fit_left               %           NaN      Data  Single     10k
# imt_fit_right              %           NaN      Data  Single     10k
#
#                        data_type       debut                    pandas_dtype
# tabular_field_name
# timezone                 tabular  2021-08-16                          string
# collection_date          tabular  2021-08-16                  datetime64[ns]
# collection_timestamp     tabular  2021-08-16  datetime64[ns, Asia/Jerusalem]
# imt_left                 tabular  2021-08-16                           float
# imt_right                tabular  2021-08-16                           float
# imt_window_width_left    tabular  2021-08-16                           float
# imt_window_width_right   tabular  2021-08-16                           float
# imt_fit_left             tabular  2021-08-16                           float
# imt_fit_right            tabular  2021-08-16                           float
