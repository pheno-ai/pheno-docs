# %% [raw]
# ---
# output-file: 17-cgm.html
# title: 17-cgm
#
# ---

# %% [markdown]
# # 17 - cgm
#
# Continuous Glucose Monitoring (CGM) measures glucose levels in a continuous manner.  <br>
# This measure provides information on blood glucose control and glucose variability and could be used to monitor patients with diabetes.
#
# Each 14-day continuous measure is termed a single CGM-connection.
#
# Using the glucose measured in the CGM connection we can calculate summary features (which was done using the iglu package) summarizing information on glucose control and variability. <br>
# These were calculated for the entire CGM connection as well as for daily segments of the data.
#
# The actual glucose measures are stored in multiple parquet files, each file holds the glucose measures for a single CGM connection. <br>
# The metadata and summary features are stored in 2 main statistics parquet files: `main.parquet`, `daily_iglu.parquet`.

# %%
#| hide
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('cgm', age_sex_dataset=None)
dl
# Out:
# DataLoader for cgm with
# 94 fields
# 2 tables: ['main_cgm', 'daily_iglu']

# %%
dl.dict
# Out:
#                                                                field_string  \
# tabular_field_name
# connection_id                                                  ConnectionID
# cgm_filename                                                 CGM timeseries
# glucose                                                             Glucose
# collection_timestamp                                   Collection timestamp
# cgm_first_date                                               CGM first date
# cgm_last_date                                                 CGM last date
# cgm_device_type                                             CGM Device type
# cgm_datapoints_lost_in_qc                         CGM datapoints lost in QC
# percentage_of_cgm_datapoints_lost_in_qc                                 NaN
# number_of_cgm_days_available                   Number of CGM days available
# number_of_cgm_datapoints_available       Number of CGM datapoints available
# timezone                                                           Timezone
# 1st qu_                                                        1st quantile
# 3rd qu_                                                        3rd quantile
# above_140                                                       % above 140
# above_180                                                       % above 180
# above_250                                                       % above 250
# below_54                                                         % below 54
# below_70                                                         % below 70
# in_range_63_140                                           % in range 63-140
# in_range_70_180                                           % in range 70-180
# adrr                                                                   ADRR
# auc                                                                     AUC
# cogi                                                                   COGI
# conga                                                                 Conga
# cv                                                                       CV
# cv_measures_mean                                                     CVmean
# cv_measures_sd                                                         CVsd
# ea1c                                                                   eA1C
# gmi                                                                     GMI
# grade                                                                 GRADE
# grade_eugly                                                     GRADE eugly
# grade_hyper                                                     GRADE hyper
# grade_hypo                                                       GRADE hypo
# gvp                                                                     GVP
# hbgi                                                                   HBGI
# hyper_index                                                     Hyper index
# hypo_index                                                       Hypo index
# igc                                                                     IGC
# iqr                                                                     IQR
# j_index                                                             J-index
# lbgi                                                                   LBGI
# m_value                                                             M value
# mad                                                                     MAD
# mag                                                                     MAG
# mage                                                                   MAGE
# min_                                                                    Min
# max_                                                                    Max
# mean                                                                   Mean
# median                                                               Median
# modd                                                                   MODD
# range                                                                 Range
# sd                                                                       SD
# sd_roc                                                               SD.Roc
# sdb                                                                     SDb
# sdbdm                                                                 SDbdm
# sddm                                                                   SDdm
# sdhhmm                                                               SDhhmm
# sdw                                                                     SDw
# sdwsh                                                                 SDwsh
# collection_date                                                        Date
# connection_day                                               Connection day
# daily_1st_quartile                                       Daily 1st quartile
# daily_3rd_quartile                                       Daily 3rd quartile
# daily_above_140                                           Daily % above 140
# daily_above_180                                           Daily % above 180
# daily_above_250                                           Daily % above 250
# daily_below_54                                             Daily % below 54
# daily_below_70                                             Daily % below 70
# daily_in_range_63_140                               Daily % in range 63-140
# daily_in_range_70_180                               Daily % in range 70-180
# daily_adrr                                                       Daily ADRR
# daily_auc                                                         Daily AUC
# daily_cogi                                                       Daily COGI
# daily_cv                                                           Daily CV
# daily_ea1c                                                       Daily eA1C
# daily_gmi                                                         Daily GMI
# daily_grade                                                     Daily GRADE
# daily_grade_eugly                                         Daily GRADE_eugly
# daily_grade_hyper                                         Daily GRADE_hyper
# daily_grade_hypo                                           Daily GRADE_hypo
# daily_gvp                                                         Daily GVP
# daily_hbgi                                                       Daily HBGI
# daily_hyper_index                                         Daily Hyper index
# daily_hypo_index                                           Daily Hypo index
# daily_igc                                                         Daily IGC
# daily_iqr                                                         Daily IQR
# daily_j_index                                                 Daily J_index
# daily_lbgi                                                       Daily LBGI
# daily_m_value                                                 Daily M value
# daily_mad                                                         Daily MAD
# daily_mag                                                         Daily MAG
# daily_mage                                                       Daily MAGE
# daily_min                                                         Daily Min
# daily_max                                                         Daily Max
# daily_mean                                                       Daily Mean
# daily_median                                                   Daily Median
# daily_range                                                     Daily Range
# daily_sd                                                           Daily SD
# daily_sd_roc                                                   Daily SD.Roc
# daily_sdwsh                                                     Daily SDwsh
#
#                                                                         description_string  \
# tabular_field_name
# connection_id                                                     CGM device connection id
# cgm_filename                             Name of the file containing the participants' ...
# glucose                                                        cgm temporal glucose values
# collection_timestamp                             CGM connection first data point timestamp
# cgm_first_date                                                   CGM connection first date
# cgm_last_date                                                     CGM connection last date
# cgm_device_type                                                            CGM Device type
# cgm_datapoints_lost_in_qc                              Number of CGM datapoints lost in QC
# percentage_of_cgm_datapoints_lost_in_qc                                                NaN
# number_of_cgm_days_available               Number of CGM days available for the connection
# number_of_cgm_datapoints_available       Number of CGM datapoints available for the con...
# timezone                                                           TImezone of measurement
# 1st qu_                                              First quantile of all glucose values.
# 3rd qu_                                              Third quantile of all glucose values.
# above_140                                Percent of glucose measures that were larger t...
# above_180                                Percent of glucose measures that were larger t...
# above_250                                Percent of glucose measures that were larger t...
# below_54                                 Percent of glucose measures that were lower th...
# below_70                                 Percent of glucose measures that were lower th...
# in_range_63_140                          Percent of glucose measures that were in a spe...
# in_range_70_180                          Percent of glucose measures that were in a spe...
# adrr                                     Average daily risk range (ADRR) is a variabili...
# auc                                      Hourly average AUC. This measure integrates, t...
# cogi                                     Continuous Glucose Monitoring Index (COGI). CO...
# conga                                    Continuous Overall Net Glycemic Action (CONGA)...
# cv                                       Coefficient of variation of all glucose values.\n
# cv_measures_mean                                                    Mean of all daily CVs.
# cv_measures_sd                                       Standard deviations of all daily CVs.
# ea1c                                     A linear transformation of the mean glucose va...
# gmi                                      A linear transformation of the mean glucose va...
# grade                                    Glycaemic Risk Assessment Diabetes Equation (G...
# grade_eugly                              Percentage of the GRADE score that is attribut...
# grade_hyper                              Percentage of the GRADE score that is attribut...
# grade_hypo                               Percentage of the GRADE score that is attribut...
# gvp                                      Glucose Variability Percentage (GVP), which is...
# hbgi                                                       High Blood Glucose Index (HBGI)
# hyper_index                              This is a weighted average of hyperglycemic va...
# hypo_index                               This is a weighted average of hypoglycemic val...
# igc                                      Index of Glycemic Control (IGC), a sum of the ...
# iqr                                      Interquartile range (IQR), calculated as the d...
# j_index                                  This index was designed to stress the importan...
# lbgi                                                        Low Blood Glucose Index (LBGI)
# m_value                                  The M-value is an index aimed to describe the ...
# mad                                      Median Absolute Deviation (MAD). This is a mea...
# mag                                      Mean Absolute Glucose (MAG). This is a measure...
# mage                                     Mean Amplitude of Glycemic Excursions (MAGE), ...
# min_                                                        Minimum of all glucose values.
# max_                                                        Maximum of all glucose values.
# mean                                                           Mean of all glucose values.
# median                                                       Median of all glucose values.
# modd                                     Mean difference between glucose values obtaine...
# range                                    Difference between the maximum and minimum glu...
# sd                                               Standard deviation of all glucose values.
# sd_roc                                   Standard deviation of all the rate of change (...
# sdb                                      SD between days, within time points. Mean valu...
# sdbdm                                    SD between days, within time points, corrected...
# sddm                                     Horizontal SD. SD of the mean glucose values, ...
# sdhhmm                                   SD between time points. Standard deviation of ...
# sdw                                      Vertical SD within days. Average value of the ...
# sdwsh                                    SD within series. Taking hour-long intervals t...
# collection_date                          Date of the daily CGM data used to calculate t...
# connection_day                                                   Day of the CGM connection
# daily_1st_quartile                                 First quantile of daily glucose values.
# daily_3rd_quartile                                 Third quantile of daily glucose values.
# daily_above_140                          Percent of daily glucose measures that were la...
# daily_above_180                          Percent of daily glucose measures that were la...
# daily_above_250                          Percent of daily glucose measures that were la...
# daily_below_54                           Percent of daily glucose measures that were lo...
# daily_below_70                           Percent of daily glucose measures that were lo...
# daily_in_range_63_140                    Percent of daily glucose measures that were in...
# daily_in_range_70_180                    Percent of daily glucose measures that were in...
# daily_adrr                               Average daily risk range (ADRR) is a variabili...
# daily_auc                                Hourly average AUC. This measure integrates, t...
# daily_cogi                               Continuous Glucose Monitoring Index (COGI). CO...
# daily_cv                                 Coefficient of variation of daily glucose values.
# daily_ea1c                               A linear transformation of the mean glucose va...
# daily_gmi                                A linear transformation of the mean glucose va...
# daily_grade                              Glycaemic Risk Assessment Diabetes Equation (G...
# daily_grade_eugly                        Percentage of the GRADE score that is attribut...
# daily_grade_hyper                        Percentage of the GRADE score that is attribut...
# daily_grade_hypo                         Percentage of the GRADE score that is attribut...
# daily_gvp                                Glucose Variability Percentage (GVP), which is...
# daily_hbgi                                                 High Blood Glucose Index (HBGI)
# daily_hyper_index                        This is a weighted average of hyperglycemic va...
# daily_hypo_index                         This is a weighted average of hypoglycemic val...
# daily_igc                                Index of Glycemic Control (IGC), a sum of the ...
# daily_iqr                                Interquartile range (IQR), calculated as the d...
# daily_j_index                            This index was designed to stress the importan...
# daily_lbgi                                                  Low Blood Glucose Index (LBGI)
# daily_m_value                            The M-value is an index aimed to describe the ...
# daily_mad                                Median Absolute Deviation (MAD). This is a mea...
# daily_mag                                Mean Absolute Glucose (MAG). This is a measure...
# daily_mage                               Mean Amplitude of Glycemic Excursions (MAGE), ...
# daily_min                                                   Minimum of all glucose values.
# daily_max                                                   Maximum of all glucose values.
# daily_mean                                                     Mean of all glucose values.
# daily_median                                                 Median of all glucose values.
# daily_range                              Difference between the maximum and minimum glu...
# daily_sd                                         Standard deviation of all glucose values.
# daily_sd_roc                             Standard deviation of all the rate of change (...
# daily_sdwsh                              SD within series. Taking hour-long intervals t...
#
#                                         parent_dataframe   relative_location  \
# tabular_field_name
# connection_id                                       main    main_cgm.parquet
# cgm_filename                                        main    main_cgm.parquet
# glucose                                     cgm_filename                 NaN
# collection_timestamp                                main    main_cgm.parquet
# cgm_first_date                                      main    main_cgm.parquet
# cgm_last_date                                       main    main_cgm.parquet
# cgm_device_type                                     main    main_cgm.parquet
# cgm_datapoints_lost_in_qc                           main    main_cgm.parquet
# percentage_of_cgm_datapoints_lost_in_qc              NaN    main_cgm.parquet
# number_of_cgm_days_available                        main    main_cgm.parquet
# number_of_cgm_datapoints_available                  main    main_cgm.parquet
# timezone                                             NaN    main_cgm.parquet
# 1st qu_                                             main    main_cgm.parquet
# 3rd qu_                                             main    main_cgm.parquet
# above_140                                           main    main_cgm.parquet
# above_180                                           main    main_cgm.parquet
# above_250                                           main    main_cgm.parquet
# below_54                                            main    main_cgm.parquet
# below_70                                            main    main_cgm.parquet
# in_range_63_140                                     main    main_cgm.parquet
# in_range_70_180                                     main    main_cgm.parquet
# adrr                                                main    main_cgm.parquet
# auc                                                 main    main_cgm.parquet
# cogi                                                main    main_cgm.parquet
# conga                                               main    main_cgm.parquet
# cv                                                  main    main_cgm.parquet
# cv_measures_mean                                    main    main_cgm.parquet
# cv_measures_sd                                      main    main_cgm.parquet
# ea1c                                                main    main_cgm.parquet
# gmi                                                 main    main_cgm.parquet
# grade                                               main    main_cgm.parquet
# grade_eugly                                         main    main_cgm.parquet
# grade_hyper                                         main    main_cgm.parquet
# grade_hypo                                          main    main_cgm.parquet
# gvp                                                 main    main_cgm.parquet
# hbgi                                                main    main_cgm.parquet
# hyper_index                                         main    main_cgm.parquet
# hypo_index                                          main    main_cgm.parquet
# igc                                                 main    main_cgm.parquet
# iqr                                                 main    main_cgm.parquet
# j_index                                             main    main_cgm.parquet
# lbgi                                                main    main_cgm.parquet
# m_value                                             main    main_cgm.parquet
# mad                                                 main    main_cgm.parquet
# mag                                                 main    main_cgm.parquet
# mage                                                main    main_cgm.parquet
# min_                                                main    main_cgm.parquet
# max_                                                main    main_cgm.parquet
# mean                                                main    main_cgm.parquet
# median                                              main    main_cgm.parquet
# modd                                                main    main_cgm.parquet
# range                                               main    main_cgm.parquet
# sd                                                  main    main_cgm.parquet
# sd_roc                                              main    main_cgm.parquet
# sdb                                                 main    main_cgm.parquet
# sdbdm                                               main    main_cgm.parquet
# sddm                                                main    main_cgm.parquet
# sdhhmm                                              main    main_cgm.parquet
# sdw                                                 main    main_cgm.parquet
# sdwsh                                               main    main_cgm.parquet
# collection_date                               daily iglu  daily_iglu.parquet
# connection_day                                daily iglu  daily_iglu.parquet
# daily_1st_quartile                            daily iglu  daily_iglu.parquet
# daily_3rd_quartile                            daily iglu  daily_iglu.parquet
# daily_above_140                               daily iglu  daily_iglu.parquet
# daily_above_180                               daily iglu  daily_iglu.parquet
# daily_above_250                               daily iglu  daily_iglu.parquet
# daily_below_54                                daily iglu  daily_iglu.parquet
# daily_below_70                                daily iglu  daily_iglu.parquet
# daily_in_range_63_140                         daily iglu  daily_iglu.parquet
# daily_in_range_70_180                         daily iglu  daily_iglu.parquet
# daily_adrr                                    daily iglu  daily_iglu.parquet
# daily_auc                                     daily iglu  daily_iglu.parquet
# daily_cogi                                    daily iglu  daily_iglu.parquet
# daily_cv                                      daily iglu  daily_iglu.parquet
# daily_ea1c                                    daily iglu  daily_iglu.parquet
# daily_gmi                                     daily iglu  daily_iglu.parquet
# daily_grade                                   daily iglu  daily_iglu.parquet
# daily_grade_eugly                             daily iglu  daily_iglu.parquet
# daily_grade_hyper                             daily iglu  daily_iglu.parquet
# daily_grade_hypo                              daily iglu  daily_iglu.parquet
# daily_gvp                                     daily iglu  daily_iglu.parquet
# daily_hbgi                                    daily iglu  daily_iglu.parquet
# daily_hyper_index                             daily iglu  daily_iglu.parquet
# daily_hypo_index                              daily iglu  daily_iglu.parquet
# daily_igc                                     daily iglu  daily_iglu.parquet
# daily_iqr                                     daily iglu  daily_iglu.parquet
# daily_j_index                                 daily iglu  daily_iglu.parquet
# daily_lbgi                                    daily iglu  daily_iglu.parquet
# daily_m_value                                 daily iglu  daily_iglu.parquet
# daily_mad                                     daily iglu  daily_iglu.parquet
# daily_mag                                     daily iglu  daily_iglu.parquet
# daily_mage                                    daily iglu  daily_iglu.parquet
# daily_min                                     daily iglu  daily_iglu.parquet
# daily_max                                     daily iglu  daily_iglu.parquet
# daily_mean                                    daily iglu  daily_iglu.parquet
# daily_median                                  daily iglu  daily_iglu.parquet
# daily_range                                   daily iglu  daily_iglu.parquet
# daily_sd                                      daily iglu  daily_iglu.parquet
# daily_sd_roc                                  daily iglu  daily_iglu.parquet
# daily_sdwsh                                   daily iglu  daily_iglu.parquet
#
#                                                      value_type    units  \
# tabular_field_name
# connection_id                                              Text     Text
# cgm_filename                                               Text      NaN
# glucose                                  Series data, continous    mg/dl
# collection_timestamp                                       Time     Time
# cgm_first_date                                             Time     Time
# cgm_last_date                                              Time     Time
# cgm_device_type                          Categorical (multiple)     Text
# cgm_datapoints_lost_in_qc                               Integer  integer
# percentage_of_cgm_datapoints_lost_in_qc                     NaN      NaN
# number_of_cgm_days_available                            Integer  integer
# number_of_cgm_datapoints_available                      Integer  integer
# timezone                                                    NaN      NaN
# 1st qu_                                              Continuous    mg/dl
# 3rd qu_                                              Continuous    mg/dl
# above_140                                            Continuous        %
# above_180                                            Continuous        %
# above_250                                            Continuous        %
# below_54                                             Continuous        %
# below_70                                             Continuous        %
# in_range_63_140                                      Continuous        %
# in_range_70_180                                      Continuous        %
# adrr                                                 Continuous      NaN
# auc                                                  Continuous  mg/dl*h
# cogi                                                 Continuous      NaN
# conga                                                Continuous      NaN
# cv                                                   Continuous      NaN
# cv_measures_mean                                     Continuous      NaN
# cv_measures_sd                                       Continuous      NaN
# ea1c                                                 Continuous    mg/dl
# gmi                                                  Continuous    mg/dl
# grade                                                Continuous      NaN
# grade_eugly                                          Continuous      NaN
# grade_hyper                                          Continuous      NaN
# grade_hypo                                           Continuous      NaN
# gvp                                                  Continuous      NaN
# hbgi                                                 Continuous      NaN
# hyper_index                                          Continuous      NaN
# hypo_index                                           Continuous      NaN
# igc                                                  Continuous      NaN
# iqr                                                  Continuous    mg/dl
# j_index                                              Continuous      NaN
# lbgi                                                 Continuous      NaN
# m_value                                              Continuous      NaN
# mad                                                  Continuous    mg/dl
# mag                                                  Continuous    mg/dl
# mage                                                 Continuous    mg/dl
# min_                                                 Continuous    mg/dl
# max_                                                 Continuous    mg/dl
# mean                                                 Continuous    mg/dl
# median                                               Continuous    mg/dl
# modd                                                 Continuous    mg/dl
# range                                                Continuous    mg/dl
# sd                                                   Continuous    mg/dl
# sd_roc                                               Continuous      NaN
# sdb                                                  Continuous    mg/dl
# sdbdm                                                Continuous    mg/dl
# sddm                                                 Continuous    mg/dl
# sdhhmm                                               Continuous    mg/dl
# sdw                                                  Continuous    mg/dl
# sdwsh                                                Continuous    mg/dl
# collection_date                                            Time     Time
# connection_day                                          Integer  integer
# daily_1st_quartile                                   Continuous    mg/dl
# daily_3rd_quartile                                   Continuous    mg/dl
# daily_above_140                                      Continuous        %
# daily_above_180                                      Continuous        %
# daily_above_250                                      Continuous        %
# daily_below_54                                       Continuous        %
# daily_below_70                                       Continuous        %
# daily_in_range_63_140                                Continuous        %
# daily_in_range_70_180                                Continuous        %
# daily_adrr                                           Continuous      NaN
# daily_auc                                            Continuous  mg/dl*h
# daily_cogi                                           Continuous      NaN
# daily_cv                                             Continuous      NaN
# daily_ea1c                                           Continuous    mg/dl
# daily_gmi                                            Continuous    mg/dl
# daily_grade                                          Continuous      NaN
# daily_grade_eugly                                    Continuous      NaN
# daily_grade_hyper                                    Continuous      NaN
# daily_grade_hypo                                     Continuous      NaN
# daily_gvp                                            Continuous      NaN
# daily_hbgi                                           Continuous      NaN
# daily_hyper_index                                    Continuous      NaN
# daily_hypo_index                                     Continuous      NaN
# daily_igc                                            Continuous      NaN
# daily_iqr                                            Continuous    mg/dl
# daily_j_index                                        Continuous      NaN
# daily_lbgi                                           Continuous      NaN
# daily_m_value                                        Continuous      NaN
# daily_mad                                            Continuous    mg/dl
# daily_mag                                            Continuous    mg/dl
# daily_mage                                           Continuous    mg/dl
# daily_min                                            Continuous    mg/dl
# daily_max                                            Continuous    mg/dl
# daily_mean                                           Continuous    mg/dl
# daily_median                                         Continuous    mg/dl
# daily_range                                          Continuous    mg/dl
# daily_sd                                             Continuous    mg/dl
# daily_sd_roc                                         Continuous      NaN
# daily_sdwsh                                          Continuous    mg/dl
#
#                                         sampling_rate item_type     array  \
# tabular_field_name
# connection_id                                     NaN      Data    Single
# cgm_filename                                      NaN      Bulk    Single
# glucose                                         15min      Data    Single
# collection_timestamp                              NaN      Data    Single
# cgm_first_date                                    NaN      Data    Single
# cgm_last_date                                     NaN      Data    Single
# cgm_device_type                                   NaN      Data    Single
# cgm_datapoints_lost_in_qc                         NaN      Data    Single
# percentage_of_cgm_datapoints_lost_in_qc           NaN       NaN       NaN
# number_of_cgm_days_available                      NaN      Data    Single
# number_of_cgm_datapoints_available                NaN      Data    Single
# timezone                                          NaN       NaN       NaN
# 1st qu_                                           NaN      Data    Single
# 3rd qu_                                           NaN      Data    Single
# above_140                                         NaN      Data    Single
# above_180                                         NaN      Data    Single
# above_250                                         NaN      Data    Single
# below_54                                          NaN      Data    Single
# below_70                                          NaN      Data    Single
# in_range_63_140                                   NaN      Data    Single
# in_range_70_180                                   NaN      Data    Single
# adrr                                              NaN      Data    Single
# auc                                               NaN      Data    Single
# cogi                                              NaN      Data    Single
# conga                                             NaN      Data    Single
# cv                                                NaN      Data    Single
# cv_measures_mean                                  NaN      Data    Single
# cv_measures_sd                                    NaN      Data    Single
# ea1c                                              NaN      Data    Single
# gmi                                               NaN      Data    Single
# grade                                             NaN      Data    Single
# grade_eugly                                       NaN      Data    Single
# grade_hyper                                       NaN      Data    Single
# grade_hypo                                        NaN      Data    Single
# gvp                                               NaN      Data    Single
# hbgi                                              NaN      Data    Single
# hyper_index                                       NaN      Data    Single
# hypo_index                                        NaN      Data    Single
# igc                                               NaN      Data    Single
# iqr                                               NaN      Data    Single
# j_index                                           NaN      Data    Single
# lbgi                                              NaN      Data    Single
# m_value                                           NaN      Data    Single
# mad                                               NaN      Data    Single
# mag                                               NaN      Data    Single
# mage                                              NaN      Data    Single
# min_                                              NaN      Data    Single
# max_                                              NaN      Data    Single
# mean                                              NaN      Data    Single
# median                                            NaN      Data    Single
# modd                                              NaN      Data    Single
# range                                             NaN      Data    Single
# sd                                                NaN      Data    Single
# sd_roc                                            NaN      Data    Single
# sdb                                               NaN      Data    Single
# sdbdm                                             NaN      Data    Single
# sddm                                              NaN      Data    Single
# sdhhmm                                            NaN      Data    Single
# sdw                                               NaN      Data    Single
# sdwsh                                             NaN      Data    Single
# collection_date                                   NaN      Data  Multiple
# connection_day                                    NaN      Data    Single
# daily_1st_quartile                                NaN      Data  Multiple
# daily_3rd_quartile                                NaN      Data  Multiple
# daily_above_140                                   NaN      Data  Multiple
# daily_above_180                                   NaN      Data  Multiple
# daily_above_250                                   NaN      Data  Multiple
# daily_below_54                                    NaN      Data  Multiple
# daily_below_70                                    NaN      Data  Multiple
# daily_in_range_63_140                             NaN      Data  Multiple
# daily_in_range_70_180                             NaN      Data  Multiple
# daily_adrr                                        NaN      Data  Multiple
# daily_auc                                         NaN      Data  Multiple
# daily_cogi                                        NaN      Data  Multiple
# daily_cv                                          NaN      Data  Multiple
# daily_ea1c                                        NaN      Data  Multiple
# daily_gmi                                         NaN      Data  Multiple
# daily_grade                                       NaN      Data  Multiple
# daily_grade_eugly                                 NaN      Data  Multiple
# daily_grade_hyper                                 NaN      Data  Multiple
# daily_grade_hypo                                  NaN      Data  Multiple
# daily_gvp                                         NaN      Data  Multiple
# daily_hbgi                                        NaN      Data  Multiple
# daily_hyper_index                                 NaN      Data  Multiple
# daily_hypo_index                                  NaN      Data  Multiple
# daily_igc                                         NaN      Data  Multiple
# daily_iqr                                         NaN      Data  Multiple
# daily_j_index                                     NaN      Data  Multiple
# daily_lbgi                                        NaN      Data  Multiple
# daily_m_value                                     NaN      Data  Multiple
# daily_mad                                         NaN      Data  Multiple
# daily_mag                                         NaN      Data  Multiple
# daily_mage                                        NaN      Data  Multiple
# daily_min                                         NaN      Data  Multiple
# daily_max                                         NaN      Data  Multiple
# daily_mean                                        NaN      Data  Multiple
# daily_median                                      NaN      Data  Multiple
# daily_range                                       NaN      Data  Multiple
# daily_sd                                          NaN      Data  Multiple
# daily_sd_roc                                      NaN      Data  Multiple
# daily_sdwsh                                       NaN      Data  Multiple
#
#                                         cohorts    data_type       debut  \
# tabular_field_name
# connection_id                               10K      tabular  2018-12-27
# cgm_filename                                10K         text  2018-12-27
# glucose                                     10K  time series  2018-12-27
# collection_timestamp                        10K      tabular  2018-12-27
# cgm_first_date                              10K      tabular  2018-12-27
# cgm_last_date                               10K      tabular  2018-12-27
# cgm_device_type                             10K      tabular  2018-12-27
# cgm_datapoints_lost_in_qc                   10K      tabular  2018-12-27
# percentage_of_cgm_datapoints_lost_in_qc     NaN          NaN         NaN
# number_of_cgm_days_available                10K      tabular  2018-12-27
# number_of_cgm_datapoints_available          10K      tabular  2018-12-27
# timezone                                    NaN          NaN         NaN
# 1st qu_                                     10K      tabular  2018-12-27
# 3rd qu_                                     10K      tabular  2018-12-27
# above_140                                   10K      tabular  2018-12-27
# above_180                                   10K      tabular  2018-12-27
# above_250                                   10K      tabular  2018-12-27
# below_54                                    10K      tabular  2018-12-27
# below_70                                    10K      tabular  2018-12-27
# in_range_63_140                             10K      tabular  2018-12-27
# in_range_70_180                             10K      tabular  2018-12-27
# adrr                                        10K      tabular  2018-12-27
# auc                                         10K      tabular  2018-12-27
# cogi                                        10K      tabular  2018-12-27
# conga                                       10K      tabular  2018-12-27
# cv                                          10K      tabular  2018-12-27
# cv_measures_mean                            10K      tabular  2018-12-27
# cv_measures_sd                              10K      tabular  2018-12-27
# ea1c                                        10K      tabular  2018-12-27
# gmi                                         10K      tabular  2018-12-27
# grade                                       10K      tabular  2018-12-27
# grade_eugly                                 10K      tabular  2018-12-27
# grade_hyper                                 10K      tabular  2018-12-27
# grade_hypo                                  10K      tabular  2018-12-27
# gvp                                         10K      tabular  2018-12-27
# hbgi                                        10K      tabular  2018-12-27
# hyper_index                                 10K      tabular  2018-12-27
# hypo_index                                  10K      tabular  2018-12-27
# igc                                         10K      tabular  2018-12-27
# iqr                                         10K      tabular  2018-12-27
# j_index                                     10K      tabular  2018-12-27
# lbgi                                        10K      tabular  2018-12-27
# m_value                                     10K      tabular  2018-12-27
# mad                                         10K      tabular  2018-12-27
# mag                                         10K      tabular  2018-12-27
# mage                                        10K      tabular  2018-12-27
# min_                                        10K      tabular  2018-12-27
# max_                                        10K      tabular  2018-12-27
# mean                                        10K      tabular  2018-12-27
# median                                      10K      tabular  2018-12-27
# modd                                        10K      tabular  2018-12-27
# range                                       10K      tabular  2018-12-27
# sd                                          10K      tabular  2018-12-27
# sd_roc                                      10K      tabular  2018-12-27
# sdb                                         10K      tabular  2018-12-27
# sdbdm                                       10K      tabular  2018-12-27
# sddm                                        10K      tabular  2018-12-27
# sdhhmm                                      10K      tabular  2018-12-27
# sdw                                         10K      tabular  2018-12-27
# sdwsh                                       10K      tabular  2018-12-27
# collection_date                             10K      tabular  2018-12-27
# connection_day                              10K      tabular  2018-12-27
# daily_1st_quartile                          10K      tabular  2018-12-27
# daily_3rd_quartile                          10K      tabular  2018-12-27
# daily_above_140                             10K      tabular  2018-12-27
# daily_above_180                             10K      tabular  2018-12-27
# daily_above_250                             10K      tabular  2018-12-27
# daily_below_54                              10K      tabular  2018-12-27
# daily_below_70                              10K      tabular  2018-12-27
# daily_in_range_63_140                       10K      tabular  2018-12-27
# daily_in_range_70_180                       10K      tabular  2018-12-27
# daily_adrr                                  10K      tabular  2018-12-27
# daily_auc                                   10K      tabular  2018-12-27
# daily_cogi                                  10K      tabular  2018-12-27
# daily_cv                                    10K      tabular  2018-12-27
# daily_ea1c                                  10K      tabular  2018-12-27
# daily_gmi                                   10K      tabular  2018-12-27
# daily_grade                                 10K      tabular  2018-12-27
# daily_grade_eugly                           10K      tabular  2018-12-27
# daily_grade_hyper                           10K      tabular  2018-12-27
# daily_grade_hypo                            10K      tabular  2018-12-27
# daily_gvp                                   10K      tabular  2018-12-27
# daily_hbgi                                  10K      tabular  2018-12-27
# daily_hyper_index                           10K      tabular  2018-12-27
# daily_hypo_index                            10K      tabular  2018-12-27
# daily_igc                                   10K      tabular  2018-12-27
# daily_iqr                                   10K      tabular  2018-12-27
# daily_j_index                               10K      tabular  2018-12-27
# daily_lbgi                                  10K      tabular  2018-12-27
# daily_m_value                               10K      tabular  2018-12-27
# daily_mad                                   10K      tabular  2018-12-27
# daily_mag                                   10K      tabular  2018-12-27
# daily_mage                                  10K      tabular  2018-12-27
# daily_min                                   10K      tabular  2018-12-27
# daily_max                                   10K      tabular  2018-12-27
# daily_mean                                  10K      tabular  2018-12-27
# daily_median                                10K      tabular  2018-12-27
# daily_range                                 10K      tabular  2018-12-27
# daily_sd                                    10K      tabular  2018-12-27
# daily_sd_roc                                10K      tabular  2018-12-27
# daily_sdwsh                                 10K      tabular  2018-12-27
#
#                                                            pandas_dtype
# tabular_field_name
# connection_id                                                       int
# cgm_filename                                                     string
# glucose                                                           float
# collection_timestamp                     datetime64[ns, Asia/Jerusalem]
# cgm_first_date                           datetime64[ns, Asia/Jerusalem]
# cgm_last_date                            datetime64[ns, Asia/Jerusalem]
# cgm_device_type                                                  string
# cgm_datapoints_lost_in_qc                                           int
# percentage_of_cgm_datapoints_lost_in_qc                           float
# number_of_cgm_days_available                                        int
# number_of_cgm_datapoints_available                                  int
# timezone                                 datetime64[ns, Asia/Jerusalem]
# 1st qu_                                                           float
# 3rd qu_                                                           float
# above_140                                                         float
# above_180                                                         float
# above_250                                                         float
# below_54                                                          float
# below_70                                                          float
# in_range_63_140                                                   float
# in_range_70_180                                                   float
# adrr                                                              float
# auc                                                               float
# cogi                                                              float
# conga                                                             float
# cv                                                                float
# cv_measures_mean                                                  float
# cv_measures_sd                                                    float
# ea1c                                                              float
# gmi                                                               float
# grade                                                             float
# grade_eugly                                                       float
# grade_hyper                                                       float
# grade_hypo                                                        float
# gvp                                                               float
# hbgi                                                              float
# hyper_index                                                       float
# hypo_index                                                        float
# igc                                                               float
# iqr                                                               float
# j_index                                                           float
# lbgi                                                              float
# m_value                                                           float
# mad                                                               float
# mag                                                               float
# mage                                                              float
# min_                                                              float
# max_                                                              float
# mean                                                              float
# median                                                            float
# modd                                                              float
# range                                                             float
# sd                                                                float
# sd_roc                                                            float
# sdb                                                               float
# sdbdm                                                             float
# sddm                                                              float
# sdhhmm                                                            float
# sdw                                                               float
# sdwsh                                                             float
# collection_date                          datetime64[ns, Asia/Jerusalem]
# connection_day                                                      int
# daily_1st_quartile                                                float
# daily_3rd_quartile                                                float
# daily_above_140                                                   float
# daily_above_180                                                   float
# daily_above_250                                                   float
# daily_below_54                                                    float
# daily_below_70                                                    float
# daily_in_range_63_140                                             float
# daily_in_range_70_180                                             float
# daily_adrr                                                        float
# daily_auc                                                         float
# daily_cogi                                                        float
# daily_cv                                                          float
# daily_ea1c                                                        float
# daily_gmi                                                         float
# daily_grade                                                       float
# daily_grade_eugly                                                 float
# daily_grade_hyper                                                 float
# daily_grade_hypo                                                  float
# daily_gvp                                                         float
# daily_hbgi                                                        float
# daily_hyper_index                                                 float
# daily_hypo_index                                                  float
# daily_igc                                                         float
# daily_iqr                                                         float
# daily_j_index                                                     float
# daily_lbgi                                                        float
# daily_m_value                                                     float
# daily_mad                                                         float
# daily_mag                                                         float
# daily_mage                                                        float
# daily_min                                                         float
# daily_max                                                         float
# daily_mean                                                        float
# daily_median                                                      float
# daily_range                                                       float
# daily_sd                                                          float
# daily_sd_roc                                                      float
# daily_sdwsh                                                       float
