# %% [raw]
# ---
# output-file: 22-bone_density.html
# title: 22-bone_density
#
# ---

# %% [markdown]
# # 22 - bone density
#
# Bone density was profiled based on DXA imaging, and includes measurements of mineral content in different parts of a variety of skeletal components.
#
# DXA (dual-energy x-ray absorptiometry) imaging is a method used to measure bone density and mineral content. A DXA scan uses a low dose of ionizing radiation to produce a detailed image of the body, specifically the bones. The scan is then analyzed by a software to determine the bone mineral density (BMD) and bone mineral content (BMC) in different parts of the body. This method is considered to be one of the most accurate methods for measuring bone density, as it is able to provide detailed information about the distribution of bone mineral content in different bony structures of the body skeleton. The spine and hip are most commonly measured because that is where most osteoporotic fractures occur. DXA imaging is commonly used for assessing the risk of osteoporosis, a condition characterized by low bone density and increased risk of fractures, and for monitoring the effects of treatments for the condition.
#
#
# The information is stored in 1 parquet file: `bone_density.parquet`

# %%
#| hide
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('bone_density', age_sex_dataset=None)
dl
# Out:
# DataLoader for bone_density with
# 166 fields
# 1 tables: ['bone_density']

# %%
dl.dict
# Out:
#                              Unnamed: 0  \
# tabular_field_name
# collection_date                       0
# timezone                              1
# collection_timestamp                  2
# body_arm_left_area                    3
# body_arm_left_bmc                     4
# body_arm_left_bmd                     5
# body_arm_right_area                   6
# body_arm_right_bmc                    7
# body_arm_right_bmd                    8
# body_arms_area                        9
# body_arms_bmc                        10
# body_arms_bmd                        11
# body_dose                            12
# body_head_area                       13
# body_head_bmc                        14
# body_head_bmd                        15
# body_leg_left_area                   16
# body_leg_left_bmc                    17
# body_leg_left_bmd                    18
# body_leg_right_area                  19
# body_leg_right_bmc                   20
# body_leg_right_bmd                   21
# body_legs_area                       22
# body_legs_bmc                        23
# body_legs_bmd                        24
# body_pelvis_area                     25
# body_pelvis_bmc                      26
# body_pelvis_bmd                      27
# body_ribs_area                       28
# body_ribs_bmc                        29
# body_ribs_bmd                        30
# body_spine_area                      31
# body_spine_bmc                       32
# body_spine_bmd                       33
# body_total_area                      34
# body_total_bmc                       35
# body_total_bmd                       36
# body_total_left_area                 37
# body_total_left_bmc                  38
# body_total_left_bmd                  39
# body_total_right_area                40
# body_total_right_bmc                 41
# body_total_right_bmd                 42
# body_trunk_area                      43
# body_trunk_bmc                       44
# body_trunk_bmd                       45
# body_trunk_left_area                 46
# body_trunk_left_bmc                  47
# body_trunk_left_bmd                  48
# body_trunk_right_area                49
# body_trunk_right_bmc                 50
# body_trunk_right_bmd                 51
# femur_lower_neck_diff_area           94
# femur_lower_neck_diff_bmc            95
# femur_lower_neck_diff_bmd            96
# femur_lower_neck_mean_area           97
# femur_lower_neck_mean_bmc            98
# femur_lower_neck_mean_bmd            99
# femur_neck_diff_area                100
# femur_neck_diff_bmc                 101
# femur_neck_diff_bmd                 102
# femur_neck_mean_area                104
# femur_neck_mean_bmc                 105
# femur_neck_mean_bmd                 106
# femur_right_lower_neck_area         110
# femur_right_lower_neck_bmc          111
# femur_right_lower_neck_bmd          112
# femur_right_neck_area               114
# femur_right_neck_bmc                115
# femur_right_neck_bmd                116
# femur_right_shaft_area              120
# femur_right_shaft_bmc               121
# femur_right_shaft_bmd               122
# femur_right_total_area              124
# femur_right_total_bmc               125
# femur_right_total_bmd               126
# femur_right_troch_area              132
# femur_right_troch_bmc               133
# femur_right_troch_bmd               134
# femur_right_upper_neck_area         139
# femur_right_upper_neck_bmc          140
# femur_right_upper_neck_bmd          141
# femur_right_wards_area              146
# femur_right_wards_bmc               147
# femur_right_wards_bmd               148
# femur_shaft_diff_area               152
# femur_shaft_diff_bmc                153
# femur_shaft_diff_bmd                154
# femur_shaft_mean_area               155
# femur_shaft_mean_bmc                156
# femur_shaft_mean_bmd                157
# femur_total_diff_area               158
# femur_total_diff_bmc                159
# femur_total_diff_bmd                160
# femur_total_mean_area               162
# femur_total_mean_bmc                163
# femur_total_mean_bmd                164
# femur_troch_diff_area               168
# femur_troch_diff_bmc                169
# femur_troch_diff_bmd                170
# femur_troch_mean_area               172
# femur_troch_mean_bmc                173
# femur_troch_mean_bmd                174
# femur_upper_neck_diff_area          178
# femur_upper_neck_diff_bmc           179
# femur_upper_neck_diff_bmd           180
# femur_upper_neck_mean_area          182
# femur_upper_neck_mean_bmc           183
# femur_upper_neck_mean_bmd           184
# femur_wards_diff_area               188
# femur_wards_diff_bmc                189
# femur_wards_diff_bmd                190
# femur_wards_mean_area               192
# femur_wards_mean_bmc                193
# femur_wards_mean_bmd                194
# spine_dose                          198
# spine_l1_area                       200
# spine_l1_average_height             201
# spine_l1_average_width              202
# spine_l1_bmc                        203
# spine_l1_bmd                        204
# spine_l1_l2_area                    206
# spine_l1_l2_average_height          207
# spine_l1_l2_average_width           208
# spine_l1_l2_bmc                     209
# spine_l1_l2_bmd                     210
# spine_l1_l3_area                    215
# spine_l1_l3_average_height          216
# spine_l1_l3_average_width           217
# spine_l1_l3_bmc                     218
# spine_l1_l3_bmd                     219
# spine_l1_l4_area                    224
# spine_l1_l4_average_height          225
# spine_l1_l4_average_width           226
# spine_l1_l4_bmc                     227
# spine_l1_l4_bmd                     228
# spine_l2_area                       236
# spine_l2_average_height             237
# spine_l2_average_width              238
# spine_l2_bmc                        239
# spine_l2_bmd                        240
# spine_l2_l3_area                    242
# spine_l2_l3_average_height          243
# spine_l2_l3_average_width           244
# spine_l2_l3_bmc                     245
# spine_l2_l3_bmd                     246
# spine_l2_l4_area                    251
# spine_l2_l4_average_height          252
# spine_l2_l4_average_width           253
# spine_l2_l4_bmc                     254
# spine_l2_l4_bmd                     255
# spine_l3_area                       263
# spine_l3_average_height             264
# spine_l3_average_width              265
# spine_l3_bmc                        266
# spine_l3_bmd                        267
# spine_l3_l4_area                    269
# spine_l3_l4_average_height          270
# spine_l3_l4_average_width           271
# spine_l3_l4_bmc                     272
# spine_l3_l4_bmd                     273
# spine_l4_area                       281
# spine_l4_average_height             282
# spine_l4_average_width              283
# spine_l4_bmc                        284
# spine_l4_bmd                        285
#
#                                                             field_string  \
# tabular_field_name
# collection_date                             Collection date (YYYY-MM-DD)
# timezone                                                        Timezone
# collection_timestamp                                Collection timestamp
# body_arm_left_area                                    Body arm left area
# body_arm_left_bmc                     Body arm left bone mineral content
# body_arm_left_bmd                     Body arm left bone mineral density
# body_arm_right_area                                  Body arm right area
# body_arm_right_bmc                   Body arm right bone mineral content
# body_arm_right_bmd                   Body arm right bone mineral density
# body_arms_area                                            Body arms area
# body_arms_bmc                             Body arms bone mineral content
# body_arms_bmd                             Body arms bone mineral density
# body_dose                                                      Body dose
# body_head_area                                            Body head area
# body_head_bmc                             Body head bone mineral content
# body_head_bmd                             Body head bone mineral density
# body_leg_left_area                                    Body leg left area
# body_leg_left_bmc                     Body leg left bone mineral content
# body_leg_left_bmd                     Body leg left bone mineral density
# body_leg_right_area                                  Body leg right area
# body_leg_right_bmc                   Body leg right bone mineral content
# body_leg_right_bmd                   Body leg right bone mineral density
# body_legs_area                                            Body legs area
# body_legs_bmc                             Body legs bone mineral content
# body_legs_bmd                             Body legs bone mineral density
# body_pelvis_area                                        Body pelvis area
# body_pelvis_bmc                         Body pelvis bone mineral content
# body_pelvis_bmd                         Body pelvis bone mineral density
# body_ribs_area                                            Body ribs area
# body_ribs_bmc                             Body ribs bone mineral content
# body_ribs_bmd                             Body ribs bone mineral density
# body_spine_area                                          Body spine area
# body_spine_bmc                           Body spine bone mineral content
# body_spine_bmd                           Body spine bone mineral density
# body_total_area                                          Body total area
# body_total_bmc                           Body total bone mineral content
# body_total_bmd                           Body total bone mineral density
# body_total_left_area                                Body total left area
# body_total_left_bmc                 Body total left bone mineral content
# body_total_left_bmd                 Body total left bone mineral density
# body_total_right_area                              Body total right area
# body_total_right_bmc               Body total right bone mineral content
# body_total_right_bmd               Body total right bone mineral density
# body_trunk_area                                          Body trunk area
# body_trunk_bmc                           Body trunk bone mineral content
# body_trunk_bmd                           Body trunk bone mineral density
# body_trunk_left_area                                Body trunk left area
# body_trunk_left_bmc                 Body trunk left bone mineral content
# body_trunk_left_bmd                 Body trunk left bone mineral density
# body_trunk_right_area                              Body trunk right area
# body_trunk_right_bmc               Body trunk right bone mineral content
# body_trunk_right_bmd               Body trunk right bone mineral density
# femur_lower_neck_diff_area                    Femur lower neck diff area
# femur_lower_neck_diff_bmc     Femur lower neck diff bone mineral content
# femur_lower_neck_diff_bmd     Femur lower neck diff bone mineral density
# femur_lower_neck_mean_area                    Femur lower neck mean area
# femur_lower_neck_mean_bmc     Femur lower neck mean bone mineral content
# femur_lower_neck_mean_bmd     Femur lower neck mean bone mineral density
# femur_neck_diff_area                                Femur neck diff area
# femur_neck_diff_bmc                 Femur neck diff bone mineral content
# femur_neck_diff_bmd                 Femur neck diff bone mineral density
# femur_neck_mean_area                                Femur neck mean area
# femur_neck_mean_bmc                 Femur neck mean bone mineral content
# femur_neck_mean_bmd                 Femur neck mean bone mineral density
# femur_right_lower_neck_area                  Femur right lower neck area
# femur_right_lower_neck_bmc   Femur right lower neck bone mineral content
# femur_right_lower_neck_bmd   Femur right lower neck bone mineral density
# femur_right_neck_area                              Femur right neck area
# femur_right_neck_bmc               Femur right neck bone mineral content
# femur_right_neck_bmd               Femur right neck bone mineral density
# femur_right_shaft_area                            Femur right shaft area
# femur_right_shaft_bmc             Femur right shaft bone mineral content
# femur_right_shaft_bmd             Femur right shaft bone mineral density
# femur_right_total_area                            Femur right total area
# femur_right_total_bmc             Femur right total bone mineral content
# femur_right_total_bmd             Femur right total bone mineral density
# femur_right_troch_area                            Femur right troch area
# femur_right_troch_bmc             Femur right troch bone mineral content
# femur_right_troch_bmd             Femur right troch bone mineral density
# femur_right_upper_neck_area                  Femur right upper neck area
# femur_right_upper_neck_bmc   Femur right upper neck bone mineral content
# femur_right_upper_neck_bmd   Femur right upper neck bone mineral density
# femur_right_wards_area                            Femur right wards area
# femur_right_wards_bmc             Femur right wards bone mineral content
# femur_right_wards_bmd             Femur right wards bone mineral density
# femur_shaft_diff_area                              Femur shaft diff area
# femur_shaft_diff_bmc               Femur shaft diff bone mineral content
# femur_shaft_diff_bmd               Femur shaft diff bone mineral density
# femur_shaft_mean_area                              Femur shaft mean area
# femur_shaft_mean_bmc               Femur shaft mean bone mineral content
# femur_shaft_mean_bmd               Femur shaft mean bone mineral density
# femur_total_diff_area                              Femur total diff area
# femur_total_diff_bmc               Femur total diff bone mineral content
# femur_total_diff_bmd               Femur total diff bone mineral density
# femur_total_mean_area                              Femur total mean area
# femur_total_mean_bmc               Femur total mean bone mineral content
# femur_total_mean_bmd               Femur total mean bone mineral density
# femur_troch_diff_area                              Femur troch diff area
# femur_troch_diff_bmc               Femur troch diff bone mineral content
# femur_troch_diff_bmd               Femur troch diff bone mineral density
# femur_troch_mean_area                              Femur troch mean area
# femur_troch_mean_bmc               Femur troch mean bone mineral content
# femur_troch_mean_bmd               Femur troch mean bone mineral density
# femur_upper_neck_diff_area                    Femur upper neck diff area
# femur_upper_neck_diff_bmc     Femur upper neck diff bone mineral content
# femur_upper_neck_diff_bmd     Femur upper neck diff bone mineral density
# femur_upper_neck_mean_area                    Femur upper neck mean area
# femur_upper_neck_mean_bmc     Femur upper neck mean bone mineral content
# femur_upper_neck_mean_bmd     Femur upper neck mean bone mineral density
# femur_wards_diff_area                              Femur wards diff area
# femur_wards_diff_bmc               Femur wards diff bone mineral content
# femur_wards_diff_bmd               Femur wards diff bone mineral density
# femur_wards_mean_area                              Femur wards mean area
# femur_wards_mean_bmc               Femur wards mean bone mineral content
# femur_wards_mean_bmd               Femur wards mean bone mineral density
# spine_dose                                                    Spine dose
# spine_l1_area                                              Spine l1 area
# spine_l1_average_height                          Spine l1 average height
# spine_l1_average_width                            Spine l1 average width
# spine_l1_bmc                               Spine l1 bone mineral content
# spine_l1_bmd                               Spine l1 bone mineral density
# spine_l1_l2_area                                        Spine l1 l2 area
# spine_l1_l2_average_height                    Spine l1 l2 average height
# spine_l1_l2_average_width                      Spine l1 l2 average width
# spine_l1_l2_bmc                         Spine l1 l2 bone mineral content
# spine_l1_l2_bmd                         Spine l1 l2 bone mineral density
# spine_l1_l3_area                                        Spine l1 l3 area
# spine_l1_l3_average_height                    Spine l1 l3 average height
# spine_l1_l3_average_width                      Spine l1 l3 average width
# spine_l1_l3_bmc                         Spine l1 l3 bone mineral content
# spine_l1_l3_bmd                         Spine l1 l3 bone mineral density
# spine_l1_l4_area                                        Spine l1 l4 area
# spine_l1_l4_average_height                    Spine l1 l4 average height
# spine_l1_l4_average_width                      Spine l1 l4 average width
# spine_l1_l4_bmc                         Spine l1 l4 bone mineral content
# spine_l1_l4_bmd                         Spine l1 l4 bone mineral density
# spine_l2_area                                              Spine l2 area
# spine_l2_average_height                          Spine l2 average height
# spine_l2_average_width                            Spine l2 average width
# spine_l2_bmc                               Spine l2 bone mineral content
# spine_l2_bmd                               Spine l2 bone mineral density
# spine_l2_l3_area                                        Spine l2 l3 area
# spine_l2_l3_average_height                    Spine l2 l3 average height
# spine_l2_l3_average_width                      Spine l2 l3 average width
# spine_l2_l3_bmc                         Spine l2 l3 bone mineral content
# spine_l2_l3_bmd                         Spine l2 l3 bone mineral density
# spine_l2_l4_area                                        Spine l2 l4 area
# spine_l2_l4_average_height                    Spine l2 l4 average height
# spine_l2_l4_average_width                      Spine l2 l4 average width
# spine_l2_l4_bmc                         Spine l2 l4 bone mineral content
# spine_l2_l4_bmd                         Spine l2 l4 bone mineral density
# spine_l3_area                                              Spine l3 area
# spine_l3_average_height                          Spine l3 average height
# spine_l3_average_width                            Spine l3 average width
# spine_l3_bmc                               Spine l3 bone mineral content
# spine_l3_bmd                               Spine l3 bone mineral density
# spine_l3_l4_area                                        Spine l3 l4 area
# spine_l3_l4_average_height                    Spine l3 l4 average height
# spine_l3_l4_average_width                      Spine l3 l4 average width
# spine_l3_l4_bmc                         Spine l3 l4 bone mineral content
# spine_l3_l4_bmd                         Spine l3 l4 bone mineral density
# spine_l4_area                                              Spine l4 area
# spine_l4_average_height                          Spine l4 average height
# spine_l4_average_width                            Spine l4 average width
# spine_l4_bmc                               Spine l4 bone mineral content
# spine_l4_bmd                               Spine l4 bone mineral density
#
#                                                       description_string  \
# tabular_field_name
# collection_date                             Collection date (YYYY-MM-DD)
# timezone                                                        Timezone
# collection_timestamp                                Collection timestamp
# body_arm_left_area                                    Body arm left area
# body_arm_left_bmc                     Body arm left bone mineral content
# body_arm_left_bmd                     Body arm left bone mineral density
# body_arm_right_area                                  Body arm right area
# body_arm_right_bmc                   Body arm right bone mineral content
# body_arm_right_bmd                   Body arm right bone mineral density
# body_arms_area                                            Body arms area
# body_arms_bmc                             Body arms bone mineral content
# body_arms_bmd                             Body arms bone mineral density
# body_dose                                                      Body dose
# body_head_area                                            Body head area
# body_head_bmc                             Body head bone mineral content
# body_head_bmd                             Body head bone mineral density
# body_leg_left_area                                    Body leg left area
# body_leg_left_bmc                     Body leg left bone mineral content
# body_leg_left_bmd                     Body leg left bone mineral density
# body_leg_right_area                                  Body leg right area
# body_leg_right_bmc                   Body leg right bone mineral content
# body_leg_right_bmd                   Body leg right bone mineral density
# body_legs_area                                            Body legs area
# body_legs_bmc                             Body legs bone mineral content
# body_legs_bmd                             Body legs bone mineral density
# body_pelvis_area                                        Body pelvis area
# body_pelvis_bmc                         Body pelvis bone mineral content
# body_pelvis_bmd                         Body pelvis bone mineral density
# body_ribs_area                                            Body ribs area
# body_ribs_bmc                             Body ribs bone mineral content
# body_ribs_bmd                             Body ribs bone mineral density
# body_spine_area                                          Body spine area
# body_spine_bmc                           Body spine bone mineral content
# body_spine_bmd                           Body spine bone mineral density
# body_total_area                                          Body total area
# body_total_bmc                           Body total bone mineral content
# body_total_bmd                           Body total bone mineral density
# body_total_left_area                                Body total left area
# body_total_left_bmc                 Body total left bone mineral content
# body_total_left_bmd                 Body total left bone mineral density
# body_total_right_area                              Body total right area
# body_total_right_bmc               Body total right bone mineral content
# body_total_right_bmd               Body total right bone mineral density
# body_trunk_area                                          Body trunk area
# body_trunk_bmc                           Body trunk bone mineral content
# body_trunk_bmd                           Body trunk bone mineral density
# body_trunk_left_area                                Body trunk left area
# body_trunk_left_bmc                 Body trunk left bone mineral content
# body_trunk_left_bmd                 Body trunk left bone mineral density
# body_trunk_right_area                              Body trunk right area
# body_trunk_right_bmc               Body trunk right bone mineral content
# body_trunk_right_bmd               Body trunk right bone mineral density
# femur_lower_neck_diff_area                    Femur lower neck diff area
# femur_lower_neck_diff_bmc     Femur lower neck diff bone mineral content
# femur_lower_neck_diff_bmd     Femur lower neck diff bone mineral density
# femur_lower_neck_mean_area                    Femur lower neck mean area
# femur_lower_neck_mean_bmc     Femur lower neck mean bone mineral content
# femur_lower_neck_mean_bmd     Femur lower neck mean bone mineral density
# femur_neck_diff_area                                Femur neck diff area
# femur_neck_diff_bmc                 Femur neck diff bone mineral content
# femur_neck_diff_bmd                 Femur neck diff bone mineral density
# femur_neck_mean_area                                Femur neck mean area
# femur_neck_mean_bmc                 Femur neck mean bone mineral content
# femur_neck_mean_bmd                 Femur neck mean bone mineral density
# femur_right_lower_neck_area                  Femur right lower neck area
# femur_right_lower_neck_bmc   Femur right lower neck bone mineral content
# femur_right_lower_neck_bmd   Femur right lower neck bone mineral density
# femur_right_neck_area                              Femur right neck area
# femur_right_neck_bmc               Femur right neck bone mineral content
# femur_right_neck_bmd               Femur right neck bone mineral density
# femur_right_shaft_area                            Femur right shaft area
# femur_right_shaft_bmc             Femur right shaft bone mineral content
# femur_right_shaft_bmd             Femur right shaft bone mineral density
# femur_right_total_area                            Femur right total area
# femur_right_total_bmc             Femur right total bone mineral content
# femur_right_total_bmd             Femur right total bone mineral density
# femur_right_troch_area                            Femur right troch area
# femur_right_troch_bmc             Femur right troch bone mineral content
# femur_right_troch_bmd             Femur right troch bone mineral density
# femur_right_upper_neck_area                  Femur right upper neck area
# femur_right_upper_neck_bmc   Femur right upper neck bone mineral content
# femur_right_upper_neck_bmd   Femur right upper neck bone mineral density
# femur_right_wards_area                            Femur right wards area
# femur_right_wards_bmc             Femur right wards bone mineral content
# femur_right_wards_bmd             Femur right wards bone mineral density
# femur_shaft_diff_area                              Femur shaft diff area
# femur_shaft_diff_bmc               Femur shaft diff bone mineral content
# femur_shaft_diff_bmd               Femur shaft diff bone mineral density
# femur_shaft_mean_area                              Femur shaft mean area
# femur_shaft_mean_bmc               Femur shaft mean bone mineral content
# femur_shaft_mean_bmd               Femur shaft mean bone mineral density
# femur_total_diff_area                              Femur total diff area
# femur_total_diff_bmc               Femur total diff bone mineral content
# femur_total_diff_bmd               Femur total diff bone mineral density
# femur_total_mean_area                              Femur total mean area
# femur_total_mean_bmc               Femur total mean bone mineral content
# femur_total_mean_bmd               Femur total mean bone mineral density
# femur_troch_diff_area                              Femur troch diff area
# femur_troch_diff_bmc               Femur troch diff bone mineral content
# femur_troch_diff_bmd               Femur troch diff bone mineral density
# femur_troch_mean_area                              Femur troch mean area
# femur_troch_mean_bmc               Femur troch mean bone mineral content
# femur_troch_mean_bmd               Femur troch mean bone mineral density
# femur_upper_neck_diff_area                    Femur upper neck diff area
# femur_upper_neck_diff_bmc     Femur upper neck diff bone mineral content
# femur_upper_neck_diff_bmd     Femur upper neck diff bone mineral density
# femur_upper_neck_mean_area                    Femur upper neck mean area
# femur_upper_neck_mean_bmc     Femur upper neck mean bone mineral content
# femur_upper_neck_mean_bmd     Femur upper neck mean bone mineral density
# femur_wards_diff_area                              Femur wards diff area
# femur_wards_diff_bmc               Femur wards diff bone mineral content
# femur_wards_diff_bmd               Femur wards diff bone mineral density
# femur_wards_mean_area                              Femur wards mean area
# femur_wards_mean_bmc               Femur wards mean bone mineral content
# femur_wards_mean_bmd               Femur wards mean bone mineral density
# spine_dose                                                    Spine dose
# spine_l1_area                                              Spine l1 area
# spine_l1_average_height                          Spine l1 average height
# spine_l1_average_width                            Spine l1 average width
# spine_l1_bmc                               Spine l1 bone mineral content
# spine_l1_bmd                               Spine l1 bone mineral density
# spine_l1_l2_area                                        Spine l1 l2 area
# spine_l1_l2_average_height                    Spine l1 l2 average height
# spine_l1_l2_average_width                      Spine l1 l2 average width
# spine_l1_l2_bmc                         Spine l1 l2 bone mineral content
# spine_l1_l2_bmd                         Spine l1 l2 bone mineral density
# spine_l1_l3_area                                        Spine l1 l3 area
# spine_l1_l3_average_height                    Spine l1 l3 average height
# spine_l1_l3_average_width                      Spine l1 l3 average width
# spine_l1_l3_bmc                         Spine l1 l3 bone mineral content
# spine_l1_l3_bmd                         Spine l1 l3 bone mineral density
# spine_l1_l4_area                                        Spine l1 l4 area
# spine_l1_l4_average_height                    Spine l1 l4 average height
# spine_l1_l4_average_width                      Spine l1 l4 average width
# spine_l1_l4_bmc                         Spine l1 l4 bone mineral content
# spine_l1_l4_bmd                         Spine l1 l4 bone mineral density
# spine_l2_area                                              Spine l2 area
# spine_l2_average_height                          Spine l2 average height
# spine_l2_average_width                            Spine l2 average width
# spine_l2_bmc                               Spine l2 bone mineral content
# spine_l2_bmd                               Spine l2 bone mineral density
# spine_l2_l3_area                                        Spine l2 l3 area
# spine_l2_l3_average_height                    Spine l2 l3 average height
# spine_l2_l3_average_width                      Spine l2 l3 average width
# spine_l2_l3_bmc                         Spine l2 l3 bone mineral content
# spine_l2_l3_bmd                         Spine l2 l3 bone mineral density
# spine_l2_l4_area                                        Spine l2 l4 area
# spine_l2_l4_average_height                    Spine l2 l4 average height
# spine_l2_l4_average_width                      Spine l2 l4 average width
# spine_l2_l4_bmc                         Spine l2 l4 bone mineral content
# spine_l2_l4_bmd                         Spine l2 l4 bone mineral density
# spine_l3_area                                              Spine l3 area
# spine_l3_average_height                          Spine l3 average height
# spine_l3_average_width                            Spine l3 average width
# spine_l3_bmc                               Spine l3 bone mineral content
# spine_l3_bmd                               Spine l3 bone mineral density
# spine_l3_l4_area                                        Spine l3 l4 area
# spine_l3_l4_average_height                    Spine l3 l4 average height
# spine_l3_l4_average_width                      Spine l3 l4 average width
# spine_l3_l4_bmc                         Spine l3 l4 bone mineral content
# spine_l3_l4_bmd                         Spine l3 l4 bone mineral density
# spine_l4_area                                              Spine l4 area
# spine_l4_average_height                          Spine l4 average height
# spine_l4_average_width                            Spine l4 average width
# spine_l4_bmc                               Spine l4 bone mineral content
# spine_l4_bmd                               Spine l4 bone mineral density
#
#                              parent_dataframe     relative_location  \
# tabular_field_name
# collection_date                           NaN  bone_density.parquet
# timezone                                  NaN  bone_density.parquet
# collection_timestamp                      NaN  bone_density.parquet
# body_arm_left_area                        NaN  bone_density.parquet
# body_arm_left_bmc                         NaN  bone_density.parquet
# body_arm_left_bmd                         NaN  bone_density.parquet
# body_arm_right_area                       NaN  bone_density.parquet
# body_arm_right_bmc                        NaN  bone_density.parquet
# body_arm_right_bmd                        NaN  bone_density.parquet
# body_arms_area                            NaN  bone_density.parquet
# body_arms_bmc                             NaN  bone_density.parquet
# body_arms_bmd                             NaN  bone_density.parquet
# body_dose                                 NaN  bone_density.parquet
# body_head_area                            NaN  bone_density.parquet
# body_head_bmc                             NaN  bone_density.parquet
# body_head_bmd                             NaN  bone_density.parquet
# body_leg_left_area                        NaN  bone_density.parquet
# body_leg_left_bmc                         NaN  bone_density.parquet
# body_leg_left_bmd                         NaN  bone_density.parquet
# body_leg_right_area                       NaN  bone_density.parquet
# body_leg_right_bmc                        NaN  bone_density.parquet
# body_leg_right_bmd                        NaN  bone_density.parquet
# body_legs_area                            NaN  bone_density.parquet
# body_legs_bmc                             NaN  bone_density.parquet
# body_legs_bmd                             NaN  bone_density.parquet
# body_pelvis_area                          NaN  bone_density.parquet
# body_pelvis_bmc                           NaN  bone_density.parquet
# body_pelvis_bmd                           NaN  bone_density.parquet
# body_ribs_area                            NaN  bone_density.parquet
# body_ribs_bmc                             NaN  bone_density.parquet
# body_ribs_bmd                             NaN  bone_density.parquet
# body_spine_area                           NaN  bone_density.parquet
# body_spine_bmc                            NaN  bone_density.parquet
# body_spine_bmd                            NaN  bone_density.parquet
# body_total_area                           NaN  bone_density.parquet
# body_total_bmc                            NaN  bone_density.parquet
# body_total_bmd                            NaN  bone_density.parquet
# body_total_left_area                      NaN  bone_density.parquet
# body_total_left_bmc                       NaN  bone_density.parquet
# body_total_left_bmd                       NaN  bone_density.parquet
# body_total_right_area                     NaN  bone_density.parquet
# body_total_right_bmc                      NaN  bone_density.parquet
# body_total_right_bmd                      NaN  bone_density.parquet
# body_trunk_area                           NaN  bone_density.parquet
# body_trunk_bmc                            NaN  bone_density.parquet
# body_trunk_bmd                            NaN  bone_density.parquet
# body_trunk_left_area                      NaN  bone_density.parquet
# body_trunk_left_bmc                       NaN  bone_density.parquet
# body_trunk_left_bmd                       NaN  bone_density.parquet
# body_trunk_right_area                     NaN  bone_density.parquet
# body_trunk_right_bmc                      NaN  bone_density.parquet
# body_trunk_right_bmd                      NaN  bone_density.parquet
# femur_lower_neck_diff_area                NaN  bone_density.parquet
# femur_lower_neck_diff_bmc                 NaN  bone_density.parquet
# femur_lower_neck_diff_bmd                 NaN  bone_density.parquet
# femur_lower_neck_mean_area                NaN  bone_density.parquet
# femur_lower_neck_mean_bmc                 NaN  bone_density.parquet
# femur_lower_neck_mean_bmd                 NaN  bone_density.parquet
# femur_neck_diff_area                      NaN  bone_density.parquet
# femur_neck_diff_bmc                       NaN  bone_density.parquet
# femur_neck_diff_bmd                       NaN  bone_density.parquet
# femur_neck_mean_area                      NaN  bone_density.parquet
# femur_neck_mean_bmc                       NaN  bone_density.parquet
# femur_neck_mean_bmd                       NaN  bone_density.parquet
# femur_right_lower_neck_area               NaN  bone_density.parquet
# femur_right_lower_neck_bmc                NaN  bone_density.parquet
# femur_right_lower_neck_bmd                NaN  bone_density.parquet
# femur_right_neck_area                     NaN  bone_density.parquet
# femur_right_neck_bmc                      NaN  bone_density.parquet
# femur_right_neck_bmd                      NaN  bone_density.parquet
# femur_right_shaft_area                    NaN  bone_density.parquet
# femur_right_shaft_bmc                     NaN  bone_density.parquet
# femur_right_shaft_bmd                     NaN  bone_density.parquet
# femur_right_total_area                    NaN  bone_density.parquet
# femur_right_total_bmc                     NaN  bone_density.parquet
# femur_right_total_bmd                     NaN  bone_density.parquet
# femur_right_troch_area                    NaN  bone_density.parquet
# femur_right_troch_bmc                     NaN  bone_density.parquet
# femur_right_troch_bmd                     NaN  bone_density.parquet
# femur_right_upper_neck_area               NaN  bone_density.parquet
# femur_right_upper_neck_bmc                NaN  bone_density.parquet
# femur_right_upper_neck_bmd                NaN  bone_density.parquet
# femur_right_wards_area                    NaN  bone_density.parquet
# femur_right_wards_bmc                     NaN  bone_density.parquet
# femur_right_wards_bmd                     NaN  bone_density.parquet
# femur_shaft_diff_area                     NaN  bone_density.parquet
# femur_shaft_diff_bmc                      NaN  bone_density.parquet
# femur_shaft_diff_bmd                      NaN  bone_density.parquet
# femur_shaft_mean_area                     NaN  bone_density.parquet
# femur_shaft_mean_bmc                      NaN  bone_density.parquet
# femur_shaft_mean_bmd                      NaN  bone_density.parquet
# femur_total_diff_area                     NaN  bone_density.parquet
# femur_total_diff_bmc                      NaN  bone_density.parquet
# femur_total_diff_bmd                      NaN  bone_density.parquet
# femur_total_mean_area                     NaN  bone_density.parquet
# femur_total_mean_bmc                      NaN  bone_density.parquet
# femur_total_mean_bmd                      NaN  bone_density.parquet
# femur_troch_diff_area                     NaN  bone_density.parquet
# femur_troch_diff_bmc                      NaN  bone_density.parquet
# femur_troch_diff_bmd                      NaN  bone_density.parquet
# femur_troch_mean_area                     NaN  bone_density.parquet
# femur_troch_mean_bmc                      NaN  bone_density.parquet
# femur_troch_mean_bmd                      NaN  bone_density.parquet
# femur_upper_neck_diff_area                NaN  bone_density.parquet
# femur_upper_neck_diff_bmc                 NaN  bone_density.parquet
# femur_upper_neck_diff_bmd                 NaN  bone_density.parquet
# femur_upper_neck_mean_area                NaN  bone_density.parquet
# femur_upper_neck_mean_bmc                 NaN  bone_density.parquet
# femur_upper_neck_mean_bmd                 NaN  bone_density.parquet
# femur_wards_diff_area                     NaN  bone_density.parquet
# femur_wards_diff_bmc                      NaN  bone_density.parquet
# femur_wards_diff_bmd                      NaN  bone_density.parquet
# femur_wards_mean_area                     NaN  bone_density.parquet
# femur_wards_mean_bmc                      NaN  bone_density.parquet
# femur_wards_mean_bmd                      NaN  bone_density.parquet
# spine_dose                                NaN  bone_density.parquet
# spine_l1_area                             NaN  bone_density.parquet
# spine_l1_average_height                   NaN  bone_density.parquet
# spine_l1_average_width                    NaN  bone_density.parquet
# spine_l1_bmc                              NaN  bone_density.parquet
# spine_l1_bmd                              NaN  bone_density.parquet
# spine_l1_l2_area                          NaN  bone_density.parquet
# spine_l1_l2_average_height                NaN  bone_density.parquet
# spine_l1_l2_average_width                 NaN  bone_density.parquet
# spine_l1_l2_bmc                           NaN  bone_density.parquet
# spine_l1_l2_bmd                           NaN  bone_density.parquet
# spine_l1_l3_area                          NaN  bone_density.parquet
# spine_l1_l3_average_height                NaN  bone_density.parquet
# spine_l1_l3_average_width                 NaN  bone_density.parquet
# spine_l1_l3_bmc                           NaN  bone_density.parquet
# spine_l1_l3_bmd                           NaN  bone_density.parquet
# spine_l1_l4_area                          NaN  bone_density.parquet
# spine_l1_l4_average_height                NaN  bone_density.parquet
# spine_l1_l4_average_width                 NaN  bone_density.parquet
# spine_l1_l4_bmc                           NaN  bone_density.parquet
# spine_l1_l4_bmd                           NaN  bone_density.parquet
# spine_l2_area                             NaN  bone_density.parquet
# spine_l2_average_height                   NaN  bone_density.parquet
# spine_l2_average_width                    NaN  bone_density.parquet
# spine_l2_bmc                              NaN  bone_density.parquet
# spine_l2_bmd                              NaN  bone_density.parquet
# spine_l2_l3_area                          NaN  bone_density.parquet
# spine_l2_l3_average_height                NaN  bone_density.parquet
# spine_l2_l3_average_width                 NaN  bone_density.parquet
# spine_l2_l3_bmc                           NaN  bone_density.parquet
# spine_l2_l3_bmd                           NaN  bone_density.parquet
# spine_l2_l4_area                          NaN  bone_density.parquet
# spine_l2_l4_average_height                NaN  bone_density.parquet
# spine_l2_l4_average_width                 NaN  bone_density.parquet
# spine_l2_l4_bmc                           NaN  bone_density.parquet
# spine_l2_l4_bmd                           NaN  bone_density.parquet
# spine_l3_area                             NaN  bone_density.parquet
# spine_l3_average_height                   NaN  bone_density.parquet
# spine_l3_average_width                    NaN  bone_density.parquet
# spine_l3_bmc                              NaN  bone_density.parquet
# spine_l3_bmd                              NaN  bone_density.parquet
# spine_l3_l4_area                          NaN  bone_density.parquet
# spine_l3_l4_average_height                NaN  bone_density.parquet
# spine_l3_l4_average_width                 NaN  bone_density.parquet
# spine_l3_l4_bmc                           NaN  bone_density.parquet
# spine_l3_l4_bmd                           NaN  bone_density.parquet
# spine_l4_area                             NaN  bone_density.parquet
# spine_l4_average_height                   NaN  bone_density.parquet
# spine_l4_average_width                    NaN  bone_density.parquet
# spine_l4_bmc                              NaN  bone_density.parquet
# spine_l4_bmd                              NaN  bone_density.parquet
#
#                              value_type      units  sampling_rate item_type  \
# tabular_field_name
# collection_date                    Date       Time            NaN      Data
# timezone                            NaN        NaN            NaN       NaN
# collection_timestamp               Date       Time            NaN      Data
# body_arm_left_area           Continuous       cm^2            NaN      Data
# body_arm_left_bmc            Continuous       gram            NaN      Data
# body_arm_left_bmd            Continuous  gram/cm^2            NaN      Data
# body_arm_right_area          Continuous       cm^2            NaN      Data
# body_arm_right_bmc           Continuous       gram            NaN      Data
# body_arm_right_bmd           Continuous  gram/cm^2            NaN      Data
# body_arms_area               Continuous       cm^2            NaN      Data
# body_arms_bmc                Continuous       gram            NaN      Data
# body_arms_bmd                Continuous  gram/cm^2            NaN      Data
# body_dose                    Continuous        μGy            NaN      Data
# body_head_area               Continuous       cm^2            NaN      Data
# body_head_bmc                Continuous       gram            NaN      Data
# body_head_bmd                Continuous  gram/cm^2            NaN      Data
# body_leg_left_area           Continuous       cm^2            NaN      Data
# body_leg_left_bmc            Continuous       gram            NaN      Data
# body_leg_left_bmd            Continuous  gram/cm^2            NaN      Data
# body_leg_right_area          Continuous       cm^2            NaN      Data
# body_leg_right_bmc           Continuous       gram            NaN      Data
# body_leg_right_bmd           Continuous  gram/cm^2            NaN      Data
# body_legs_area               Continuous       cm^2            NaN      Data
# body_legs_bmc                Continuous       gram            NaN      Data
# body_legs_bmd                Continuous  gram/cm^2            NaN      Data
# body_pelvis_area             Continuous       cm^2            NaN      Data
# body_pelvis_bmc              Continuous       gram            NaN      Data
# body_pelvis_bmd              Continuous  gram/cm^2            NaN      Data
# body_ribs_area               Continuous       cm^2            NaN      Data
# body_ribs_bmc                Continuous       gram            NaN      Data
# body_ribs_bmd                Continuous  gram/cm^2            NaN      Data
# body_spine_area              Continuous       cm^2            NaN      Data
# body_spine_bmc               Continuous       gram            NaN      Data
# body_spine_bmd               Continuous  gram/cm^2            NaN      Data
# body_total_area              Continuous       cm^2            NaN      Data
# body_total_bmc               Continuous       gram            NaN      Data
# body_total_bmd               Continuous  gram/cm^2            NaN      Data
# body_total_left_area         Continuous       cm^2            NaN      Data
# body_total_left_bmc          Continuous       gram            NaN      Data
# ...
# femur_shaft_diff_bmc         Single     10K   tabular  2020-06-09
# femur_shaft_diff_bmd         Single     10K   tabular  2020-06-09
# femur_shaft_mean_area        Single     10K   tabular  2020-06-09
# femur_shaft_mean_bmc         Single     10K   tabular  2020-06-09
# femur_shaft_mean_bmd         Single     10K   tabular  2020-06-09
# femur_total_diff_area        Single     10K   tabular  2020-06-09
# femur_total_diff_bmc         Single     10K   tabular  2020-06-09
# femur_total_diff_bmd         Single     10K   tabular  2020-06-09
# femur_total_mean_area        Single     10K   tabular  2020-06-09
# femur_total_mean_bmc         Single     10K   tabular  2020-06-09
# femur_total_mean_bmd         Single     10K   tabular  2020-06-09
# femur_troch_diff_area        Single     10K   tabular  2020-06-09
# femur_troch_diff_bmc         Single     10K   tabular  2020-06-09
# femur_troch_diff_bmd         Single     10K   tabular  2020-06-09
# femur_troch_mean_area        Single     10K   tabular  2020-06-09
# femur_troch_mean_bmc         Single     10K   tabular  2020-06-09
# femur_troch_mean_bmd         Single     10K   tabular  2020-06-09
# femur_upper_neck_diff_area   Single     10K   tabular  2020-06-09
# femur_upper_neck_diff_bmc    Single     10K   tabular  2020-06-09
# femur_upper_neck_diff_bmd    Single     10K   tabular  2020-06-09
# femur_upper_neck_mean_area   Single     10K   tabular  2020-06-09
# femur_upper_neck_mean_bmc    Single     10K   tabular  2020-06-09
# femur_upper_neck_mean_bmd    Single     10K   tabular  2020-06-09
# femur_wards_diff_area        Single     10K   tabular  2020-06-09
# femur_wards_diff_bmc         Single     10K   tabular  2020-06-09
# femur_wards_diff_bmd         Single     10K   tabular  2020-06-09
# femur_wards_mean_area        Single     10K   tabular  2020-06-09
# femur_wards_mean_bmc         Single     10K   tabular  2020-06-09
# femur_wards_mean_bmd         Single     10K   tabular  2020-06-09
# spine_dose                   Single     10K   tabular  2020-06-09
# spine_l1_area                Single     10K   tabular  2020-06-09
# spine_l1_average_height      Single     10K   tabular  2020-06-09
# spine_l1_average_width       Single     10K   tabular  2020-06-09
# spine_l1_bmc                 Single     10K   tabular  2020-06-09
# spine_l1_bmd                 Single     10K   tabular  2020-06-09
# spine_l1_l2_area             Single     10K   tabular  2020-06-09
# spine_l1_l2_average_height   Single     10K   tabular  2020-06-09
# spine_l1_l2_average_width    Single     10K   tabular  2020-06-09
# spine_l1_l2_bmc              Single     10K   tabular  2020-06-09
# spine_l1_l2_bmd              Single     10K   tabular  2020-06-09
# spine_l1_l3_area             Single     10K   tabular  2020-06-09
# spine_l1_l3_average_height   Single     10K   tabular  2020-06-09
# spine_l1_l3_average_width    Single     10K   tabular  2020-06-09
# spine_l1_l3_bmc              Single     10K   tabular  2020-06-09
# spine_l1_l3_bmd              Single     10K   tabular  2020-06-09
# spine_l1_l4_area             Single     10K   tabular  2020-06-09
# spine_l1_l4_average_height   Single     10K   tabular  2020-06-09
# spine_l1_l4_average_width    Single     10K   tabular  2020-06-09
# spine_l1_l4_bmc              Single     10K   tabular  2020-06-09
# spine_l1_l4_bmd              Single     10K   tabular  2020-06-09
# spine_l2_area                Single     10K   tabular  2020-06-09
# spine_l2_average_height      Single     10K   tabular  2020-06-09
# spine_l2_average_width       Single     10K   tabular  2020-06-09
# spine_l2_bmc                 Single     10K   tabular  2020-06-09
# spine_l2_bmd                 Single     10K   tabular  2020-06-09
# spine_l2_l3_area             Single     10K   tabular  2020-06-09
# spine_l2_l3_average_height   Single     10K   tabular  2020-06-09
# spine_l2_l3_average_width    Single     10K   tabular  2020-06-09
# spine_l2_l3_bmc              Single     10K   tabular  2020-06-09
# spine_l2_l3_bmd              Single     10K   tabular  2020-06-09
# spine_l2_l4_area             Single     10K   tabular  2020-06-09
# spine_l2_l4_average_height   Single     10K   tabular  2020-06-09
# spine_l2_l4_average_width    Single     10K   tabular  2020-06-09
# spine_l2_l4_bmc              Single     10K   tabular  2020-06-09
# spine_l2_l4_bmd              Single     10K   tabular  2020-06-09
# spine_l3_area                Single     10K   tabular  2020-06-09
# spine_l3_average_height      Single     10K   tabular  2020-06-09
# spine_l3_average_width       Single     10K   tabular  2020-06-09
# spine_l3_bmc                 Single     10K   tabular  2020-06-09
# spine_l3_bmd                 Single     10K   tabular  2020-06-09
# spine_l3_l4_area             Single     10K   tabular  2020-06-09
# spine_l3_l4_average_height   Single     10K   tabular  2020-06-09
# spine_l3_l4_average_width    Single     10K   tabular  2020-06-09
# spine_l3_l4_bmc              Single     10K   tabular  2020-06-09
# spine_l3_l4_bmd              Single     10K   tabular  2020-06-09
# spine_l4_area                Single     10K   tabular  2020-06-09
# spine_l4_average_height      Single     10K   tabular  2020-06-09
# spine_l4_average_width       Single     10K   tabular  2020-06-09
# spine_l4_bmc                 Single     10K   tabular  2020-06-09
# spine_l4_bmd                 Single     10K   tabular  2020-06-09
#
#                                                pandas_dtype
# tabular_field_name
# collection_date                              datetime64[ns]
# timezone                                             string
# collection_timestamp         datetime64[ns, Asia/Jerusalem]
# body_arm_left_area                                    float
# body_arm_left_bmc                                     float
# body_arm_left_bmd                                     float
# body_arm_right_area                                   float
# body_arm_right_bmc                                    float
# body_arm_right_bmd                                    float
# body_arms_area                                        float
# body_arms_bmc                                         float
# body_arms_bmd                                         float
# body_dose                                             float
# body_head_area                                        float
# body_head_bmc                                         float
# body_head_bmd                                         float
# body_leg_left_area                                    float
# body_leg_left_bmc                                     float
# body_leg_left_bmd                                     float
# body_leg_right_area                                   float
# body_leg_right_bmc                                    float
# body_leg_right_bmd                                    float
# body_legs_area                                        float
# body_legs_bmc                                         float
# body_legs_bmd                                         float
# body_pelvis_area                                      float
# body_pelvis_bmc                                       float
# body_pelvis_bmd                                       float
# body_ribs_area                                        float
# body_ribs_bmc                                         float
# body_ribs_bmd                                         float
# body_spine_area                                       float
# body_spine_bmc                                        float
# body_spine_bmd                                        float
# body_total_area                                       float
# body_total_bmc                                        float
# body_total_bmd                                        float
# body_total_left_area                                  float
# body_total_left_bmc                                   float
# body_total_left_bmd                                   float
# body_total_right_area                                 float
# body_total_right_bmc                                  float
# body_total_right_bmd                                  float
# body_trunk_area                                       float
# body_trunk_bmc                                        float
# body_trunk_bmd                                        float
# body_trunk_left_area                                  float
# body_trunk_left_bmc                                   float
# body_trunk_left_bmd                                   float
# body_trunk_right_area                                 float
# body_trunk_right_bmc                                  float
# body_trunk_right_bmd                                  float
# femur_lower_neck_diff_area                            float
# femur_lower_neck_diff_bmc                             float
# femur_lower_neck_diff_bmd                             float
# femur_lower_neck_mean_area                            float
# femur_lower_neck_mean_bmc                             float
# femur_lower_neck_mean_bmd                             float
# femur_neck_diff_area                                  float
# femur_neck_diff_bmc                                   float
# femur_neck_diff_bmd                                   float
# femur_neck_mean_area                                  float
# femur_neck_mean_bmc                                   float
# femur_neck_mean_bmd                                   float
# femur_right_lower_neck_area                           float
# femur_right_lower_neck_bmc                            float
# femur_right_lower_neck_bmd                            float
# femur_right_neck_area                                 float
# femur_right_neck_bmc                                  float
# femur_right_neck_bmd                                  float
# femur_right_shaft_area                                float
# femur_right_shaft_bmc                                 float
# femur_right_shaft_bmd                                 float
# femur_right_total_area                                float
# femur_right_total_bmc                                 float
# femur_right_total_bmd                                 float
# femur_right_troch_area                                float
# femur_right_troch_bmc                                 float
# femur_right_troch_bmd                                 float
# femur_right_upper_neck_area                           float
# femur_right_upper_neck_bmc                            float
# femur_right_upper_neck_bmd                            float
# femur_right_wards_area                                float
# femur_right_wards_bmc                                 float
# femur_right_wards_bmd                                 float
# femur_shaft_diff_area                                 float
# femur_shaft_diff_bmc                                  float
# femur_shaft_diff_bmd                                  float
# femur_shaft_mean_area                                 float
# femur_shaft_mean_bmc                                  float
# femur_shaft_mean_bmd                                  float
# femur_total_diff_area                                 float
# femur_total_diff_bmc                                  float
# femur_total_diff_bmd                                  float
# femur_total_mean_area                                 float
# femur_total_mean_bmc                                  float
# femur_total_mean_bmd                                  float
# femur_troch_diff_area                                 float
# femur_troch_diff_bmc                                  float
# femur_troch_diff_bmd                                  float
# femur_troch_mean_area                                 float
# femur_troch_mean_bmc                                  float
# femur_troch_mean_bmd                                  float
# femur_upper_neck_diff_area                            float
# femur_upper_neck_diff_bmc                             float
# femur_upper_neck_diff_bmd                             float
# femur_upper_neck_mean_area                            float
# femur_upper_neck_mean_bmc                             float
# femur_upper_neck_mean_bmd                             float
# femur_wards_diff_area                                 float
# femur_wards_diff_bmc                                  float
# femur_wards_diff_bmd                                  float
# femur_wards_mean_area                                 float
# femur_wards_mean_bmc                                  float
# femur_wards_mean_bmd                                  float
# spine_dose                                            float
# spine_l1_area                                         float
# spine_l1_average_height                               float
# spine_l1_average_width                                float
# spine_l1_bmc                                          float
# spine_l1_bmd                                          float
# spine_l1_l2_area                                      float
# spine_l1_l2_average_height                            float
# spine_l1_l2_average_width                             float
# spine_l1_l2_bmc                                       float
# spine_l1_l2_bmd                                       float
# spine_l1_l3_area                                      float
# spine_l1_l3_average_height                            float
# spine_l1_l3_average_width                             float
# spine_l1_l3_bmc                                       float
# spine_l1_l3_bmd                                       float
# spine_l1_l4_area                                      float
# spine_l1_l4_average_height                            float
# spine_l1_l4_average_width                             float
# spine_l1_l4_bmc                                       float
# spine_l1_l4_bmd                                       float
# spine_l2_area                                         float
# spine_l2_average_height                               float
# spine_l2_average_width                                float
# spine_l2_bmc                                          float
# spine_l2_bmd                                          float
# spine_l2_l3_area                                      float
# spine_l2_l3_average_height                            float
# spine_l2_l3_average_width                             float
# spine_l2_l3_bmc                                       float
# spine_l2_l3_bmd                                       float
# spine_l2_l4_area                                      float
# spine_l2_l4_average_height                            float
# spine_l2_l4_average_width                             float
# spine_l2_l4_bmc                                       float
# spine_l2_l4_bmd                                       float
# spine_l3_area                                         float
# spine_l3_average_height                               float
# spine_l3_average_width                                float
# spine_l3_bmc                                          float
# spine_l3_bmd                                          float
# spine_l3_l4_area                                      float
# spine_l3_l4_average_height                            float
# spine_l3_l4_average_width                             float
# spine_l3_l4_bmc                                       float
# spine_l3_l4_bmd                                       float
# spine_l4_area                                         float
# spine_l4_average_height                               float
# spine_l4_average_width                                float
# spine_l4_bmc                                          float
# spine_l4_bmd                                          float
