# %% [raw]
# ---
# output-file: 15-ecg.html
# title: 15-ecg
#
# ---

# %% [markdown]
# # 15 - ecg
# An electrocardiogram (ECG) is a simple test that can be used to check your heart's rhythm and electrical activity. Sensors attached to the skin are used to detect the electrical signals produced by the heart each time it beats.
#
# A resting 12-lead ECG is recorded at each visit for participants. The record length is 10 seconds and the sample rate is 1000Hz. We collect both the raw waveform ECG signal from all leads and tabular data. The tabular data are features which have been extracted automatically by the machine from the raw data such as the P wave duration.
#
# The information is stored in 2 tabular parquet files: `ecg_main.parquet`, `ecg_qc.parquet`, which contain tabular features and QC checks on the raw ECG waveform data. Mutiple time series parquet files contain the raw and processed ECG waveform data

# %%
#| hide
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('ecg', age_sex_dataset=None)
dl
# Out:
# DataLoader for ecg with
# 163 fields
# 2 tables: ['ecg_main', 'ecg_qc']

# %%
dl.dict
# Out:
#                                       Unnamed: 0  \
# tabular_field_name
# collection_date                                0
# timezone                                       1
# collection_timestamp                           2
# MDC_ECG_LEAD_I                                 3
# MDC_ECG_LEAD_II                                4
# MDC_ECG_LEAD_III                               5
# MDC_ECG_LEAD_aVR                               6
# MDC_ECG_LEAD_aVL                               7
# MDC_ECG_LEAD_aVF                               8
# MDC_ECG_LEAD_V1                                9
# MDC_ECG_LEAD_V2                               10
# MDC_ECG_LEAD_V3                               11
# MDC_ECG_LEAD_V4                               12
# MDC_ECG_LEAD_V5                               13
# MDC_ECG_LEAD_V6                               14
# MDC_ECG_LEAD_I_clean                          15
# MDC_ECG_LEAD_II_clean                         16
# MDC_ECG_LEAD_III_clean                        17
# MDC_ECG_LEAD_aVR_clean                        18
# MDC_ECG_LEAD_aVL_clean                        19
# MDC_ECG_LEAD_aVF_clean                        20
# MDC_ECG_LEAD_V1_clean                         21
# MDC_ECG_LEAD_V2_clean                         22
# MDC_ECG_LEAD_V3_clean                         23
# MDC_ECG_LEAD_V4_clean                         24
# MDC_ECG_LEAD_V5_clean                         25
# MDC_ECG_LEAD_V6_clean                         26
# raw_ecg_time_series                           27
# processed_ecg_time_series                     28
# hr_bpm                                        29
# p_ms                                          30
# pr_ms                                         31
# qrs_ms                                        32
# qt_ms                                         33
# qtc_ms                                        34
# conclusion                                    35
# p_axis                                        36
# t_axis                                        37
# qrs_axis                                      38
# r_r_ms                                        39
# j_mv_aVF                                      40
# j_mv_aVL                                      41
# j_mv_aVR                                      42
# j_mv_I                                        43
# j_mv_II                                       44
# j_mv_III                                      45
# j_mv_V1                                       46
# j_mv_V2                                       47
# j_mv_V3                                       48
# j_mv_V4                                       49
# j_mv_V5                                       50
# j_mv_V6                                       51
# p_mv_aVF                                      52
# p_mv_aVL                                      53
# p_mv_I                                        54
# p_mv_II                                       55
# p_mv_III                                      56
# p_mv_V1                                       57
# p_mv_V2                                       58
# p_mv_V3                                       59
# p_mv_V4                                       60
# p_mv_V5                                       61
# p_mv_V6                                       62
# r_ms_aVF                                      63
# r_ms_aVL                                      64
# r_ms_aVR                                      65
# r_ms_I                                        66
# r_ms_II                                       67
# r_ms_III                                      68
# r_ms_V1                                       69
# r_ms_V2                                       70
# r_ms_V3                                       71
# r_ms_V4                                       72
# r_ms_V5                                       73
# r_ms_V6                                       74
# r_mv_aVF                                      75
# r_mv_aVL                                      76
# r_mv_aVR                                      77
# r_mv_I                                        78
# r_mv_II                                       79
# r_mv_III                                      80
# r_mv_V1                                       81
# r_mv_V2                                       82
# r_mv_V3                                       83
# r_mv_V4                                       84
# r_mv_V5                                       85
# r_mv_V6                                       86
# s_mv_aVF                                      87
# s_mv_aVL                                      88
# s_mv_aVR                                      89
# s_mv_I                                        90
# s_mv_II                                       91
# s_mv_III                                      92
# s_mv_V1                                       93
# s_mv_V2                                       94
# s_mv_V3                                       95
# s_mv_V4                                       96
# s_mv_V5                                       97
# s_mv_V6                                       98
# st_mv_aVF                                     99
# st_mv_aVL                                    100
# st_mv_aVR                                    101
# st_mv_I                                      102
# st_mv_II                                     103
# st_mv_III                                    104
# st_mv_V1                                     105
# st_mv_V2                                     106
# st_mv_V3                                     107
# st_mv_V4                                     108
# st_mv_V5                                     109
# st_mv_V6                                     110
# t_mv_aVF                                     111
# t_mv_aVL                                     112
# t_mv_aVR                                     113
# t_mv_I                                       114
# t_mv_II                                      115
# t_mv_III                                     116
# t_mv_V1                                      117
# t_mv_V2                                      118
# t_mv_V3                                      119
# t_mv_V4                                      120
# t_mv_V5                                      121
# t_mv_V6                                      122
# non_confirmed_diagnosis                      123
# qrs                                          124
# st_t                                         125
# MDC_ECG_LEAD_I__stationarity_check           126
# MDC_ECG_LEAD_II__stationarity_check          127
# MDC_ECG_LEAD_III__stationarity_check         128
# MDC_ECG_LEAD_aVR__stationarity_check         129
# MDC_ECG_LEAD_aVL__stationarity_check         130
# MDC_ECG_LEAD_aVF__stationarity_check         131
# MDC_ECG_LEAD_V1__stationarity_check          132
# MDC_ECG_LEAD_V2__stationarity_check          133
# MDC_ECG_LEAD_V3__stationarity_check          134
# MDC_ECG_LEAD_V4__stationarity_check          135
# MDC_ECG_LEAD_V5__stationarity_check          136
# MDC_ECG_LEAD_V6__heart_rate_check            137
# MDC_ECG_LEAD_I__heart_rate_check             138
# MDC_ECG_LEAD_II__heart_rate_check            139
# MDC_ECG_LEAD_III__heart_rate_check           140
# MDC_ECG_LEAD_aVR__heart_rate_check           141
# MDC_ECG_LEAD_aVL__heart_rate_check           142
# MDC_ECG_LEAD_aVF__heart_rate_check           143
# MDC_ECG_LEAD_V1__heart_rate_check            144
# MDC_ECG_LEAD_V2__heart_rate_check            145
# MDC_ECG_LEAD_V3__heart_rate_check            146
# MDC_ECG_LEAD_V4__heart_rate_check            147
# MDC_ECG_LEAD_V5__heart_rate_check            148
# MDC_ECG_LEAD_V6__heart_rate_check            149
# MDC_ECG_LEAD_I__SNR_check                    150
# MDC_ECG_LEAD_II__SNR_check                   151
# MDC_ECG_LEAD_III__SNR_check                  152
# MDC_ECG_LEAD_aVR__SNR_check                  153
# MDC_ECG_LEAD_aVL__SNR_check                  154
# MDC_ECG_LEAD_aVF__SNR_check                  155
# MDC_ECG_LEAD_V1__SNR_check                   156
# MDC_ECG_LEAD_V2__SNR_check                   157
# MDC_ECG_LEAD_V3__SNR_check                   158
# MDC_ECG_LEAD_V4__SNR_check                   159
# MDC_ECG_LEAD_V5__SNR_check                   160
# MDC_ECG_LEAD_V6__SNR_check                   161
# MDC_ECG_LEAD_I__SNR                          162
# MDC_ECG_LEAD_II__SNR                         163
# MDC_ECG_LEAD_III__SNR                        164
# MDC_ECG_LEAD_aVR__SNR                        165
# MDC_ECG_LEAD_aVL__SNR                        166
# MDC_ECG_LEAD_aVF__SNR                        167
# MDC_ECG_LEAD_V1__SNR                         168
# MDC_ECG_LEAD_V2__SNR                         169
# MDC_ECG_LEAD_V3__SNR                         170
# MDC_ECG_LEAD_V4__SNR                         171
# MDC_ECG_LEAD_V5__SNR                         172
# MDC_ECG_LEAD_V6__SNR                         173
# MDC_ECG_LEAD_I__ecg_quality                  174
# MDC_ECG_LEAD_II__ecg_quality                 175
# MDC_ECG_LEAD_III__ecg_quality                176
# MDC_ECG_LEAD_aVR__ecg_quality                177
# MDC_ECG_LEAD_aVL__ecg_quality                178
# MDC_ECG_LEAD_aVF__ecg_quality                179
# MDC_ECG_LEAD_V1__ecg_quality                 180
# MDC_ECG_LEAD_V2__ecg_quality                 181
# MDC_ECG_LEAD_V3__ecg_quality                 182
# MDC_ECG_LEAD_V4__ecg_quality                 183
# MDC_ECG_LEAD_V5__ecg_quality                 184
# MDC_ECG_LEAD_V6__ecg_quality                 185
#
#                                                                    field_string  \
# tabular_field_name
# collection_date                                    Collection date (YYYY-MM-DD)
# timezone                                                               Timezone
# collection_timestamp                                       Collection timestamp
# MDC_ECG_LEAD_I                                                       ECG lead I
# MDC_ECG_LEAD_II                                                     ECG lead II
# MDC_ECG_LEAD_III                                                   ECG lead III
# MDC_ECG_LEAD_aVR                                                   ECG lead aVR
# MDC_ECG_LEAD_aVL                                                   ECG lead aVL
# MDC_ECG_LEAD_aVF                                                   ECG lead aVF
# MDC_ECG_LEAD_V1                                                     ECG lead V1
# MDC_ECG_LEAD_V2                                                     ECG lead V2
# MDC_ECG_LEAD_V3                                                     ECG lead V3
# MDC_ECG_LEAD_V4                                                     ECG lead V4
# MDC_ECG_LEAD_V5                                                     ECG lead V5
# MDC_ECG_LEAD_V6                                                     ECG lead V6
# MDC_ECG_LEAD_I_clean                                                 ECG lead I
# MDC_ECG_LEAD_II_clean                                               ECG lead II
# MDC_ECG_LEAD_III_clean                                             ECG lead III
# MDC_ECG_LEAD_aVR_clean                                             ECG lead aVR
# MDC_ECG_LEAD_aVL_clean                                             ECG lead aVL
# MDC_ECG_LEAD_aVF_clean                                             ECG lead aVF
# MDC_ECG_LEAD_V1_clean                                               ECG lead V1
# MDC_ECG_LEAD_V2_clean                                               ECG lead V2
# MDC_ECG_LEAD_V3_clean                                               ECG lead V3
# MDC_ECG_LEAD_V4_clean                                               ECG lead V4
# MDC_ECG_LEAD_V5_clean                                               ECG lead V5
# MDC_ECG_LEAD_V6_clean                                               ECG lead V6
# raw_ecg_time_series                              Raw ECG times series file path
# processed_ecg_time_series                  Processed ECG times series file path
# hr_bpm                                                               Heart rate
# p_ms                                                           P wave duration
# pr_ms                                                               PR interval
# qrs_ms                                                             QRS duration
# qt_ms                                                               QT interval
# qtc_ms                                                             QTc interval
# conclusion                                     ECG machine generated conclusion
# p_axis                                                                   P axis
# t_axis                                                                   T axis
# qrs_axis                                                               QRS axis
# r_r_ms                                                              RR interval
# j_mv_aVF                                         Amplitude of J wave (aVF lead)
# j_mv_aVL                                         Amplitude of J wave (aVL lead)
# j_mv_aVR                                         Amplitude of J wave (aVR lead)
# j_mv_I                                             Amplitude of J wave (I lead)
# j_mv_II                                           Amplitude of J wave (II lead)
# j_mv_III                                         Amplitude of J wave (III lead)
# j_mv_V1                                           Amplitude of J wave (V1 lead)
# j_mv_V2                                           Amplitude of J wave (V2 lead)
# j_mv_V3                                           Amplitude of J wave (V3 lead)
# j_mv_V4                                           Amplitude of J wave (V4 lead)
# j_mv_V5                                           Amplitude of J wave (V5 lead)
# j_mv_V6                                           Amplitude of J wave (V6 lead)
# p_mv_aVF                                         Amplitude of P wave (aVF lead)
# p_mv_aVL                                         Amplitude of P wave (aVL lead)
# p_mv_I                                             Amplitude of P wave (I lead)
# p_mv_II                                           Amplitude of P wave (II lead)
# p_mv_III                                         Amplitude of P wave (III lead)
# p_mv_V1                                           Amplitude of P wave (V1 lead)
# p_mv_V2                                           Amplitude of P wave (V2 lead)
# p_mv_V3                                           Amplitude of P wave (V3 lead)
# p_mv_V4                                           Amplitude of P wave (V4 lead)
# p_mv_V5                                           Amplitude of P wave (V5 lead)
# p_mv_V6                                           Amplitude of P wave (V6 lead)
# r_ms_aVF                                             R wave duration (aVF lead)
# r_ms_aVL                                             R wave duration (aVL lead)
# r_ms_aVR                                             R wave duration (aVR lead)
# r_ms_I                                                 R wave duration (I lead)
# r_ms_II                                               R wave duration (II lead)
# r_ms_III                                             R wave duration (III lead)
# r_ms_V1                                               R wave duration (V1 lead)
# r_ms_V2                                               R wave duration (V2 lead)
# r_ms_V3                                               R wave duration (V3 lead)
# r_ms_V4                                               R wave duration (V4 lead)
# r_ms_V5                                               R wave duration (V5 lead)
# r_ms_V6                                               R wave duration (V6 lead)
# r_mv_aVF                                         Amplitude of R wave (aVF lead)
# r_mv_aVL                                         Amplitude of R wave (aVL lead)
# r_mv_aVR                                         Amplitude of R wave (aVR lead)
# r_mv_I                                             Amplitude of R wave (I lead)
# r_mv_II                                           Amplitude of R wave (II lead)
# r_mv_III                                         Amplitude of R wave (III lead)
# r_mv_V1                                           Amplitude of R wave (V1 lead)
# r_mv_V2                                           Amplitude of R wave (V2 lead)
# r_mv_V3                                           Amplitude of R wave (V3 lead)
# r_mv_V4                                           Amplitude of R wave (V4 lead)
# r_mv_V5                                           Amplitude of R wave (V5 lead)
# r_mv_V6                                           Amplitude of R wave (V6 lead)
# s_mv_aVF                                         Amplitude of S wave (aVF lead)
# s_mv_aVL                                         Amplitude of S wave (aVL lead)
# s_mv_aVR                                         Amplitude of S wave (aVR lead)
# s_mv_I                                             Amplitude of S wave (I lead)
# s_mv_II                                           Amplitude of S wave (II lead)
# s_mv_III                                         Amplitude of S wave (III lead)
# s_mv_V1                                           Amplitude of S wave (V1 lead)
# s_mv_V2                                           Amplitude of S wave (V2 lead)
# s_mv_V3                                           Amplitude of S wave (V3 lead)
# s_mv_V4                                           Amplitude of S wave (V4 lead)
# s_mv_V5                                           Amplitude of S wave (V5 lead)
# s_mv_V6                                           Amplitude of S wave (V6 lead)
# st_mv_aVF                                               ST elevation (aVF lead)
# st_mv_aVL                                               ST elevation (aVL lead)
# st_mv_aVR                                               ST elevation (aVR lead)
# st_mv_I                                                   ST elevation (I lead)
# st_mv_II                                                 ST elevation (II lead)
# st_mv_III                                               ST elevation (III lead)
# st_mv_V1                                                 ST elevation (V1 lead)
# st_mv_V2                                                 ST elevation (V2 lead)
# st_mv_V3                                                 ST elevation (V3 lead)
# st_mv_V4                                                 ST elevation (V4 lead)
# st_mv_V5                                                 ST elevation (V5 lead)
# st_mv_V6                                                 ST elevation (V6 lead)
# t_mv_aVF                                         Amplitude of T wave (aVF lead)
# t_mv_aVL                                         Amplitude of T wave (aVL lead)
# t_mv_aVR                                         Amplitude of T wave (aVR lead)
# t_mv_I                                             Amplitude of T wave (I lead)
# t_mv_II                                           Amplitude of T wave (II lead)
# t_mv_III                                         Amplitude of T wave (III lead)
# t_mv_V1                                           Amplitude of T wave (V1 lead)
# t_mv_V2                                           Amplitude of T wave (V2 lead)
# t_mv_V3                                           Amplitude of T wave (V3 lead)
# t_mv_V4                                           Amplitude of T wave (V4 lead)
# t_mv_V5                                           Amplitude of T wave (V5 lead)
# t_mv_V6                                           Amplitude of T wave (V6 lead)
# non_confirmed_diagnosis                         ECG machine generated diagnosis
# qrs                                                             QRS information
# st_t                                                       ST segment diagnosis
# MDC_ECG_LEAD_I__stationarity_check        Stationarity check for specified lead
# MDC_ECG_LEAD_II__stationarity_check       Stationarity check for specified lead
# MDC_ECG_LEAD_III__stationarity_check      Stationarity check for specified lead
# MDC_ECG_LEAD_aVR__stationarity_check      Stationarity check for specified lead
# MDC_ECG_LEAD_aVL__stationarity_check      Stationarity check for specified lead
# MDC_ECG_LEAD_aVF__stationarity_check      Stationarity check for specified lead
# MDC_ECG_LEAD_V1__stationarity_check       Stationarity check for specified lead
# MDC_ECG_LEAD_V2__stationarity_check       Stationarity check for specified lead
# MDC_ECG_LEAD_V3__stationarity_check       Stationarity check for specified lead
# MDC_ECG_LEAD_V4__stationarity_check       Stationarity check for specified lead
# MDC_ECG_LEAD_V5__stationarity_check       Stationarity check for specified lead
# MDC_ECG_LEAD_V6__heart_rate_check           Heart rate check for specified lead
# MDC_ECG_LEAD_I__heart_rate_check            Heart rate check for specified lead
# MDC_ECG_LEAD_II__heart_rate_check           Heart rate check for specified lead
# MDC_ECG_LEAD_III__heart_rate_check          Heart rate check for specified lead
# MDC_ECG_LEAD_aVR__heart_rate_check          Heart rate check for specified lead
# MDC_ECG_LEAD_aVL__heart_rate_check          Heart rate check for specified lead
# MDC_ECG_LEAD_aVF__heart_rate_check          Heart rate check for specified lead
# MDC_ECG_LEAD_V1__heart_rate_check           Heart rate check for specified lead
# MDC_ECG_LEAD_V2__heart_rate_check           Heart rate check for specified lead
# MDC_ECG_LEAD_V3__heart_rate_check           Heart rate check for specified lead
# MDC_ECG_LEAD_V4__heart_rate_check           Heart rate check for specified lead
# MDC_ECG_LEAD_V5__heart_rate_check           Heart rate check for specified lead
# MDC_ECG_LEAD_V6__heart_rate_check           Heart rate check for specified lead
# MDC_ECG_LEAD_I__SNR_check                          SNR check for specified lead
# MDC_ECG_LEAD_II__SNR_check                         SNR check for specified lead
# MDC_ECG_LEAD_III__SNR_check                        SNR check for specified lead
# MDC_ECG_LEAD_aVR__SNR_check                        SNR check for specified lead
# MDC_ECG_LEAD_aVL__SNR_check                        SNR check for specified lead
# MDC_ECG_LEAD_aVF__SNR_check                        SNR check for specified lead
# MDC_ECG_LEAD_V1__SNR_check                         SNR check for specified lead
# MDC_ECG_LEAD_V2__SNR_check                         SNR check for specified lead
# MDC_ECG_LEAD_V3__SNR_check                         SNR check for specified lead
# MDC_ECG_LEAD_V4__SNR_check                         SNR check for specified lead
# MDC_ECG_LEAD_V5__SNR_check                         SNR check for specified lead
# MDC_ECG_LEAD_V6__SNR_check                         SNR check for specified lead
# MDC_ECG_LEAD_I__SNR                    Signal to noise ratio for specified lead
# MDC_ECG_LEAD_II__SNR                   Signal to noise ratio for specified lead
# MDC_ECG_LEAD_III__SNR                  Signal to noise ratio for specified lead
# MDC_ECG_LEAD_aVR__SNR                  Signal to noise ratio for specified lead
# MDC_ECG_LEAD_aVL__SNR                  Signal to noise ratio for specified lead
# MDC_ECG_LEAD_aVF__SNR                  Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V1__SNR                   Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V2__SNR                   Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V3__SNR                   Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V4__SNR                   Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V5__SNR                   Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V6__SNR                   Signal to noise ratio for specified lead
# MDC_ECG_LEAD_I__ecg_quality           Neurokit quality score for specified lead
# MDC_ECG_LEAD_II__ecg_quality          Neurokit quality score for specified lead
# MDC_ECG_LEAD_III__ecg_quality         Neurokit quality score for specified lead
# MDC_ECG_LEAD_aVR__ecg_quality         Neurokit quality score for specified lead
# MDC_ECG_LEAD_aVL__ecg_quality         Neurokit quality score for specified lead
# MDC_ECG_LEAD_aVF__ecg_quality         Neurokit quality score for specified lead
# MDC_ECG_LEAD_V1__ecg_quality          Neurokit quality score for specified lead
# MDC_ECG_LEAD_V2__ecg_quality          Neurokit quality score for specified lead
# MDC_ECG_LEAD_V3__ecg_quality          Neurokit quality score for specified lead
# MDC_ECG_LEAD_V4__ecg_quality          Neurokit quality score for specified lead
# MDC_ECG_LEAD_V5__ecg_quality          Neurokit quality score for specified lead
# MDC_ECG_LEAD_V6__ecg_quality          Neurokit quality score for specified lead
#
#                                                              description_string  \
# tabular_field_name
# collection_date                                    Collection date (YYYY-MM-DD)
# timezone                                         Timezone for timestamp columns
# collection_timestamp                                       Collection timestamp
# MDC_ECG_LEAD_I                               Raw ECG signal for specificed lead
# MDC_ECG_LEAD_II                              Raw ECG signal for specificed lead
# MDC_ECG_LEAD_III                             Raw ECG signal for specificed lead
# MDC_ECG_LEAD_aVR                             Raw ECG signal for specificed lead
# MDC_ECG_LEAD_aVL                             Raw ECG signal for specificed lead
# MDC_ECG_LEAD_aVF                             Raw ECG signal for specificed lead
# MDC_ECG_LEAD_V1                              Raw ECG signal for specificed lead
# MDC_ECG_LEAD_V2                              Raw ECG signal for specificed lead
# MDC_ECG_LEAD_V3                              Raw ECG signal for specificed lead
# MDC_ECG_LEAD_V4                              Raw ECG signal for specificed lead
# MDC_ECG_LEAD_V5                              Raw ECG signal for specificed lead
# MDC_ECG_LEAD_V6                              Raw ECG signal for specificed lead
# MDC_ECG_LEAD_I_clean                        Clean ECG signal for specified lead
# MDC_ECG_LEAD_II_clean                       Clean ECG signal for specified lead
# MDC_ECG_LEAD_III_clean                      Clean ECG signal for specified lead
# MDC_ECG_LEAD_aVR_clean                      Clean ECG signal for specified lead
# MDC_ECG_LEAD_aVL_clean                      Clean ECG signal for specified lead
# MDC_ECG_LEAD_aVF_clean                      Clean ECG signal for specified lead
# MDC_ECG_LEAD_V1_clean                       Clean ECG signal for specified lead
# MDC_ECG_LEAD_V2_clean                       Clean ECG signal for specified lead
# MDC_ECG_LEAD_V3_clean                       Clean ECG signal for specified lead
# MDC_ECG_LEAD_V4_clean                       Clean ECG signal for specified lead
# MDC_ECG_LEAD_V5_clean                       Clean ECG signal for specified lead
# MDC_ECG_LEAD_V6_clean                       Clean ECG signal for specified lead
# raw_ecg_time_series                         S3 reference to raw ECG time series
# processed_ecg_time_series             S3 reference to processed ECG time series
# hr_bpm                                                                      NaN
# p_ms                                                                        NaN
# pr_ms                                                                       NaN
# qrs_ms                                                                      NaN
# qt_ms                                                                       NaN
# qtc_ms                                                                      NaN
# conclusion                                                                  NaN
# p_axis                                                                      NaN
# t_axis                                                                      NaN
# qrs_axis                                                                    NaN
# r_r_ms                                                                      NaN
# j_mv_aVF                                                                    NaN
# j_mv_aVL                                                                    NaN
# j_mv_aVR                                                                    NaN
# j_mv_I                                                                      NaN
# j_mv_II                                                                     NaN
# j_mv_III                                                                    NaN
# j_mv_V1                                                                     NaN
# j_mv_V2                                                                     NaN
# j_mv_V3                                                                     NaN
# j_mv_V4                                                                     NaN
# j_mv_V5                                                                     NaN
# j_mv_V6                                                                     NaN
# p_mv_aVF                                                                    NaN
# p_mv_aVL                                                                    NaN
# p_mv_I                                                                      NaN
# p_mv_II                                                                     NaN
# p_mv_III                                                                    NaN
# p_mv_V1                                                                     NaN
# p_mv_V2                                                                     NaN
# p_mv_V3                                                                     NaN
# p_mv_V4                                                                     NaN
# p_mv_V5                                                                     NaN
# p_mv_V6                                                                     NaN
# r_ms_aVF                                                                    NaN
# r_ms_aVL                                                                    NaN
# r_ms_aVR                                                                    NaN
# r_ms_I                                                                      NaN
# r_ms_II                                                                     NaN
# r_ms_III                                                                    NaN
# r_ms_V1                                                                     NaN
# r_ms_V2                                                                     NaN
# r_ms_V3                                                                     NaN
# r_ms_V4                                                                     NaN
# r_ms_V5                                                                     NaN
# r_ms_V6                                                                     NaN
# r_mv_aVF                                                                    NaN
# r_mv_aVL                                                                    NaN
# r_mv_aVR                                                                    NaN
# r_mv_I                                                                      NaN
# r_mv_II                                                                     NaN
# r_mv_III                                                                    NaN
# r_mv_V1                                                                     NaN
# r_mv_V2                                                                     NaN
# r_mv_V3                                                                     NaN
# r_mv_V4                                                                     NaN
# r_mv_V5                                                                     NaN
# r_mv_V6                                                                     NaN
# s_mv_aVF                                                                    NaN
# s_mv_aVL                                                                    NaN
# s_mv_aVR                                                                    NaN
# s_mv_I                                                                      NaN
# s_mv_II                                                                     NaN
# s_mv_III                                                                    NaN
# s_mv_V1                                                                     NaN
# s_mv_V2                                                                     NaN
# s_mv_V3                                                                     NaN
# s_mv_V4                                                                     NaN
# s_mv_V5                                                                     NaN
# s_mv_V6                                                                     NaN
# st_mv_aVF                                                                   NaN
# st_mv_aVL                                                                   NaN
# st_mv_aVR                                                                   NaN
# st_mv_I                                                                     NaN
# st_mv_II                                                                    NaN
# st_mv_III                                                                   NaN
# st_mv_V1                                                                    NaN
# st_mv_V2                                                                    NaN
# st_mv_V3                                                                    NaN
# st_mv_V4                                                                    NaN
# st_mv_V5                                                                    NaN
# st_mv_V6                                                                    NaN
# t_mv_aVF                                                                    NaN
# t_mv_aVL                                                                    NaN
# t_mv_aVR                                                                    NaN
# t_mv_I                                                                      NaN
# t_mv_II                                                                     NaN
# t_mv_III                                                                    NaN
# t_mv_V1                                                                     NaN
# t_mv_V2                                                                     NaN
# t_mv_V3                                                                     NaN
# t_mv_V4                                                                     NaN
# t_mv_V5                                                                     NaN
# t_mv_V6                                                                     NaN
# non_confirmed_diagnosis                                                     NaN
# qrs                                                             QRS information
# st_t                                                                        NaN
# MDC_ECG_LEAD_I__stationarity_check        Stationarity check for specified lead
# MDC_ECG_LEAD_II__stationarity_check       Stationarity check for specified lead
# MDC_ECG_LEAD_III__stationarity_check      Stationarity check for specified lead
# MDC_ECG_LEAD_aVR__stationarity_check      Stationarity check for specified lead
# MDC_ECG_LEAD_aVL__stationarity_check      Stationarity check for specified lead
# MDC_ECG_LEAD_aVF__stationarity_check      Stationarity check for specified lead
# MDC_ECG_LEAD_V1__stationarity_check       Stationarity check for specified lead
# MDC_ECG_LEAD_V2__stationarity_check       Stationarity check for specified lead
# MDC_ECG_LEAD_V3__stationarity_check       Stationarity check for specified lead
# MDC_ECG_LEAD_V4__stationarity_check       Stationarity check for specified lead
# MDC_ECG_LEAD_V5__stationarity_check       Stationarity check for specified lead
# MDC_ECG_LEAD_V6__heart_rate_check           Heart rate check for specified lead
# MDC_ECG_LEAD_I__heart_rate_check            Heart rate check for specified lead
# MDC_ECG_LEAD_II__heart_rate_check           Heart rate check for specified lead
# MDC_ECG_LEAD_III__heart_rate_check          Heart rate check for specified lead
# MDC_ECG_LEAD_aVR__heart_rate_check          Heart rate check for specified lead
# MDC_ECG_LEAD_aVL__heart_rate_check          Heart rate check for specified lead
# MDC_ECG_LEAD_aVF__heart_rate_check          Heart rate check for specified lead
# MDC_ECG_LEAD_V1__heart_rate_check           Heart rate check for specified lead
# MDC_ECG_LEAD_V2__heart_rate_check           Heart rate check for specified lead
# MDC_ECG_LEAD_V3__heart_rate_check           Heart rate check for specified lead
# MDC_ECG_LEAD_V4__heart_rate_check           Heart rate check for specified lead
# MDC_ECG_LEAD_V5__heart_rate_check           Heart rate check for specified lead
# MDC_ECG_LEAD_V6__heart_rate_check           Heart rate check for specified lead
# MDC_ECG_LEAD_I__SNR_check                          SNR check for specified lead
# MDC_ECG_LEAD_II__SNR_check                         SNR check for specified lead
# MDC_ECG_LEAD_III__SNR_check                        SNR check for specified lead
# MDC_ECG_LEAD_aVR__SNR_check                        SNR check for specified lead
# MDC_ECG_LEAD_aVL__SNR_check                        SNR check for specified lead
# MDC_ECG_LEAD_aVF__SNR_check                        SNR check for specified lead
# MDC_ECG_LEAD_V1__SNR_check                         SNR check for specified lead
# MDC_ECG_LEAD_V2__SNR_check                         SNR check for specified lead
# MDC_ECG_LEAD_V3__SNR_check                         SNR check for specified lead
# MDC_ECG_LEAD_V4__SNR_check                         SNR check for specified lead
# MDC_ECG_LEAD_V5__SNR_check                         SNR check for specified lead
# MDC_ECG_LEAD_V6__SNR_check                         SNR check for specified lead
# MDC_ECG_LEAD_I__SNR                    Signal to noise ratio for specified lead
# MDC_ECG_LEAD_II__SNR                   Signal to noise ratio for specified lead
# MDC_ECG_LEAD_III__SNR                  Signal to noise ratio for specified lead
# MDC_ECG_LEAD_aVR__SNR                  Signal to noise ratio for specified lead
# MDC_ECG_LEAD_aVL__SNR                  Signal to noise ratio for specified lead
# MDC_ECG_LEAD_aVF__SNR                  Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V1__SNR                   Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V2__SNR                   Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V3__SNR                   Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V4__SNR                   Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V5__SNR                   Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V6__SNR                   Signal to noise ratio for specified lead
# MDC_ECG_LEAD_I__ecg_quality           Neurokit quality score for specified lead
# MDC_ECG_LEAD_II__ecg_quality          Neurokit quality score for specified lead
# MDC_ECG_LEAD_III__ecg_quality         Neurokit quality score for specified lead
# MDC_ECG_LEAD_aVR__ecg_quality         Neurokit quality score for specified lead
# MDC_ECG_LEAD_aVL__ecg_quality         Neurokit quality score for specified lead
# MDC_ECG_LEAD_aVF__ecg_quality         Neurokit quality score for specified lead
# MDC_ECG_LEAD_V1__ecg_quality          Neurokit quality score for specified lead
# MDC_ECG_LEAD_V2__ecg_quality          Neurokit quality score for specified lead
# MDC_ECG_LEAD_V3__ecg_quality          Neurokit quality score for specified lead
# MDC_ECG_LEAD_V4__ecg_quality          Neurokit quality score for specified lead
# MDC_ECG_LEAD_V5__ecg_quality          Neurokit quality score for specified lead
# MDC_ECG_LEAD_V6__ecg_quality          Neurokit quality score for specified lead
#
#                                                parent_dataframe  \
# tabular_field_name
# collection_date                                             NaN
# timezone                                                    NaN
# collection_timestamp                                        NaN
# MDC_ECG_LEAD_I                              raw_ecg_time_series
# MDC_ECG_LEAD_II                             raw_ecg_time_series
# MDC_ECG_LEAD_III                            raw_ecg_time_series
# MDC_ECG_LEAD_aVR                            raw_ecg_time_series
# MDC_ECG_LEAD_aVL                            raw_ecg_time_series
# MDC_ECG_LEAD_aVF                            raw_ecg_time_series
# MDC_ECG_LEAD_V1                             raw_ecg_time_series
# MDC_ECG_LEAD_V2                             raw_ecg_time_series
# MDC_ECG_LEAD_V3                             raw_ecg_time_series
# MDC_ECG_LEAD_V4                             raw_ecg_time_series
# MDC_ECG_LEAD_V5                             raw_ecg_time_series
# MDC_ECG_LEAD_V6                             raw_ecg_time_series
# MDC_ECG_LEAD_I_clean                  processed_ecg_time_series
# MDC_ECG_LEAD_II_clean                 processed_ecg_time_series
# MDC_ECG_LEAD_III_clean                processed_ecg_time_series
# MDC_ECG_LEAD_aVR_clean                processed_ecg_time_series
# MDC_ECG_LEAD_aVL_clean                processed_ecg_time_series
# MDC_ECG_LEAD_aVF_clean                processed_ecg_time_series
# MDC_ECG_LEAD_V1_clean                 processed_ecg_time_series
# MDC_ECG_LEAD_V2_clean                 processed_ecg_time_series
# MDC_ECG_LEAD_V3_clean                 processed_ecg_time_series
# MDC_ECG_LEAD_V4_clean                 processed_ecg_time_series
# MDC_ECG_LEAD_V5_clean                 processed_ecg_time_series
# MDC_ECG_LEAD_V6_clean                 processed_ecg_time_series
# raw_ecg_time_series                                         NaN
# processed_ecg_time_series                                   NaN
# hr_bpm                                                      NaN
# p_ms                                                        NaN
# pr_ms                                                       NaN
# qrs_ms                                                      NaN
# qt_ms                                                       NaN
# qtc_ms                                                      NaN
# conclusion                                                  NaN
# p_axis                                                      NaN
# t_axis                                                      NaN
# qrs_axis                                                    NaN
# r_r_ms                                                      NaN
# j_mv_aVF                                                    NaN
# j_mv_aVL                                                    NaN
# j_mv_aVR                                                    NaN
# j_mv_I                                                      NaN
# j_mv_II                                                     NaN
# j_mv_III                                                    NaN
# j_mv_V1                                                     NaN
# j_mv_V2                                                     NaN
# j_mv_V3                                                     NaN
# j_mv_V4                                                     NaN
# j_mv_V5                                                     NaN
# j_mv_V6                                                     NaN
# p_mv_aVF                                                    NaN
# p_mv_aVL                                                    NaN
# p_mv_I                                                      NaN
# p_mv_II                                                     NaN
# p_mv_III                                                    NaN
# p_mv_V1                                                     NaN
# p_mv_V2                                                     NaN
# p_mv_V3                                                     NaN
# p_mv_V4                                                     NaN
# p_mv_V5                                                     NaN
# p_mv_V6                                                     NaN
# r_ms_aVF                                                    NaN
# r_ms_aVL                                                    NaN
# r_ms_aVR                                                    NaN
# r_ms_I                                                      NaN
# r_ms_II                                                     NaN
# r_ms_III                                                    NaN
# r_ms_V1                                                     NaN
# r_ms_V2                                                     NaN
# r_ms_V3                                                     NaN
# r_ms_V4                                                     NaN
# r_ms_V5                                                     NaN
# r_ms_V6                                                     NaN
# r_mv_aVF                                                    NaN
# r_mv_aVL                                                    NaN
# r_mv_aVR                                                    NaN
# r_mv_I                                                      NaN
# r_mv_II                                                     NaN
# r_mv_III                                                    NaN
# r_mv_V1                                                     NaN
# r_mv_V2                                                     NaN
# r_mv_V3                                                     NaN
# r_mv_V4                                                     NaN
# r_mv_V5                                                     NaN
# r_mv_V6                                                     NaN
# s_mv_aVF                                                    NaN
# s_mv_aVL                                                    NaN
# s_mv_aVR                                                    NaN
# s_mv_I                                                      NaN
# s_mv_II                                                     NaN
# s_mv_III                                                    NaN
# s_mv_V1                                                     NaN
# s_mv_V2                                                     NaN
# s_mv_V3                                                     NaN
# s_mv_V4                                                     NaN
# s_mv_V5                                                     NaN
# s_mv_V6                                                     NaN
# st_mv_aVF                                                   NaN
# st_mv_aVL                                                   NaN
# st_mv_aVR                                                   NaN
# ...
# MDC_ECG_LEAD_aVL__SNR_check           Single     10K      Tabular  2019-09-10
# MDC_ECG_LEAD_aVF__SNR_check           Single     10K      Tabular  2019-09-11
# MDC_ECG_LEAD_V1__SNR_check            Single     10K      Tabular  2019-09-12
# MDC_ECG_LEAD_V2__SNR_check            Single     10K      Tabular  2019-09-13
# MDC_ECG_LEAD_V3__SNR_check            Single     10K      Tabular  2019-09-14
# MDC_ECG_LEAD_V4__SNR_check            Single     10K      Tabular  2019-09-15
# MDC_ECG_LEAD_V5__SNR_check            Single     10K      Tabular  2019-09-16
# MDC_ECG_LEAD_V6__SNR_check            Single     10K      Tabular  2019-09-17
# MDC_ECG_LEAD_I__SNR                   Single     10K      Tabular  2019-09-18
# MDC_ECG_LEAD_II__SNR                  Single     10K      Tabular  2019-09-19
# MDC_ECG_LEAD_III__SNR                 Single     10K      Tabular  2019-09-20
# MDC_ECG_LEAD_aVR__SNR                 Single     10K      Tabular  2019-09-21
# MDC_ECG_LEAD_aVL__SNR                 Single     10K      Tabular  2019-09-22
# MDC_ECG_LEAD_aVF__SNR                 Single     10K      Tabular  2019-09-23
# MDC_ECG_LEAD_V1__SNR                  Single     10K      Tabular  2019-09-24
# MDC_ECG_LEAD_V2__SNR                  Single     10K      Tabular  2019-09-25
# MDC_ECG_LEAD_V3__SNR                  Single     10K      Tabular  2019-09-26
# MDC_ECG_LEAD_V4__SNR                  Single     10K      Tabular  2019-09-27
# MDC_ECG_LEAD_V5__SNR                  Single     10K      Tabular  2019-09-28
# MDC_ECG_LEAD_V6__SNR                  Single     10K      Tabular  2019-09-29
# MDC_ECG_LEAD_I__ecg_quality           Single     10K      Tabular  2019-09-30
# MDC_ECG_LEAD_II__ecg_quality          Single     10K      Tabular  2019-10-01
# MDC_ECG_LEAD_III__ecg_quality         Single     10K      Tabular  2019-10-02
# MDC_ECG_LEAD_aVR__ecg_quality         Single     10K      Tabular  2019-10-03
# MDC_ECG_LEAD_aVL__ecg_quality         Single     10K      Tabular  2019-10-04
# MDC_ECG_LEAD_aVF__ecg_quality         Single     10K      Tabular  2019-10-05
# MDC_ECG_LEAD_V1__ecg_quality          Single     10K      Tabular  2019-10-06
# MDC_ECG_LEAD_V2__ecg_quality          Single     10K      Tabular  2019-10-07
# MDC_ECG_LEAD_V3__ecg_quality          Single     10K      Tabular  2019-10-08
# MDC_ECG_LEAD_V4__ecg_quality          Single     10K      Tabular  2019-10-09
# MDC_ECG_LEAD_V5__ecg_quality          Single     10K      Tabular  2019-10-10
# MDC_ECG_LEAD_V6__ecg_quality          Single     10K      Tabular  2019-10-11
#
#                                                         pandas_dtype
# tabular_field_name
# collection_date                                       datetime64[ns]
# timezone                                                      string
# collection_timestamp                  datetime64[ns, Asia/Jerusalem]
# MDC_ECG_LEAD_I                                                 int64
# MDC_ECG_LEAD_II                                                int64
# MDC_ECG_LEAD_III                                               int64
# MDC_ECG_LEAD_aVR                                               int64
# MDC_ECG_LEAD_aVL                                               int64
# MDC_ECG_LEAD_aVF                                               int64
# MDC_ECG_LEAD_V1                                                int64
# MDC_ECG_LEAD_V2                                                int64
# MDC_ECG_LEAD_V3                                                int64
# MDC_ECG_LEAD_V4                                                int64
# MDC_ECG_LEAD_V5                                                int64
# MDC_ECG_LEAD_V6                                                int64
# MDC_ECG_LEAD_I_clean                                           int64
# MDC_ECG_LEAD_II_clean                                          int64
# MDC_ECG_LEAD_III_clean                                         int64
# MDC_ECG_LEAD_aVR_clean                                         int64
# MDC_ECG_LEAD_aVL_clean                                         int64
# MDC_ECG_LEAD_aVF_clean                                         int64
# MDC_ECG_LEAD_V1_clean                                          int64
# MDC_ECG_LEAD_V2_clean                                          int64
# MDC_ECG_LEAD_V3_clean                                          int64
# MDC_ECG_LEAD_V4_clean                                          int64
# MDC_ECG_LEAD_V5_clean                                          int64
# MDC_ECG_LEAD_V6_clean                                          int64
# raw_ecg_time_series                                           object
# processed_ecg_time_series                                     object
# hr_bpm                                                       float64
# p_ms                                                         float64
# pr_ms                                                        float64
# qrs_ms                                                       float64
# qt_ms                                                        float64
# qtc_ms                                                       float64
# conclusion                                                    string
# p_axis                                                       float64
# t_axis                                                       float64
# qrs_axis                                                     float64
# r_r_ms                                                       float64
# j_mv_aVF                                                     float64
# j_mv_aVL                                                     float64
# j_mv_aVR                                                     float64
# j_mv_I                                                       float64
# j_mv_II                                                      float64
# j_mv_III                                                     float64
# j_mv_V1                                                      float64
# j_mv_V2                                                      float64
# j_mv_V3                                                      float64
# j_mv_V4                                                      float64
# j_mv_V5                                                      float64
# j_mv_V6                                                      float64
# p_mv_aVF                                                     float64
# p_mv_aVL                                                     float64
# p_mv_I                                                       float64
# p_mv_II                                                      float64
# p_mv_III                                                     float64
# p_mv_V1                                                      float64
# p_mv_V2                                                      float64
# p_mv_V3                                                      float64
# p_mv_V4                                                      float64
# p_mv_V5                                                      float64
# p_mv_V6                                                      float64
# r_ms_aVF                                                     float64
# r_ms_aVL                                                     float64
# r_ms_aVR                                                     float64
# r_ms_I                                                       float64
# r_ms_II                                                      float64
# r_ms_III                                                     float64
# r_ms_V1                                                      float64
# r_ms_V2                                                      float64
# r_ms_V3                                                      float64
# r_ms_V4                                                      float64
# r_ms_V5                                                      float64
# r_ms_V6                                                      float64
# r_mv_aVF                                                     float64
# r_mv_aVL                                                     float64
# r_mv_aVR                                                     float64
# r_mv_I                                                       float64
# r_mv_II                                                      float64
# r_mv_III                                                     float64
# r_mv_V1                                                      float64
# r_mv_V2                                                      float64
# r_mv_V3                                                      float64
# r_mv_V4                                                      float64
# r_mv_V5                                                      float64
# r_mv_V6                                                      float64
# s_mv_aVF                                                     float64
# s_mv_aVL                                                     float64
# s_mv_aVR                                                     float64
# s_mv_I                                                       float64
# s_mv_II                                                      float64
# s_mv_III                                                     float64
# s_mv_V1                                                      float64
# s_mv_V2                                                      float64
# s_mv_V3                                                      float64
# s_mv_V4                                                      float64
# s_mv_V5                                                      float64
# s_mv_V6                                                      float64
# st_mv_aVF                                                    float64
# st_mv_aVL                                                    float64
# st_mv_aVR                                                    float64
# st_mv_I                                                      float64
# st_mv_II                                                     float64
# st_mv_III                                                    float64
# st_mv_V1                                                     float64
# st_mv_V2                                                     float64
# st_mv_V3                                                     float64
# st_mv_V4                                                     float64
# st_mv_V5                                                     float64
# st_mv_V6                                                     float64
# t_mv_aVF                                                     float64
# t_mv_aVL                                                     float64
# t_mv_aVR                                                     float64
# t_mv_I                                                       float64
# t_mv_II                                                      float64
# t_mv_III                                                     float64
# t_mv_V1                                                      float64
# t_mv_V2                                                      float64
# t_mv_V3                                                      float64
# t_mv_V4                                                      float64
# t_mv_V5                                                      float64
# t_mv_V6                                                      float64
# non_confirmed_diagnosis                                       string
# qrs                                                           string
# st_t                                                          string
# MDC_ECG_LEAD_I__stationarity_check                           float64
# MDC_ECG_LEAD_II__stationarity_check                          float64
# MDC_ECG_LEAD_III__stationarity_check                         float64
# MDC_ECG_LEAD_aVR__stationarity_check                         float64
# MDC_ECG_LEAD_aVL__stationarity_check                         float64
# MDC_ECG_LEAD_aVF__stationarity_check                         float64
# MDC_ECG_LEAD_V1__stationarity_check                          float64
# MDC_ECG_LEAD_V2__stationarity_check                          float64
# MDC_ECG_LEAD_V3__stationarity_check                          float64
# MDC_ECG_LEAD_V4__stationarity_check                          float64
# MDC_ECG_LEAD_V5__stationarity_check                          float64
# MDC_ECG_LEAD_V6__heart_rate_check                            float64
# MDC_ECG_LEAD_I__heart_rate_check                             float64
# MDC_ECG_LEAD_II__heart_rate_check                            float64
# MDC_ECG_LEAD_III__heart_rate_check                           float64
# MDC_ECG_LEAD_aVR__heart_rate_check                           float64
# MDC_ECG_LEAD_aVL__heart_rate_check                           float64
# MDC_ECG_LEAD_aVF__heart_rate_check                           float64
# MDC_ECG_LEAD_V1__heart_rate_check                            float64
# MDC_ECG_LEAD_V2__heart_rate_check                            float64
# MDC_ECG_LEAD_V3__heart_rate_check                            float64
# MDC_ECG_LEAD_V4__heart_rate_check                            float64
# MDC_ECG_LEAD_V5__heart_rate_check                            float64
# MDC_ECG_LEAD_V6__heart_rate_check                            float64
# MDC_ECG_LEAD_I__SNR_check                                    float64
# MDC_ECG_LEAD_II__SNR_check                                   float64
# MDC_ECG_LEAD_III__SNR_check                                  float64
# MDC_ECG_LEAD_aVR__SNR_check                                  float64
# MDC_ECG_LEAD_aVL__SNR_check                                  float64
# MDC_ECG_LEAD_aVF__SNR_check                                  float64
# MDC_ECG_LEAD_V1__SNR_check                                   float64
# MDC_ECG_LEAD_V2__SNR_check                                   float64
# MDC_ECG_LEAD_V3__SNR_check                                   float64
# MDC_ECG_LEAD_V4__SNR_check                                   float64
# MDC_ECG_LEAD_V5__SNR_check                                   float64
# MDC_ECG_LEAD_V6__SNR_check                                   float64
# MDC_ECG_LEAD_I__SNR                                          float64
# MDC_ECG_LEAD_II__SNR                                         float64
# MDC_ECG_LEAD_III__SNR                                        float64
# MDC_ECG_LEAD_aVR__SNR                                        float64
# MDC_ECG_LEAD_aVL__SNR                                        float64
# MDC_ECG_LEAD_aVF__SNR                                        float64
# MDC_ECG_LEAD_V1__SNR                                         float64
# MDC_ECG_LEAD_V2__SNR                                         float64
# MDC_ECG_LEAD_V3__SNR                                         float64
# MDC_ECG_LEAD_V4__SNR                                         float64
# MDC_ECG_LEAD_V5__SNR                                         float64
# MDC_ECG_LEAD_V6__SNR                                         float64
# MDC_ECG_LEAD_I__ecg_quality                                  float64
# MDC_ECG_LEAD_II__ecg_quality                                 float64
# MDC_ECG_LEAD_III__ecg_quality                                float64
# MDC_ECG_LEAD_aVR__ecg_quality                                float64
# MDC_ECG_LEAD_aVL__ecg_quality                                float64
# MDC_ECG_LEAD_aVF__ecg_quality                                float64
# MDC_ECG_LEAD_V1__ecg_quality                                 float64
# MDC_ECG_LEAD_V2__ecg_quality                                 float64
# MDC_ECG_LEAD_V3__ecg_quality                                 float64
# MDC_ECG_LEAD_V4__ecg_quality                                 float64
# MDC_ECG_LEAD_V5__ecg_quality                                 float64
# MDC_ECG_LEAD_V6__ecg_quality                                 float64
