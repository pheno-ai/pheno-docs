# %% [raw]
# ---
# output-file: 4-liver_ultrasound.html
# title: 4-liver_ultrasound
#
# ---

# %% [markdown]
# # 4 - liver ultrasound
#
# Liver ultrasound was performed using the Supersonic Aixplorer MACH 30 (Hologic, USA).  The Supersonic Imagine Aixplorer is an ultrasound device that is able to measure the liver's stiffness, viscosity, attenuation and sound speed to diagnose and monitor liver conditions such as steatosis, fibrosis and inflammation. The device uses several ultrasound-based measures, including Speed of Sound (SSp.PLUS), Attenuation Index (Att.PLUS), Viscosity (Vi.PLUS) and Elasticity (Two-Dimensional ShareWave Elastography (2D-SWE)) to evaluate the liver and improve diagnosis performance. These measurements have been shown to be correlated to different stages of liver conditions.
#
# Ultrasound-based liver measurements were performed using ShearWave Elastography (2D- SWE.PLUS) for elasticity assessment, sound speed Plane-wave ultrasound and attenuation. Plane-wave ultrasound was measured for assessment of liver steatosis (fatness) and viscosity plane-wave ultrasound for assessment of viscosity as a marker of inflammation. Measurements were performed with a C6-1X convex transducer using the UltraFast software available on the Mach 30 ultrasound system. US images of the liver were also saved.
#
# Measurement protocol: All patients were examined in supine position, with the right arm elevated above the head, by an intercostal approach, in the right liver lobe. Acquisitions were performed during neutral respiratory apnea. Initially the Attenuation and Speed of Sound were measured from a homogeneous area of the liver parenchyma free of vessels or other structures. Measurements were performed from 3 different liver regions. 2D-SWE and viscosity were then measured from 3 different locations in an area of relative uniform elasticity, at a depth of 3–5 cm using stability index tool (SI) derived from the spatial and temporal stiffness stability at a stability index >90%.
#
#
# The information is stored in 1 parquet file: `liver_us.parquet`

# %%
#| hide
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('liver_ultrasound', age_sex_dataset=None)
dl
# Out:
# DataLoader for liver_ultrasound with
# 56 fields
# 1 tables: ['liver_us']

# %%
dl.dict
# Out:
#                                                                                     field_string  \
# tabular_field_name
# timezone                                                                                Timezone
# collection_date                                                     Collection date (YYYY-MM-DD)
# collection_timestamp                                                        Collection timestamp
# liver_ultrasound_qbox_depth                                          Liver ultrasound qbox depth
# liver_ultrasound_qbox_diameter                                    Liver ultrasound qbox diameter
# liver_ultrasound_stability_index                                Liver ultrasound stability index
# elasticity_qbox_minimum                                                Elasticity (qbox minimum)
# elasticity_qbox_maximum                                                Elasticity (qbox maximum)
# elasticity_qbox_median                                                  Elasticity (qbox median)
# elasticity_qbox_standard_deviation                          Elasticity (qbox standard deviation)
# elasticity_qbox_mean                                                      Elasticity (qbox mean)
# elasticity_mean_minimum_of_qboxes                            Elasticity (mean minimum of qboxes)
# elasticity_mean_maximum_of_qboxes                            Elasticity (mean maximum of qboxes)
# elasticity_mean_median_of_qboxes                              Elasticity (mean median of qboxes)
# elasticity_mean_standard_deviation_of_qboxes      Elasticity (mean standard deviation of qboxes)
# elasticity_mean_mean_of_qboxes                                  Elasticity (mean mean of qboxes)
# elasticity_median_minimum_of_qboxes                        Elasticity (median minimum of qboxes)
# elasticity_median_maximum_of_qboxes                        Elasticity (median maximum of qboxes)
# elasticity_median_median_of_qboxes                          Elasticity (median median of qboxes)
# elasticity_median_standard_deviation_of_qboxes  Elasticity (median standard deviation of qboxes)
# elasticity_median_mean_of_qboxes                              Elasticity (median mean of qboxes)
# velocity_qbox_minimum                                                    Velocity (qbox minimum)
# velocity_qbox_maximum                                                    Velocity (qbox maximum)
# velocity_qbox_median                                                      Velocity (qbox median)
# velocity_qbox_standard_deviation                              Velocity (qbox standard deviation)
# velocity_qbox_mean                                                          Velocity (qbox mean)
# velocity_mean_minimum_of_qboxes                                Velocity (mean minimum of qboxes)
# velocity_mean_maximum_of_qboxes                                Velocity (mean maximum of qboxes)
# velocity_mean_median_of_qboxes                                  Velocity (mean median of qboxes)
# velocity_mean_standard_deviation_of_qboxes          Velocity (mean standard deviation of qboxes)
# velocity_mean_mean_of_qboxes                                      Velocity (mean mean of qboxes)
# velocity_median_minimum_of_qboxes                            Velocity (median minimum of qboxes)
# velocity_median_maximum_of_qboxes                            Velocity (median maximum of qboxes)
# velocity_median_median_of_qboxes                              Velocity (median median of qboxes)
# velocity_median_standard_deviation_of_qboxes      Velocity (median standard deviation of qboxes)
# velocity_median_mean_of_qboxes                                  Velocity (median mean of qboxes)
# viscosity_qbox_median                                                    Viscosity (qbox median)
# viscosity_qbox_standard_deviation                            Viscosity (qbox standard deviation)
# viscosity_qbox_mean                                                        Viscosity (qbox mean)
# viscosity_mean_median_of_qboxes                                Viscosity (mean median of qboxes)
# viscosity_mean_standard_deviation_of_qboxes        Viscosity (mean standard deviation of qboxes)
# viscosity_mean_mean_of_qboxes                                    Viscosity (mean mean of qboxes)
# viscosity_median_median_of_qboxes                            Viscosity (median median of qboxes)
# viscosity_median_standard_deviation_of_qboxes    Viscosity (median standard deviation of qboxes)
# viscosity_median_mean_of_median                                Viscosity (median mean of median)
# dispersion_qbox_median                                                  Dispersion (qbox median)
# dispersion_qbox_standard_deviation                          Dispersion (qbox standard deviation)
# dispersion_qbox_mean                                                      Dispersion (qbox mean)
# dispersion_mean_median_of_qboxes                              Dispersion (mean median of qboxes)
# dispersion_mean_standard_deviation_of_qboxes      Dispersion (mean standard deviation of qboxes)
# dispersion_mean_mean_of_qboxes                                  Dispersion (mean mean of qboxes)
# dispersion_median_median_of_qboxes                          Dispersion (median median of qboxes)
# dispersion_median_standard_deviation_of_qboxes  Dispersion (median standard deviation of qboxes)
# dispersion_median_mean_of_median                              Dispersion (median mean of median)
# attenuation_coefficient_qbox                                      Attenuation coefficient (qbox)
# speed_of_sound_qbox                                                        Speed of sound (qbox)
#
#                                                                               description_string  \
# tabular_field_name
# timezone                                                                                Timezone
# collection_date                                                     Collection date (YYYY-MM-DD)
# collection_timestamp                                                        Collection timestamp
# liver_ultrasound_qbox_depth                                          Liver ultrasound qbox depth
# liver_ultrasound_qbox_diameter                                    Liver ultrasound qbox diameter
# liver_ultrasound_stability_index                                Liver ultrasound stability index
# elasticity_qbox_minimum                                                Elasticity (qbox minimum)
# elasticity_qbox_maximum                                                Elasticity (qbox maximum)
# elasticity_qbox_median                                                  Elasticity (qbox median)
# elasticity_qbox_standard_deviation                          Elasticity (qbox standard deviation)
# elasticity_qbox_mean                                                      Elasticity (qbox mean)
# elasticity_mean_minimum_of_qboxes                            Elasticity (mean minimum of qboxes)
# elasticity_mean_maximum_of_qboxes                            Elasticity (mean maximum of qboxes)
# elasticity_mean_median_of_qboxes                              Elasticity (mean median of qboxes)
# elasticity_mean_standard_deviation_of_qboxes      Elasticity (mean standard deviation of qboxes)
# elasticity_mean_mean_of_qboxes                                  Elasticity (mean mean of qboxes)
# elasticity_median_minimum_of_qboxes                        Elasticity (median minimum of qboxes)
# elasticity_median_maximum_of_qboxes                        Elasticity (median maximum of qboxes)
# elasticity_median_median_of_qboxes                          Elasticity (median median of qboxes)
# elasticity_median_standard_deviation_of_qboxes  Elasticity (median standard deviation of qboxes)
# elasticity_median_mean_of_qboxes                              Elasticity (median mean of qboxes)
# velocity_qbox_minimum                                                    Velocity (qbox minimum)
# velocity_qbox_maximum                                                    Velocity (qbox maximum)
# velocity_qbox_median                                                      Velocity (qbox median)
# velocity_qbox_standard_deviation                              Velocity (qbox standard deviation)
# velocity_qbox_mean                                                          Velocity (qbox mean)
# velocity_mean_minimum_of_qboxes                                Velocity (mean minimum of qboxes)
# velocity_mean_maximum_of_qboxes                                Velocity (mean maximum of qboxes)
# velocity_mean_median_of_qboxes                                  Velocity (mean median of qboxes)
# velocity_mean_standard_deviation_of_qboxes          Velocity (mean standard deviation of qboxes)
# velocity_mean_mean_of_qboxes                                      Velocity (mean mean of qboxes)
# velocity_median_minimum_of_qboxes                            Velocity (median minimum of qboxes)
# velocity_median_maximum_of_qboxes                            Velocity (median maximum of qboxes)
# velocity_median_median_of_qboxes                              Velocity (median median of qboxes)
# velocity_median_standard_deviation_of_qboxes      Velocity (median standard deviation of qboxes)
# velocity_median_mean_of_qboxes                                  Velocity (median mean of qboxes)
# viscosity_qbox_median                                                    Viscosity (qbox median)
# viscosity_qbox_standard_deviation                            Viscosity (qbox standard deviation)
# viscosity_qbox_mean                                                        Viscosity (qbox mean)
# viscosity_mean_median_of_qboxes                                Viscosity (mean median of qboxes)
# viscosity_mean_standard_deviation_of_qboxes        Viscosity (mean standard deviation of qboxes)
# viscosity_mean_mean_of_qboxes                                    Viscosity (mean mean of qboxes)
# viscosity_median_median_of_qboxes                            Viscosity (median median of qboxes)
# viscosity_median_standard_deviation_of_qboxes    Viscosity (median standard deviation of qboxes)
# viscosity_median_mean_of_median                                Viscosity (median mean of median)
# dispersion_qbox_median                                                  Dispersion (qbox median)
# dispersion_qbox_standard_deviation                          Dispersion (qbox standard deviation)
# dispersion_qbox_mean                                                      Dispersion (qbox mean)
# dispersion_mean_median_of_qboxes                              Dispersion (mean median of qboxes)
# dispersion_mean_standard_deviation_of_qboxes      Dispersion (mean standard deviation of qboxes)
# dispersion_mean_mean_of_qboxes                                  Dispersion (mean mean of qboxes)
# dispersion_median_median_of_qboxes                          Dispersion (median median of qboxes)
# dispersion_median_standard_deviation_of_qboxes  Dispersion (median standard deviation of qboxes)
# dispersion_median_mean_of_median                              Dispersion (median mean of median)
# attenuation_coefficient_qbox                                      Attenuation coefficient (qbox)
# speed_of_sound_qbox                                                        Speed of sound (qbox)
#
#                                                 parent_dataframe  \
# tabular_field_name
# timezone                                                     NaN
# collection_date                                              NaN
# collection_timestamp                                         NaN
# liver_ultrasound_qbox_depth                                  NaN
# liver_ultrasound_qbox_diameter                               NaN
# liver_ultrasound_stability_index                             NaN
# elasticity_qbox_minimum                                      NaN
# elasticity_qbox_maximum                                      NaN
# elasticity_qbox_median                                       NaN
# elasticity_qbox_standard_deviation                           NaN
# elasticity_qbox_mean                                         NaN
# elasticity_mean_minimum_of_qboxes                            NaN
# elasticity_mean_maximum_of_qboxes                            NaN
# elasticity_mean_median_of_qboxes                             NaN
# elasticity_mean_standard_deviation_of_qboxes                 NaN
# elasticity_mean_mean_of_qboxes                               NaN
# elasticity_median_minimum_of_qboxes                          NaN
# elasticity_median_maximum_of_qboxes                          NaN
# elasticity_median_median_of_qboxes                           NaN
# elasticity_median_standard_deviation_of_qboxes               NaN
# elasticity_median_mean_of_qboxes                             NaN
# velocity_qbox_minimum                                        NaN
# velocity_qbox_maximum                                        NaN
# velocity_qbox_median                                         NaN
# velocity_qbox_standard_deviation                             NaN
# velocity_qbox_mean                                           NaN
# velocity_mean_minimum_of_qboxes                              NaN
# velocity_mean_maximum_of_qboxes                              NaN
# velocity_mean_median_of_qboxes                               NaN
# velocity_mean_standard_deviation_of_qboxes                   NaN
# velocity_mean_mean_of_qboxes                                 NaN
# velocity_median_minimum_of_qboxes                            NaN
# velocity_median_maximum_of_qboxes                            NaN
# velocity_median_median_of_qboxes                             NaN
# velocity_median_standard_deviation_of_qboxes                 NaN
# velocity_median_mean_of_qboxes                               NaN
# viscosity_qbox_median                                        NaN
# viscosity_qbox_standard_deviation                            NaN
# viscosity_qbox_mean                                          NaN
# viscosity_mean_median_of_qboxes                              NaN
# viscosity_mean_standard_deviation_of_qboxes                  NaN
# viscosity_mean_mean_of_qboxes                                NaN
# viscosity_median_median_of_qboxes                            NaN
# viscosity_median_standard_deviation_of_qboxes                NaN
# viscosity_median_mean_of_median                              NaN
# dispersion_qbox_median                                       NaN
# dispersion_qbox_standard_deviation                           NaN
# dispersion_qbox_mean                                         NaN
# dispersion_mean_median_of_qboxes                             NaN
# dispersion_mean_standard_deviation_of_qboxes                 NaN
# dispersion_mean_mean_of_qboxes                               NaN
# dispersion_median_median_of_qboxes                           NaN
# dispersion_median_standard_deviation_of_qboxes               NaN
# dispersion_median_mean_of_median                             NaN
# attenuation_coefficient_qbox                                 NaN
# speed_of_sound_qbox                                          NaN
#
#                                                relative_location  value_type  \
# tabular_field_name
# timezone                                        liver_us.parquet       Text
# collection_date                                 liver_us.parquet        Date
# collection_timestamp                            liver_us.parquet        Time
# liver_ultrasound_qbox_depth                     liver_us.parquet  Continuous
# liver_ultrasound_qbox_diameter                  liver_us.parquet  Continuous
# liver_ultrasound_stability_index                liver_us.parquet  Continuous
# elasticity_qbox_minimum                         liver_us.parquet  Continuous
# elasticity_qbox_maximum                         liver_us.parquet  Continuous
# elasticity_qbox_median                          liver_us.parquet  Continuous
# elasticity_qbox_standard_deviation              liver_us.parquet  Continuous
# elasticity_qbox_mean                            liver_us.parquet  Continuous
# elasticity_mean_minimum_of_qboxes               liver_us.parquet  Continuous
# elasticity_mean_maximum_of_qboxes               liver_us.parquet  Continuous
# elasticity_mean_median_of_qboxes                liver_us.parquet  Continuous
# elasticity_mean_standard_deviation_of_qboxes    liver_us.parquet  Continuous
# elasticity_mean_mean_of_qboxes                  liver_us.parquet  Continuous
# elasticity_median_minimum_of_qboxes             liver_us.parquet  Continuous
# elasticity_median_maximum_of_qboxes             liver_us.parquet  Continuous
# elasticity_median_median_of_qboxes              liver_us.parquet  Continuous
# elasticity_median_standard_deviation_of_qboxes  liver_us.parquet  Continuous
# elasticity_median_mean_of_qboxes                liver_us.parquet  Continuous
# velocity_qbox_minimum                           liver_us.parquet  Continuous
# velocity_qbox_maximum                           liver_us.parquet  Continuous
# velocity_qbox_median                            liver_us.parquet  Continuous
# velocity_qbox_standard_deviation                liver_us.parquet  Continuous
# velocity_qbox_mean                              liver_us.parquet  Continuous
# velocity_mean_minimum_of_qboxes                 liver_us.parquet  Continuous
# velocity_mean_maximum_of_qboxes                 liver_us.parquet  Continuous
# velocity_mean_median_of_qboxes                  liver_us.parquet  Continuous
# velocity_mean_standard_deviation_of_qboxes      liver_us.parquet  Continuous
# velocity_mean_mean_of_qboxes                    liver_us.parquet  Continuous
# velocity_median_minimum_of_qboxes               liver_us.parquet  Continuous
# velocity_median_maximum_of_qboxes               liver_us.parquet  Continuous
# velocity_median_median_of_qboxes                liver_us.parquet  Continuous
# velocity_median_standard_deviation_of_qboxes    liver_us.parquet  Continuous
# velocity_median_mean_of_qboxes                  liver_us.parquet  Continuous
# viscosity_qbox_median                           liver_us.parquet  Continuous
# viscosity_qbox_standard_deviation               liver_us.parquet  Continuous
# viscosity_qbox_mean                             liver_us.parquet  Continuous
# viscosity_mean_median_of_qboxes                 liver_us.parquet  Continuous
# viscosity_mean_standard_deviation_of_qboxes     liver_us.parquet  Continuous
# viscosity_mean_mean_of_qboxes                   liver_us.parquet  Continuous
# viscosity_median_median_of_qboxes               liver_us.parquet  Continuous
# viscosity_median_standard_deviation_of_qboxes   liver_us.parquet  Continuous
# viscosity_median_mean_of_median                 liver_us.parquet  Continuous
# dispersion_qbox_median                          liver_us.parquet  Continuous
# dispersion_qbox_standard_deviation              liver_us.parquet  Continuous
# dispersion_qbox_mean                            liver_us.parquet  Continuous
# dispersion_mean_median_of_qboxes                liver_us.parquet  Continuous
# dispersion_mean_standard_deviation_of_qboxes    liver_us.parquet  Continuous
# dispersion_mean_mean_of_qboxes                  liver_us.parquet  Continuous
# dispersion_median_median_of_qboxes              liver_us.parquet  Continuous
# dispersion_median_standard_deviation_of_qboxes  liver_us.parquet  Continuous
# dispersion_median_mean_of_median                liver_us.parquet  Continuous
# attenuation_coefficient_qbox                    liver_us.parquet  Continuous
# speed_of_sound_qbox                             liver_us.parquet  Continuous
#
#                                                     units  sampling_rate  \
# tabular_field_name
# timezone                                              NaN            NaN
# collection_date                                       NaN            NaN
# collection_timestamp                                  NaN            NaN
# liver_ultrasound_qbox_depth                            cm            NaN
# liver_ultrasound_qbox_diameter                         mm            NaN
# liver_ultrasound_stability_index                     None            NaN
# elasticity_qbox_minimum                               kPa            NaN
# elasticity_qbox_maximum                               kPa            NaN
# elasticity_qbox_median                                kPa            NaN
# elasticity_qbox_standard_deviation                    kPa            NaN
# elasticity_qbox_mean                                  kPa            NaN
# elasticity_mean_minimum_of_qboxes                     kPa            NaN
# elasticity_mean_maximum_of_qboxes                     kPa            NaN
# elasticity_mean_median_of_qboxes                      kPa            NaN
# elasticity_mean_standard_deviation_of_qboxes          kPa            NaN
# elasticity_mean_mean_of_qboxes                        kPa            NaN
# elasticity_median_minimum_of_qboxes                   kPa            NaN
# elasticity_median_maximum_of_qboxes                   kPa            NaN
# elasticity_median_median_of_qboxes                    kPa            NaN
# elasticity_median_standard_deviation_of_qboxes        kPa            NaN
# elasticity_median_mean_of_qboxes                      kPa            NaN
# velocity_qbox_minimum                                 m/s            NaN
# velocity_qbox_maximum                                 m/s            NaN
# velocity_qbox_median                                  m/s            NaN
# velocity_qbox_standard_deviation                      m/s            NaN
# velocity_qbox_mean                                    m/s            NaN
# velocity_mean_minimum_of_qboxes                       m/s            NaN
# velocity_mean_maximum_of_qboxes                       m/s            NaN
# velocity_mean_median_of_qboxes                        m/s            NaN
# velocity_mean_standard_deviation_of_qboxes            m/s            NaN
# velocity_mean_mean_of_qboxes                          m/s            NaN
# velocity_median_minimum_of_qboxes                     m/s            NaN
# velocity_median_maximum_of_qboxes                     m/s            NaN
# velocity_median_median_of_qboxes                      m/s            NaN
# velocity_median_standard_deviation_of_qboxes          m/s            NaN
# velocity_median_mean_of_qboxes                        m/s            NaN
# viscosity_qbox_median                                Pa.s            NaN
# viscosity_qbox_standard_deviation                    Pa.s            NaN
# viscosity_qbox_mean                                  Pa.s            NaN
# viscosity_mean_median_of_qboxes                      Pa.s            NaN
# viscosity_mean_standard_deviation_of_qboxes          Pa.s            NaN
# viscosity_mean_mean_of_qboxes                        Pa.s            NaN
# viscosity_median_median_of_qboxes                    Pa.s            NaN
# viscosity_median_standard_deviation_of_qboxes        Pa.s            NaN
# viscosity_median_mean_of_median                      Pa.s            NaN
# dispersion_qbox_median                          (m/s)/kHz            NaN
# dispersion_qbox_standard_deviation              (m/s)/kHz            NaN
# dispersion_qbox_mean                            (m/s)/kHz            NaN
# dispersion_mean_median_of_qboxes                (m/s)/kHz            NaN
# dispersion_mean_standard_deviation_of_qboxes    (m/s)/kHz            NaN
# dispersion_mean_mean_of_qboxes                  (m/s)/kHz            NaN
# dispersion_median_median_of_qboxes              (m/s)/kHz            NaN
# dispersion_median_standard_deviation_of_qboxes  (m/s)/kHz            NaN
# dispersion_median_mean_of_median                (m/s)/kHz            NaN
# attenuation_coefficient_qbox                    dB/cm/MHz            NaN
# speed_of_sound_qbox                                   m/s            NaN
#
#                                                item_type     array cohorts  \
# tabular_field_name
# timezone                                            Data  Multiple     10k
# collection_date                                     Data  Multiple     10k
# collection_timestamp                                Data  Multiple     10k
# liver_ultrasound_qbox_depth                         Data  Multiple     10k
# liver_ultrasound_qbox_diameter                      Data  Multiple     10k
# liver_ultrasound_stability_index                    Data  Multiple     10k
# elasticity_qbox_minimum                             Data  Multiple     10k
# elasticity_qbox_maximum                             Data  Multiple     10k
# elasticity_qbox_median                              Data  Multiple     10k
# elasticity_qbox_standard_deviation                  Data  Multiple     10k
# elasticity_qbox_mean                                Data  Multiple     10k
# elasticity_mean_minimum_of_qboxes                   Data  Multiple     10k
# elasticity_mean_maximum_of_qboxes                   Data  Multiple     10k
# elasticity_mean_median_of_qboxes                    Data  Multiple     10k
# elasticity_mean_standard_deviation_of_qboxes        Data  Multiple     10k
# elasticity_mean_mean_of_qboxes                      Data  Multiple     10k
# elasticity_median_minimum_of_qboxes                 Data  Multiple     10k
# elasticity_median_maximum_of_qboxes                 Data  Multiple     10k
# elasticity_median_median_of_qboxes                  Data  Multiple     10k
# elasticity_median_standard_deviation_of_qboxes      Data  Multiple     10k
# elasticity_median_mean_of_qboxes                    Data  Multiple     10k
# velocity_qbox_minimum                               Data  Multiple     10k
# velocity_qbox_maximum                               Data  Multiple     10k
# velocity_qbox_median                                Data  Multiple     10k
# velocity_qbox_standard_deviation                    Data  Multiple     10k
# velocity_qbox_mean                                  Data  Multiple     10k
# velocity_mean_minimum_of_qboxes                     Data  Multiple     10k
# velocity_mean_maximum_of_qboxes                     Data  Multiple     10k
# velocity_mean_median_of_qboxes                      Data  Multiple     10k
# velocity_mean_standard_deviation_of_qboxes          Data  Multiple     10k
# velocity_mean_mean_of_qboxes                        Data  Multiple     10k
# velocity_median_minimum_of_qboxes                   Data  Multiple     10k
# velocity_median_maximum_of_qboxes                   Data  Multiple     10k
# velocity_median_median_of_qboxes                    Data  Multiple     10k
# velocity_median_standard_deviation_of_qboxes        Data  Multiple     10k
# velocity_median_mean_of_qboxes                      Data  Multiple     10k
# viscosity_qbox_median                               Data  Multiple     10k
# viscosity_qbox_standard_deviation                   Data  Multiple     10k
# viscosity_qbox_mean                                 Data  Multiple     10k
# viscosity_mean_median_of_qboxes                     Data  Multiple     10k
# viscosity_mean_standard_deviation_of_qboxes         Data  Multiple     10k
# viscosity_mean_mean_of_qboxes                       Data  Multiple     10k
# viscosity_median_median_of_qboxes                   Data  Multiple     10k
# viscosity_median_standard_deviation_of_qboxes       Data  Multiple     10k
# viscosity_median_mean_of_median                     Data  Multiple     10k
# dispersion_qbox_median                              Data  Multiple     10k
# dispersion_qbox_standard_deviation                  Data  Multiple     10k
# dispersion_qbox_mean                                Data  Multiple     10k
# dispersion_mean_median_of_qboxes                    Data  Multiple     10k
# dispersion_mean_standard_deviation_of_qboxes        Data  Multiple     10k
# dispersion_mean_mean_of_qboxes                      Data  Multiple     10k
# dispersion_median_median_of_qboxes                  Data  Multiple     10k
# dispersion_median_standard_deviation_of_qboxes      Data  Multiple     10k
# dispersion_median_mean_of_median                    Data  Multiple     10k
# attenuation_coefficient_qbox                        Data  Multiple     10k
# speed_of_sound_qbox                                 Data  Multiple     10k
#
#                                                data_type       debut  \
# tabular_field_name
# timezone                                         tabular  2021-08-16
# collection_date                                  tabular  2021-08-16
# collection_timestamp                             tabular  2021-08-16
# liver_ultrasound_qbox_depth                      tabular  2021-08-16
# liver_ultrasound_qbox_diameter                   tabular  2021-08-16
# liver_ultrasound_stability_index                 tabular  2021-08-16
# elasticity_qbox_minimum                          tabular  2021-08-16
# elasticity_qbox_maximum                          tabular  2021-08-16
# elasticity_qbox_median                           tabular  2021-08-16
# elasticity_qbox_standard_deviation               tabular  2021-08-16
# elasticity_qbox_mean                             tabular  2021-08-16
# elasticity_mean_minimum_of_qboxes                tabular  2021-08-16
# elasticity_mean_maximum_of_qboxes                tabular  2021-08-16
# elasticity_mean_median_of_qboxes                 tabular  2021-08-16
# elasticity_mean_standard_deviation_of_qboxes     tabular  2021-08-16
# elasticity_mean_mean_of_qboxes                   tabular  2021-08-16
# elasticity_median_minimum_of_qboxes              tabular  2021-08-16
# elasticity_median_maximum_of_qboxes              tabular  2021-08-16
# elasticity_median_median_of_qboxes               tabular  2021-08-16
# elasticity_median_standard_deviation_of_qboxes   tabular  2021-08-16
# elasticity_median_mean_of_qboxes                 tabular  2021-08-16
# velocity_qbox_minimum                            tabular  2021-08-16
# velocity_qbox_maximum                            tabular  2021-08-16
# velocity_qbox_median                             tabular  2021-08-16
# velocity_qbox_standard_deviation                 tabular  2021-08-16
# velocity_qbox_mean                               tabular  2021-08-16
# velocity_mean_minimum_of_qboxes                  tabular  2021-08-16
# velocity_mean_maximum_of_qboxes                  tabular  2021-08-16
# velocity_mean_median_of_qboxes                   tabular  2021-08-16
# velocity_mean_standard_deviation_of_qboxes       tabular  2021-08-16
# velocity_mean_mean_of_qboxes                     tabular  2021-08-16
# velocity_median_minimum_of_qboxes                tabular  2021-08-16
# velocity_median_maximum_of_qboxes                tabular  2021-08-16
# velocity_median_median_of_qboxes                 tabular  2021-08-16
# velocity_median_standard_deviation_of_qboxes     tabular  2021-08-16
# velocity_median_mean_of_qboxes                   tabular  2021-08-16
# viscosity_qbox_median                            tabular  2021-08-16
# viscosity_qbox_standard_deviation                tabular  2021-08-16
# viscosity_qbox_mean                              tabular  2021-08-16
# viscosity_mean_median_of_qboxes                  tabular  2021-08-16
# viscosity_mean_standard_deviation_of_qboxes      tabular  2021-08-16
# viscosity_mean_mean_of_qboxes                    tabular  2021-08-16
# viscosity_median_median_of_qboxes                tabular  2021-08-16
# viscosity_median_standard_deviation_of_qboxes    tabular  2021-08-16
# viscosity_median_mean_of_median                  tabular  2021-08-16
# dispersion_qbox_median                           tabular  2021-08-16
# dispersion_qbox_standard_deviation               tabular  2021-08-16
# dispersion_qbox_mean                             tabular  2021-08-16
# dispersion_mean_median_of_qboxes                 tabular  2021-08-16
# dispersion_mean_standard_deviation_of_qboxes     tabular  2021-08-16
# dispersion_mean_mean_of_qboxes                   tabular  2021-08-16
# dispersion_median_median_of_qboxes               tabular  2021-08-16
# dispersion_median_standard_deviation_of_qboxes   tabular  2021-08-16
# dispersion_median_mean_of_median                 tabular  2021-08-16
# attenuation_coefficient_qbox                     tabular  2021-08-16
# speed_of_sound_qbox                              tabular  2021-08-16
#
#                                                                   pandas_dtype
# tabular_field_name
# timezone                                                                string
# collection_date                                                 datetime64[ns]
# collection_timestamp                            datetime64[ns, Asia/Jerusalem]
# liver_ultrasound_qbox_depth                                              float
# liver_ultrasound_qbox_diameter                                           float
# liver_ultrasound_stability_index                                         float
# elasticity_qbox_minimum                                                  float
# elasticity_qbox_maximum                                                  float
# elasticity_qbox_median                                                   float
# elasticity_qbox_standard_deviation                                       float
# elasticity_qbox_mean                                                     float
# elasticity_mean_minimum_of_qboxes                                        float
# elasticity_mean_maximum_of_qboxes                                        float
# elasticity_mean_median_of_qboxes                                         float
# elasticity_mean_standard_deviation_of_qboxes                             float
# elasticity_mean_mean_of_qboxes                                           float
# elasticity_median_minimum_of_qboxes                                      float
# elasticity_median_maximum_of_qboxes                                      float
# elasticity_median_median_of_qboxes                                       float
# elasticity_median_standard_deviation_of_qboxes                           float
# elasticity_median_mean_of_qboxes                                         float
# velocity_qbox_minimum                                                    float
# velocity_qbox_maximum                                                    float
# velocity_qbox_median                                                     float
# velocity_qbox_standard_deviation                                         float
# velocity_qbox_mean                                                       float
# velocity_mean_minimum_of_qboxes                                          float
# velocity_mean_maximum_of_qboxes                                          float
# velocity_mean_median_of_qboxes                                           float
# velocity_mean_standard_deviation_of_qboxes                               float
# velocity_mean_mean_of_qboxes                                             float
# velocity_median_minimum_of_qboxes                                        float
# velocity_median_maximum_of_qboxes                                        float
# velocity_median_median_of_qboxes                                         float
# velocity_median_standard_deviation_of_qboxes                             float
# velocity_median_mean_of_qboxes                                           float
# viscosity_qbox_median                                                    float
# viscosity_qbox_standard_deviation                                        float
# viscosity_qbox_mean                                                      float
# viscosity_mean_median_of_qboxes                                          float
# viscosity_mean_standard_deviation_of_qboxes                              float
# viscosity_mean_mean_of_qboxes                                            float
# viscosity_median_median_of_qboxes                                        float
# viscosity_median_standard_deviation_of_qboxes                            float
# viscosity_median_mean_of_median                                          float
# dispersion_qbox_median                                                   float
# dispersion_qbox_standard_deviation                                       float
# dispersion_qbox_mean                                                     float
# dispersion_mean_median_of_qboxes                                         float
# dispersion_mean_standard_deviation_of_qboxes                             float
# dispersion_mean_mean_of_qboxes                                           float
# dispersion_median_median_of_qboxes                                       float
# dispersion_median_standard_deviation_of_qboxes                           float
# dispersion_median_mean_of_median                                         float
# attenuation_coefficient_qbox                                             float
# speed_of_sound_qbox                                                      float
