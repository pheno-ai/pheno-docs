# %% [raw]
# ---
# output-file: 11-body_composition.html
# title: 11-body_composition
#
# ---

# %% [markdown]
# # 11 - body composition
#
# Body composition was profiled based on DXA (dual-energy x-ray absorptiometry) imaging, and includes measurements of fat and lean mass for the legs, arms, trunk, gynoid, and android, as well as measurements of total scan visceral adipose tissue (VAT) and subcutaneous adipose tissue (SAT) area, mass and volume are included.
#
# DXA (dual-energy x-ray absorptiometry) is a medical imaging technique that is used to measure body composition, specifically the amounts of bone, fat, and lean muscle tissue in the body. A DXA scan uses a low dose of ionizing radiation to produce a detailed image of the body, which is then analyzed by a software to determine the body composition. This method is considered to be one of the most accurate methods for measuring body composition, as it is able to distinguish between different types of tissue and provide detailed information about the distribution of fat and muscle in the body. DXA imaging is commonly used for assessing bone density and for monitoring changes in body composition over time, such as during weight loss, muscle building programs or for assessment of sarcopenia.
#
#
# The information is stored in 1 parquet file: `body_composition.parquet`

# %%
#| hide
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('body_composition', age_sex_dataset=None)
dl
# Out:
# DataLoader for body_composition with
# 158 fields
# 1 tables: ['body_composition']

# %%
dl.dict
# Out:
#                                                                              field_string  \
# tabular_field_name
# collection_date                                              Collection date (YYYY-MM-DD)
# timezone                                                                         Timezone
# collection_timestamp                                                 Collection timestamp
# body_comp_android_bone_mass                            Body composition android bone mass
# body_comp_android_fat_free_mass                    Body composition android fat free mass
# body_comp_android_fat_mass                              Body composition android fat mass
# body_comp_android_lean_mass                            Body composition android lean mass
# body_comp_android_region_percent_fat          Body composition android region percent fat
# body_comp_android_tissue_mass                        Body composition android tissue mass
# body_comp_android_tissue_percent_fat          Body composition android tissue percent fat
# body_comp_android_total_mass                          Body composition android total mass
# body_comp_arm_left_bone_mass                          Body composition arm left bone mass
# body_comp_arm_left_fat_free_mass                  Body composition arm left fat free mass
# body_comp_arm_left_fat_mass                            Body composition arm left fat mass
# body_comp_arm_left_lean_mass                          Body composition arm left lean mass
# body_comp_arm_left_region_percent_fat        Body composition arm left region percent fat
# body_comp_arm_left_tissue_mass                      Body composition arm left tissue mass
# body_comp_arm_left_tissue_percent_fat        Body composition arm left tissue percent fat
# body_comp_arm_left_total_mass                        Body composition arm left total mass
# body_comp_arm_right_bone_mass                        Body composition arm right bone mass
# body_comp_arm_right_fat_free_mass                Body composition arm right fat free mass
# body_comp_arm_right_fat_mass                          Body composition arm right fat mass
# body_comp_arm_right_lean_mass                        Body composition arm right lean mass
# body_comp_arm_right_region_percent_fat      Body composition arm right region percent fat
# body_comp_arm_right_tissue_mass                    Body composition arm right tissue mass
# body_comp_arm_right_tissue_percent_fat      Body composition arm right tissue percent fat
# body_comp_arm_right_total_mass                      Body composition arm right total mass
# body_comp_arms_bone_mass                                  Body composition arms bone mass
# body_comp_arms_diff_bone_mass                        Body composition arms diff bone mass
# body_comp_arms_diff_fat_free_mass                Body composition arms diff fat free mass
# body_comp_arms_diff_fat_mass                          Body composition arms diff fat mass
# body_comp_arms_diff_lean_mass                        Body composition arms diff lean mass
# body_comp_arms_diff_region_percent_fat      Body composition arms diff region percent fat
# body_comp_arms_diff_tissue_mass                    Body composition arms diff tissue mass
# body_comp_arms_diff_tissue_percent_fat      Body composition arms diff tissue percent fat
# body_comp_arms_diff_total_mass                      Body composition arms diff total mass
# body_comp_arms_fat_free_mass                          Body composition arms fat free mass
# body_comp_arms_fat_mass                                    Body composition arms fat mass
# body_comp_arms_lean_mass                                  Body composition arms lean mass
# body_comp_arms_region_percent_fat                Body composition arms region percent fat
# body_comp_arms_tissue_mass                              Body composition arms tissue mass
# body_comp_arms_tissue_percent_fat                Body composition arms tissue percent fat
# body_comp_arms_total_mass                                Body composition arms total mass
# body_comp_dose                                                      Body composition dose
# body_comp_gynoid_bone_mass                              Body composition gynoid bone mass
# body_comp_gynoid_fat_free_mass                      Body composition gynoid fat free mass
# body_comp_gynoid_fat_mass                                Body composition gynoid fat mass
# body_comp_gynoid_lean_mass                              Body composition gynoid lean mass
# body_comp_gynoid_region_percent_fat            Body composition gynoid region percent fat
# body_comp_gynoid_tissue_mass                          Body composition gynoid tissue mass
# body_comp_gynoid_tissue_percent_fat            Body composition gynoid tissue percent fat
# body_comp_gynoid_total_mass                            Body composition gynoid total mass
# body_comp_leg_left_bone_mass                          Body composition leg left bone mass
# body_comp_leg_left_fat_free_mass                  Body composition leg left fat free mass
# body_comp_leg_left_fat_mass                            Body composition leg left fat mass
# body_comp_leg_left_lean_mass                          Body composition leg left lean mass
# body_comp_leg_left_region_percent_fat        Body composition leg left region percent fat
# body_comp_leg_left_tissue_mass                      Body composition leg left tissue mass
# body_comp_leg_left_tissue_percent_fat        Body composition leg left tissue percent fat
# body_comp_leg_left_total_mass                        Body composition leg left total mass
# body_comp_leg_right_bone_mass                        Body composition leg right bone mass
# body_comp_leg_right_fat_free_mass                Body composition leg right fat free mass
# body_comp_leg_right_fat_mass                          Body composition leg right fat mass
# body_comp_leg_right_lean_mass                        Body composition leg right lean mass
# body_comp_leg_right_region_percent_fat      Body composition leg right region percent fat
# body_comp_leg_right_tissue_mass                    Body composition leg right tissue mass
# body_comp_leg_right_tissue_percent_fat      Body composition leg right tissue percent fat
# body_comp_leg_right_total_mass                      Body composition leg right total mass
# body_comp_legs_bone_mass                                  Body composition legs bone mass
# body_comp_legs_diff_bone_mass                        Body composition legs diff bone mass
# body_comp_legs_diff_fat_free_mass                Body composition legs diff fat free mass
# body_comp_legs_diff_fat_mass                          Body composition legs diff fat mass
# body_comp_legs_diff_lean_mass                        Body composition legs diff lean mass
# body_comp_legs_diff_region_percent_fat      Body composition legs diff region percent fat
# body_comp_legs_diff_tissue_mass                    Body composition legs diff tissue mass
# body_comp_legs_diff_tissue_percent_fat      Body composition legs diff tissue percent fat
# body_comp_legs_diff_total_mass                      Body composition legs diff total mass
# body_comp_legs_fat_free_mass                          Body composition legs fat free mass
# body_comp_legs_fat_mass                                    Body composition legs fat mass
# body_comp_legs_lean_mass                                  Body composition legs lean mass
# body_comp_legs_region_percent_fat                Body composition legs region percent fat
# body_comp_legs_tissue_mass                              Body composition legs tissue mass
# body_comp_legs_tissue_percent_fat                Body composition legs tissue percent fat
# body_comp_legs_total_mass                                Body composition legs total mass
# body_comp_total_bone_mass                                Body composition total bone mass
# body_comp_total_diff_bone_mass                      Body composition total diff bone mass
# body_comp_total_diff_fat_free_mass              Body composition total diff fat free mass
# body_comp_total_diff_fat_mass                        Body composition total diff fat mass
# body_comp_total_diff_lean_mass                      Body composition total diff lean mass
# body_comp_total_diff_region_percent_fat    Body composition total diff region percent fat
# body_comp_total_diff_tissue_mass                  Body composition total diff tissue mass
# body_comp_total_diff_tissue_percent_fat    Body composition total diff tissue percent fat
# body_comp_total_diff_total_mass                    Body composition total diff total mass
# body_comp_total_fat_free_mass                        Body composition total fat free mass
# body_comp_total_fat_mass                                  Body composition total fat mass
# body_comp_total_lean_mass                                Body composition total lean mass
# body_comp_total_left_bone_mass                      Body composition total left bone mass
# body_comp_total_left_fat_free_mass              Body composition total left fat free mass
# body_comp_total_left_fat_mass                        Body composition total left fat mass
# body_comp_total_left_lean_mass                      Body composition total left lean mass
# body_comp_total_left_region_percent_fat    Body composition total left region percent fat
# body_comp_total_left_tissue_mass                  Body composition total left tissue mass
# body_comp_total_left_tissue_percent_fat    Body composition total left tissue percent fat
# body_comp_total_left_total_mass                    Body composition total left total mass
# body_comp_total_region_percent_fat              Body composition total region percent fat
# body_comp_total_right_bone_mass                    Body composition total right bone mass
# body_comp_total_right_fat_free_mass            Body composition total right fat free mass
# body_comp_total_right_fat_mass                      Body composition total right fat mass
# body_comp_total_right_lean_mass                    Body composition total right lean mass
# body_comp_total_right_region_percent_fat  Body composition total right region percent fat
# body_comp_total_right_tissue_mass                Body composition total right tissue mass
# body_comp_total_right_tissue_percent_fat  Body composition total right tissue percent fat
# body_comp_total_right_total_mass                  Body composition total right total mass
# body_comp_total_tissue_mass                            Body composition total tissue mass
# body_comp_total_tissue_percent_fat              Body composition total tissue percent fat
# body_comp_total_total_mass                              Body composition total total mass
# body_comp_trunk_bone_mass                                Body composition trunk bone mass
# body_comp_trunk_diff_bone_mass                      Body composition trunk diff bone mass
# body_comp_trunk_diff_fat_free_mass              Body composition trunk diff fat free mass
# body_comp_trunk_diff_fat_mass                        Body composition trunk diff fat mass
# body_comp_trunk_diff_lean_mass                      Body composition trunk diff lean mass
# body_comp_trunk_diff_region_percent_fat    Body composition trunk diff region percent fat
# body_comp_trunk_diff_tissue_mass                  Body composition trunk diff tissue mass
# body_comp_trunk_diff_tissue_percent_fat    Body composition trunk diff tissue percent fat
# body_comp_trunk_diff_total_mass                    Body composition trunk diff total mass
# body_comp_trunk_fat_free_mass                        Body composition trunk fat free mass
# body_comp_trunk_fat_mass                                  Body composition trunk fat mass
# body_comp_trunk_lean_mass                                Body composition trunk lean mass
# body_comp_trunk_left_bone_mass                      Body composition trunk left bone mass
# body_comp_trunk_left_fat_free_mass              Body composition trunk left fat free mass
# body_comp_trunk_left_fat_mass                        Body composition trunk left fat mass
# body_comp_trunk_left_lean_mass                      Body composition trunk left lean mass
# body_comp_trunk_left_region_percent_fat    Body composition trunk left region percent fat
# body_comp_trunk_left_tissue_mass                  Body composition trunk left tissue mass
# body_comp_trunk_left_tissue_percent_fat    Body composition trunk left tissue percent fat
# body_comp_trunk_left_total_mass                    Body composition trunk left total mass
# body_comp_trunk_region_percent_fat              Body composition trunk region percent fat
# body_comp_trunk_right_bone_mass                    Body composition trunk right bone mass
# body_comp_trunk_right_fat_free_mass            Body composition trunk right fat free mass
# body_comp_trunk_right_fat_mass                      Body composition trunk right fat mass
# body_comp_trunk_right_lean_mass                    Body composition trunk right lean mass
# body_comp_trunk_right_region_percent_fat  Body composition trunk right region percent fat
# body_comp_trunk_right_tissue_mass                Body composition trunk right tissue mass
# body_comp_trunk_right_tissue_percent_fat  Body composition trunk right tissue percent fat
# body_comp_trunk_right_total_mass                  Body composition trunk right total mass
# body_comp_trunk_tissue_mass                            Body composition trunk tissue mass
# body_comp_trunk_tissue_percent_fat              Body composition trunk tissue percent fat
# body_comp_trunk_total_mass                              Body composition trunk total mass
# total_scan_dose                                                           Total scan dose
# total_scan_sat_area                           Total scan subcutaneous adipose tissue area
# total_scan_sat_mass                           Total scan subcutaneous adipose tissue mass
# total_scan_sat_volume                       Total scan subcutaneous adipose tissue volume
# total_scan_vat_area                               Total scan visceral adipose tissue area
# total_scan_vat_mass                               Total scan visceral adipose tissue mass
# total_scan_vat_volume                           Total scan visceral adipose tissue volume
# body_fat_percentage                              Body fat percentage (from Tanita device)
# bmr                                        Basal metabolic rate (BMR) from Tanita device)
# trunk_fat_percentage                             Trunk fat percentage from Tanita device)
#
#                                                                        description_string  \
# tabular_field_name
# collection_date                                              Collection date (YYYY-MM-DD)
# timezone                                                                         Timezone
# collection_timestamp                                                 Collection timestamp
# body_comp_android_bone_mass                            Body composition android bone mass
# body_comp_android_fat_free_mass                    Body composition android fat free mass
# body_comp_android_fat_mass                              Body composition android fat mass
# body_comp_android_lean_mass                            Body composition android lean mass
# body_comp_android_region_percent_fat          Body composition android region percent fat
# body_comp_android_tissue_mass                        Body composition android tissue mass
# body_comp_android_tissue_percent_fat          Body composition android tissue percent fat
# body_comp_android_total_mass                          Body composition android total mass
# body_comp_arm_left_bone_mass                          Body composition arm left bone mass
# body_comp_arm_left_fat_free_mass                  Body composition arm left fat free mass
# body_comp_arm_left_fat_mass                            Body composition arm left fat mass
# body_comp_arm_left_lean_mass                          Body composition arm left lean mass
# body_comp_arm_left_region_percent_fat        Body composition arm left region percent fat
# body_comp_arm_left_tissue_mass                      Body composition arm left tissue mass
# body_comp_arm_left_tissue_percent_fat        Body composition arm left tissue percent fat
# body_comp_arm_left_total_mass                        Body composition arm left total mass
# body_comp_arm_right_bone_mass                        Body composition arm right bone mass
# body_comp_arm_right_fat_free_mass                Body composition arm right fat free mass
# body_comp_arm_right_fat_mass                          Body composition arm right fat mass
# body_comp_arm_right_lean_mass                        Body composition arm right lean mass
# body_comp_arm_right_region_percent_fat      Body composition arm right region percent fat
# body_comp_arm_right_tissue_mass                    Body composition arm right tissue mass
# body_comp_arm_right_tissue_percent_fat      Body composition arm right tissue percent fat
# body_comp_arm_right_total_mass                      Body composition arm right total mass
# body_comp_arms_bone_mass                                  Body composition arms bone mass
# body_comp_arms_diff_bone_mass                        Body composition arms diff bone mass
# body_comp_arms_diff_fat_free_mass                Body composition arms diff fat free mass
# body_comp_arms_diff_fat_mass                          Body composition arms diff fat mass
# body_comp_arms_diff_lean_mass                        Body composition arms diff lean mass
# body_comp_arms_diff_region_percent_fat      Body composition arms diff region percent fat
# body_comp_arms_diff_tissue_mass                    Body composition arms diff tissue mass
# body_comp_arms_diff_tissue_percent_fat      Body composition arms diff tissue percent fat
# body_comp_arms_diff_total_mass                      Body composition arms diff total mass
# body_comp_arms_fat_free_mass                          Body composition arms fat free mass
# body_comp_arms_fat_mass                                    Body composition arms fat mass
# body_comp_arms_lean_mass                                  Body composition arms lean mass
# body_comp_arms_region_percent_fat                Body composition arms region percent fat
# body_comp_arms_tissue_mass                              Body composition arms tissue mass
# body_comp_arms_tissue_percent_fat                Body composition arms tissue percent fat
# body_comp_arms_total_mass                                Body composition arms total mass
# body_comp_dose                                                      Body composition dose
# body_comp_gynoid_bone_mass                              Body composition gynoid bone mass
# body_comp_gynoid_fat_free_mass                      Body composition gynoid fat free mass
# body_comp_gynoid_fat_mass                                Body composition gynoid fat mass
# body_comp_gynoid_lean_mass                              Body composition gynoid lean mass
# body_comp_gynoid_region_percent_fat            Body composition gynoid region percent fat
# body_comp_gynoid_tissue_mass                          Body composition gynoid tissue mass
# body_comp_gynoid_tissue_percent_fat            Body composition gynoid tissue percent fat
# body_comp_gynoid_total_mass                            Body composition gynoid total mass
# body_comp_leg_left_bone_mass                          Body composition leg left bone mass
# body_comp_leg_left_fat_free_mass                  Body composition leg left fat free mass
# body_comp_leg_left_fat_mass                            Body composition leg left fat mass
# body_comp_leg_left_lean_mass                          Body composition leg left lean mass
# body_comp_leg_left_region_percent_fat        Body composition leg left region percent fat
# body_comp_leg_left_tissue_mass                      Body composition leg left tissue mass
# body_comp_leg_left_tissue_percent_fat        Body composition leg left tissue percent fat
# body_comp_leg_left_total_mass                        Body composition leg left total mass
# body_comp_leg_right_bone_mass                        Body composition leg right bone mass
# body_comp_leg_right_fat_free_mass                Body composition leg right fat free mass
# body_comp_leg_right_fat_mass                          Body composition leg right fat mass
# body_comp_leg_right_lean_mass                        Body composition leg right lean mass
# body_comp_leg_right_region_percent_fat      Body composition leg right region percent fat
# body_comp_leg_right_tissue_mass                    Body composition leg right tissue mass
# body_comp_leg_right_tissue_percent_fat      Body composition leg right tissue percent fat
# body_comp_leg_right_total_mass                      Body composition leg right total mass
# body_comp_legs_bone_mass                                  Body composition legs bone mass
# body_comp_legs_diff_bone_mass                        Body composition legs diff bone mass
# body_comp_legs_diff_fat_free_mass                Body composition legs diff fat free mass
# body_comp_legs_diff_fat_mass                          Body composition legs diff fat mass
# body_comp_legs_diff_lean_mass                        Body composition legs diff lean mass
# body_comp_legs_diff_region_percent_fat      Body composition legs diff region percent fat
# body_comp_legs_diff_tissue_mass                    Body composition legs diff tissue mass
# body_comp_legs_diff_tissue_percent_fat      Body composition legs diff tissue percent fat
# body_comp_legs_diff_total_mass                      Body composition legs diff total mass
# body_comp_legs_fat_free_mass                          Body composition legs fat free mass
# body_comp_legs_fat_mass                                    Body composition legs fat mass
# body_comp_legs_lean_mass                                  Body composition legs lean mass
# body_comp_legs_region_percent_fat                Body composition legs region percent fat
# body_comp_legs_tissue_mass                              Body composition legs tissue mass
# body_comp_legs_tissue_percent_fat                Body composition legs tissue percent fat
# body_comp_legs_total_mass                                Body composition legs total mass
# body_comp_total_bone_mass                                Body composition total bone mass
# body_comp_total_diff_bone_mass                      Body composition total diff bone mass
# body_comp_total_diff_fat_free_mass              Body composition total diff fat free mass
# body_comp_total_diff_fat_mass                        Body composition total diff fat mass
# body_comp_total_diff_lean_mass                      Body composition total diff lean mass
# body_comp_total_diff_region_percent_fat    Body composition total diff region percent fat
# body_comp_total_diff_tissue_mass                  Body composition total diff tissue mass
# body_comp_total_diff_tissue_percent_fat    Body composition total diff tissue percent fat
# body_comp_total_diff_total_mass                    Body composition total diff total mass
# body_comp_total_fat_free_mass                        Body composition total fat free mass
# body_comp_total_fat_mass                                  Body composition total fat mass
# body_comp_total_lean_mass                                Body composition total lean mass
# body_comp_total_left_bone_mass                      Body composition total left bone mass
# body_comp_total_left_fat_free_mass              Body composition total left fat free mass
# body_comp_total_left_fat_mass                        Body composition total left fat mass
# body_comp_total_left_lean_mass                      Body composition total left lean mass
# body_comp_total_left_region_percent_fat    Body composition total left region percent fat
# body_comp_total_left_tissue_mass                  Body composition total left tissue mass
# body_comp_total_left_tissue_percent_fat    Body composition total left tissue percent fat
# body_comp_total_left_total_mass                    Body composition total left total mass
# body_comp_total_region_percent_fat              Body composition total region percent fat
# body_comp_total_right_bone_mass                    Body composition total right bone mass
# body_comp_total_right_fat_free_mass            Body composition total right fat free mass
# body_comp_total_right_fat_mass                      Body composition total right fat mass
# body_comp_total_right_lean_mass                    Body composition total right lean mass
# body_comp_total_right_region_percent_fat  Body composition total right region percent fat
# body_comp_total_right_tissue_mass                Body composition total right tissue mass
# body_comp_total_right_tissue_percent_fat  Body composition total right tissue percent fat
# body_comp_total_right_total_mass                  Body composition total right total mass
# body_comp_total_tissue_mass                            Body composition total tissue mass
# body_comp_total_tissue_percent_fat              Body composition total tissue percent fat
# body_comp_total_total_mass                              Body composition total total mass
# body_comp_trunk_bone_mass                                Body composition trunk bone mass
# body_comp_trunk_diff_bone_mass                      Body composition trunk diff bone mass
# body_comp_trunk_diff_fat_free_mass              Body composition trunk diff fat free mass
# body_comp_trunk_diff_fat_mass                        Body composition trunk diff fat mass
# body_comp_trunk_diff_lean_mass                      Body composition trunk diff lean mass
# body_comp_trunk_diff_region_percent_fat    Body composition trunk diff region percent fat
# body_comp_trunk_diff_tissue_mass                  Body composition trunk diff tissue mass
# body_comp_trunk_diff_tissue_percent_fat    Body composition trunk diff tissue percent fat
# body_comp_trunk_diff_total_mass                    Body composition trunk diff total mass
# body_comp_trunk_fat_free_mass                        Body composition trunk fat free mass
# body_comp_trunk_fat_mass                                  Body composition trunk fat mass
# body_comp_trunk_lean_mass                                Body composition trunk lean mass
# body_comp_trunk_left_bone_mass                      Body composition trunk left bone mass
# body_comp_trunk_left_fat_free_mass              Body composition trunk left fat free mass
# body_comp_trunk_left_fat_mass                        Body composition trunk left fat mass
# body_comp_trunk_left_lean_mass                      Body composition trunk left lean mass
# body_comp_trunk_left_region_percent_fat    Body composition trunk left region percent fat
# body_comp_trunk_left_tissue_mass                  Body composition trunk left tissue mass
# body_comp_trunk_left_tissue_percent_fat    Body composition trunk left tissue percent fat
# body_comp_trunk_left_total_mass                    Body composition trunk left total mass
# body_comp_trunk_region_percent_fat              Body composition trunk region percent fat
# body_comp_trunk_right_bone_mass                    Body composition trunk right bone mass
# body_comp_trunk_right_fat_free_mass            Body composition trunk right fat free mass
# body_comp_trunk_right_fat_mass                      Body composition trunk right fat mass
# body_comp_trunk_right_lean_mass                    Body composition trunk right lean mass
# body_comp_trunk_right_region_percent_fat  Body composition trunk right region percent fat
# body_comp_trunk_right_tissue_mass                Body composition trunk right tissue mass
# body_comp_trunk_right_tissue_percent_fat  Body composition trunk right tissue percent fat
# body_comp_trunk_right_total_mass                  Body composition trunk right total mass
# body_comp_trunk_tissue_mass                            Body composition trunk tissue mass
# body_comp_trunk_tissue_percent_fat              Body composition trunk tissue percent fat
# body_comp_trunk_total_mass                              Body composition trunk total mass
# total_scan_dose                                                           Total scan dose
# total_scan_sat_area                           Total scan subcutaneous adipose tissue area
# total_scan_sat_mass                           Total scan subcutaneous adipose tissue mass
# total_scan_sat_volume                       Total scan subcutaneous adipose tissue volume
# total_scan_vat_area                               Total scan visceral adipose tissue area
# total_scan_vat_mass                               Total scan visceral adipose tissue mass
# total_scan_vat_volume                           Total scan visceral adipose tissue volume
# body_fat_percentage                              Body fat percentage (from Tanita device)
# bmr                                        Basal metabolic rate (BMR) from Tanita device)
# trunk_fat_percentage                             Trunk fat percentage from Tanita device)
#
#                                           parent_dataframe  \
# tabular_field_name
# collection_date                                        NaN
# timezone                                               NaN
# collection_timestamp                                   NaN
# body_comp_android_bone_mass                            NaN
# body_comp_android_fat_free_mass                        NaN
# body_comp_android_fat_mass                             NaN
# body_comp_android_lean_mass                            NaN
# body_comp_android_region_percent_fat                   NaN
# body_comp_android_tissue_mass                          NaN
# body_comp_android_tissue_percent_fat                   NaN
# body_comp_android_total_mass                           NaN
# body_comp_arm_left_bone_mass                           NaN
# body_comp_arm_left_fat_free_mass                       NaN
# body_comp_arm_left_fat_mass                            NaN
# body_comp_arm_left_lean_mass                           NaN
# body_comp_arm_left_region_percent_fat                  NaN
# body_comp_arm_left_tissue_mass                         NaN
# body_comp_arm_left_tissue_percent_fat                  NaN
# body_comp_arm_left_total_mass                          NaN
# body_comp_arm_right_bone_mass                          NaN
# body_comp_arm_right_fat_free_mass                      NaN
# body_comp_arm_right_fat_mass                           NaN
# body_comp_arm_right_lean_mass                          NaN
# body_comp_arm_right_region_percent_fat                 NaN
# body_comp_arm_right_tissue_mass                        NaN
# body_comp_arm_right_tissue_percent_fat                 NaN
# body_comp_arm_right_total_mass                         NaN
# body_comp_arms_bone_mass                               NaN
# body_comp_arms_diff_bone_mass                          NaN
# body_comp_arms_diff_fat_free_mass                      NaN
# body_comp_arms_diff_fat_mass                           NaN
# body_comp_arms_diff_lean_mass                          NaN
# body_comp_arms_diff_region_percent_fat                 NaN
# body_comp_arms_diff_tissue_mass                        NaN
# body_comp_arms_diff_tissue_percent_fat                 NaN
# body_comp_arms_diff_total_mass                         NaN
# body_comp_arms_fat_free_mass                           NaN
# body_comp_arms_fat_mass                                NaN
# body_comp_arms_lean_mass                               NaN
# body_comp_arms_region_percent_fat                      NaN
# body_comp_arms_tissue_mass                             NaN
# body_comp_arms_tissue_percent_fat                      NaN
# body_comp_arms_total_mass                              NaN
# body_comp_dose                                         NaN
# body_comp_gynoid_bone_mass                             NaN
# body_comp_gynoid_fat_free_mass                         NaN
# body_comp_gynoid_fat_mass                              NaN
# body_comp_gynoid_lean_mass                             NaN
# body_comp_gynoid_region_percent_fat                    NaN
# body_comp_gynoid_tissue_mass                           NaN
# body_comp_gynoid_tissue_percent_fat                    NaN
# body_comp_gynoid_total_mass                            NaN
# body_comp_leg_left_bone_mass                           NaN
# body_comp_leg_left_fat_free_mass                       NaN
# body_comp_leg_left_fat_mass                            NaN
# body_comp_leg_left_lean_mass                           NaN
# body_comp_leg_left_region_percent_fat                  NaN
# body_comp_leg_left_tissue_mass                         NaN
# body_comp_leg_left_tissue_percent_fat                  NaN
# body_comp_leg_left_total_mass                          NaN
# body_comp_leg_right_bone_mass                          NaN
# body_comp_leg_right_fat_free_mass                      NaN
# body_comp_leg_right_fat_mass                           NaN
# body_comp_leg_right_lean_mass                          NaN
# body_comp_leg_right_region_percent_fat                 NaN
# body_comp_leg_right_tissue_mass                        NaN
# body_comp_leg_right_tissue_percent_fat                 NaN
# body_comp_leg_right_total_mass                         NaN
# body_comp_legs_bone_mass                               NaN
# body_comp_legs_diff_bone_mass                          NaN
# body_comp_legs_diff_fat_free_mass                      NaN
# body_comp_legs_diff_fat_mass                           NaN
# body_comp_legs_diff_lean_mass                          NaN
# body_comp_legs_diff_region_percent_fat                 NaN
# body_comp_legs_diff_tissue_mass                        NaN
# body_comp_legs_diff_tissue_percent_fat                 NaN
# body_comp_legs_diff_total_mass                         NaN
# body_comp_legs_fat_free_mass                           NaN
# body_comp_legs_fat_mass                                NaN
# body_comp_legs_lean_mass                               NaN
# body_comp_legs_region_percent_fat                      NaN
# body_comp_legs_tissue_mass                             NaN
# body_comp_legs_tissue_percent_fat                      NaN
# body_comp_legs_total_mass                              NaN
# body_comp_total_bone_mass                              NaN
# body_comp_total_diff_bone_mass                         NaN
# body_comp_total_diff_fat_free_mass                     NaN
# body_comp_total_diff_fat_mass                          NaN
# body_comp_total_diff_lean_mass                         NaN
# body_comp_total_diff_region_percent_fat                NaN
# body_comp_total_diff_tissue_mass                       NaN
# body_comp_total_diff_tissue_percent_fat                NaN
# body_comp_total_diff_total_mass                        NaN
# body_comp_total_fat_free_mass                          NaN
# body_comp_total_fat_mass                               NaN
# body_comp_total_lean_mass                              NaN
# body_comp_total_left_bone_mass                         NaN
# body_comp_total_left_fat_free_mass                     NaN
# body_comp_total_left_fat_mass                          NaN
# body_comp_total_left_lean_mass                         NaN
# body_comp_total_left_region_percent_fat                NaN
# body_comp_total_left_tissue_mass                       NaN
# body_comp_total_left_tissue_percent_fat                NaN
# body_comp_total_left_total_mass                        NaN
# body_comp_total_region_percent_fat                     NaN
# body_comp_total_right_bone_mass                        NaN
# body_comp_total_right_fat_free_mass                    NaN
# body_comp_total_right_fat_mass                         NaN
# body_comp_total_right_lean_mass                        NaN
# body_comp_total_right_region_percent_fat               NaN
# body_comp_total_right_tissue_mass                      NaN
# body_comp_total_right_tissue_percent_fat               NaN
# body_comp_total_right_total_mass                       NaN
# body_comp_total_tissue_mass                            NaN
# body_comp_total_tissue_percent_fat                     NaN
# body_comp_total_total_mass                             NaN
# body_comp_trunk_bone_mass                              NaN
# body_comp_trunk_diff_bone_mass                         NaN
# body_comp_trunk_diff_fat_free_mass                     NaN
# body_comp_trunk_diff_fat_mass                          NaN
# body_comp_trunk_diff_lean_mass                         NaN
# body_comp_trunk_diff_region_percent_fat                NaN
# body_comp_trunk_diff_tissue_mass                       NaN
# body_comp_trunk_diff_tissue_percent_fat                NaN
# body_comp_trunk_diff_total_mass                        NaN
# body_comp_trunk_fat_free_mass                          NaN
# body_comp_trunk_fat_mass                               NaN
# body_comp_trunk_lean_mass                              NaN
# body_comp_trunk_left_bone_mass                         NaN
# body_comp_trunk_left_fat_free_mass                     NaN
# body_comp_trunk_left_fat_mass                          NaN
# body_comp_trunk_left_lean_mass                         NaN
# body_comp_trunk_left_region_percent_fat                NaN
# body_comp_trunk_left_tissue_mass                       NaN
# body_comp_trunk_left_tissue_percent_fat                NaN
# body_comp_trunk_left_total_mass                        NaN
# body_comp_trunk_region_percent_fat                     NaN
# body_comp_trunk_right_bone_mass                        NaN
# body_comp_trunk_right_fat_free_mass                    NaN
# body_comp_trunk_right_fat_mass                         NaN
# body_comp_trunk_right_lean_mass                        NaN
# body_comp_trunk_right_region_percent_fat               NaN
# body_comp_trunk_right_tissue_mass                      NaN
# body_comp_trunk_right_tissue_percent_fat               NaN
# body_comp_trunk_right_total_mass                       NaN
# body_comp_trunk_tissue_mass                            NaN
# body_comp_trunk_tissue_percent_fat                     NaN
# body_comp_trunk_total_mass                             NaN
# total_scan_dose                                        NaN
# total_scan_sat_area                                    NaN
# total_scan_sat_mass                                    NaN
# total_scan_sat_volume                                  NaN
# total_scan_vat_area                                    NaN
# total_scan_vat_mass                                    NaN
# total_scan_vat_volume                                  NaN
# body_fat_percentage                                    NaN
# bmr                                                    NaN
# trunk_fat_percentage                                   NaN
#
#                                                  relative_location  \
# tabular_field_name
# collection_date                           body_composition.parquet
# timezone                                  body_composition.parquet
# collection_timestamp                      body_composition.parquet
# body_comp_android_bone_mass               body_composition.parquet
# body_comp_android_fat_free_mass           body_composition.parquet
# body_comp_android_fat_mass                body_composition.parquet
# body_comp_android_lean_mass               body_composition.parquet
# body_comp_android_region_percent_fat      body_composition.parquet
# body_comp_android_tissue_mass             body_composition.parquet
# body_comp_android_tissue_percent_fat      body_composition.parquet
# body_comp_android_total_mass              body_composition.parquet
# body_comp_arm_left_bone_mass              body_composition.parquet
# body_comp_arm_left_fat_free_mass          body_composition.parquet
# body_comp_arm_left_fat_mass               body_composition.parquet
# body_comp_arm_left_lean_mass              body_composition.parquet
# body_comp_arm_left_region_percent_fat     body_composition.parquet
# body_comp_arm_left_tissue_mass            body_composition.parquet
# body_comp_arm_left_tissue_percent_fat     body_composition.parquet
# body_comp_arm_left_total_mass             body_composition.parquet
# body_comp_arm_right_bone_mass             body_composition.parquet
# body_comp_arm_right_fat_free_mass         body_composition.parquet
# body_comp_arm_right_fat_mass              body_composition.parquet
# body_comp_arm_right_lean_mass             body_composition.parquet
# body_comp_arm_right_region_percent_fat    body_composition.parquet
# body_comp_arm_right_tissue_mass           body_composition.parquet
# body_comp_arm_right_tissue_percent_fat    body_composition.parquet
# body_comp_arm_right_total_mass            body_composition.parquet
# body_comp_arms_bone_mass                  body_composition.parquet
# body_comp_arms_diff_bone_mass             body_composition.parquet
# body_comp_arms_diff_fat_free_mass         body_composition.parquet
# body_comp_arms_diff_fat_mass              body_composition.parquet
# body_comp_arms_diff_lean_mass             body_composition.parquet
# body_comp_arms_diff_region_percent_fat    body_composition.parquet
# body_comp_arms_diff_tissue_mass           body_composition.parquet
# body_comp_arms_diff_tissue_percent_fat    body_composition.parquet
# body_comp_arms_diff_total_mass            body_composition.parquet
# body_comp_arms_fat_free_mass              body_composition.parquet
# body_comp_arms_fat_mass                   body_composition.parquet
# body_comp_arms_lean_mass                  body_composition.parquet
# body_comp_arms_region_percent_fat         body_composition.parquet
# body_comp_arms_tissue_mass                body_composition.parquet
# body_comp_arms_tissue_percent_fat         body_composition.parquet
# body_comp_arms_total_mass                 body_composition.parquet
# body_comp_dose                            body_composition.parquet
# body_comp_gynoid_bone_mass                body_composition.parquet
# body_comp_gynoid_fat_free_mass            body_composition.parquet
# body_comp_gynoid_fat_mass                 body_composition.parquet
# body_comp_gynoid_lean_mass                body_composition.parquet
# body_comp_gynoid_region_percent_fat       body_composition.parquet
# body_comp_gynoid_tissue_mass              body_composition.parquet
# body_comp_gynoid_tissue_percent_fat       body_composition.parquet
# body_comp_gynoid_total_mass               body_composition.parquet
# body_comp_leg_left_bone_mass              body_composition.parquet
# body_comp_leg_left_fat_free_mass          body_composition.parquet
# body_comp_leg_left_fat_mass               body_composition.parquet
# body_comp_leg_left_lean_mass              body_composition.parquet
# body_comp_leg_left_region_percent_fat     body_composition.parquet
# body_comp_leg_left_tissue_mass            body_composition.parquet
# body_comp_leg_left_tissue_percent_fat     body_composition.parquet
# body_comp_leg_left_total_mass             body_composition.parquet
# body_comp_leg_right_bone_mass             body_composition.parquet
# body_comp_leg_right_fat_free_mass         body_composition.parquet
# body_comp_leg_right_fat_mass              body_composition.parquet
# body_comp_leg_right_lean_mass             body_composition.parquet
# body_comp_leg_right_region_percent_fat    body_composition.parquet
# body_comp_leg_right_tissue_mass           body_composition.parquet
# body_comp_leg_right_tissue_percent_fat    body_composition.parquet
# body_comp_leg_right_total_mass            body_composition.parquet
# body_comp_legs_bone_mass                  body_composition.parquet
# body_comp_legs_diff_bone_mass             body_composition.parquet
# body_comp_legs_diff_fat_free_mass         body_composition.parquet
# body_comp_legs_diff_fat_mass              body_composition.parquet
# body_comp_legs_diff_lean_mass             body_composition.parquet
# body_comp_legs_diff_region_percent_fat    body_composition.parquet
# body_comp_legs_diff_tissue_mass           body_composition.parquet
# body_comp_legs_diff_tissue_percent_fat    body_composition.parquet
# body_comp_legs_diff_total_mass            body_composition.parquet
# body_comp_legs_fat_free_mass              body_composition.parquet
# body_comp_legs_fat_mass                   body_composition.parquet
# body_comp_legs_lean_mass                  body_composition.parquet
# body_comp_legs_region_percent_fat         body_composition.parquet
# body_comp_legs_tissue_mass                body_composition.parquet
# body_comp_legs_tissue_percent_fat         body_composition.parquet
# body_comp_legs_total_mass                 body_composition.parquet
# body_comp_total_bone_mass                 body_composition.parquet
# body_comp_total_diff_bone_mass            body_composition.parquet
# body_comp_total_diff_fat_free_mass        body_composition.parquet
# body_comp_total_diff_fat_mass             body_composition.parquet
# body_comp_total_diff_lean_mass            body_composition.parquet
# body_comp_total_diff_region_percent_fat   body_composition.parquet
# body_comp_total_diff_tissue_mass          body_composition.parquet
# body_comp_total_diff_tissue_percent_fat   body_composition.parquet
# body_comp_total_diff_total_mass           body_composition.parquet
# body_comp_total_fat_free_mass             body_composition.parquet
# body_comp_total_fat_mass                  body_composition.parquet
# body_comp_total_lean_mass                 body_composition.parquet
# body_comp_total_left_bone_mass            body_composition.parquet
# body_comp_total_left_fat_free_mass        body_composition.parquet
# body_comp_total_left_fat_mass             body_composition.parquet
# body_comp_total_left_lean_mass            body_composition.parquet
# body_comp_total_left_region_percent_fat   body_composition.parquet
# body_comp_total_left_tissue_mass          body_composition.parquet
# body_comp_total_left_tissue_percent_fat   body_composition.parquet
# body_comp_total_left_total_mass           body_composition.parquet
# body_comp_total_region_percent_fat        body_composition.parquet
# body_comp_total_right_bone_mass           body_composition.parquet
# body_comp_total_right_fat_free_mass       body_composition.parquet
# body_comp_total_right_fat_mass            body_composition.parquet
# body_comp_total_right_lean_mass           body_composition.parquet
# body_comp_total_right_region_percent_fat  body_composition.parquet
# body_comp_total_right_tissue_mass         body_composition.parquet
# body_comp_total_right_tissue_percent_fat  body_composition.parquet
# body_comp_total_right_total_mass          body_composition.parquet
# body_comp_total_tissue_mass               body_composition.parquet
# body_comp_total_tissue_percent_fat        body_composition.parquet
# body_comp_total_total_mass                body_composition.parquet
# ...
# body_comp_total_left_fat_free_mass                 2020-06-09
# body_comp_total_left_fat_mass                      2020-06-09
# body_comp_total_left_lean_mass                     2020-06-09
# body_comp_total_left_region_percent_fat            2020-06-09
# body_comp_total_left_tissue_mass                   2020-06-09
# body_comp_total_left_tissue_percent_fat            2020-06-09
# body_comp_total_left_total_mass                    2020-06-09
# body_comp_total_region_percent_fat                 2020-06-09
# body_comp_total_right_bone_mass                    2020-06-09
# body_comp_total_right_fat_free_mass                2020-06-09
# body_comp_total_right_fat_mass                     2020-06-09
# body_comp_total_right_lean_mass                    2020-06-09
# body_comp_total_right_region_percent_fat           2020-06-09
# body_comp_total_right_tissue_mass                  2020-06-09
# body_comp_total_right_tissue_percent_fat           2020-06-09
# body_comp_total_right_total_mass                   2020-06-09
# body_comp_total_tissue_mass                        2020-06-09
# body_comp_total_tissue_percent_fat                 2020-06-09
# body_comp_total_total_mass                         2020-06-09
# body_comp_trunk_bone_mass                          2020-06-09
# body_comp_trunk_diff_bone_mass                     2020-06-09
# body_comp_trunk_diff_fat_free_mass                 2020-06-09
# body_comp_trunk_diff_fat_mass                      2020-06-09
# body_comp_trunk_diff_lean_mass                     2020-06-09
# body_comp_trunk_diff_region_percent_fat            2020-06-09
# body_comp_trunk_diff_tissue_mass                   2020-06-09
# body_comp_trunk_diff_tissue_percent_fat            2020-06-09
# body_comp_trunk_diff_total_mass                    2020-06-09
# body_comp_trunk_fat_free_mass                      2020-06-09
# body_comp_trunk_fat_mass                           2020-06-09
# body_comp_trunk_lean_mass                          2020-06-09
# body_comp_trunk_left_bone_mass                     2020-06-09
# body_comp_trunk_left_fat_free_mass                 2020-06-09
# body_comp_trunk_left_fat_mass                      2020-06-09
# body_comp_trunk_left_lean_mass                     2020-06-09
# body_comp_trunk_left_region_percent_fat            2020-06-09
# body_comp_trunk_left_tissue_mass                   2020-06-09
# body_comp_trunk_left_tissue_percent_fat            2020-06-09
# body_comp_trunk_left_total_mass                    2020-06-09
# body_comp_trunk_region_percent_fat                 2020-06-09
# body_comp_trunk_right_bone_mass                    2020-06-09
# body_comp_trunk_right_fat_free_mass                2020-06-09
# body_comp_trunk_right_fat_mass                     2020-06-09
# body_comp_trunk_right_lean_mass                    2020-06-09
# body_comp_trunk_right_region_percent_fat           2020-06-09
# body_comp_trunk_right_tissue_mass                  2020-06-09
# body_comp_trunk_right_tissue_percent_fat           2020-06-09
# body_comp_trunk_right_total_mass                   2020-06-09
# body_comp_trunk_tissue_mass                        2020-06-09
# body_comp_trunk_tissue_percent_fat                 2020-06-09
# body_comp_trunk_total_mass                         2020-06-09
# total_scan_dose                                    2020-06-09
# total_scan_sat_area                                2020-06-09
# total_scan_sat_mass                                2020-06-09
# total_scan_sat_volume                              2020-06-09
# total_scan_vat_area                                2020-06-09
# total_scan_vat_mass                                2020-06-09
# total_scan_vat_volume                              2020-06-09
# body_fat_percentage                       2019-01-29 00:00:00
# bmr                                       2019-01-29 00:00:00
# trunk_fat_percentage                      2019-01-29 00:00:00
#
#                                                             pandas_dtype
# tabular_field_name
# collection_date                                           datetime64[ns]
# timezone                                                          string
# collection_timestamp                      datetime64[ns, Asia/Jerusalem]
# body_comp_android_bone_mass                                        float
# body_comp_android_fat_free_mass                                    float
# body_comp_android_fat_mass                                         float
# body_comp_android_lean_mass                                        float
# body_comp_android_region_percent_fat                               float
# body_comp_android_tissue_mass                                      float
# body_comp_android_tissue_percent_fat                               float
# body_comp_android_total_mass                                       float
# body_comp_arm_left_bone_mass                                       float
# body_comp_arm_left_fat_free_mass                                   float
# body_comp_arm_left_fat_mass                                        float
# body_comp_arm_left_lean_mass                                       float
# body_comp_arm_left_region_percent_fat                              float
# body_comp_arm_left_tissue_mass                                     float
# body_comp_arm_left_tissue_percent_fat                              float
# body_comp_arm_left_total_mass                                      float
# body_comp_arm_right_bone_mass                                      float
# body_comp_arm_right_fat_free_mass                                  float
# body_comp_arm_right_fat_mass                                       float
# body_comp_arm_right_lean_mass                                      float
# body_comp_arm_right_region_percent_fat                             float
# body_comp_arm_right_tissue_mass                                    float
# body_comp_arm_right_tissue_percent_fat                             float
# body_comp_arm_right_total_mass                                     float
# body_comp_arms_bone_mass                                           float
# body_comp_arms_diff_bone_mass                                      float
# body_comp_arms_diff_fat_free_mass                                  float
# body_comp_arms_diff_fat_mass                                       float
# body_comp_arms_diff_lean_mass                                      float
# body_comp_arms_diff_region_percent_fat                             float
# body_comp_arms_diff_tissue_mass                                    float
# body_comp_arms_diff_tissue_percent_fat                             float
# body_comp_arms_diff_total_mass                                     float
# body_comp_arms_fat_free_mass                                       float
# body_comp_arms_fat_mass                                            float
# body_comp_arms_lean_mass                                           float
# body_comp_arms_region_percent_fat                                  float
# body_comp_arms_tissue_mass                                         float
# body_comp_arms_tissue_percent_fat                                  float
# body_comp_arms_total_mass                                          float
# body_comp_dose                                                     float
# body_comp_gynoid_bone_mass                                         float
# body_comp_gynoid_fat_free_mass                                     float
# body_comp_gynoid_fat_mass                                          float
# body_comp_gynoid_lean_mass                                         float
# body_comp_gynoid_region_percent_fat                                float
# body_comp_gynoid_tissue_mass                                       float
# body_comp_gynoid_tissue_percent_fat                                float
# body_comp_gynoid_total_mass                                        float
# body_comp_leg_left_bone_mass                                       float
# body_comp_leg_left_fat_free_mass                                   float
# body_comp_leg_left_fat_mass                                        float
# body_comp_leg_left_lean_mass                                       float
# body_comp_leg_left_region_percent_fat                              float
# body_comp_leg_left_tissue_mass                                     float
# body_comp_leg_left_tissue_percent_fat                              float
# body_comp_leg_left_total_mass                                      float
# body_comp_leg_right_bone_mass                                      float
# body_comp_leg_right_fat_free_mass                                  float
# body_comp_leg_right_fat_mass                                       float
# body_comp_leg_right_lean_mass                                      float
# body_comp_leg_right_region_percent_fat                             float
# body_comp_leg_right_tissue_mass                                    float
# body_comp_leg_right_tissue_percent_fat                             float
# body_comp_leg_right_total_mass                                     float
# body_comp_legs_bone_mass                                           float
# body_comp_legs_diff_bone_mass                                      float
# body_comp_legs_diff_fat_free_mass                                  float
# body_comp_legs_diff_fat_mass                                       float
# body_comp_legs_diff_lean_mass                                      float
# body_comp_legs_diff_region_percent_fat                             float
# body_comp_legs_diff_tissue_mass                                    float
# body_comp_legs_diff_tissue_percent_fat                             float
# body_comp_legs_diff_total_mass                                     float
# body_comp_legs_fat_free_mass                                       float
# body_comp_legs_fat_mass                                            float
# body_comp_legs_lean_mass                                           float
# body_comp_legs_region_percent_fat                                  float
# body_comp_legs_tissue_mass                                         float
# body_comp_legs_tissue_percent_fat                                  float
# body_comp_legs_total_mass                                          float
# body_comp_total_bone_mass                                          float
# body_comp_total_diff_bone_mass                                     float
# body_comp_total_diff_fat_free_mass                                 float
# body_comp_total_diff_fat_mass                                      float
# body_comp_total_diff_lean_mass                                     float
# body_comp_total_diff_region_percent_fat                            float
# body_comp_total_diff_tissue_mass                                   float
# body_comp_total_diff_tissue_percent_fat                            float
# body_comp_total_diff_total_mass                                    float
# body_comp_total_fat_free_mass                                      float
# body_comp_total_fat_mass                                           float
# body_comp_total_lean_mass                                          float
# body_comp_total_left_bone_mass                                     float
# body_comp_total_left_fat_free_mass                                 float
# body_comp_total_left_fat_mass                                      float
# body_comp_total_left_lean_mass                                     float
# body_comp_total_left_region_percent_fat                            float
# body_comp_total_left_tissue_mass                                   float
# body_comp_total_left_tissue_percent_fat                            float
# body_comp_total_left_total_mass                                    float
# body_comp_total_region_percent_fat                                 float
# body_comp_total_right_bone_mass                                    float
# body_comp_total_right_fat_free_mass                                float
# body_comp_total_right_fat_mass                                     float
# body_comp_total_right_lean_mass                                    float
# body_comp_total_right_region_percent_fat                           float
# body_comp_total_right_tissue_mass                                  float
# body_comp_total_right_tissue_percent_fat                           float
# body_comp_total_right_total_mass                                   float
# body_comp_total_tissue_mass                                        float
# body_comp_total_tissue_percent_fat                                 float
# body_comp_total_total_mass                                         float
# body_comp_trunk_bone_mass                                          float
# body_comp_trunk_diff_bone_mass                                     float
# body_comp_trunk_diff_fat_free_mass                                 float
# body_comp_trunk_diff_fat_mass                                      float
# body_comp_trunk_diff_lean_mass                                     float
# body_comp_trunk_diff_region_percent_fat                            float
# body_comp_trunk_diff_tissue_mass                                   float
# body_comp_trunk_diff_tissue_percent_fat                            float
# body_comp_trunk_diff_total_mass                                    float
# body_comp_trunk_fat_free_mass                                      float
# body_comp_trunk_fat_mass                                           float
# body_comp_trunk_lean_mass                                          float
# body_comp_trunk_left_bone_mass                                     float
# body_comp_trunk_left_fat_free_mass                                 float
# body_comp_trunk_left_fat_mass                                      float
# body_comp_trunk_left_lean_mass                                     float
# body_comp_trunk_left_region_percent_fat                            float
# body_comp_trunk_left_tissue_mass                                   float
# body_comp_trunk_left_tissue_percent_fat                            float
# body_comp_trunk_left_total_mass                                    float
# body_comp_trunk_region_percent_fat                                 float
# body_comp_trunk_right_bone_mass                                    float
# body_comp_trunk_right_fat_free_mass                                float
# body_comp_trunk_right_fat_mass                                     float
# body_comp_trunk_right_lean_mass                                    float
# body_comp_trunk_right_region_percent_fat                           float
# body_comp_trunk_right_tissue_mass                                  float
# body_comp_trunk_right_tissue_percent_fat                           float
# body_comp_trunk_right_total_mass                                   float
# body_comp_trunk_tissue_mass                                        float
# body_comp_trunk_tissue_percent_fat                                 float
# body_comp_trunk_total_mass                                         float
# total_scan_dose                                                    float
# total_scan_sat_area                                                float
# total_scan_sat_mass                                                float
# total_scan_sat_volume                                              float
# total_scan_vat_area                                                float
# total_scan_vat_mass                                                float
# total_scan_vat_volume                                              float
# body_fat_percentage                                                float
# bmr                                                                float
# trunk_fat_percentage                                               float
