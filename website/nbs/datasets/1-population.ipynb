# %% [raw]
# ---
# output-file: 1-population.html
# title: 1-population
#
# ---

# %% [markdown]
# # 1 - population
#
# Population characteristics of the Human Phenotype Project study participants including birth month and year, sex and visits information.
#
# The information is stored in 2 parquet files:
#
# - population.parquet - contains sex, month and year of birth per participant
# - events.parquet - also contains information regarding participant visits and calls

# %%
#| hide
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('population', age_sex_dataset=None)
dl
# Out:
# DataLoader for population with
# 10 fields
# 1 tables: ['events']

# %%
dl.dict
# Out:
#                                          field_string  \
# tabular_field_name
# month_of_birth                         Month of birth
# year_of_birth                           Year of birth
# sex                                               Sex
# research_stage_type               Research stage type
# visit_center                             Visit center
# research_stage_timestamp  Timestamp of research stage
# research_stage_date            Date of research stage
# age_at_research_stage           Age at research stage
# study_id                                     Study ID
# timezone                                     Timezone
#
#                                                          description_string  \
# tabular_field_name
# month_of_birth                                               Month of birth
# year_of_birth                                                 Year of birth
# sex                                                                     Sex
# research_stage_type                          The type of the research stage
# visit_center                              The name of the assessment center
# research_stage_timestamp  The timestamp of the research stage. For examp...
# research_stage_date       The date of the research stage. For example, i...
# age_at_research_stage     The age of the participant during the research...
# study_id                                               The study identifier
# timezone                                                           Timezone
#
#                           parent_dataframe relative_location  \
# tabular_field_name
# month_of_birth                         NaN    events.parquet
# year_of_birth                          NaN    events.parquet
# sex                                    NaN    events.parquet
# research_stage_type                    NaN    events.parquet
# visit_center                           NaN    events.parquet
# research_stage_timestamp               NaN    events.parquet
# research_stage_date                    NaN    events.parquet
# age_at_research_stage                  NaN    events.parquet
# study_id                               NaN    events.parquet
# timezone                               NaN    events.parquet
#
#                                       value_type units  sampling_rate  \
# tabular_field_name
# month_of_birth                           Integer  None            NaN
# year_of_birth                            Integer  None            NaN
# sex                         Categorical (single)  None            NaN
# research_stage_type       Categorical (multiple)  None            NaN
# visit_center              Categorical (multiple)  None            NaN
# research_stage_timestamp                    Date  None            NaN
# research_stage_date                         Date  None            NaN
# age_at_research_stage                    Integer  None            NaN
# study_id                  Categorical (multiple)  None            NaN
# timezone                                    Date  None            NaN
#
#                          item_type array cohorts data_type       debut  \
# tabular_field_name
# month_of_birth                Data    No     10K   Tabular  2019-01-01
# year_of_birth                 Data    No     10K   Tabular  2019-01-01
# sex                           Data    No     10K   Tabular  2019-01-01
# research_stage_type           Data    No     10K   Tabular  2019-01-01
# visit_center                  Data    No     10K   Tabular  2019-01-01
# research_stage_timestamp      Data    No     10K   Tabular  2019-01-01
# research_stage_date           Data    No     10K   Tabular  2019-01-01
# age_at_research_stage         Data    No     10K   Tabular  2019-01-01
# study_id                      Data    No     10K   Tabular  2019-01-01
# timezone                      Data    No     10K   Tabular  2019-01-01
#
#                                             pandas_dtype
# tabular_field_name
# month_of_birth                                       int
# year_of_birth                                        int
# sex                                             category
# research_stage_type                             category
# visit_center                                    category
# research_stage_timestamp  datetime64[ns, Asia/Jerusalem]
# research_stage_date                       datetime64[ns]
# age_at_research_stage                              float
# study_id                                        category
# timezone                                          string
