# %% [raw]
# ---
# output-file: 013-gut_microbiome.html
# title: 013-gut_microbiome
# ---

# %% [markdown]
# # Gut microbiome dataset
#
# Metagenomics is the study of genetic material from environmental samples, including microbial communities. It involves sequencing the DNA of all microorganisms in the sample, rather than isolating individual organisms. Metagenomics enables the identification and functional analysis of microorganisms in diverse environments, including soil, water, and the human body.
#
# This dataset maps out the human gut microbiota per participant via shotgun metagenomic sequencing given stool samples. It is then compared to known references of gut flora to measure prevalence of specific microbes.
#
# Gut microbiome metagenomics can be used to identify potential biomarkers of disease, develop personalized treatment strategies, and better understand the complex relationship between the gut microbiota and human physiology. It has already been providing insights into the role of gut microbes in various diseases such as obesity, diabetes and IBD.
#
# To measure the genetic makeup of the human gut flora given stool samples via metagenomics, the following steps done:
#
# 1. Collection of stool sample: For each visit, a stool sample is collected from the individual and stored appropriately to preserve the microbial community.
# 2. DNA extraction: DNA is extracted from the stool sample using specialized techniques to isolate the microbial DNA from other materials present in the sample.
# 3. DNA fragmentation and sequencing: The extracted DNA is then fragmented into small pieces and sequenced using high-throughput sequencing technologies.
# 4. Quality control: The resulting raw sequencing data is then pre-processed, removing low-quality reads and artifacts of the sequencing methodology.
# 5. Taxonomic classification: The processed sequencing data is then compared to databases of known microbial sequences to identify and classify the microbial species presence and their respective abundances in the sample.
#
# ### Data availability:
# The information is stored in multiple parquet files:
# - `gut_microbiome.parquet`: Sequencing and QC statistics.
# - `urs`: Segal Lab relative abundance.
# - `metaphlan_*`: 8 tables with MetaPhlAn 4 relative abundances, separated by taxonomic levels.

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('gut_microbiome')
dl
# Out:
# DataLoader for gut_microbiome with
# 46 fields
# 2 tables: ['gut_microbiome', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                                                                      field_string  \
# tabular_field_name
# collection_timestamp                                            Sampled timestamp
# collection_date                                                      Sampled date
# timezone                                                                 Timezone
# sample_name                                                           Sample name
# urs_metadata_parquet                                      URS abundances metadata
# urs_abundance_parquet                                              URS abundances
# metaphlan_abundance_kingdom_parquet               MetaPhlAn 4 abundance (kingdom)
# metaphlan_abundance_phylum_parquet                 MetaPhlAn 4 abundance (phylum)
# metaphlan_abundance_class_parquet                   MetaPhlAn 4 abundance (class)
# metaphlan_abundance_order_parquet                   MetaPhlAn 4 abundance (order)
# metaphlan_abundance_family_parquet                MetaPhlAn 4 abundance (famiily)
# metaphlan_abundance_genus_parquet                   MetaPhlAn 4 abundance (genus)
# metaphlan_abundance_species_parquet               MetaPhlAn 4 abundance (species)
# metaphlan_abundance_strain_parquet                 MetaPhlAn 4 abundance (strain)
# raw_fastq                                                          Raw FASTQ path
# trimmed_fastq                                                  Post QC FASTQ path
# non_human_fastq                                              Non-human FASTQ path
# fastqc_html                                                      FASTQC HTML path
# fastqc_zip                                                        FASTQC zip path
# human_variants_bed                                     Human variants plink (BED)
# human_variants_bim                                     Human variants plink (BIM)
# human_variants_fam                                     Human variants plink (FAM)
# urs_mapped_bam                                                URS mapped bam path
# urs_mapped_single_bacteria_per_read_bam     URS mapped bam path (best match only)
# urs_mapped_metrics_txt                               URS Bowtie2 metric file path
# urs_mapped_results_csv                                        URS abundances path
# metaphlan4_results_txt                                 MetaPhlAn 4 abundance path
# duplicate_reads_count                                       Duplicate reads count
# excessive_duplicate_reads                               Excessive duplicate reads
# raw_read_count                                                    Raw reads count
# trimmed_read_count                                            Post QC reads count
# human_variant_count                             Detectable human variants count
# human_read_count                                                Human reads count
# urs_mapped_read_count                                      URS mapped reads count
# wgs_compare_error_total                           WGS vs stool compare - #Errors
# wgs_compare_errors_percent                        WGS vs stool compare - %Errors
# wgs_compare_count_homozygous             WGS vs stool compare - #Homozygous SNPs
# wgs_compare_count_variants                           WGS vs stool compare - #SNPs
# wgs_compare_pass                         WGS vs stool compare - Passed Validation
# raw_read_length                                               Legnth of raw reads
# single_ended                                                      Is single ended
# is_genotek                                                              Vial type
# run_name                                                               Batch name
# wgs_dna_code                                                         WGS DNA code
#
#                                                                         description_string  \
# tabular_field_name
# collection_timestamp                                                 Time sample was given
# collection_date                                                      Date sample was given
# timezone                                                                          Timezone
# sample_name                                                                    Sample Name
# urs_metadata_parquet                                  Organism classification and taxonomy
# urs_abundance_parquet                    Aggregated abundance (mapped to the URS refere...
# metaphlan_abundance_kingdom_parquet      Aggregated abundance (MetaPhlAn 4) at the king...
# metaphlan_abundance_phylum_parquet       Aggregated abundance (MetaPhlAn 4) at the phyl...
# metaphlan_abundance_class_parquet        Aggregated abundance (MetaPhlAn 4) at the clas...
# metaphlan_abundance_order_parquet        Aggregated abundance (MetaPhlAn 4) at the orde...
# metaphlan_abundance_family_parquet       Aggregated abundance (MetaPhlAn 4) at the fami...
# metaphlan_abundance_genus_parquet        Aggregated abundance (MetaPhlAn 4) at the genu...
# metaphlan_abundance_species_parquet      Aggregated abundance (MetaPhlAn 4) at the spec...
# metaphlan_abundance_strain_parquet       Aggregated abundance (MetaPhlAn 4) at the stra...
# raw_fastq                                                          The original FASTQ file
# trimmed_fastq                            FASTQ file post Trimmomatic (removing adaptors...
# non_human_fastq                          FASTQ file for non-human reads (Post Trimmomatic)
# fastqc_html                                         FASTQC Output for Post QC FASTQ - HTML
# fastqc_zip                                           FASTQC Output for Post QC FASTQ - Zip
# human_variants_bed                       Plink file containing all the human alleles ex...
# human_variants_bim                       Plink file containing all the human variants e...
# human_variants_fam                          Plink file containing only the specific sample
# urs_mapped_bam                                          Reads aligned to the URS reference
# urs_mapped_single_bacteria_per_read_bam  Reads aligned to the URS reference, but only t...
# urs_mapped_metrics_txt                         Bowtie2 metric output for the URS alignment
# urs_mapped_results_csv                                             URS relative abundances
# metaphlan4_results_txt                                      MetaPhlAn4 relative abundances
# duplicate_reads_count                                     #Reads that are exact duplciates
# excessive_duplicate_reads                Whether the sample contain an abnormal amount ...
# raw_read_count                                                #Reads in the original FASTQ
# trimmed_read_count                                             #Reads in the Post QC FASTQ
# human_variant_count                                           #Variants in the Plink files
# human_read_count                                      #Reads successfuly aligned to humans
# urs_mapped_read_count                    #Reads mapped to the URS reference panel (not ...
# wgs_compare_error_total                  #Errors when comparing homozygous SNPs found i...
# wgs_compare_errors_percent               %Errors when comparing homozygous SNPs found i...
# wgs_compare_count_homozygous                        #homozygous SNPs found in stool vs WGS
# wgs_compare_count_variants                                     #SNPs found in stool vs WGS
# wgs_compare_pass                                            Passed Stool Vs WGS validation
# raw_read_length                                  Length of reads (from the Raw FASTQ file)
# single_ended                                          Single ended (SE) or pair ended (PE)
# is_genotek                                          Type of vial used for stool collecting
# run_name                                             The run-name of the sample's batch(s)
# wgs_dna_code                                                                  WGS DNA code
#
#                                                              relative_location  \
# tabular_field_name
# collection_timestamp                     gut_microbiome/gut_microbiome.parquet
# collection_date                          gut_microbiome/gut_microbiome.parquet
# timezone                                 gut_microbiome/gut_microbiome.parquet
# sample_name                              gut_microbiome/gut_microbiome.parquet
# urs_metadata_parquet                     gut_microbiome/gut_microbiome.parquet
# urs_abundance_parquet                    gut_microbiome/gut_microbiome.parquet
# metaphlan_abundance_kingdom_parquet      gut_microbiome/gut_microbiome.parquet
# metaphlan_abundance_phylum_parquet       gut_microbiome/gut_microbiome.parquet
# metaphlan_abundance_class_parquet        gut_microbiome/gut_microbiome.parquet
# metaphlan_abundance_order_parquet        gut_microbiome/gut_microbiome.parquet
# metaphlan_abundance_family_parquet       gut_microbiome/gut_microbiome.parquet
# metaphlan_abundance_genus_parquet        gut_microbiome/gut_microbiome.parquet
# metaphlan_abundance_species_parquet      gut_microbiome/gut_microbiome.parquet
# metaphlan_abundance_strain_parquet       gut_microbiome/gut_microbiome.parquet
# raw_fastq                                gut_microbiome/gut_microbiome.parquet
# trimmed_fastq                            gut_microbiome/gut_microbiome.parquet
# non_human_fastq                          gut_microbiome/gut_microbiome.parquet
# fastqc_html                              gut_microbiome/gut_microbiome.parquet
# fastqc_zip                               gut_microbiome/gut_microbiome.parquet
# human_variants_bed                       gut_microbiome/gut_microbiome.parquet
# human_variants_bim                       gut_microbiome/gut_microbiome.parquet
# human_variants_fam                       gut_microbiome/gut_microbiome.parquet
# urs_mapped_bam                           gut_microbiome/gut_microbiome.parquet
# urs_mapped_single_bacteria_per_read_bam  gut_microbiome/gut_microbiome.parquet
# urs_mapped_metrics_txt                   gut_microbiome/gut_microbiome.parquet
# urs_mapped_results_csv                   gut_microbiome/gut_microbiome.parquet
# metaphlan4_results_txt                   gut_microbiome/gut_microbiome.parquet
# duplicate_reads_count                    gut_microbiome/gut_microbiome.parquet
# excessive_duplicate_reads                gut_microbiome/gut_microbiome.parquet
# raw_read_count                           gut_microbiome/gut_microbiome.parquet
# trimmed_read_count                       gut_microbiome/gut_microbiome.parquet
# human_variant_count                      gut_microbiome/gut_microbiome.parquet
# human_read_count                         gut_microbiome/gut_microbiome.parquet
# urs_mapped_read_count                    gut_microbiome/gut_microbiome.parquet
# wgs_compare_error_total                  gut_microbiome/gut_microbiome.parquet
# wgs_compare_errors_percent               gut_microbiome/gut_microbiome.parquet
# wgs_compare_count_homozygous             gut_microbiome/gut_microbiome.parquet
# wgs_compare_count_variants               gut_microbiome/gut_microbiome.parquet
# wgs_compare_pass                         gut_microbiome/gut_microbiome.parquet
# raw_read_length                          gut_microbiome/gut_microbiome.parquet
# single_ended                             gut_microbiome/gut_microbiome.parquet
# is_genotek                               gut_microbiome/gut_microbiome.parquet
# run_name                                 gut_microbiome/gut_microbiome.parquet
# wgs_dna_code                             gut_microbiome/gut_microbiome.parquet
#
#                                                    value_type units  \
# tabular_field_name
# collection_timestamp                                     Date  Time
# collection_date                                          Date  Time
# timezone                                                 Text   NaN
# sample_name                                              Text   NaN
# urs_metadata_parquet                            Binary string   NaN
# urs_abundance_parquet                           Binary string   NaN
# metaphlan_abundance_kingdom_parquet             Binary string   NaN
# metaphlan_abundance_phylum_parquet              Binary string   NaN
# metaphlan_abundance_class_parquet               Binary string   NaN
# metaphlan_abundance_order_parquet               Binary string   NaN
# metaphlan_abundance_family_parquet              Binary string   NaN
# metaphlan_abundance_genus_parquet               Binary string   NaN
# metaphlan_abundance_species_parquet             Binary string   NaN
# metaphlan_abundance_strain_parquet              Binary string   NaN
# raw_fastq                                       Binary string   NaN
# trimmed_fastq                                   Binary string   NaN
# non_human_fastq                                 Binary string   NaN
# fastqc_html                                     Binary string   NaN
# fastqc_zip                                      Binary string   NaN
# human_variants_bed                              Binary string   NaN
# human_variants_bim                              Binary string   NaN
# human_variants_fam                              Binary string   NaN
# urs_mapped_bam                                  Binary string   NaN
# urs_mapped_single_bacteria_per_read_bam         Binary string   NaN
# urs_mapped_metrics_txt                          Binary string   NaN
# urs_mapped_results_csv                          Binary string   NaN
# metaphlan4_results_txt                          Binary string   NaN
# duplicate_reads_count                                 Integer   NaN
# excessive_duplicate_reads                             Boolean   NaN
# raw_read_count                                        Integer   NaN
# trimmed_read_count                                    Integer   NaN
# human_variant_count                                   Integer   NaN
# human_read_count                                      Integer   NaN
# urs_mapped_read_count                                 Integer   NaN
# wgs_compare_error_total                               Integer   NaN
# wgs_compare_errors_percent                         Continuous   NaN
# wgs_compare_count_homozygous                          Integer   NaN
# wgs_compare_count_variants                            Integer   NaN
# wgs_compare_pass                         Categorical (single)   NaN
# raw_read_length                                       Integer   NaN
# single_ended                                          Boolean   NaN
# is_genotek                                            Boolean   NaN
# run_name                                                 Text   NaN
# wgs_dna_code                                          Integer   NaN
#
#                                          sampling_rate item_type   array  \
# tabular_field_name
# collection_timestamp                               NaN      Data  Single
# collection_date                                    NaN      Data  Single
# timezone                                           NaN      Data  Single
# sample_name                                        NaN      Data  Single
# urs_metadata_parquet                               NaN      Bulk  Single
# urs_abundance_parquet                              NaN      Bulk  Single
# metaphlan_abundance_kingdom_parquet                NaN      Bulk  Single
# metaphlan_abundance_phylum_parquet                 NaN      Bulk  Single
# metaphlan_abundance_class_parquet                  NaN      Bulk  Single
# metaphlan_abundance_order_parquet                  NaN      Bulk  Single
# metaphlan_abundance_family_parquet                 NaN      Bulk  Single
# metaphlan_abundance_genus_parquet                  NaN      Bulk  Single
# metaphlan_abundance_species_parquet                NaN      Bulk  Single
# metaphlan_abundance_strain_parquet                 NaN      Bulk  Single
# raw_fastq                                          NaN      Bulk  Single
# trimmed_fastq                                      NaN      Bulk  Single
# non_human_fastq                                    NaN      Bulk  Single
# fastqc_html                                        NaN      Bulk  Single
# fastqc_zip                                         NaN      Bulk  Single
# human_variants_bed                                 NaN      Bulk  Single
# human_variants_bim                                 NaN      Bulk  Single
# human_variants_fam                                 NaN      Bulk  Single
# urs_mapped_bam                                     NaN      Bulk  Single
# urs_mapped_single_bacteria_per_read_bam            NaN      Bulk  Single
# urs_mapped_metrics_txt                             NaN      Bulk  Single
# urs_mapped_results_csv                             NaN      Bulk  Single
# metaphlan4_results_txt                             NaN      Bulk  Single
# duplicate_reads_count                              NaN      Data  Single
# excessive_duplicate_reads                          NaN      Data  Single
# raw_read_count                                     NaN      Data  Single
# trimmed_read_count                                 NaN      Data  Single
# human_variant_count                                NaN      Data  Single
# human_read_count                                   NaN      Data  Single
# urs_mapped_read_count                              NaN      Data  Single
# wgs_compare_error_total                            NaN      Data  Single
# wgs_compare_errors_percent                         NaN      Data  Single
# wgs_compare_count_homozygous                       NaN      Data  Single
# wgs_compare_count_variants                         NaN      Data  Single
# wgs_compare_pass                                   NaN      Data  Single
# raw_read_length                                    NaN      Data  Single
# single_ended                                       NaN      Data  Single
# is_genotek                                         NaN      Data  Single
# run_name                                           NaN      Data  Single
# wgs_dna_code                                       NaN      Data  Single
#
#                                         cohorts  data_type  debut  \
# tabular_field_name
# collection_timestamp                        10k   Metadata    NaN
# collection_date                             10k   Metadata    NaN
# timezone                                    10k   Metadata    NaN
# sample_name                                 10k   Metadata    NaN
# urs_metadata_parquet                        10k  Molecular    NaN
# urs_abundance_parquet                       10k  Molecular    NaN
# metaphlan_abundance_kingdom_parquet         10k  Molecular    NaN
# metaphlan_abundance_phylum_parquet          10k  Molecular    NaN
# metaphlan_abundance_class_parquet           10k  Molecular    NaN
# metaphlan_abundance_order_parquet           10k  Molecular    NaN
# metaphlan_abundance_family_parquet          10k  Molecular    NaN
# metaphlan_abundance_genus_parquet           10k  Molecular    NaN
# metaphlan_abundance_species_parquet         10k  Molecular    NaN
# metaphlan_abundance_strain_parquet          10k  Molecular    NaN
# raw_fastq                                   10k  Molecular    NaN
# trimmed_fastq                               10k  Molecular    NaN
# non_human_fastq                             10k  Molecular    NaN
# fastqc_html                                 10k   Metadata    NaN
# fastqc_zip                                  10k   Metadata    NaN
# human_variants_bed                          10k  Molecular    NaN
# human_variants_bim                          10k  Molecular    NaN
# human_variants_fam                          10k  Molecular    NaN
# urs_mapped_bam                              10k  Molecular    NaN
# urs_mapped_single_bacteria_per_read_bam     10k  Molecular    NaN
# urs_mapped_metrics_txt                      10k   Metadata    NaN
# urs_mapped_results_csv                      10k    Tabular    NaN
# metaphlan4_results_txt                      10k    Tabular    NaN
# duplicate_reads_count                       10k   Metadata    NaN
# excessive_duplicate_reads                   10k   Metadata    NaN
# raw_read_count                              10k   Metadata    NaN
# trimmed_read_count                          10k   Metadata    NaN
# human_variant_count                         10k   Metadata    NaN
# human_read_count                            10k   Metadata    NaN
# urs_mapped_read_count                       10k   Metadata    NaN
# wgs_compare_error_total                     10k   Metadata    NaN
# wgs_compare_errors_percent                  10k   Metadata    NaN
# wgs_compare_count_homozygous                10k   Metadata    NaN
# wgs_compare_count_variants                  10k   Metadata    NaN
# wgs_compare_pass                            10k   Metadata    NaN
# raw_read_length                             10k   Metadata    NaN
# single_ended                                10k   Metadata    NaN
# is_genotek                                  10k   Metadata    NaN
# run_name                                    10k   Metadata    NaN
# wgs_dna_code                                10k   Metadata    NaN
#
#                                                            pandas_dtype  \
# tabular_field_name
# collection_timestamp                     datetime64[ns, Asia/Jerusalem]
# collection_date                                          datetime64[ns]
# timezone                                                         string
# sample_name                                                      string
# urs_metadata_parquet                                           category
# urs_abundance_parquet                                          category
# metaphlan_abundance_kingdom_parquet                            category
# metaphlan_abundance_phylum_parquet                             category
# metaphlan_abundance_class_parquet                              category
# metaphlan_abundance_order_parquet                              category
# metaphlan_abundance_family_parquet                             category
# metaphlan_abundance_genus_parquet                              category
# metaphlan_abundance_species_parquet                            category
# metaphlan_abundance_strain_parquet                             category
# raw_fastq                                                        string
# trimmed_fastq                                                    string
# non_human_fastq                                                  string
# fastqc_html                                                      string
# fastqc_zip                                                       string
# human_variants_bed                                               string
# human_variants_bim                                               string
# human_variants_fam                                               string
# urs_mapped_bam                                                   string
# urs_mapped_single_bacteria_per_read_bam                          string
# urs_mapped_metrics_txt                                           string
# urs_mapped_results_csv                                           string
# metaphlan4_results_txt                                           string
# duplicate_reads_count                                               int
# excessive_duplicate_reads                                          bool
# raw_read_count                                                      int
# trimmed_read_count                                                  int
# human_variant_count                                                 int
# human_read_count                                                    int
# urs_mapped_read_count                                               int
# wgs_compare_error_total                                             int
# wgs_compare_errors_percent                                        float
# wgs_compare_count_homozygous                                        int
# wgs_compare_count_variants                                          int
# wgs_compare_pass                                               category
# raw_read_length                                                     int
# single_ended                                                       bool
# is_genotek                                                         bool
# run_name                                                         string
# wgs_dna_code                                                        int
#
#                                          parent_dataframe  data_coding
# tabular_field_name
# collection_timestamp                                  NaN          NaN
# collection_date                                       NaN          NaN
# timezone                                              NaN          NaN
# sample_name                                           NaN          NaN
# urs_metadata_parquet                                  NaN          NaN
# urs_abundance_parquet                                 NaN          NaN
# metaphlan_abundance_kingdom_parquet                   NaN          NaN
# metaphlan_abundance_phylum_parquet                    NaN          NaN
# metaphlan_abundance_class_parquet                     NaN          NaN
# metaphlan_abundance_order_parquet                     NaN          NaN
# metaphlan_abundance_family_parquet                    NaN          NaN
# metaphlan_abundance_genus_parquet                     NaN          NaN
# metaphlan_abundance_species_parquet                   NaN          NaN
# metaphlan_abundance_strain_parquet                    NaN          NaN
# raw_fastq                                             NaN          NaN
# trimmed_fastq                                         NaN          NaN
# non_human_fastq                                       NaN          NaN
# fastqc_html                                           NaN          NaN
# fastqc_zip                                            NaN          NaN
# human_variants_bed                                    NaN          NaN
# human_variants_bim                                    NaN          NaN
# human_variants_fam                                    NaN          NaN
# urs_mapped_bam                                        NaN          NaN
# urs_mapped_single_bacteria_per_read_bam               NaN          NaN
# urs_mapped_metrics_txt                                NaN          NaN
# urs_mapped_results_csv                                NaN          NaN
# metaphlan4_results_txt                                NaN          NaN
# duplicate_reads_count                                 NaN          NaN
# excessive_duplicate_reads                             NaN          NaN
# raw_read_count                                        NaN          NaN
# trimmed_read_count                                    NaN          NaN
# human_variant_count                                   NaN          NaN
# human_read_count                                      NaN          NaN
# urs_mapped_read_count                                 NaN          NaN
# wgs_compare_error_total                               NaN          NaN
# wgs_compare_errors_percent                            NaN          NaN
# wgs_compare_count_homozygous                          NaN          NaN
# wgs_compare_count_variants                            NaN          NaN
# wgs_compare_pass                                      NaN          NaN
# raw_read_length                                       NaN          NaN
# single_ended                                          NaN          NaN
# is_genotek                                            NaN          NaN
# run_name                                              NaN          NaN
# wgs_dna_code                                          NaN          NaN
