# %% [raw]
# ---
# output-file: 009-sleep.html
# title: 009-sleep
# ---

# %% [markdown]
# # Sleep monitoring dataset
#
# Sleep monitoring includes sleep staging, body positioning, respiratory events, heart rate, oxygen saturation and snoring, measured concurrently over three nights.
#
# Obstructive sleep apnea (OSA) is a sleep disorder in which a person’s breathing is interrupted during sleep due to obstruction of the upper airway as a result of relaxation of the throat muscles. This obstruction can lead to pauses in breathing for short periods of time, which can cause loud snoring, reduction in the  blood oxygen levels, stress response, awakening and fragmented sleep.
#
# A home sleep apnea test (HSAT) is a non-invasive test used to diagnose sleep apnea. During an HSAT, a patient wears a portable device overnight to monitor their breathing, heart rate, oxygen levels, snoring, and other sleep patterns. The device records this data and it is then analyzed by clinically-validated algorithms that compute apnea-related indices. The data can also be used to study sleep architecture and other aspects of sleep, such as heart rate variability (HRV) and arrhythmia.
#
# The device used for sleep monitoring in the Human Phenotype Project is the FDA-approved WatchPAT-300 by Itamar Medical. This device contains 5 sensors: An actigraph worn on the wrist; A pulse oximeter and a Peripheral Arterial Tone (PAT) probe worn on the finger; and a microphone and accelerometer worn on the chest for respiratory effort, snoring and body position measurement.
#
# The device's algorithms provide 3 main indices for diagnosis of OSA: Apnea/Hypopnea Index (AHI), Respiratory Disturbance Index (RDI), Oxygen Desaturation Index (ODI). The device's algoithms also provide indices for diagnosis of Atrial Fibrillation (not FDA-approved yet): Premature beats per minute, Atrial fibrillation longest event.
#
# The WatchPAT device is given to participants during the visit to the clinical testing center who then record 3 nights of sleep at home during the following two weeks (Figure 4). The recorded tested nights should reflect the usual sleeping regimen / typical bedtime (for example, not after exceeding alcohol consumption).
#
# ### Data availability:
# The information is stored in 2 main statistics parquet files: `sleep.parquet`, `hrv.parquet`; In multiple events parquets and in multiple time series parquets / EDF files containing sensor channels for each night of logging.

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('sleep')
dl
# Out:
# DataLoader for sleep with
# 473 fields
# 3 tables: ['sleep', 'hrv', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                                                                                          field_string  \
# tabular_field_name
# collection_timestamp                                                             Collection timestamp
# collection_date                                                                       Collection date
# night                                                                                           Night
# warnings                                                                                     Warnings
# timezone                                                                                     Timezone
# device_sn                                                                        Device serial number
# hardware_version                                                                     Hardware version
# software_version                                                                     Software version
# device_model                                                                             Device model
# channels_edf_file                                                                   Channels EDF file
# channels_time_series                                Combined timeseries with all channels for all ...
# events_time_series                                                                 Events time series
# ahi                                                                                               AHI
# ahi_4_percent                                                                                  AHI 4%
# ahi_central                                                                               AHI central
# ahi_central_during_nrem                                                       AHI central during NREM
# ahi_central_during_rem                                                         AHI central during REM
# ahi_during_left                                                                       AHI during left
# ahi_during_non_supine                                                           AHI during non-supine
# ahi_during_nrem                                                                       AHI during NREM
# ahi_during_prone                                                                     AHI during prone
# ahi_during_rem                                                                         AHI during REM
# ahi_during_right                                                                     AHI during right
# ahi_during_supine                                                                   AHI during supine
# ahi_rdi_desaturation_threshold                                         AHI/RDI desaturation threshold
# atrial_fibrillation_longest_event                                   Atrial fibrillation longest event
# csr_percent                                                                               CSR percent
# desaturations_mean_nadir                                                     Desaturations mean nadir
# desaturations_of_4_9                                                            Desaturations of 4-9%
# desaturations_of_10_20                                                        Desaturations of 10-20%
# desaturations_above_20                                                        Desaturations above 20%
# heart_rate_max_during_nrem                                                 Heart rate max during NREM
# heart_rate_max_during_rem                                                   Heart rate max during REM
# heart_rate_max_during_sleep                                               Heart rate max during sleep
# heart_rate_max_during_wake                                                 Heart rate max during wake
# heart_rate_mean_during_nrem                                               Heart rate mean during NREM
# heart_rate_mean_during_rem                                                 Heart rate mean during REM
# heart_rate_mean_during_sleep                                             Heart rate mean during sleep
# heart_rate_mean_during_wake                                               Heart rate mean during wake
# heart_rate_min_during_nrem                                                 Heart rate min during NREM
# heart_rate_min_during_rem                                                   Heart rate min during REM
# heart_rate_min_during_sleep                                               Heart rate min during sleep
# heart_rate_min_during_wake                                                 Heart rate min during wake
# number_of_4_percent_desaturation_apnea_hypopnea...    Number of 4% desaturation apnea hypopnea events
# number_of_all_respiratory_events                                     Number of all respiratory events
# number_of_apnea_hypopnea_events                                       Number of apnea hypopnea events
# number_of_central_apnea_hypopnea_events                       Number of central apnea hypopnea events
# number_of_desaturation_events                                           Number of desaturation events
# number_of_transitions_nrem_to_rem                               Number of transitions: non-REM to REM
# number_of_transitions_nrem_to_wake                             Number of transitions: non-REM to wake
# number_of_transitions_rem_to_nrem                               Number of transitions: REM to non-REM
# number_of_transitions_rem_to_wake                                  Number of transitions: REM to wake
# number_of_transitions_wake_to_nrem                             Number of transitions: wake to non-REM
# number_of_transitions_wake_to_rem                                  Number of transitions: wake to REM
# number_of_wakes                                                                       Number of wakes
# odi                                                                                               ODI
# odi_during_left                                                                       ODI during left
# odi_during_non_supine                                                           ODI during non-supine
# odi_during_nrem                                                                       ODI during NREM
# odi_during_prone                                                                     ODI during prone
# odi_during_rem                                                                         ODI during REM
# odi_during_right                                                                     ODI during right
# odi_during_supine                                                                   ODI during supine
# percent_of_deep_sleep_time                                                 Percent of deep sleep time
# percent_of_light_sleep_time                                               Percent of light sleep time
# percent_of_rem_sleep_time                                                   Percent of REM sleep time
# premature_beats_per_minute                                                 Premature beats per minute
# quality_score_heart_rate                                                           Quality score: PAT
# quality_score_pat                                                                  Quality score: PAT
# quality_score_sbp                                                                  Quality score: SBP
# quality_score_spo2                                                                Quality score: SaO2
# rdi                                                                                               RDI
# rdi_during_left                                                                       RDI during left
# rdi_during_non_supine                                                           RDI during non-supine
# rdi_during_nrem                                                                       RDI during NREM
# rdi_during_prone                                                                     RDI during prone
# rdi_during_rem                                                                         RDI during REM
# rdi_during_right                                                                     RDI during right
# rdi_during_supine                                                                   RDI during supine
# rem_latency                                                                               REM latency
# saturation_below_70                                                              Saturation below 70%
# saturation_below_80                                                              Saturation below 80%
# saturation_below_85                                                              Saturation below 85%
# saturation_below_90                                                              Saturation below 90%
# saturation_below_or_equal_88                                            Saturation below or equal 88%
# saturation_max_value                                                             Saturation max value
# saturation_mean                                                                       Saturation mean
# saturation_min_value                                                             Saturation min value
# sleep_efficiency                                                                     Sleep efficiency
# sleep_latency                                                                           Sleep latency
# snore_above_40db                                                                     Snore above 40dB
# snore_above_45db                                                                     Snore above 45dB
# snore_above_50db                                                                     Snore above 50dB
# snore_above_60db                                                                     Snore above 60dB
# snore_above_70db                                                                     Snore above 70dB
# snore_above_80db                                                                     Snore above 80dB
# snore_db_mean                                                                           Snore dB mean
# study_end_time                                                                         Study end time
# study_start_time                                                                     Study start time
# time_to_transition_nrem_to_rem                                     Time to transition: non-REM to REM
# time_to_transition_nrem_to_wake                                   Time to transition: non-REM to wake
# time_to_transition_rem_to_nrem                                     Time to transition: REM to non-REM
# time_to_transition_rem_to_wake                                        Time to transition: REM to wake
# time_to_transition_wake_to_nrem                                   Time to transition: wake to non-REM
# time_to_transition_wake_to_rem                                        Time to transition: wake to REM
# total_arousal_sleep_time                                                     Total arousal sleep time
# total_atrial_fibrillation_time                                         Total atrial fibrillation time
# total_deep_sleep_time                                                           Total deep sleep time
# total_left_sleep_time                                                           Total left sleep time
# total_light_sleep_time                                                         Total light sleep time
# total_non_supine_sleep_time                                               Total non supine sleep time
# total_prone_sleep_time                                                         Total prone sleep time
# total_rem_sleep_time                                                             Total REM sleep time
# total_right_sleep_time                                                         Total right sleep time
# total_sleep_time                                                                     Total sleep time
# total_study_time                                                                     Total study time
# total_supine_sleep_time                                                       Total supine sleep time
# total_time_in_bed                                                             Total time in bed (TIB)
# total_valid_apnea_central_sleep_time                             Total valid apnea central sleep time
# total_valid_apnea_sleep_time                                             Total valid apnea sleep time
# total_valid_arrhythmia_sleep_time                                   Total valid arrhythmia sleep time
# total_wake_time                                                                       Total wake time
# total_wake_time_after_sleep_onset                            Total wake time after sleep onset (WASO)
# collection_timestamp                                               Collection timestamp (event start)
# event_end                                                                                   Event end
# event                                                                                           Event
# channel                                                                                       Channel
# start                                                                                    Start second
# end                                                                                        End second
# actigraph                                                                                   Actigraph
# sleep_stage                                                                               Sleep stage
# heart_rate                                                                                 Heart rate
# heart_rate_raw                                                                         Heart rate raw
# pat_amplitude                                                                           PAT amplitude
# pat_infra                                                                                   PAT infra
# pat_lpf                                                                                       PAT LPF
# pat_view                                                                                     PAT view
# body_position                                                                           Body position
# respiratory_movement                                                             Respiratory movement
# snore_db                                                                                     Snore dB
# spo2                                                                                             SpO2
# hrv_frequency_hf_during_night                                          HRV frequency: HF during night
# hrv_frequency_hf_during_nrem                                            HRV frequency: HF during NREM
# hrv_frequency_hf_during_rem                                              HRV frequency: HF during REM
# hrv_frequency_hf_during_wake                                            HRV frequency: HF during wake
# hrv_frequency_hfn_during_night                                        HRV frequency: HFn during night
# hrv_frequency_hfn_during_nrem                                          HRV frequency: HFn during NREM
# hrv_frequency_hfn_during_rem                                            HRV frequency: HFn during REM
# hrv_frequency_hfn_during_wake                                          HRV frequency: HFn during wake
# hrv_frequency_lf_during_night                                          HRV frequency: LF during night
# hrv_frequency_lf_during_nrem                                            HRV frequency: LF during NREM
# hrv_frequency_lf_during_rem                                              HRV frequency: LF during REM
# hrv_frequency_lf_during_wake                                            HRV frequency: LF during wake
# hrv_frequency_lfhf_during_night                                      HRV frequency: LFHF during night
# hrv_frequency_lfhf_during_nrem                                        HRV frequency: LFHF during NREM
# hrv_frequency_lfhf_during_rem                                          HRV frequency: LFHF during REM
# hrv_frequency_lfhf_during_wake                                        HRV frequency: LFHF during wake
# hrv_frequency_lfn_during_night                                        HRV frequency: LFn during night
# hrv_frequency_lfn_during_nrem                                          HRV frequency: LFn during NREM
# hrv_frequency_lfn_during_rem                                            HRV frequency: LFn during REM
# hrv_frequency_lfn_during_wake                                          HRV frequency: LFn during wake
# hrv_frequency_lnhf_during_night                                      HRV frequency: LnHF during night
# hrv_frequency_lnhf_during_nrem                                        HRV frequency: LnHF during NREM
# hrv_frequency_lnhf_during_rem                                          HRV frequency: LnHF during REM
# hrv_frequency_lnhf_during_wake                                        HRV frequency: LnHF during wake
# hrv_frequency_ulf_during_night                                        HRV frequency: ULF during night
# hrv_frequency_ulf_during_nrem                                          HRV frequency: ULF during NREM
# hrv_frequency_ulf_during_rem                                            HRV frequency: ULF during REM
# hrv_frequency_ulf_during_wake                                          HRV frequency: ULF during wake
# hrv_frequency_vhf_during_night                                        HRV frequency: VHF during night
# hrv_frequency_vhf_during_nrem                                          HRV frequency: VHF during NREM
# hrv_frequency_vhf_during_rem                                            HRV frequency: VHF during REM
# hrv_frequency_vhf_during_wake                                          HRV frequency: VHF during wake
# hrv_frequency_vlf_during_night                                        HRV frequency: VLF during night
# hrv_frequency_vlf_during_nrem                                          HRV frequency: VLF during NREM
# hrv_frequency_vlf_during_rem                                            HRV frequency: VLF during REM
# hrv_frequency_vlf_during_wake                                          HRV frequency: VLF during wake
# hrv_nonlinear_ai_during_night                                          HRV nonlinear: AI during night
# hrv_nonlinear_ai_during_nrem                                            HRV nonlinear: AI during NREM
# hrv_nonlinear_ai_during_rem                                              HRV nonlinear: AI during REM
# hrv_nonlinear_ai_during_wake                                            HRV nonlinear: AI during wake
# hrv_nonlinear_apen_during_night                                      HRV nonlinear: ApEn during night
# hrv_nonlinear_apen_during_nrem                                        HRV nonlinear: ApEn during NREM
# hrv_nonlinear_apen_during_rem                                          HRV nonlinear: ApEn during REM
# hrv_nonlinear_apen_during_wake                                        HRV nonlinear: ApEn during wake
# hrv_nonlinear_c1a_during_night                                        HRV nonlinear: C1a during night
# hrv_nonlinear_c1a_during_nrem                                          HRV nonlinear: C1a during NREM
# hrv_nonlinear_c1a_during_rem                                            HRV nonlinear: C1a during REM
# hrv_nonlinear_c1a_during_wake                                          HRV nonlinear: C1a during wake
# hrv_nonlinear_c1d_during_night                                        HRV nonlinear: C1d during night
# hrv_nonlinear_c1d_during_nrem                                          HRV nonlinear: C1d during NREM
# hrv_nonlinear_c1d_during_rem                                            HRV nonlinear: C1d during REM
# hrv_nonlinear_c1d_during_wake                                          HRV nonlinear: C1d during wake
# hrv_nonlinear_c2a_during_night                                        HRV nonlinear: C2a during night
# hrv_nonlinear_c2a_during_nrem                                          HRV nonlinear: C2a during NREM
# hrv_nonlinear_c2a_during_rem                                            HRV nonlinear: C2a during REM
# hrv_nonlinear_c2a_during_wake                                          HRV nonlinear: C2a during wake
# hrv_nonlinear_c2d_during_night                                        HRV nonlinear: C2d during night
# hrv_nonlinear_c2d_during_nrem                                          HRV nonlinear: C2d during NREM
# hrv_nonlinear_c2d_during_rem                                            HRV nonlinear: C2d during REM
# hrv_nonlinear_c2d_during_wake                                          HRV nonlinear: C2d during wake
# hrv_nonlinear_ca_during_night                                          HRV nonlinear: Ca during night
# hrv_nonlinear_ca_during_nrem                                            HRV nonlinear: Ca during NREM
# hrv_nonlinear_ca_during_rem                                              HRV nonlinear: Ca during REM
# hrv_nonlinear_ca_during_wake                                            HRV nonlinear: Ca during wake
# hrv_nonlinear_cd_during_night                                          HRV nonlinear: Cd during night
# hrv_nonlinear_cd_during_nrem                                            HRV nonlinear: Cd during NREM
# hrv_nonlinear_cd_during_rem                                              HRV nonlinear: Cd during REM
# hrv_nonlinear_cd_during_wake                                            HRV nonlinear: Cd during wake
# hrv_nonlinear_csi_during_night                                        HRV nonlinear: CSI during night
# hrv_nonlinear_csi_during_nrem                                          HRV nonlinear: CSI during NREM
# hrv_nonlinear_csi_during_rem                                            HRV nonlinear: CSI during REM
# hrv_nonlinear_csi_during_wake                                          HRV nonlinear: CSI during wake
# hrv_nonlinear_csi_modified_during_night                      HRV nonlinear: CSI_Modified during night
# hrv_nonlinear_csi_modified_during_nrem                        HRV nonlinear: CSI_Modified during NREM
# hrv_nonlinear_csi_modified_during_rem                          HRV nonlinear: CSI_Modified during REM
# hrv_nonlinear_csi_modified_during_wake                        HRV nonlinear: CSI_Modified during wake
# hrv_nonlinear_cvi_during_night                                        HRV nonlinear: CVI during night
# hrv_nonlinear_cvi_during_nrem                                          HRV nonlinear: CVI during NREM
# hrv_nonlinear_cvi_during_rem                                            HRV nonlinear: CVI during REM
# hrv_nonlinear_cvi_during_wake                                          HRV nonlinear: CVI during wake
# hrv_nonlinear_dfa_alpha1_during_night                          HRV nonlinear: DFA_alpha1 during night
# hrv_nonlinear_dfa_alpha1_during_nrem                            HRV nonlinear: DFA_alpha1 during NREM
# hrv_nonlinear_dfa_alpha1_during_rem                              HRV nonlinear: DFA_alpha1 during REM
# hrv_nonlinear_dfa_alpha1_during_wake                            HRV nonlinear: DFA_alpha1 during wake
# hrv_nonlinear_dfa_alpha2_during_night                          HRV nonlinear: DFA_alpha2 during night
# hrv_nonlinear_dfa_alpha2_during_nrem                            HRV nonlinear: DFA_alpha2 during NREM
# hrv_nonlinear_dfa_alpha2_during_rem                              HRV nonlinear: DFA_alpha2 during REM
# hrv_nonlinear_dfa_alpha2_during_wake                            HRV nonlinear: DFA_alpha2 during wake
# hrv_nonlinear_gi_during_night                                          HRV nonlinear: GI during night
# hrv_nonlinear_gi_during_nrem                                            HRV nonlinear: GI during NREM
# hrv_nonlinear_gi_during_rem                                              HRV nonlinear: GI during REM
# hrv_nonlinear_gi_during_wake                                            HRV nonlinear: GI during wake
# hrv_nonlinear_hfd_during_night                                        HRV nonlinear: HFD during night
# hrv_nonlinear_hfd_during_nrem                                          HRV nonlinear: HFD during NREM
# hrv_nonlinear_hfd_during_rem                                            HRV nonlinear: HFD during REM
# hrv_nonlinear_hfd_during_wake                                          HRV nonlinear: HFD during wake
# hrv_nonlinear_ials_during_night                                      HRV nonlinear: IALS during night
# hrv_nonlinear_ials_during_nrem                                        HRV nonlinear: IALS during NREM
# hrv_nonlinear_ials_during_rem                                          HRV nonlinear: IALS during REM
# hrv_nonlinear_ials_during_wake                                        HRV nonlinear: IALS during wake
# hrv_nonlinear_kfd_during_night                                        HRV nonlinear: KFD during night
# hrv_nonlinear_kfd_during_nrem                                          HRV nonlinear: KFD during NREM
# hrv_nonlinear_kfd_during_rem                                            HRV nonlinear: KFD during REM
# hrv_nonlinear_kfd_during_wake                                          HRV nonlinear: KFD during wake
# hrv_nonlinear_lzc_during_night                                        HRV nonlinear: LZC during night
# hrv_nonlinear_lzc_during_nrem                                          HRV nonlinear: LZC during NREM
# hrv_nonlinear_lzc_during_rem                                            HRV nonlinear: LZC during REM
# hrv_nonlinear_lzc_during_wake                                          HRV nonlinear: LZC during wake
# hrv_nonlinear_mfdfa_alpha1_asymmetry_during_night   HRV nonlinear: MFDFA_alpha1 asymmetry during n...
# hrv_nonlinear_mfdfa_alpha1_asymmetry_during_nrem    HRV nonlinear: MFDFA_alpha1 asymmetry during NREM
# hrv_nonlinear_mfdfa_alpha1_asymmetry_during_rem      HRV nonlinear: MFDFA_alpha1 asymmetry during REM
# hrv_nonlinear_mfdfa_alpha1_asymmetry_during_wake    HRV nonlinear: MFDFA_alpha1 asymmetry during wake
# hrv_nonlinear_mfdfa_alpha1_delta_during_night          HRV nonlinear: MFDFA_alpha1 delta during night
# hrv_nonlinear_mfdfa_alpha1_delta_during_nrem            HRV nonlinear: MFDFA_alpha1 delta during NREM
# hrv_nonlinear_mfdfa_alpha1_delta_during_rem              HRV nonlinear: MFDFA_alpha1 delta during REM
# hrv_nonlinear_mfdfa_alpha1_delta_during_wake            HRV nonlinear: MFDFA_alpha1 delta during wake
# hrv_nonlinear_mfdfa_alpha1_fluctuation_during_n...  HRV nonlinear: MFDFA_alpha1 fluctuation during...
# hrv_nonlinear_mfdfa_alpha1_fluctuation_during_nrem  HRV nonlinear: MFDFA_alpha1 fluctuation during...
# hrv_nonlinear_mfdfa_alpha1_fluctuation_during_rem   HRV nonlinear: MFDFA_alpha1 fluctuation during...
# hrv_nonlinear_mfdfa_alpha1_fluctuation_during_wake  HRV nonlinear: MFDFA_alpha1 fluctuation during...
# hrv_nonlinear_mfdfa_alpha1_increment_during_night   HRV nonlinear: MFDFA_alpha1 increment during n...
# hrv_nonlinear_mfdfa_alpha1_increment_during_nrem    HRV nonlinear: MFDFA_alpha1 increment during NREM
# hrv_nonlinear_mfdfa_alpha1_increment_during_rem      HRV nonlinear: MFDFA_alpha1 increment during REM
# hrv_nonlinear_mfdfa_alpha1_increment_during_wake    HRV nonlinear: MFDFA_alpha1 increment during wake
# hrv_nonlinear_mfdfa_alpha1_max_during_night              HRV nonlinear: MFDFA_alpha1 max during night
# hrv_nonlinear_mfdfa_alpha1_max_during_nrem                HRV nonlinear: MFDFA_alpha1 max during NREM
# hrv_nonlinear_mfdfa_alpha1_max_during_rem                  HRV nonlinear: MFDFA_alpha1 max during REM
# hrv_nonlinear_mfdfa_alpha1_max_during_wake                HRV nonlinear: MFDFA_alpha1 max during wake
# hrv_nonlinear_mfdfa_alpha1_mean_during_night            HRV nonlinear: MFDFA_alpha1 mean during night
# hrv_nonlinear_mfdfa_alpha1_mean_during_nrem              HRV nonlinear: MFDFA_alpha1 mean during NREM
# hrv_nonlinear_mfdfa_alpha1_mean_during_rem                HRV nonlinear: MFDFA_alpha1 mean during REM
# hrv_nonlinear_mfdfa_alpha1_mean_during_wake              HRV nonlinear: MFDFA_alpha1 mean during wake
# hrv_nonlinear_mfdfa_alpha1_peak_during_night            HRV nonlinear: MFDFA_alpha1 peak during night
# hrv_nonlinear_mfdfa_alpha1_peak_during_nrem              HRV nonlinear: MFDFA_alpha1 peak during NREM
# hrv_nonlinear_mfdfa_alpha1_peak_during_rem                HRV nonlinear: MFDFA_alpha1 peak during REM
# hrv_nonlinear_mfdfa_alpha1_peak_during_wake              HRV nonlinear: MFDFA_alpha1 peak during wake
# hrv_nonlinear_mfdfa_alpha1_width_during_night          HRV nonlinear: MFDFA_alpha1 width during night
# hrv_nonlinear_mfdfa_alpha1_width_during_nrem            HRV nonlinear: MFDFA_alpha1 width during NREM
# hrv_nonlinear_mfdfa_alpha1_width_during_rem              HRV nonlinear: MFDFA_alpha1 width during REM
# hrv_nonlinear_mfdfa_alpha1_width_during_wake            HRV nonlinear: MFDFA_alpha1 width during wake
# hrv_nonlinear_mfdfa_alpha2_asymmetry_during_night   HRV nonlinear: MFDFA_alpha2 asymmetry during n...
# hrv_nonlinear_mfdfa_alpha2_asymmetry_during_nrem    HRV nonlinear: MFDFA_alpha2 asymmetry during NREM
# hrv_nonlinear_mfdfa_alpha2_asymmetry_during_rem      HRV nonlinear: MFDFA_alpha2 asymmetry during REM
# hrv_nonlinear_mfdfa_alpha2_asymmetry_during_wake    HRV nonlinear: MFDFA_alpha2 asymmetry during wake
# hrv_nonlinear_mfdfa_alpha2_delta_during_night          HRV nonlinear: MFDFA_alpha2 delta during night
# hrv_nonlinear_mfdfa_alpha2_delta_during_nrem            HRV nonlinear: MFDFA_alpha2 delta during NREM
# hrv_nonlinear_mfdfa_alpha2_delta_during_rem              HRV nonlinear: MFDFA_alpha2 delta during REM
# hrv_nonlinear_mfdfa_alpha2_delta_during_wake            HRV nonlinear: MFDFA_alpha2 delta during wake
# hrv_nonlinear_mfdfa_alpha2_fluctuation_during_n...  HRV nonlinear: MFDFA_alpha2 fluctuation during...
# hrv_nonlinear_mfdfa_alpha2_fluctuation_during_nrem  HRV nonlinear: MFDFA_alpha2 fluctuation during...
# hrv_nonlinear_mfdfa_alpha2_fluctuation_during_rem   HRV nonlinear: MFDFA_alpha2 fluctuation during...
# hrv_nonlinear_mfdfa_alpha2_fluctuation_during_wake  HRV nonlinear: MFDFA_alpha2 fluctuation during...
# hrv_nonlinear_mfdfa_alpha2_increment_during_night   HRV nonlinear: MFDFA_alpha2 increment during n...
# hrv_nonlinear_mfdfa_alpha2_increment_during_nrem    HRV nonlinear: MFDFA_alpha2 increment during NREM
# hrv_nonlinear_mfdfa_alpha2_increment_during_rem      HRV nonlinear: MFDFA_alpha2 increment during REM
# hrv_nonlinear_mfdfa_alpha2_increment_during_wake    HRV nonlinear: MFDFA_alpha2 increment during wake
# hrv_nonlinear_mfdfa_alpha2_max_during_night              HRV nonlinear: MFDFA_alpha2 max during night
# hrv_nonlinear_mfdfa_alpha2_max_during_nrem                HRV nonlinear: MFDFA_alpha2 max during NREM
# hrv_nonlinear_mfdfa_alpha2_max_during_rem                  HRV nonlinear: MFDFA_alpha2 max during REM
# hrv_nonlinear_mfdfa_alpha2_max_during_wake                HRV nonlinear: MFDFA_alpha2 max during wake
# hrv_nonlinear_mfdfa_alpha2_mean_during_night            HRV nonlinear: MFDFA_alpha2 mean during night
# hrv_nonlinear_mfdfa_alpha2_mean_during_nrem              HRV nonlinear: MFDFA_alpha2 mean during NREM
# hrv_nonlinear_mfdfa_alpha2_mean_during_rem                HRV nonlinear: MFDFA_alpha2 mean during REM
# hrv_nonlinear_mfdfa_alpha2_mean_during_wake              HRV nonlinear: MFDFA_alpha2 mean during wake
# hrv_nonlinear_mfdfa_alpha2_peak_during_night            HRV nonlinear: MFDFA_alpha2 peak during night
# hrv_nonlinear_mfdfa_alpha2_peak_during_nrem              HRV nonlinear: MFDFA_alpha2 peak during NREM
# hrv_nonlinear_mfdfa_alpha2_peak_during_rem                HRV nonlinear: MFDFA_alpha2 peak during REM
# hrv_nonlinear_mfdfa_alpha2_peak_during_wake              HRV nonlinear: MFDFA_alpha2 peak during wake
# hrv_nonlinear_mfdfa_alpha2_width_during_night          HRV nonlinear: MFDFA_alpha2 width during night
# hrv_nonlinear_mfdfa_alpha2_width_during_nrem            HRV nonlinear: MFDFA_alpha2 width during NREM
# hrv_nonlinear_mfdfa_alpha2_width_during_rem              HRV nonlinear: MFDFA_alpha2 width during REM
# hrv_nonlinear_mfdfa_alpha2_width_during_wake            HRV nonlinear: MFDFA_alpha2 width during wake
# hrv_nonlinear_msen_during_night                                      HRV nonlinear: MSEn during night
# hrv_nonlinear_msen_during_nrem                                        HRV nonlinear: MSEn during NREM
# hrv_nonlinear_msen_during_rem                                          HRV nonlinear: MSEn during REM
# hrv_nonlinear_msen_during_wake                                        HRV nonlinear: MSEn during wake
# hrv_nonlinear_pas_during_night                                        HRV nonlinear: PAS during night
# hrv_nonlinear_pas_during_nrem                                          HRV nonlinear: PAS during NREM
# hrv_nonlinear_pas_during_rem                                            HRV nonlinear: PAS during REM
# hrv_nonlinear_pas_during_wake                                          HRV nonlinear: PAS during wake
# hrv_nonlinear_pi_during_night                                          HRV nonlinear: PI during night
# hrv_nonlinear_pi_during_nrem                                            HRV nonlinear: PI during NREM
# hrv_nonlinear_pi_during_rem                                              HRV nonlinear: PI during REM
# hrv_nonlinear_pi_during_wake                                            HRV nonlinear: PI during wake
# hrv_nonlinear_pip_during_night                                        HRV nonlinear: PIP during night
# hrv_nonlinear_pip_during_nrem                                          HRV nonlinear: PIP during NREM
# hrv_nonlinear_pip_during_rem                                            HRV nonlinear: PIP during REM
# hrv_nonlinear_pip_during_wake                                          HRV nonlinear: PIP during wake
# hrv_nonlinear_pss_during_night                                        HRV nonlinear: PSS during night
# hrv_nonlinear_pss_during_nrem                                          HRV nonlinear: PSS during NREM
# hrv_nonlinear_pss_during_rem                                            HRV nonlinear: PSS during REM
# hrv_nonlinear_pss_during_wake                                          HRV nonlinear: PSS during wake
# hrv_nonlinear_s_during_night                                            HRV nonlinear: S during night
# hrv_nonlinear_s_during_nrem                                              HRV nonlinear: S during NREM
# hrv_nonlinear_s_during_rem                                                HRV nonlinear: S during REM
# hrv_nonlinear_s_during_wake                                              HRV nonlinear: S during wake
# hrv_nonlinear_sampen_during_night                                  HRV nonlinear: SampEn during night
# hrv_nonlinear_sampen_during_nrem                                    HRV nonlinear: SampEn during NREM
# hrv_nonlinear_sampen_during_rem                                      HRV nonlinear: SampEn during REM
# hrv_nonlinear_sampen_during_wake                                    HRV nonlinear: SampEn during wake
# hrv_nonlinear_sd1_during_night                                        HRV nonlinear: SD1 during night
# hrv_nonlinear_sd1_during_nrem                                          HRV nonlinear: SD1 during NREM
# hrv_nonlinear_sd1_during_rem                                            HRV nonlinear: SD1 during REM
# hrv_nonlinear_sd1_during_wake                                          HRV nonlinear: SD1 during wake
# hrv_nonlinear_sd1a_during_night                                      HRV nonlinear: SD1a during night
# hrv_nonlinear_sd1a_during_nrem                                        HRV nonlinear: SD1a during NREM
# hrv_nonlinear_sd1a_during_rem                                          HRV nonlinear: SD1a during REM
# hrv_nonlinear_sd1a_during_wake                                        HRV nonlinear: SD1a during wake
# hrv_nonlinear_sd1d_during_night                                      HRV nonlinear: SD1d during night
# hrv_nonlinear_sd1d_during_nrem                                        HRV nonlinear: SD1d during NREM
# hrv_nonlinear_sd1d_during_rem                                          HRV nonlinear: SD1d during REM
# hrv_nonlinear_sd1d_during_wake                                        HRV nonlinear: SD1d during wake
# hrv_nonlinear_sd1sd2_during_night                                  HRV nonlinear: SD1SD2 during night
# hrv_nonlinear_sd1sd2_during_nrem                                    HRV nonlinear: SD1SD2 during NREM
# hrv_nonlinear_sd1sd2_during_rem                                      HRV nonlinear: SD1SD2 during REM
# hrv_nonlinear_sd1sd2_during_wake                                    HRV nonlinear: SD1SD2 during wake
# hrv_nonlinear_sd2_during_night                                        HRV nonlinear: SD2 during night
# hrv_nonlinear_sd2_during_nrem                                          HRV nonlinear: SD2 during NREM
# hrv_nonlinear_sd2_during_rem                                            HRV nonlinear: SD2 during REM
# hrv_nonlinear_sd2_during_wake                                          HRV nonlinear: SD2 during wake
# hrv_nonlinear_sd2a_during_night                                      HRV nonlinear: SD2a during night
# hrv_nonlinear_sd2a_during_nrem                                        HRV nonlinear: SD2a during NREM
# hrv_nonlinear_sd2a_during_rem                                          HRV nonlinear: SD2a during REM
# hrv_nonlinear_sd2a_during_wake                                        HRV nonlinear: SD2a during wake
# hrv_nonlinear_sd2d_during_night                                      HRV nonlinear: SD2d during night
# hrv_nonlinear_sd2d_during_nrem                                        HRV nonlinear: SD2d during NREM
# hrv_nonlinear_sd2d_during_rem                                          HRV nonlinear: SD2d during REM
# hrv_nonlinear_sd2d_during_wake                                        HRV nonlinear: SD2d during wake
# hrv_nonlinear_sdnna_during_night                                    HRV nonlinear: SDNNa during night
# hrv_nonlinear_sdnna_during_nrem                                      HRV nonlinear: SDNNa during NREM
# hrv_nonlinear_sdnna_during_rem                                        HRV nonlinear: SDNNa during REM
# hrv_nonlinear_sdnna_during_wake                                      HRV nonlinear: SDNNa during wake
# hrv_nonlinear_sdnnd_during_night                                    HRV nonlinear: SDNNd during night
# hrv_nonlinear_sdnnd_during_nrem                                      HRV nonlinear: SDNNd during NREM
# hrv_nonlinear_sdnnd_during_rem                                        HRV nonlinear: SDNNd during REM
# hrv_nonlinear_sdnnd_during_wake                                      HRV nonlinear: SDNNd during wake
# hrv_nonlinear_shanen_during_night                                  HRV nonlinear: ShanEn during night
# hrv_nonlinear_shanen_during_nrem                                    HRV nonlinear: ShanEn during NREM
# hrv_nonlinear_shanen_during_rem                                      HRV nonlinear: ShanEn during REM
# hrv_nonlinear_shanen_during_wake                                    HRV nonlinear: ShanEn during wake
# hrv_nonlinear_si_during_night                                          HRV nonlinear: SI during night
# hrv_nonlinear_si_during_nrem                                            HRV nonlinear: SI during NREM
# hrv_nonlinear_si_during_rem                                              HRV nonlinear: SI during REM
# hrv_nonlinear_si_during_wake                                            HRV nonlinear: SI during wake
# hrv_quality_score_during_night                                        HRV: quality score during night
# hrv_quality_score_during_nrem                                          HRV: quality score during NREM
# hrv_quality_score_during_rem                                            HRV: quality score during REM
# hrv_quality_score_during_wake                                          HRV: quality score during wake
# hrv_time_cvnn_during_night                                                HRV time: CVNN during night
# hrv_time_cvnn_during_nrem                                                  HRV time: CVNN during NREM
# hrv_time_cvnn_during_rem                                                    HRV time: CVNN during REM
# hrv_time_cvnn_during_wake                                                  HRV time: CVNN during wake
# hrv_time_cvsd_during_night                                                HRV time: CVSD during night
# hrv_time_cvsd_during_nrem                                                  HRV time: CVSD during NREM
# hrv_time_cvsd_during_rem                                                    HRV time: CVSD during REM
# hrv_time_cvsd_during_wake                                                  HRV time: CVSD during wake
# hrv_time_during_night                                                          HRV: time during night
# hrv_time_during_nrem                                                            HRV: time during NREM
# hrv_time_during_rem                                                              HRV: time during REM
# hrv_time_during_wake                                                            HRV: time during wake
# hrv_time_hti_during_night                                                  HRV time: HTI during night
# hrv_time_hti_during_nrem                                                    HRV time: HTI during NREM
# hrv_time_hti_during_rem                                                      HRV time: HTI during REM
# hrv_time_hti_during_wake                                                    HRV time: HTI during wake
# hrv_time_iqrnn_during_night                                              HRV time: IQRNN during night
# hrv_time_iqrnn_during_nrem                                                HRV time: IQRNN during NREM
# hrv_time_iqrnn_during_rem                                                  HRV time: IQRNN during REM
# hrv_time_iqrnn_during_wake                                                HRV time: IQRNN during wake
# hrv_time_madnn_during_night                                              HRV time: MadNN during night
# hrv_time_madnn_during_nrem                                                HRV time: MadNN during NREM
# hrv_time_madnn_during_rem                                                  HRV time: MadNN during REM
# hrv_time_madnn_during_wake                                                HRV time: MadNN during wake
# hrv_time_maxnn_during_night                                              HRV time: MaxNN during night
# hrv_time_maxnn_during_nrem                                                HRV time: MaxNN during NREM
# hrv_time_maxnn_during_rem                                                  HRV time: MaxNN during REM
# hrv_time_maxnn_during_wake                                                HRV time: MaxNN during wake
# hrv_time_mcvnn_during_night                                              HRV time: MCVNN during night
# hrv_time_mcvnn_during_nrem                                                HRV time: MCVNN during NREM
# hrv_time_mcvnn_during_rem                                                  HRV time: MCVNN during REM
# hrv_time_mcvnn_during_wake                                                HRV time: MCVNN during wake
# hrv_time_meannn_during_night                                            HRV time: MeanNN during night
# hrv_time_meannn_during_nrem                                              HRV time: MeanNN during NREM
# hrv_time_meannn_during_rem                                                HRV time: MeanNN during REM
# hrv_time_meannn_during_wake                                              HRV time: MeanNN during wake
# hrv_time_mediannn_during_night                                        HRV time: MedianNN during night
# hrv_time_mediannn_during_nrem                                          HRV time: MedianNN during NREM
# hrv_time_mediannn_during_rem                                            HRV time: MedianNN during REM
# hrv_time_mediannn_during_wake                                          HRV time: MedianNN during wake
# hrv_time_minnn_during_night                                              HRV time: MinNN during night
# hrv_time_minnn_during_nrem                                                HRV time: MinNN during NREM
# hrv_time_minnn_during_rem                                                  HRV time: MinNN during REM
# hrv_time_minnn_during_wake                                                HRV time: MinNN during wake
# hrv_time_pnn20_during_night                                              HRV time: pNN20 during night
# hrv_time_pnn20_during_nrem                                                HRV time: pNN20 during NREM
# hrv_time_pnn20_during_rem                                                  HRV time: pNN20 during REM
# hrv_time_pnn20_during_wake                                                HRV time: pNN20 during wake
# hrv_time_pnn50_during_night                                              HRV time: pNN50 during night
# hrv_time_pnn50_during_nrem                                                HRV time: pNN50 during NREM
# hrv_time_pnn50_during_rem                                                  HRV time: pNN50 during REM
# hrv_time_pnn50_during_wake                                                HRV time: pNN50 during wake
# hrv_time_prc20nn_during_night                                          HRV time: Prc20NN during night
# hrv_time_prc20nn_during_nrem                                            HRV time: Prc20NN during NREM
# hrv_time_prc20nn_during_rem                                              HRV time: Prc20NN during REM
# hrv_time_prc20nn_during_wake                                            HRV time: Prc20NN during wake
# hrv_time_prc80nn_during_night                                          HRV time: Prc80NN during night
# hrv_time_prc80nn_during_nrem                                            HRV time: Prc80NN during NREM
# hrv_time_prc80nn_during_rem                                              HRV time: Prc80NN during REM
# hrv_time_prc80nn_during_wake                                            HRV time: Prc80NN during wake
# hrv_time_rmssd_during_night                                              HRV time: RMSSD during night
# hrv_time_rmssd_during_nrem                                                HRV time: RMSSD during NREM
# hrv_time_rmssd_during_rem                                                  HRV time: RMSSD during REM
# hrv_time_rmssd_during_wake                                                HRV time: RMSSD during wake
# hrv_time_sdann1_during_night                                            HRV time: SDANN1 during night
# hrv_time_sdann1_during_nrem                                              HRV time: SDANN1 during NREM
# ...
# hrv_nonlinear_lzc_during_rem                                NaN
# hrv_nonlinear_lzc_during_wake                               NaN
# hrv_nonlinear_mfdfa_alpha1_asymmetry_during_night           NaN
# hrv_nonlinear_mfdfa_alpha1_asymmetry_during_nrem            NaN
# hrv_nonlinear_mfdfa_alpha1_asymmetry_during_rem             NaN
# hrv_nonlinear_mfdfa_alpha1_asymmetry_during_wake            NaN
# hrv_nonlinear_mfdfa_alpha1_delta_during_night               NaN
# hrv_nonlinear_mfdfa_alpha1_delta_during_nrem                NaN
# hrv_nonlinear_mfdfa_alpha1_delta_during_rem                 NaN
# hrv_nonlinear_mfdfa_alpha1_delta_during_wake                NaN
# hrv_nonlinear_mfdfa_alpha1_fluctuation_during_n...          NaN
# hrv_nonlinear_mfdfa_alpha1_fluctuation_during_nrem          NaN
# hrv_nonlinear_mfdfa_alpha1_fluctuation_during_rem           NaN
# hrv_nonlinear_mfdfa_alpha1_fluctuation_during_wake          NaN
# hrv_nonlinear_mfdfa_alpha1_increment_during_night           NaN
# hrv_nonlinear_mfdfa_alpha1_increment_during_nrem            NaN
# hrv_nonlinear_mfdfa_alpha1_increment_during_rem             NaN
# hrv_nonlinear_mfdfa_alpha1_increment_during_wake            NaN
# hrv_nonlinear_mfdfa_alpha1_max_during_night                 NaN
# hrv_nonlinear_mfdfa_alpha1_max_during_nrem                  NaN
# hrv_nonlinear_mfdfa_alpha1_max_during_rem                   NaN
# hrv_nonlinear_mfdfa_alpha1_max_during_wake                  NaN
# hrv_nonlinear_mfdfa_alpha1_mean_during_night                NaN
# hrv_nonlinear_mfdfa_alpha1_mean_during_nrem                 NaN
# hrv_nonlinear_mfdfa_alpha1_mean_during_rem                  NaN
# hrv_nonlinear_mfdfa_alpha1_mean_during_wake                 NaN
# hrv_nonlinear_mfdfa_alpha1_peak_during_night                NaN
# hrv_nonlinear_mfdfa_alpha1_peak_during_nrem                 NaN
# hrv_nonlinear_mfdfa_alpha1_peak_during_rem                  NaN
# hrv_nonlinear_mfdfa_alpha1_peak_during_wake                 NaN
# hrv_nonlinear_mfdfa_alpha1_width_during_night               NaN
# hrv_nonlinear_mfdfa_alpha1_width_during_nrem                NaN
# hrv_nonlinear_mfdfa_alpha1_width_during_rem                 NaN
# hrv_nonlinear_mfdfa_alpha1_width_during_wake                NaN
# hrv_nonlinear_mfdfa_alpha2_asymmetry_during_night           NaN
# hrv_nonlinear_mfdfa_alpha2_asymmetry_during_nrem            NaN
# hrv_nonlinear_mfdfa_alpha2_asymmetry_during_rem             NaN
# hrv_nonlinear_mfdfa_alpha2_asymmetry_during_wake            NaN
# hrv_nonlinear_mfdfa_alpha2_delta_during_night               NaN
# hrv_nonlinear_mfdfa_alpha2_delta_during_nrem                NaN
# hrv_nonlinear_mfdfa_alpha2_delta_during_rem                 NaN
# hrv_nonlinear_mfdfa_alpha2_delta_during_wake                NaN
# hrv_nonlinear_mfdfa_alpha2_fluctuation_during_n...          NaN
# hrv_nonlinear_mfdfa_alpha2_fluctuation_during_nrem          NaN
# hrv_nonlinear_mfdfa_alpha2_fluctuation_during_rem           NaN
# hrv_nonlinear_mfdfa_alpha2_fluctuation_during_wake          NaN
# hrv_nonlinear_mfdfa_alpha2_increment_during_night           NaN
# hrv_nonlinear_mfdfa_alpha2_increment_during_nrem            NaN
# hrv_nonlinear_mfdfa_alpha2_increment_during_rem             NaN
# hrv_nonlinear_mfdfa_alpha2_increment_during_wake            NaN
# hrv_nonlinear_mfdfa_alpha2_max_during_night                 NaN
# hrv_nonlinear_mfdfa_alpha2_max_during_nrem                  NaN
# hrv_nonlinear_mfdfa_alpha2_max_during_rem                   NaN
# hrv_nonlinear_mfdfa_alpha2_max_during_wake                  NaN
# hrv_nonlinear_mfdfa_alpha2_mean_during_night                NaN
# hrv_nonlinear_mfdfa_alpha2_mean_during_nrem                 NaN
# hrv_nonlinear_mfdfa_alpha2_mean_during_rem                  NaN
# hrv_nonlinear_mfdfa_alpha2_mean_during_wake                 NaN
# hrv_nonlinear_mfdfa_alpha2_peak_during_night                NaN
# hrv_nonlinear_mfdfa_alpha2_peak_during_nrem                 NaN
# hrv_nonlinear_mfdfa_alpha2_peak_during_rem                  NaN
# hrv_nonlinear_mfdfa_alpha2_peak_during_wake                 NaN
# hrv_nonlinear_mfdfa_alpha2_width_during_night               NaN
# hrv_nonlinear_mfdfa_alpha2_width_during_nrem                NaN
# hrv_nonlinear_mfdfa_alpha2_width_during_rem                 NaN
# hrv_nonlinear_mfdfa_alpha2_width_during_wake                NaN
# hrv_nonlinear_msen_during_night                             NaN
# hrv_nonlinear_msen_during_nrem                              NaN
# hrv_nonlinear_msen_during_rem                               NaN
# hrv_nonlinear_msen_during_wake                              NaN
# hrv_nonlinear_pas_during_night                              NaN
# hrv_nonlinear_pas_during_nrem                               NaN
# hrv_nonlinear_pas_during_rem                                NaN
# hrv_nonlinear_pas_during_wake                               NaN
# hrv_nonlinear_pi_during_night                               NaN
# hrv_nonlinear_pi_during_nrem                                NaN
# hrv_nonlinear_pi_during_rem                                 NaN
# hrv_nonlinear_pi_during_wake                                NaN
# hrv_nonlinear_pip_during_night                              NaN
# hrv_nonlinear_pip_during_nrem                               NaN
# hrv_nonlinear_pip_during_rem                                NaN
# hrv_nonlinear_pip_during_wake                               NaN
# hrv_nonlinear_pss_during_night                              NaN
# hrv_nonlinear_pss_during_nrem                               NaN
# hrv_nonlinear_pss_during_rem                                NaN
# hrv_nonlinear_pss_during_wake                               NaN
# hrv_nonlinear_s_during_night                                NaN
# hrv_nonlinear_s_during_nrem                                 NaN
# hrv_nonlinear_s_during_rem                                  NaN
# hrv_nonlinear_s_during_wake                                 NaN
# hrv_nonlinear_sampen_during_night                           NaN
# hrv_nonlinear_sampen_during_nrem                            NaN
# hrv_nonlinear_sampen_during_rem                             NaN
# hrv_nonlinear_sampen_during_wake                            NaN
# hrv_nonlinear_sd1_during_night                              NaN
# hrv_nonlinear_sd1_during_nrem                               NaN
# hrv_nonlinear_sd1_during_rem                                NaN
# hrv_nonlinear_sd1_during_wake                               NaN
# hrv_nonlinear_sd1a_during_night                             NaN
# hrv_nonlinear_sd1a_during_nrem                              NaN
# hrv_nonlinear_sd1a_during_rem                               NaN
# hrv_nonlinear_sd1a_during_wake                              NaN
# hrv_nonlinear_sd1d_during_night                             NaN
# hrv_nonlinear_sd1d_during_nrem                              NaN
# hrv_nonlinear_sd1d_during_rem                               NaN
# hrv_nonlinear_sd1d_during_wake                              NaN
# hrv_nonlinear_sd1sd2_during_night                           NaN
# hrv_nonlinear_sd1sd2_during_nrem                            NaN
# hrv_nonlinear_sd1sd2_during_rem                             NaN
# hrv_nonlinear_sd1sd2_during_wake                            NaN
# hrv_nonlinear_sd2_during_night                              NaN
# hrv_nonlinear_sd2_during_nrem                               NaN
# hrv_nonlinear_sd2_during_rem                                NaN
# hrv_nonlinear_sd2_during_wake                               NaN
# hrv_nonlinear_sd2a_during_night                             NaN
# hrv_nonlinear_sd2a_during_nrem                              NaN
# hrv_nonlinear_sd2a_during_rem                               NaN
# hrv_nonlinear_sd2a_during_wake                              NaN
# hrv_nonlinear_sd2d_during_night                             NaN
# hrv_nonlinear_sd2d_during_nrem                              NaN
# hrv_nonlinear_sd2d_during_rem                               NaN
# hrv_nonlinear_sd2d_during_wake                              NaN
# hrv_nonlinear_sdnna_during_night                            NaN
# hrv_nonlinear_sdnna_during_nrem                             NaN
# hrv_nonlinear_sdnna_during_rem                              NaN
# hrv_nonlinear_sdnna_during_wake                             NaN
# hrv_nonlinear_sdnnd_during_night                            NaN
# hrv_nonlinear_sdnnd_during_nrem                             NaN
# hrv_nonlinear_sdnnd_during_rem                              NaN
# hrv_nonlinear_sdnnd_during_wake                             NaN
# hrv_nonlinear_shanen_during_night                           NaN
# hrv_nonlinear_shanen_during_nrem                            NaN
# hrv_nonlinear_shanen_during_rem                             NaN
# hrv_nonlinear_shanen_during_wake                            NaN
# hrv_nonlinear_si_during_night                               NaN
# hrv_nonlinear_si_during_nrem                                NaN
# hrv_nonlinear_si_during_rem                                 NaN
# hrv_nonlinear_si_during_wake                                NaN
# hrv_quality_score_during_night                              NaN
# hrv_quality_score_during_nrem                               NaN
# hrv_quality_score_during_rem                                NaN
# hrv_quality_score_during_wake                               NaN
# hrv_time_cvnn_during_night                                  NaN
# hrv_time_cvnn_during_nrem                                   NaN
# hrv_time_cvnn_during_rem                                    NaN
# hrv_time_cvnn_during_wake                                   NaN
# hrv_time_cvsd_during_night                                  NaN
# hrv_time_cvsd_during_nrem                                   NaN
# hrv_time_cvsd_during_rem                                    NaN
# hrv_time_cvsd_during_wake                                   NaN
# hrv_time_during_night                                       NaN
# hrv_time_during_nrem                                        NaN
# hrv_time_during_rem                                         NaN
# hrv_time_during_wake                                        NaN
# hrv_time_hti_during_night                                   NaN
# hrv_time_hti_during_nrem                                    NaN
# hrv_time_hti_during_rem                                     NaN
# hrv_time_hti_during_wake                                    NaN
# hrv_time_iqrnn_during_night                                 NaN
# hrv_time_iqrnn_during_nrem                                  NaN
# hrv_time_iqrnn_during_rem                                   NaN
# hrv_time_iqrnn_during_wake                                  NaN
# hrv_time_madnn_during_night                                 NaN
# hrv_time_madnn_during_nrem                                  NaN
# hrv_time_madnn_during_rem                                   NaN
# hrv_time_madnn_during_wake                                  NaN
# hrv_time_maxnn_during_night                                 NaN
# hrv_time_maxnn_during_nrem                                  NaN
# hrv_time_maxnn_during_rem                                   NaN
# hrv_time_maxnn_during_wake                                  NaN
# hrv_time_mcvnn_during_night                                 NaN
# hrv_time_mcvnn_during_nrem                                  NaN
# hrv_time_mcvnn_during_rem                                   NaN
# hrv_time_mcvnn_during_wake                                  NaN
# hrv_time_meannn_during_night                                NaN
# hrv_time_meannn_during_nrem                                 NaN
# hrv_time_meannn_during_rem                                  NaN
# hrv_time_meannn_during_wake                                 NaN
# hrv_time_mediannn_during_night                              NaN
# hrv_time_mediannn_during_nrem                               NaN
# hrv_time_mediannn_during_rem                                NaN
# hrv_time_mediannn_during_wake                               NaN
# hrv_time_minnn_during_night                                 NaN
# hrv_time_minnn_during_nrem                                  NaN
# hrv_time_minnn_during_rem                                   NaN
# hrv_time_minnn_during_wake                                  NaN
# hrv_time_pnn20_during_night                                 NaN
# hrv_time_pnn20_during_nrem                                  NaN
# hrv_time_pnn20_during_rem                                   NaN
# hrv_time_pnn20_during_wake                                  NaN
# hrv_time_pnn50_during_night                                 NaN
# hrv_time_pnn50_during_nrem                                  NaN
# hrv_time_pnn50_during_rem                                   NaN
# hrv_time_pnn50_during_wake                                  NaN
# hrv_time_prc20nn_during_night                               NaN
# hrv_time_prc20nn_during_nrem                                NaN
# hrv_time_prc20nn_during_rem                                 NaN
# hrv_time_prc20nn_during_wake                                NaN
# hrv_time_prc80nn_during_night                               NaN
# hrv_time_prc80nn_during_nrem                                NaN
# hrv_time_prc80nn_during_rem                                 NaN
# hrv_time_prc80nn_during_wake                                NaN
# hrv_time_rmssd_during_night                                 NaN
# hrv_time_rmssd_during_nrem                                  NaN
# hrv_time_rmssd_during_rem                                   NaN
# hrv_time_rmssd_during_wake                                  NaN
# hrv_time_sdann1_during_night                                NaN
# hrv_time_sdann1_during_nrem                                 NaN
# hrv_time_sdann1_during_rem                                  NaN
# hrv_time_sdann1_during_wake                                 NaN
# hrv_time_sdann2_during_night                                NaN
# hrv_time_sdann2_during_nrem                                 NaN
# hrv_time_sdann2_during_rem                                  NaN
# hrv_time_sdann2_during_wake                                 NaN
# hrv_time_sdann5_during_night                                NaN
# hrv_time_sdann5_during_nrem                                 NaN
# hrv_time_sdann5_during_rem                                  NaN
# hrv_time_sdann5_during_wake                                 NaN
# hrv_time_sdnn_during_night                                  NaN
# hrv_time_sdnn_during_nrem                                   NaN
# hrv_time_sdnn_during_rem                                    NaN
# hrv_time_sdnn_during_wake                                   NaN
# hrv_time_sdnni1_during_night                                NaN
# hrv_time_sdnni1_during_nrem                                 NaN
# hrv_time_sdnni1_during_rem                                  NaN
# hrv_time_sdnni1_during_wake                                 NaN
# hrv_time_sdnni2_during_night                                NaN
# hrv_time_sdnni2_during_nrem                                 NaN
# hrv_time_sdnni2_during_rem                                  NaN
# hrv_time_sdnni2_during_wake                                 NaN
# hrv_time_sdnni5_during_night                                NaN
# hrv_time_sdnni5_during_nrem                                 NaN
# hrv_time_sdnni5_during_rem                                  NaN
# hrv_time_sdnni5_during_wake                                 NaN
# hrv_time_sdsd_during_night                                  NaN
# hrv_time_sdsd_during_nrem                                   NaN
# hrv_time_sdsd_during_rem                                    NaN
# hrv_time_sdsd_during_wake                                   NaN
# hrv_time_tinn_during_night                                  NaN
# hrv_time_tinn_during_nrem                                   NaN
# hrv_time_tinn_during_rem                                    NaN
# hrv_time_tinn_during_wake                                   NaN
