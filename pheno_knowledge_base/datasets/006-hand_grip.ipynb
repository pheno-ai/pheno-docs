# %% [raw]
# ---
# output-file: 006-hand_grip.html
# title: 006-hand_grip
# ---

# %% [markdown]
# # Hand grip strength dataset
# Hand grip strength (HGS) is an effective marker of general health in middle age and older adulthood. Grip strength is measured by squeezing a type of muscle strength testing equipment, known as a dynamometer.
#
# HGS is a measure of the maximum force that an individual can exert with their hand. It is a widely used measure of muscular strength. HGS is an easy and quick measure to obtain.
#
# In a clinical setting, HGS is often used as a measure to assess changes in muscle strength over time. For example, in patients with conditions such as osteoarthritis, rheumatoid arthritis, or sarcopenia, Additionally, HGS can be used to assess the effectiveness of rehabilitation programs, such as those used to recover from a stroke or other neurological condition.
#
# HGS is measured using a Jamar Hydraulic Hand Dynamometer. The measurement is a measure of the static force (without movement) that the hand can exert when squeezing around the dynamometer.
#
# ### Data availability:
# The information is stored in 1 parquet file: `hand_grip.parquet`

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('hand_grip')
dl
# Out:
# DataLoader for hand_grip with
# 10 fields
# 2 tables: ['hand_grip', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                                             field_string  \
# tabular_field_name
# collection_date             Collection date (YYYY-MM-DD)
# collection_timestamp                Collection timestamp
# finger_grip_strength_left    Finger grip strength (left)
# finger_grip_strength_right  Finger grip strength (right)
# dominant_hand                              Dominant hand
# hand_grip_strength_left        Hand grip strength (left)
# hand_grip_strength_right      Hand grip strength (right)
# timezone                                        Timezone
#
#                                               description_string  \
# tabular_field_name
# collection_date                     Collection date (YYYY-MM-DD)
# collection_timestamp                        Collection timestamp
# finger_grip_strength_left            Finger grip strength (left)
# finger_grip_strength_right          Finger grip strength (right)
# dominant_hand               Hand preference for fine motor tasks
# hand_grip_strength_left               Hand grip strength (left)
# hand_grip_strength_right             Hand grip strength (right)
# timezone                                                Timezone
#
#                                       relative_location  \
# tabular_field_name
# collection_date             hand_grip/hand_grip.parquet
# collection_timestamp        hand_grip/hand_grip.parquet
# finger_grip_strength_left   hand_grip/hand_grip.parquet
# finger_grip_strength_right  hand_grip/hand_grip.parquet
# dominant_hand               hand_grip/hand_grip.parquet
# hand_grip_strength_left     hand_grip/hand_grip.parquet
# hand_grip_strength_right    hand_grip/hand_grip.parquet
# timezone                    hand_grip/hand_grip.parquet
#
#                                        value_type units  sampling_rate  \
# tabular_field_name
# collection_date                              Time  Time            NaN
# collection_timestamp                         Time  Time            NaN
# finger_grip_strength_left              Continuous    kg            NaN
# finger_grip_strength_right             Continuous    kg            NaN
# dominant_hand               Categorical (single)    NaN            NaN
# hand_grip_strength_left                Continuous    kg            NaN
# hand_grip_strength_right               Continuous    kg            NaN
# timezone                    Categorical (single)    NaN            NaN
#
#                            item_type   array cohorts data_type       debut  \
# tabular_field_name
# collection_date                 Data  Single     10K   Tabular  2019-01-29
# collection_timestamp            Data  Single     10K   Tabular  2019-01-29
# finger_grip_strength_left       Data  Single     10K   Tabular  2019-01-29
# finger_grip_strength_right      Data  Single     10K   Tabular  2019-01-29
# dominant_hand                   Data  Single     10K   Tabular  2019-01-29
# hand_grip_strength_left         Data  Single     10K   Tabular  2019-01-29
# hand_grip_strength_right        Data  Single     10K   Tabular  2019-01-29
# timezone                        Data  Single     10K   Tabular  2019-01-29
#
#                                               pandas_dtype  parent_dataframe
# tabular_field_name
# collection_date                             datetime64[ns]               NaN
# collection_timestamp        datetime64[ns, Asia/Jerusalem]               NaN
# finger_grip_strength_left                            float               NaN
# finger_grip_strength_right                           float               NaN
# dominant_hand                                     category               NaN
# hand_grip_strength_left                              float               NaN
# hand_grip_strength_right                             float               NaN
# timezone                                            string               NaN
