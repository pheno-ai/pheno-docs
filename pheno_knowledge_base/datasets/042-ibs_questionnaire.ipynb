# %% [raw]
# ---
# output-file: 042-ibs_questionnaire.html
# title: 042-ibs_questionnaire
# ---

# %% [markdown]
# # IBS Questionnaire
#
# This IBS survey is an adaptation of the UK Biobank online gastro-intestinal health self-assessment questionnaire. Many of the questions in the UK Biobank gut health (IBS) questionnaire were adopted from the World Gastroenterology Association questionnaire (2009).
# Questions asked are related to the participant’s bowel habits, characterization of abdominal pain patterns, accompanying symptoms, and history of IBS in the family.
#
# ### Data availability:
# The information is stored in 2 parquet files: `ibs_questionnaire.parquet` and `ibs_mapping.parquet`

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('ibs_questionnaire')
dl
# Out:
# DataLoader for ibs_questionnaire with
# 59 fields
# 2 tables: ['ibs_questionnaire', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                                                                                   field_string  \
# tabular_field_name
# collection_timestamp                                                      Collection timestamp
# collection_date                                                                Collection date
# timezone                                                                              Timezone
# abdomen_pain_frequency_past_3_months         Frequency of discomfort/pain in abdomen in las...
# abdomen_pain_women_during_period             Discomfort/pain occurring only during menstrua...
# abdomen_pain_past_6_months                    Abdominal discomfort/pain for 6 months or longer
# abdomen_pain_imrpove_after_bowl_movement     Frequency of discomfort/pain getting better or...
# abdomen_pain_increases_bowl_movements        More frequent bowel movements when abdominal d...
# abdomen_pain_decreases_bowl_movements        Less frequent bowel movements when abdominal d...
# soft_stool_during_abdomen_pain               Stools looser when abdominal discomfort/pain s...
# hard_stool_during_abdomen_pain               Frequency of harder stools when abdominal disc...
# hard_stool_frequency_past_3_months           Frequency of hard/lumpy stools in the last 3 m...
# soft_stool_frequency_past_3_months           Frequency of loose/mushy/watery stools in the ...
# abdomen_pain_current                         Currently (in last 3 months) suffer from abdom...
# abdomen_pain_current_severity                               Severity of current abdominal pain
# abdomen_pain_days_out_of_10                     Number of days (out of 10) with abdominal pain
# abdomen_pain_current_distension                     Currently suffer from abdominal distension
# abdomen_pain_current_distension_severity     Severity of current abdominal distension/tight...
# bowl_movements_current_satisfaction                             Satisfaction with bowel habits
# abdomen_pain_current_general_interference    Degree to which abdominal pain/discomfort/alte...
# bowl_movements_daily_max                        Greatest number of times bowels opened per day
# bowl_movements_daily_min                          Least number of times bowels opened per week
# bowl_movements_daily_average                     Average number of times bowels opened per day
# abdomen_pain_work_weeks_missed_number        Number of weeks absent from work due to IBS, i...
# abdomen_pain_work_weeks_missed_choice                             When gave up work due to IBS
# abdomen_pain_work_weeks_suffering            Number of weeks (in the last year) at work suf...
# back_pain_past_3_months                      Degree bothered by back pain in the past 3 months
# legs_joint_pain_past_3_months                Degree bothered by pain in arms/legs/joints in...
# menstural_cramps_past_3_months               Degree bothered by menstrual cramps or other p...
# headaches_past_3_months                      Degree bothered by headaches in the last 3 months
# chest_pain_past_3_months                     Degree bothered by chest pain in the last 3 mo...
# dizziness_past_3_months                      Degree bothered by dizziness in the last 3 months
# fainting_past_3_months                       Degree bothered by fainting spells in the last...
# heart_race_past_3_months                     Degree bothered by feeling heart pound/race in...
# shortness_of_breath_past_3_months            Degree bothered by shortness of breath in the ...
# intercourse_pain_past_3_months               Degree bothered by pain/problems during interc...
# bladder_irritability_past_3_months           Degree bothered by urinary frequency/bladder i...
# nausea_past_3_months                            Degree bothered by nausea in the last 3 months
# tired_past_3_months                          Degree bothered by feeling tired all the time ...
# sleeping_trouble_past_3_months               Degree bothered by trouble sleeping in the las...
# anxiety_treatment_past                          Ever been offered/sought treatment for anxiety
# depression_treatment_past                    Ever been offered/sought treatment for depression
# sensitive_stomach                                                            Sensitive stomach
# history_family_ibs                                                       Family history of IBS
# history_birth_caesarian_section                                      Born by caesarian section
# history_childhood_antibiotics                Long-term/recurrent antibiotics as child or te...
# history_diagnoses_celiac                     Diagnosed with coeliac disease or gluten sensi...
# history_diagnoses_celiac_method              Method of coeliac disease/gluten sensitivity d...
# history_diagnoses_ibs                                                  Ever diagnosed with IBS
# history_ibs_symptoms_speed                                      Speed of onset of IBS symptoms
# history_ibs_first_symptoms_infection         Infectious illness diagnosis status when IBS s...
# history_ibs_first_symptoms_infection_choice  Infection diagnosed alongside IBS when IBS sym...
# history_ibs_first_symptoms_fever                           Fever when IBS symptoms first began
# history_ibs_first_symptoms_diarrhoea                   Diarrhoea when IBS symptoms first began
# history_ibs_first_symptoms_bloody_diarrhoea     Bloody diarrhoea when IBS symptoms first began
# history_ibs_first_symptoms_vomiting                     Vomiting when IBS symptoms first began
# ibs_mapping                                                            IBS survey code mapping
#
#                                                                             description_string  \
# tabular_field_name
# collection_timestamp                                                                       NaN
# collection_date                                                                            NaN
# timezone                                                           Timezone of the measurments
# abdomen_pain_frequency_past_3_months         In the last 3 months, how often did you have d...
# abdomen_pain_women_during_period             Did this discomfort or pain occur only during ...
# abdomen_pain_past_6_months                   Have you had this discomfort or pain 6 months ...
# abdomen_pain_imrpove_after_bowl_movement     How often did this discomfort or pain get bett...
# abdomen_pain_increases_bowl_movements        When this discomfort or pain started, did you ...
# abdomen_pain_decreases_bowl_movements        When this discomfort or pain started, did you ...
# soft_stool_during_abdomen_pain               When this discomfort or pain started, were you...
# hard_stool_during_abdomen_pain               When this discomfort or pain started, how ofte...
# hard_stool_frequency_past_3_months           In the last 3 months, how often did you have h...
# soft_stool_frequency_past_3_months           In the last 3 months, how often did you have l...
# abdomen_pain_current                         Do you currently (in the last 3 months) suffer...
# abdomen_pain_current_severity                               How severe is your abdominal pain?
# abdomen_pain_days_out_of_10                  Please move the slider to select the number of...
# abdomen_pain_current_distension              Do you currently suffer from abdominal distens...
# abdomen_pain_current_distension_severity     How severe is your abdominal distension/tightn...
# bowl_movements_current_satisfaction          How happy/satisfied are you with your bowel ha...
# abdomen_pain_current_general_interference    Please indicate how much abdominal pain or dis...
# bowl_movements_daily_max                     What is the greatest number of times you open ...
# bowl_movements_daily_min                     What is the least number of times you open you...
# bowl_movements_daily_average                 What is the average number of times you open y...
# abdomen_pain_work_weeks_missed_number        In the last year approximately how many weeks ...
# abdomen_pain_work_weeks_missed_choice        Question asked when the participant had given ...
# abdomen_pain_work_weeks_suffering            Question asked how many weeks (in the last yea...
# back_pain_past_3_months                      During the past 3 months, how much have you be...
# legs_joint_pain_past_3_months                During the past 3 months, how much have you be...
# menstural_cramps_past_3_months               During the past 3 months, how much have you be...
# headaches_past_3_months                      During the past 3 months, how much have you be...
# chest_pain_past_3_months                     During the past 3 months, how much have you be...
# dizziness_past_3_months                      During the past 3 months, how much have you be...
# fainting_past_3_months                       During the past 3 months, how much have you be...
# heart_race_past_3_months                     During the past 3 months, how much have you be...
# shortness_of_breath_past_3_months            During the past 3 months, how much have you be...
# intercourse_pain_past_3_months               During the past 3 months, how much have you be...
# bladder_irritability_past_3_months           During the past 3 months, how much have you be...
# nausea_past_3_months                         During the past 3 months, how much have you be...
# tired_past_3_months                          During the past 3 months, how much have you be...
# sleeping_trouble_past_3_months               During the past 3 months, how much have you be...
# anxiety_treatment_past                       Have you ever been offered or sought treatment...
# depression_treatment_past                    Have you ever been offered or sought treatment...
# sensitive_stomach                                             Do you have a sensitive stomach?
# history_family_ibs                           Do you have a family history of IBS in your pa...
# history_birth_caesarian_section                            Were you born by caesarian section?
# history_childhood_antibiotics                During childhood or as a teenager did you rece...
# history_diagnoses_celiac                     Have you been diagnosed with coeliac disease/g...
# history_diagnoses_celiac_method              When you were diagnosed with coeliac disease/g...
# history_diagnoses_ibs                                   Have you ever been diagnosed with IBS?
# history_ibs_symptoms_speed                   Did your IBS symptoms start suddenly, over one...
# history_ibs_first_symptoms_infection         When your IBS symptoms first began (or up to t...
# history_ibs_first_symptoms_infection_choice  Question asked the participant to select the i...
# history_ibs_first_symptoms_fever             When your IBS symptoms first began (or up to t...
# history_ibs_first_symptoms_diarrhoea         When your IBS symptoms first began (or up to t...
# history_ibs_first_symptoms_bloody_diarrhoea  When your IBS symptoms first began (or up to t...
# history_ibs_first_symptoms_vomiting          When your IBS symptoms first began (or up to t...
# ibs_mapping                                  Mappings of survey codes to English and Hebrew...
#
#                                                                        relative_location  \
# tabular_field_name
# collection_timestamp                         ibs_questionnaire/ibs_questionnaire.parquet
# collection_date                              ibs_questionnaire/ibs_questionnaire.parquet
# timezone                                     ibs_questionnaire/ibs_questionnaire.parquet
# abdomen_pain_frequency_past_3_months         ibs_questionnaire/ibs_questionnaire.parquet
# abdomen_pain_women_during_period             ibs_questionnaire/ibs_questionnaire.parquet
# abdomen_pain_past_6_months                   ibs_questionnaire/ibs_questionnaire.parquet
# abdomen_pain_imrpove_after_bowl_movement     ibs_questionnaire/ibs_questionnaire.parquet
# abdomen_pain_increases_bowl_movements        ibs_questionnaire/ibs_questionnaire.parquet
# abdomen_pain_decreases_bowl_movements        ibs_questionnaire/ibs_questionnaire.parquet
# soft_stool_during_abdomen_pain               ibs_questionnaire/ibs_questionnaire.parquet
# hard_stool_during_abdomen_pain               ibs_questionnaire/ibs_questionnaire.parquet
# hard_stool_frequency_past_3_months           ibs_questionnaire/ibs_questionnaire.parquet
# soft_stool_frequency_past_3_months           ibs_questionnaire/ibs_questionnaire.parquet
# abdomen_pain_current                         ibs_questionnaire/ibs_questionnaire.parquet
# abdomen_pain_current_severity                ibs_questionnaire/ibs_questionnaire.parquet
# abdomen_pain_days_out_of_10                  ibs_questionnaire/ibs_questionnaire.parquet
# abdomen_pain_current_distension              ibs_questionnaire/ibs_questionnaire.parquet
# abdomen_pain_current_distension_severity     ibs_questionnaire/ibs_questionnaire.parquet
# bowl_movements_current_satisfaction          ibs_questionnaire/ibs_questionnaire.parquet
# abdomen_pain_current_general_interference    ibs_questionnaire/ibs_questionnaire.parquet
# bowl_movements_daily_max                     ibs_questionnaire/ibs_questionnaire.parquet
# bowl_movements_daily_min                     ibs_questionnaire/ibs_questionnaire.parquet
# bowl_movements_daily_average                 ibs_questionnaire/ibs_questionnaire.parquet
# abdomen_pain_work_weeks_missed_number        ibs_questionnaire/ibs_questionnaire.parquet
# abdomen_pain_work_weeks_missed_choice        ibs_questionnaire/ibs_questionnaire.parquet
# abdomen_pain_work_weeks_suffering            ibs_questionnaire/ibs_questionnaire.parquet
# back_pain_past_3_months                      ibs_questionnaire/ibs_questionnaire.parquet
# legs_joint_pain_past_3_months                ibs_questionnaire/ibs_questionnaire.parquet
# menstural_cramps_past_3_months               ibs_questionnaire/ibs_questionnaire.parquet
# headaches_past_3_months                      ibs_questionnaire/ibs_questionnaire.parquet
# chest_pain_past_3_months                     ibs_questionnaire/ibs_questionnaire.parquet
# dizziness_past_3_months                      ibs_questionnaire/ibs_questionnaire.parquet
# fainting_past_3_months                       ibs_questionnaire/ibs_questionnaire.parquet
# heart_race_past_3_months                     ibs_questionnaire/ibs_questionnaire.parquet
# shortness_of_breath_past_3_months            ibs_questionnaire/ibs_questionnaire.parquet
# intercourse_pain_past_3_months               ibs_questionnaire/ibs_questionnaire.parquet
# bladder_irritability_past_3_months           ibs_questionnaire/ibs_questionnaire.parquet
# nausea_past_3_months                         ibs_questionnaire/ibs_questionnaire.parquet
# tired_past_3_months                          ibs_questionnaire/ibs_questionnaire.parquet
# sleeping_trouble_past_3_months               ibs_questionnaire/ibs_questionnaire.parquet
# anxiety_treatment_past                       ibs_questionnaire/ibs_questionnaire.parquet
# depression_treatment_past                    ibs_questionnaire/ibs_questionnaire.parquet
# sensitive_stomach                            ibs_questionnaire/ibs_questionnaire.parquet
# history_family_ibs                           ibs_questionnaire/ibs_questionnaire.parquet
# history_birth_caesarian_section              ibs_questionnaire/ibs_questionnaire.parquet
# history_childhood_antibiotics                ibs_questionnaire/ibs_questionnaire.parquet
# history_diagnoses_celiac                     ibs_questionnaire/ibs_questionnaire.parquet
# history_diagnoses_celiac_method              ibs_questionnaire/ibs_questionnaire.parquet
# history_diagnoses_ibs                        ibs_questionnaire/ibs_questionnaire.parquet
# history_ibs_symptoms_speed                   ibs_questionnaire/ibs_questionnaire.parquet
# history_ibs_first_symptoms_infection         ibs_questionnaire/ibs_questionnaire.parquet
# history_ibs_first_symptoms_infection_choice  ibs_questionnaire/ibs_questionnaire.parquet
# history_ibs_first_symptoms_fever             ibs_questionnaire/ibs_questionnaire.parquet
# history_ibs_first_symptoms_diarrhoea         ibs_questionnaire/ibs_questionnaire.parquet
# history_ibs_first_symptoms_bloody_diarrhoea  ibs_questionnaire/ibs_questionnaire.parquet
# history_ibs_first_symptoms_vomiting          ibs_questionnaire/ibs_questionnaire.parquet
# ibs_mapping                                  ibs_questionnaire/ibs_questionnaire.parquet
#
#                                                          value_type units  \
# tabular_field_name
# collection_timestamp                                           Time  Time
# collection_date                                                Time  Time
# timezone                                                       Text   NaN
# abdomen_pain_frequency_past_3_months           Categorical (single)   NaN
# abdomen_pain_women_during_period               Categorical (single)   NaN
# abdomen_pain_past_6_months                     Categorical (single)   NaN
# abdomen_pain_imrpove_after_bowl_movement       Categorical (single)   NaN
# abdomen_pain_increases_bowl_movements          Categorical (single)   NaN
# abdomen_pain_decreases_bowl_movements          Categorical (single)   NaN
# soft_stool_during_abdomen_pain                 Categorical (single)   NaN
# hard_stool_during_abdomen_pain                 Categorical (single)   NaN
# hard_stool_frequency_past_3_months             Categorical (single)   NaN
# soft_stool_frequency_past_3_months             Categorical (single)   NaN
# abdomen_pain_current                           Categorical (single)   NaN
# abdomen_pain_current_severity                               Integer   NaN
# abdomen_pain_days_out_of_10                                 Integer   NaN
# abdomen_pain_current_distension                Categorical (single)   NaN
# abdomen_pain_current_distension_severity                    Integer   NaN
# bowl_movements_current_satisfaction                         Integer   NaN
# abdomen_pain_current_general_interference                   Integer   NaN
# bowl_movements_daily_max                                    Integer   NaN
# bowl_movements_daily_min                                    Integer   NaN
# bowl_movements_daily_average                                Integer   NaN
# abdomen_pain_work_weeks_missed_number                       Integer   NaN
# abdomen_pain_work_weeks_missed_choice        Categorical (multiple)   NaN
# abdomen_pain_work_weeks_suffering                           Integer   NaN
# back_pain_past_3_months                        Categorical (single)   NaN
# legs_joint_pain_past_3_months                  Categorical (single)   NaN
# menstural_cramps_past_3_months                 Categorical (single)   NaN
# headaches_past_3_months                        Categorical (single)   NaN
# chest_pain_past_3_months                       Categorical (single)   NaN
# dizziness_past_3_months                        Categorical (single)   NaN
# fainting_past_3_months                         Categorical (single)   NaN
# heart_race_past_3_months                       Categorical (single)   NaN
# shortness_of_breath_past_3_months              Categorical (single)   NaN
# intercourse_pain_past_3_months                 Categorical (single)   NaN
# bladder_irritability_past_3_months             Categorical (single)   NaN
# nausea_past_3_months                           Categorical (single)   NaN
# tired_past_3_months                            Categorical (single)   NaN
# sleeping_trouble_past_3_months                 Categorical (single)   NaN
# anxiety_treatment_past                         Categorical (single)   NaN
# depression_treatment_past                      Categorical (single)   NaN
# sensitive_stomach                              Categorical (single)   NaN
# history_family_ibs                             Categorical (single)   NaN
# history_birth_caesarian_section                Categorical (single)   NaN
# history_childhood_antibiotics                  Categorical (single)   NaN
# history_diagnoses_celiac                       Categorical (single)   NaN
# history_diagnoses_celiac_method                Categorical (single)   NaN
# history_diagnoses_ibs                          Categorical (single)   NaN
# history_ibs_symptoms_speed                     Categorical (single)   NaN
# history_ibs_first_symptoms_infection           Categorical (single)   NaN
# history_ibs_first_symptoms_infection_choice    Categorical (single)   NaN
# history_ibs_first_symptoms_fever               Categorical (single)   NaN
# history_ibs_first_symptoms_diarrhoea           Categorical (single)   NaN
# history_ibs_first_symptoms_bloody_diarrhoea    Categorical (single)   NaN
# history_ibs_first_symptoms_vomiting            Categorical (single)   NaN
# ibs_mapping                                                     NaN   NaN
#
#                                              sampling_rate item_type   array  \
# tabular_field_name
# collection_timestamp                                   NaN      Data  Single
# collection_date                                        NaN      Data  Single
# timezone                                               NaN      Data  Single
# abdomen_pain_frequency_past_3_months                   NaN      Data  Single
# abdomen_pain_women_during_period                       NaN      Data  Single
# abdomen_pain_past_6_months                             NaN      Data  Single
# abdomen_pain_imrpove_after_bowl_movement               NaN      Data  Single
# abdomen_pain_increases_bowl_movements                  NaN      Data  Single
# abdomen_pain_decreases_bowl_movements                  NaN      Data  Single
# soft_stool_during_abdomen_pain                         NaN      Data  Single
# hard_stool_during_abdomen_pain                         NaN      Data  Single
# hard_stool_frequency_past_3_months                     NaN      Data  Single
# soft_stool_frequency_past_3_months                     NaN      Data  Single
# abdomen_pain_current                                   NaN      Data  Single
# abdomen_pain_current_severity                          NaN      Data  Single
# abdomen_pain_days_out_of_10                            NaN      Data  Single
# abdomen_pain_current_distension                        NaN      Data  Single
# abdomen_pain_current_distension_severity               NaN      Data  Single
# bowl_movements_current_satisfaction                    NaN      Data  Single
# abdomen_pain_current_general_interference              NaN      Data  Single
# bowl_movements_daily_max                               NaN      Data  Single
# bowl_movements_daily_min                               NaN      Data  Single
# bowl_movements_daily_average                           NaN      Data  Single
# abdomen_pain_work_weeks_missed_number                  NaN      Data  Single
# abdomen_pain_work_weeks_missed_choice                  NaN      Data  Single
# abdomen_pain_work_weeks_suffering                      NaN      Data  Single
# back_pain_past_3_months                                NaN      Data  Single
# legs_joint_pain_past_3_months                          NaN   Defined  Single
# menstural_cramps_past_3_months                         NaN      Data  Single
# headaches_past_3_months                                NaN      Data  Single
# chest_pain_past_3_months                               NaN      Data  Single
# dizziness_past_3_months                                NaN      Data  Single
# fainting_past_3_months                                 NaN      Data  Single
# heart_race_past_3_months                               NaN      Data  Single
# shortness_of_breath_past_3_months                      NaN      Data  Single
# intercourse_pain_past_3_months                         NaN      Data  Single
# bladder_irritability_past_3_months                     NaN      Data  Single
# nausea_past_3_months                                   NaN      Data  Single
# tired_past_3_months                                    NaN      Data  Single
# sleeping_trouble_past_3_months                         NaN      Data  Single
# anxiety_treatment_past                                 NaN      Data  Single
# depression_treatment_past                              NaN      Data  Single
# sensitive_stomach                                      NaN      Data  Single
# history_family_ibs                                     NaN      Data  Single
# history_birth_caesarian_section                        NaN      Data  Single
# history_childhood_antibiotics                          NaN      Data  Single
# history_diagnoses_celiac                               NaN      Data  Single
# history_diagnoses_celiac_method                        NaN      Data  Single
# history_diagnoses_ibs                                  NaN      Data  Single
# history_ibs_symptoms_speed                             NaN      Data  Single
# history_ibs_first_symptoms_infection                   NaN      Data  Single
# history_ibs_first_symptoms_infection_choice            NaN      Data  Single
# history_ibs_first_symptoms_fever                       NaN      Data  Single
# history_ibs_first_symptoms_diarrhoea                   NaN      Data  Single
# history_ibs_first_symptoms_bloody_diarrhoea            NaN      Data  Single
# history_ibs_first_symptoms_vomiting                    NaN      Data  Single
# ibs_mapping                                            NaN      Bulk  Single
#
#                                             cohorts data_type  debut  \
# tabular_field_name
# collection_timestamp                            10K   Tabular    NaN
# collection_date                                 10K   Tabular    NaN
# timezone                                        10K   Tabular    NaN
# abdomen_pain_frequency_past_3_months            10K   Tabular    NaN
# abdomen_pain_women_during_period                10K   Tabular    NaN
# abdomen_pain_past_6_months                      10K   Tabular    NaN
# abdomen_pain_imrpove_after_bowl_movement        10K   Tabular    NaN
# abdomen_pain_increases_bowl_movements           10K   Tabular    NaN
# abdomen_pain_decreases_bowl_movements           10K   Tabular    NaN
# soft_stool_during_abdomen_pain                  10K   Tabular    NaN
# hard_stool_during_abdomen_pain                  10K   Tabular    NaN
# hard_stool_frequency_past_3_months              10K   Tabular    NaN
# soft_stool_frequency_past_3_months              10K   Tabular    NaN
# abdomen_pain_current                            10K   Tabular    NaN
# abdomen_pain_current_severity                   10K   Tabular    NaN
# abdomen_pain_days_out_of_10                     10K   Tabular    NaN
# abdomen_pain_current_distension                 10K   Tabular    NaN
# abdomen_pain_current_distension_severity        10K   Tabular    NaN
# bowl_movements_current_satisfaction             10K   Tabular    NaN
# abdomen_pain_current_general_interference       10K   Tabular    NaN
# bowl_movements_daily_max                        10K   Tabular    NaN
# bowl_movements_daily_min                        10K   Tabular    NaN
# bowl_movements_daily_average                    10K   Tabular    NaN
# abdomen_pain_work_weeks_missed_number           10K   Tabular    NaN
# abdomen_pain_work_weeks_missed_choice           10K   Tabular    NaN
# abdomen_pain_work_weeks_suffering               10K   Tabular    NaN
# back_pain_past_3_months                         10K   Tabular    NaN
# legs_joint_pain_past_3_months                   10K   Tabular    NaN
# menstural_cramps_past_3_months                  10K   Tabular    NaN
# headaches_past_3_months                         10K   Tabular    NaN
# chest_pain_past_3_months                        10K   Tabular    NaN
# dizziness_past_3_months                         10K   Tabular    NaN
# fainting_past_3_months                          10K   Tabular    NaN
# heart_race_past_3_months                        10K   Tabular    NaN
# shortness_of_breath_past_3_months               10K   Tabular    NaN
# intercourse_pain_past_3_months                  10K   Tabular    NaN
# bladder_irritability_past_3_months              10K   Tabular    NaN
# nausea_past_3_months                            10K   Tabular    NaN
# tired_past_3_months                             10K   Tabular    NaN
# sleeping_trouble_past_3_months                  10K   Tabular    NaN
# anxiety_treatment_past                          10K   Tabular    NaN
# depression_treatment_past                       10K   Tabular    NaN
# sensitive_stomach                               10K   Tabular    NaN
# history_family_ibs                              10K   Tabular    NaN
# history_birth_caesarian_section                 10K   Tabular    NaN
# history_childhood_antibiotics                   10K   Tabular    NaN
# history_diagnoses_celiac                        10K   Tabular    NaN
# history_diagnoses_celiac_method                 10K   Tabular    NaN
# history_diagnoses_ibs                           10K   Tabular    NaN
# history_ibs_symptoms_speed                      10K   Tabular    NaN
# history_ibs_first_symptoms_infection            10K   Tabular    NaN
# history_ibs_first_symptoms_infection_choice     10K   Tabular    NaN
# history_ibs_first_symptoms_fever                10K   Tabular    NaN
# history_ibs_first_symptoms_diarrhoea            10K   Tabular    NaN
# history_ibs_first_symptoms_bloody_diarrhoea     10K   Tabular    NaN
# history_ibs_first_symptoms_vomiting             10K   Tabular    NaN
# ibs_mapping                                     10K   Tabular    NaN
#
#                                                                pandas_dtype  \
# tabular_field_name
# collection_timestamp                         datetime64[ns, Asia/Jerusalem]
# collection_date                                              datetime64[ns]
# timezone                                                             string
# abdomen_pain_frequency_past_3_months                                    int
# abdomen_pain_women_during_period                                        int
# abdomen_pain_past_6_months                                              int
# abdomen_pain_imrpove_after_bowl_movement                                int
# abdomen_pain_increases_bowl_movements                                   int
# abdomen_pain_decreases_bowl_movements                                   int
# soft_stool_during_abdomen_pain                                          int
# hard_stool_during_abdomen_pain                                          int
# hard_stool_frequency_past_3_months                                      int
# soft_stool_frequency_past_3_months                                      int
# abdomen_pain_current                                                    int
# abdomen_pain_current_severity                                           int
# abdomen_pain_days_out_of_10                                             int
# abdomen_pain_current_distension                                         int
# abdomen_pain_current_distension_severity                                int
# bowl_movements_current_satisfaction                                     int
# abdomen_pain_current_general_interference                               int
# bowl_movements_daily_max                                                int
# bowl_movements_daily_min                                                int
# bowl_movements_daily_average                                            int
# abdomen_pain_work_weeks_missed_number                                   int
# abdomen_pain_work_weeks_missed_choice                                   int
# abdomen_pain_work_weeks_suffering                                       int
# back_pain_past_3_months                                                 int
# legs_joint_pain_past_3_months                                           int
# menstural_cramps_past_3_months                                          int
# headaches_past_3_months                                                 int
# chest_pain_past_3_months                                                int
# dizziness_past_3_months                                                 int
# fainting_past_3_months                                                  int
# heart_race_past_3_months                                                int
# shortness_of_breath_past_3_months                                       int
# intercourse_pain_past_3_months                                          int
# bladder_irritability_past_3_months                                      int
# nausea_past_3_months                                                    int
# tired_past_3_months                                                     int
# sleeping_trouble_past_3_months                                          int
# anxiety_treatment_past                                                  int
# depression_treatment_past                                               int
# sensitive_stomach                                                       int
# history_family_ibs                                                      int
# history_birth_caesarian_section                                         int
# history_childhood_antibiotics                                           int
# history_diagnoses_celiac                                                int
# history_diagnoses_celiac_method                                         int
# history_diagnoses_ibs                                                   int
# history_ibs_symptoms_speed                                              int
# history_ibs_first_symptoms_infection                                    int
# history_ibs_first_symptoms_infection_choice                             int
# history_ibs_first_symptoms_fever                                        int
# history_ibs_first_symptoms_diarrhoea                                    int
# history_ibs_first_symptoms_bloody_diarrhoea                             int
# history_ibs_first_symptoms_vomiting                                     int
# ibs_mapping                                                          string
#
#                                              parent_dataframe data_coding
# tabular_field_name
# collection_timestamp                                      NaN         NaN
# collection_date                                           NaN         NaN
# timezone                                                  NaN         NaN
# abdomen_pain_frequency_past_3_months                      NaN        IBS1
# abdomen_pain_women_during_period                          NaN        IBS2
# abdomen_pain_past_6_months                                NaN         503
# abdomen_pain_imrpove_after_bowl_movement                  NaN         950
# abdomen_pain_increases_bowl_movements                     NaN         950
# abdomen_pain_decreases_bowl_movements                     NaN         950
# soft_stool_during_abdomen_pain                            NaN         950
# hard_stool_during_abdomen_pain                            NaN         950
# hard_stool_frequency_past_3_months                        NaN         950
# soft_stool_frequency_past_3_months                        NaN         950
# abdomen_pain_current                                      NaN         503
# abdomen_pain_current_severity                             NaN         NaN
# abdomen_pain_days_out_of_10                               NaN         NaN
# abdomen_pain_current_distension                           NaN         503
# abdomen_pain_current_distension_severity                  NaN         NaN
# bowl_movements_current_satisfaction                       NaN         NaN
# abdomen_pain_current_general_interference                 NaN         NaN
# bowl_movements_daily_max                                  NaN         NaN
# bowl_movements_daily_min                                  NaN         NaN
# bowl_movements_daily_average                              NaN         NaN
# abdomen_pain_work_weeks_missed_number                     NaN         NaN
# abdomen_pain_work_weeks_missed_choice                     NaN        IBS3
# abdomen_pain_work_weeks_suffering                         NaN         NaN
# back_pain_past_3_months                                   NaN         399
# legs_joint_pain_past_3_months                             NaN         399
# menstural_cramps_past_3_months                            NaN         399
# headaches_past_3_months                                   NaN         399
# chest_pain_past_3_months                                  NaN         399
# dizziness_past_3_months                                   NaN         399
# fainting_past_3_months                                    NaN         399
# heart_race_past_3_months                                  NaN         399
# shortness_of_breath_past_3_months                         NaN         399
# intercourse_pain_past_3_months                            NaN         399
# bladder_irritability_past_3_months                        NaN         399
# nausea_past_3_months                                      NaN         399
# tired_past_3_months                                       NaN         399
# sleeping_trouble_past_3_months                            NaN         399
# anxiety_treatment_past                                    NaN         503
# depression_treatment_past                                 NaN         503
# sensitive_stomach                                         NaN         502
# history_family_ibs                                        NaN         502
# history_birth_caesarian_section                           NaN         502
# history_childhood_antibiotics                             NaN         502
# history_diagnoses_celiac                                  NaN         502
# history_diagnoses_celiac_method                           NaN        1862
# history_diagnoses_ibs                                     NaN         502
# history_ibs_symptoms_speed                                NaN        2730
# history_ibs_first_symptoms_infection                      NaN         503
# history_ibs_first_symptoms_infection_choice               NaN        7310
# history_ibs_first_symptoms_fever                          NaN         503
# history_ibs_first_symptoms_diarrhoea                      NaN         503
# history_ibs_first_symptoms_bloody_diarrhoea               NaN         503
# history_ibs_first_symptoms_vomiting                       NaN         503
# ibs_mapping                                               NaN         NaN
