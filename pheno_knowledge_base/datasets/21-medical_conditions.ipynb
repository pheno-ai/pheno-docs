# %% [raw]
# ---
# output-file: 21-medical_conditions.html
# title: 21-medical_conditions
# ---

# %% [markdown]
# # Medical conditions dataset
#
# The The Human Phenotype Project study medical conditions diagnosis data is based on self reported, participant provided information. Self-reported medical diagnosis are coded according to the WHO International Classification of Diseases 11th Revision (ICD-11) codes.
#
# The medical conditions diagnosis information collection in the Human Phenotype Project is based on self reporting of conditions either through direct questions on specific conditions in self filled online questionnaires or through self recall of conditions diagnosis in an interview with a research staff member.
#
# ### Data availability:
# The information is stored in 1 parquet file: `medical_conditions.parquet`

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('medical_conditions')
dl
# Out:
# DataLoader for medical_conditions with
# 316 fields
# 2 tables: ['medical_conditions', 'age_sex']

# %%
dl.dfs['medical_conditions'].head()
# Out:
# medical_condition                     abortion  abscess_of_anal_regions  \
# participant_id cohort research_stage
# 1000942861     10k    00_00_visit        False                    False
# 6246892435     10k    00_00_visit        False                    False
# 6246285054     10k    00_00_visit        False                    False
# 6244080653     10k    00_00_visit        False                    False
# 6243209379     10k    00_00_visit        False                    False
#
# medical_condition                      acne  acquired_hearing_impairment  \
# participant_id cohort research_stage
# 1000942861     10k    00_00_visit     False                        False
# 6246892435     10k    00_00_visit     False                        False
# 6246285054     10k    00_00_visit      True                        False
# 6244080653     10k    00_00_visit     False                        False
# 6243209379     10k    00_00_visit     False                        False
#
# medical_condition                     acquired_hypothyroidism  \
# participant_id cohort research_stage
# 1000942861     10k    00_00_visit                       False
# 6246892435     10k    00_00_visit                       False
# 6246285054     10k    00_00_visit                       False
# 6244080653     10k    00_00_visit                       False
# 6243209379     10k    00_00_visit                       False
#
# medical_condition                     acute_inflammatory_demyelinating_polyneuropathy  \
# participant_id cohort research_stage
# 1000942861     10k    00_00_visit                                               False
# 6246892435     10k    00_00_visit                                               False
# 6246285054     10k    00_00_visit                                               False
# 6244080653     10k    00_00_visit                                               False
# 6243209379     10k    00_00_visit                                               False
#
# medical_condition                     acute_myocardial_infarction  \
# participant_id cohort research_stage
# 1000942861     10k    00_00_visit                           False
# 6246892435     10k    00_00_visit                           False
# 6246285054     10k    00_00_visit                           False
# 6244080653     10k    00_00_visit                           False
# 6243209379     10k    00_00_visit                           False
#
# medical_condition                     acute_pancreatitis  \
# participant_id cohort research_stage
# 1000942861     10k    00_00_visit                  False
# 6246892435     10k    00_00_visit                  False
# 6246285054     10k    00_00_visit                  False
# 6244080653     10k    00_00_visit                  False
# 6243209379     10k    00_00_visit                  False
#
# medical_condition                     adhesive_capsulitis_of_shoulder  \
# participant_id cohort research_stage
# 1000942861     10k    00_00_visit                               False
# 6246892435     10k    00_00_visit                               False
# 6246285054     10k    00_00_visit                               False
# 6244080653     10k    00_00_visit                               False
# 6243209379     10k    00_00_visit                               False
#
# medical_condition                     adrenocortical_insufficiency  ...  \
# participant_id cohort research_stage                                ...
# 1000942861     10k    00_00_visit                            False  ...
# 6246892435     10k    00_00_visit                            False  ...
# 6246285054     10k    00_00_visit                            False  ...
# 6244080653     10k    00_00_visit                            False  ...
# 6243209379     10k    00_00_visit                            False  ...
#
# medical_condition                     vasculitis  \
# participant_id cohort research_stage
# 1000942861     10k    00_00_visit          False
# 6246892435     10k    00_00_visit          False
# 6246285054     10k    00_00_visit          False
# 6244080653     10k    00_00_visit          False
# 6243209379     10k    00_00_visit          False
#
# medical_condition                     venous_complications_in_pregnancy  \
# participant_id cohort research_stage
# 1000942861     10k    00_00_visit                                 False
# 6246892435     10k    00_00_visit                                 False
# 6246285054     10k    00_00_visit                                 False
# 6244080653     10k    00_00_visit                                 False
# 6243209379     10k    00_00_visit                                 False
#
# medical_condition                     ventricular_premature_depolarization  \
# participant_id cohort research_stage
# 1000942861     10k    00_00_visit                                    False
# 6246892435     10k    00_00_visit                                    False
# 6246285054     10k    00_00_visit                                    False
# 6244080653     10k    00_00_visit                                    False
# 6243209379     10k    00_00_visit                                    False
#
# medical_condition                     ventricular_tachyarrhythmia  \
# participant_id cohort research_stage
# 1000942861     10k    00_00_visit                           False
# 6246892435     10k    00_00_visit                           False
# 6246285054     10k    00_00_visit                           False
# 6244080653     10k    00_00_visit                           False
# 6243209379     10k    00_00_visit                           False
#
# medical_condition                     vitamin_b12_deficiency  \
# participant_id cohort research_stage
# 1000942861     10k    00_00_visit                      False
# 6246892435     10k    00_00_visit                      False
# 6246285054     10k    00_00_visit                      False
# 6244080653     10k    00_00_visit                      False
# 6243209379     10k    00_00_visit                      False
#
# medical_condition                     vitamin_d_deficiency  vitiligo  \
# participant_id cohort research_stage
# 1000942861     10k    00_00_visit                    False     False
# 6246892435     10k    00_00_visit                    False     False
# 6246285054     10k    00_00_visit                    False     False
# 6244080653     10k    00_00_visit                    False     False
# 6243209379     10k    00_00_visit                    False     False
#
# medical_condition                     whooping_cough_due_to_bordetella_pertussis  \
# participant_id cohort research_stage
# 1000942861     10k    00_00_visit                                          False
# 6246892435     10k    00_00_visit                                          False
# 6246285054     10k    00_00_visit                                          False
# 6244080653     10k    00_00_visit                                          False
# 6243209379     10k    00_00_visit                                          False
#
# medical_condition                     wilson_disease  zoster
# participant_id cohort research_stage
# 1000942861     10k    00_00_visit              False   False
# 6246892435     10k    00_00_visit              False   False
# 6246285054     10k    00_00_visit              False   False
# 6244080653     10k    00_00_visit              False   False
# 6243209379     10k    00_00_visit              False   False
#
# [5 rows x 314 columns]

# %%
dl.dict
# Out:
#                                                                           field_string  \
# tabular_field_name
# abortion                                                                      Abortion
# abscess_of_anal_regions                                        Abscess of anal regions
# acne                                                                              Acne
# acquired_hearing_impairment                                Acquired hearing impairment
# acquired_hypothyroidism                                        Acquired hypothyroidism
# ...                                                                                ...
# vitamin_d_deficiency                                              Vitamin D deficiency
# vitiligo                                                                      Vitiligo
# whooping_cough_due_to_bordetella_pertussis  Whooping cough due to Bordetella pertussis
# wilson_disease                                                          Wilson disease
# zoster                                                                          Zoster
#
#                                                                            description_string  \
# tabular_field_name
# abortion                                            Abortion (JA00) reported at time of visit
# abscess_of_anal_regions                     Abscess of anal regions (DB70.0) reported at t...
# acne                                                    Acne (ED80) reported at time of visit
# acquired_hearing_impairment                 Acquired hearing impairment (AB51) reported at...
# acquired_hypothyroidism                     Acquired hypothyroidism (5A00.2) reported at t...
# ...                                                                                       ...
# vitamin_d_deficiency                        Vitamin D deficiency (5B57) reported at time o...
# vitiligo                                          Vitiligo (ED63.0) reported at time of visit
# whooping_cough_due_to_bordetella_pertussis  Whooping cough due to Bordetella pertussis (1C...
# wilson_disease                              Wilson disease (5C64.00) reported at time of v...
# zoster                                                Zoster (1E91) reported at time of visit
#
#                                             parent_dataframe  \
# tabular_field_name
# abortion                                                 NaN
# abscess_of_anal_regions                                  NaN
# acne                                                     NaN
# acquired_hearing_impairment                              NaN
# acquired_hypothyroidism                                  NaN
# ...                                                      ...
# vitamin_d_deficiency                                     NaN
# vitiligo                                                 NaN
# whooping_cough_due_to_bordetella_pertussis               NaN
# wilson_disease                                           NaN
# zoster                                                   NaN
#
#                                                      relative_location  \
# tabular_field_name
# abortion                                    medical_conditions.parquet
# abscess_of_anal_regions                     medical_conditions.parquet
# acne                                        medical_conditions.parquet
# acquired_hearing_impairment                 medical_conditions.parquet
# acquired_hypothyroidism                     medical_conditions.parquet
# ...                                                                ...
# vitamin_d_deficiency                        medical_conditions.parquet
# vitiligo                                    medical_conditions.parquet
# whooping_cough_due_to_bordetella_pertussis  medical_conditions.parquet
# wilson_disease                              medical_conditions.parquet
# zoster                                      medical_conditions.parquet
#
#                                                       value_type units  \
# tabular_field_name
# abortion                                    Categorical (single)  None
# abscess_of_anal_regions                     Categorical (single)  None
# acne                                        Categorical (single)  None
# acquired_hearing_impairment                 Categorical (single)  None
# acquired_hypothyroidism                     Categorical (single)  None
# ...                                                          ...   ...
# vitamin_d_deficiency                        Categorical (single)  None
# vitiligo                                    Categorical (single)  None
# whooping_cough_due_to_bordetella_pertussis  Categorical (single)  None
# wilson_disease                              Categorical (single)  None
# zoster                                      Categorical (single)  None
#
#                                             sampling_rate item_type array  \
# tabular_field_name
# abortion                                              NaN      Data    No
# abscess_of_anal_regions                               NaN      Data    No
# acne                                                  NaN      Data    No
# acquired_hearing_impairment                           NaN      Data    No
# acquired_hypothyroidism                               NaN      Data    No
# ...                                                   ...       ...   ...
# vitamin_d_deficiency                                  NaN      Data    No
# vitiligo                                              NaN      Data    No
# whooping_cough_due_to_bordetella_pertussis            NaN      Data    No
# wilson_disease                                        NaN      Data    No
# zoster                                                NaN      Data    No
#
#                                            cohorts data_type       debut  \
# tabular_field_name
# abortion                                       10K   Tabular  2019-01-29
# abscess_of_anal_regions                        10K   Tabular  2019-01-29
# acne                                           10K   Tabular  2019-01-29
# acquired_hearing_impairment                    10K   Tabular  2019-01-29
# acquired_hypothyroidism                        10K   Tabular  2019-01-29
# ...                                            ...       ...         ...
# vitamin_d_deficiency                           10K   Tabular  2019-01-29
# vitiligo                                       10K   Tabular  2019-01-29
# whooping_cough_due_to_bordetella_pertussis     10K   Tabular  2019-01-29
# wilson_disease                                 10K   Tabular  2019-01-29
# zoster                                         10K   Tabular  2019-01-29
#
#                                            pandas_dtype
# tabular_field_name
# abortion                                           bool
# abscess_of_anal_regions                            bool
# acne                                               bool
# acquired_hearing_impairment                        bool
# acquired_hypothyroidism                            bool
# ...                                                 ...
# vitamin_d_deficiency                               bool
# vitiligo                                           bool
# whooping_cough_due_to_bordetella_pertussis         bool
# wilson_disease                                     bool
# zoster                                             bool
#
# [314 rows x 13 columns]
