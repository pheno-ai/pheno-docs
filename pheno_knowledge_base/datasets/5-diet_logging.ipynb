# %% [raw]
# ---
# output-file: 5-diet_logging.html
# title: 5-diet_logging
# ---

# %% [markdown]
# # Diet logging dataset
#
# Diet logging using a smartphone app involves collecting data on food and drink consumption through a mobile application. These data include information such as types of food, serving sizes, nutritional information and the times of consumption. The data is used to track dietary habits and can be used in scientific research to gain insights into the dietary habits of a population and to correlate to other temporal measurements and events.
#
# ### Data availability:
# The information is stored in 3 parquet files: `diet_logging.parquet`, `diet_logging_events.parquet`,  `raw_diet_logging_events.parquet `which contains a summary table, processed and raw diet logging data respectively.

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('diet_logging')
dl
# Out:
# Warning: index is not unique for diet_logging_events.parquet
# DataLoader for diet_logging with
# 22 fields
# 3 tables: ['diet_logging', 'diet_logging_events', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                                         field_string  \
# tabular_field_name
# collection_timestamp            Collection timestamp
# collection_date                                 Date
# logging_day              Logging day per participant
# total_logging_days       Total number of days logged
# timezone                                    Timezone
# food_items                                Food items
# diet_logging_events              Diet logging events
# raw_diet_logging_events      Raw diet logging events
#
#                                                         description_string  \
# tabular_field_name
# collection_timestamp                                  Collection timestamp
# collection_date          Datetime column relecting the time food item w...
# logging_day                Integer indicating which day of logging period
# total_logging_days       Total number of days diet was logged per resea...
# timezone                                                          Timezone
# food_items                      Total number of food items logged per day
# diet_logging_events                       File path to diet logging events
# raw_diet_logging_events               File path to raw diet logging events
#
#                          parent_dataframe  \
# tabular_field_name
# collection_timestamp                  NaN
# collection_date                       NaN
# logging_day                           NaN
# total_logging_days                    NaN
# timezone                              NaN
# food_items                            NaN
# diet_logging_events                   NaN
# raw_diet_logging_events               NaN
#
#                                                  relative_location value_type  \
# tabular_field_name
# collection_timestamp            /diet_logging/diet_logging.parquet       Time
# collection_date                 /diet_logging/diet_logging.parquet       Time
# logging_day              /diet_logging/diet_logging_events.parquet    Integer
# total_logging_days              /diet_logging/diet_logging.parquet    Integer
# timezone                        /diet_logging/diet_logging.parquet       Text
# food_items                      /diet_logging/diet_logging.parquet    Integer
# diet_logging_events             /diet_logging/diet_logging.parquet       Text
# raw_diet_logging_events         /diet_logging/diet_logging.parquet       Text
#
#                          units  sampling_rate item_type   array cohorts  \
# tabular_field_name
# collection_timestamp      Time            NaN      Data  Single     10K
# collection_date           Time            NaN      Data  Single     10K
# logging_day              None             NaN      Data  Single     10K
# total_logging_days        None            NaN      Data  Single     10K
# timezone                  None            NaN      Data  Single     10K
# food_items                None            NaN      Data  Single     10K
# diet_logging_events       None            NaN      Data  Single     10K
# raw_diet_logging_events   None            NaN      Data  Single     10K
#
#                            data_type       debut  \
# tabular_field_name
# collection_timestamp     Time Series  2019-01-29
# collection_date          Time Series  2019-09-01
# logging_day              Time Series  2019-09-01
# total_logging_days       Time Series  2019-09-01
# timezone                 Time Series  2019-09-01
# food_items               Time Series  2019-09-01
# diet_logging_events      Time Series  2019-09-01
# raw_diet_logging_events  Time Series  2019-09-01
#
#                                            pandas_dtype
# tabular_field_name
# collection_timestamp     datetime64[ns, Asia/Jerusalem]
# collection_date                          datetime64[ns]
# logging_day                                         int
# total_logging_days                                  int
# timezone                                         string
# food_items                                          int
# diet_logging_events                              string
# raw_diet_logging_events                          string
