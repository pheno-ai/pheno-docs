# %% [raw]
# ---
# output-file: 5-diet_logging.html
# title: 5-diet_logging
# ---

# %% [markdown]
# # Diet logging dataset
#
# Diet logging using a smartphone app involves collecting data on food and drink consumption through a mobile application. These data include information such as types of food, serving sizes, nutritional information and the times of consumption. The data is used to track dietary habits and can be used in scientific research to gain insights into the dietary habits of a population and to correlate to other temporal measurements and events.
#
# ### Data availability:
# The information is stored in 2 parquet file: `diet_logging.parquet`, `raw_diet_logging.parquet` which contain the processed and raw diet logging data respectively.

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('diet_logging', age_sex_dataset=None)
# Out:
# /home/jovyan/projects/pheno-utils_new/pheno_utils/pheno_loader.py:404: UserWarning: Error loading s3://pheno-master-data-collection-v1-prod-us-east-1/diet_logging/:
# Error creating dataset. Could not read schema from 'pheno-master-data-collection-v1-prod-us-east-1/diet_logging/diet_logging_data_dictionary.csv': Could not open Parquet input source 'pheno-master-data-collection-v1-prod-us-east-1/diet_logging/diet_logging_data_dictionary.csv': Parquet magic bytes not found in footer. Either the file is corrupted or this is not a parquet file.. Is this a 'parquet' file?
#   warnings.warn(f'Error loading {df_path}:\n{err}')

# %% [markdown]
# # Data dictionary

# %%
dl.dict.head()
# Out:
#                                      field_string  \
# tabular_field_name
# collection_timestamp         Collection timestamp
# collection_date                              Date
# logging_day           Logging day per participant
# total_logging_days    Total number of days logged
# timezone                                 Timezone
#
#                                                      description_string  \
# tabular_field_name
# collection_timestamp                               Collection timestamp
# collection_date       Datetime column relecting the time food item w...
# logging_day             Integer indicating which day of logging period
# total_logging_days    Total number of days diet was logged per resea...
# timezone                                                       Timezone
#
#                       parent_dataframe            relative_location  \
# tabular_field_name
# collection_timestamp               NaN         diet_logging.parquet
# collection_date                    NaN         diet_logging.parquet
# logging_day                        NaN  diet_logging_events.parquet
# total_logging_days                 NaN         diet_logging.parquet
# timezone                           NaN         diet_logging.parquet
#
#                      value_type  units  sampling_rate item_type   array  \
# tabular_field_name
# collection_timestamp       Time   Time            NaN      Data  Single
# collection_date            Time   Time            NaN      Data  Single
# logging_day             Integer  None             NaN      Data  Single
# total_logging_days      Integer   None            NaN      Data  Single
# timezone                   Text   None            NaN      Data  Single
#
#                      cohorts    data_type       debut  \
# tabular_field_name
# collection_timestamp     10K  Time Series  2019-01-29
# collection_date          10K  Time Series  2019-09-01
# logging_day              10K  Time Series  2019-09-01
# total_logging_days       10K  Time Series  2019-09-01
# timezone                 10K  Time Series  2019-09-01
#
#                                         pandas_dtype
# tabular_field_name
# collection_timestamp  datetime64[ns, Asia/Jerusalem]
# collection_date                       datetime64[ns]
# logging_day                                    float
# total_logging_days                               int
# timezone                                      string
