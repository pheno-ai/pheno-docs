# %% [raw]
# ---
# output-file: 9-sleep.html
# title: 9-sleep
# ---

# %% [markdown]
# # Sleep monitoring dataset
#
# Sleep monitoring includes sleep staging, body positioning, respiratory events, heart rate, oxygen saturation and snoring, measured concurrently over three nights.
#
# Obstructive sleep apnea (OSA) is a sleep disorder in which a person’s breathing is interrupted during sleep due to obstruction of the upper airway as a result of relaxation of the throat muscles. This obstruction can lead to pauses in breathing for short periods of time, which can cause loud snoring, reduction in the  blood oxygen levels, stress response, awakening and fragmented sleep.
#
# A home sleep apnea test (HSAT) is a non-invasive test used to diagnose sleep apnea. During an HSAT, a patient wears a portable device overnight to monitor their breathing, heart rate, oxygen levels, snoring, and other sleep patterns. The device records this data and it is then analyzed by clinically-validated algorithms that compute apnea-related indices. The data can also be used to study sleep architecture and other aspects of sleep, such as heart rate variability (HRV) and arrhythmia.
#
# The device used for sleep monitoring in the Human Phenotype Project is the FDA-approved WatchPAT-300 by Itamar Medical. This device contains 5 sensors: An actigraph worn on the wrist; A pulse oximeter and a Peripheral Arterial Tone (PAT) probe worn on the finger; and a microphone and accelerometer worn on the chest for respiratory effort, snoring and body position measurement.
#
# The device's algorithms provide 3 main indices for diagnosis of OSA: Apnea/Hypopnea Index (AHI), Respiratory Disturbance Index (RDI), Oxygen Desaturation Index (ODI). The device's algoithms also provide indices for diagnosis of Atrial Fibrillation (not FDA-approved yet): Premature beats per minute, Atrial fibrillation longest event.
#
# The WatchPAT device is given to participants during the visit to the clinical testing center who then record 3 nights of sleep at home during the following two weeks (Figure 4). The recorded tested nights should reflect the usual sleeping regimen / typical bedtime (for example, not after exceeding alcohol consumption).
#
# ### Data availability:
# The information is stored in 2 main statistics parquet files: `main.parquet`, `hrv.parquet`; In a sleep events file `events.parquet` and in multiple time series parquets / EDF files containing sensor channels for each night of logging.

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('sleep')
dl
# Out:
# DataLoader for sleep with
# 473 fields
# 3 tables: ['sleep', 'hrv', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                                            field_string  \
# tabular_field_name
# collection_timestamp               Collection timestamp
# collection_date                         Collection date
# night                                             Night
# warnings                                       Warnings
# timezone                                       Timezone
# ...                                                 ...
# hrv_time_sdsd_during_wake    HRV time: SDSD during wake
# hrv_time_tinn_during_night  HRV time: TINN during night
# hrv_time_tinn_during_nrem    HRV time: TINN during NREM
# hrv_time_tinn_during_rem      HRV time: TINN during REM
# hrv_time_tinn_during_wake    HRV time: TINN during wake
#
#                                                            description_string  \
# tabular_field_name
# collection_timestamp                                     Collection timestamp
# collection_date                                               Collection date
# night                                                                   Night
# warnings                                                    Analysis warnings
# timezone                                                             Timezone
# ...                                                                       ...
# hrv_time_sdsd_during_wake   The standard deviation of the successive diffe...
# hrv_time_tinn_during_night  The baseline width of the RR intervals distrib...
# hrv_time_tinn_during_nrem   The baseline width of the RR intervals distrib...
# hrv_time_tinn_during_rem    The baseline width of the RR intervals distrib...
# hrv_time_tinn_during_wake   The baseline width of the RR intervals distrib...
#
#                            parent_dataframe     relative_location  \
# tabular_field_name
# collection_timestamp                    NaN  /sleep/sleep.parquet
# collection_date                         NaN  /sleep/sleep.parquet
# night                                   NaN  /sleep/sleep.parquet
# warnings                                NaN  /sleep/sleep.parquet
# timezone                                NaN  /sleep/sleep.parquet
# ...                                     ...                   ...
# hrv_time_sdsd_during_wake               NaN    /sleep/hrv.parquet
# hrv_time_tinn_during_night              NaN    /sleep/hrv.parquet
# hrv_time_tinn_during_nrem               NaN    /sleep/hrv.parquet
# hrv_time_tinn_during_rem                NaN    /sleep/hrv.parquet
# hrv_time_tinn_during_wake               NaN    /sleep/hrv.parquet
#
#                                         value_type      units sampling_rate  \
# tabular_field_name
# collection_timestamp                          Time       Time           NaN
# collection_date                               Time       Date           NaN
# night                                      Integer       None           NaN
# warnings                    Categorical (multiple)       Text           NaN
# timezone                      Categorical (single)       Text           NaN
# ...                                            ...        ...           ...
# hrv_time_sdsd_during_wake               Continuous  Undefined           NaN
# hrv_time_tinn_during_night              Continuous  Undefined           NaN
# hrv_time_tinn_during_nrem               Continuous  Undefined           NaN
# hrv_time_tinn_during_rem                Continuous  Undefined           NaN
# hrv_time_tinn_during_wake               Continuous  Undefined           NaN
#
#                            item_type     array cohorts data_type       debut  \
# tabular_field_name
# collection_timestamp            Data  Multiple     10K   Tabular  2020-01-15
# collection_date                 Data  Multiple     10K   Tabular  2020-01-15
# night                           Data  Multiple     10K   Tabular  2020-01-15
# warnings                        Data  Multiple     10K   Tabular  2020-01-15
# timezone                        Data  Multiple     10K   Tabular  2020-01-15
# ...                              ...       ...     ...       ...         ...
# hrv_time_sdsd_during_wake       Data  Multiple     10K   Tabular  2020-01-15
# hrv_time_tinn_during_night      Data  Multiple     10K   Tabular  2020-01-15
# hrv_time_tinn_during_nrem       Data  Multiple     10K   Tabular  2020-01-15
# hrv_time_tinn_during_rem        Data  Multiple     10K   Tabular  2020-01-15
# hrv_time_tinn_during_wake       Data  Multiple     10K   Tabular  2020-01-15
#
#                                               pandas_dtype
# tabular_field_name
# collection_timestamp        datetime64[ns, Asia/Jerusalem]
# collection_date                             datetime64[ns]
# night                                                  int
# warnings                                          category
# timezone                                            string
# ...                                                    ...
# hrv_time_sdsd_during_wake                            float
# hrv_time_tinn_during_night                           float
# hrv_time_tinn_during_nrem                            float
# hrv_time_tinn_during_rem                             float
# hrv_time_tinn_during_wake                            float
#
# [489 rows x 13 columns]
