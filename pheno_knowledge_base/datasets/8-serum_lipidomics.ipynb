# %% [raw]
# ---
# output-file: 8-serum_lipidomics.html
# title: 8-serum_lipidomics
# ---

# %% [markdown]
# # Serum lipidomics dataset
#
# High throughput untargeted lipidomics in serum by Ultra-High-Performance Liquid Chromatography Electrospray ionization High-resolution mass spectrometry (UHPLC-ESI-HRMS).
#
# The serum metabolome is known to represent a variety of environmental, genetic and other endogenous factors (Bar et al. 2020). Lipidomics is a subfield of metabolomics, which is defined as the study of pathways and networks of cellular lipids in biological systems. Lipids perform various functions within the body, from structural components of cell membranes, to energy reserve and regulating hormones. These pivotal functions highlight circulating lipids as playing a key role in a number of age-related diseases such as cardiovascular disease and stroke (Holmes et al. 2018; Michos et al. 2019).
#
# ### Data availability:
# The information is stored in 1 parquet file: `serum_lipidomics.parquet`

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('serum_lipidomics')
dl
# Out:
# DataLoader for serum_lipidomics with
# 202 fields
# 2 tables: ['serum_lipidomics', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                                         field_string  description_string  \
# tabular_field_name
# collection_date         Collection date (YYYY-MM-DD)                 NaN
# collection_timestamp            Collection timestamp                 NaN
# timezone                                    Timezone                 NaN
# 22:6_cholesteryl_ester        22:6 Cholesteryl Ester                 NaN
# acca_c10:0                                AcCa C10:0                 NaN
# ...                                              ...                 ...
# lysopc_22:6                              lysoPC 22:6                 NaN
# lysope_16:0                              lysoPE 16:0                 NaN
# lysope_18:0                              lysoPE 18:0                 NaN
# lysope_18:1                              lysoPE 18:1                 NaN
# lysope_18:2                              lysoPE 18:2                 NaN
#
#                         parent_dataframe  \
# tabular_field_name
# collection_date                      NaN
# collection_timestamp                 NaN
# timezone                             NaN
# 22:6_cholesteryl_ester               NaN
# acca_c10:0                           NaN
# ...                                  ...
# lysopc_22:6                          NaN
# lysope_16:0                          NaN
# lysope_18:0                          NaN
# lysope_18:1                          NaN
# lysope_18:2                          NaN
#
#                                                  relative_location  \
# tabular_field_name
# collection_date         /serum_lipidomics/serum_lipidomics.parquet
# collection_timestamp    /serum_lipidomics/serum_lipidomics.parquet
# timezone                /serum_lipidomics/serum_lipidomics.parquet
# 22:6_cholesteryl_ester  /serum_lipidomics/serum_lipidomics.parquet
# acca_c10:0              /serum_lipidomics/serum_lipidomics.parquet
# ...                                                            ...
# lysopc_22:6             /serum_lipidomics/serum_lipidomics.parquet
# lysope_16:0             /serum_lipidomics/serum_lipidomics.parquet
# lysope_18:0             /serum_lipidomics/serum_lipidomics.parquet
# lysope_18:1             /serum_lipidomics/serum_lipidomics.parquet
# lysope_18:2             /serum_lipidomics/serum_lipidomics.parquet
#
#                         value_type              units  sampling_rate  \
# tabular_field_name
# collection_date                NaN                NaN            NaN
# collection_timestamp           NaN                NaN            NaN
# timezone                       NaN                NaN            NaN
# 22:6_cholesteryl_ester  Continuous  Intensity (log10)            NaN
# acca_c10:0              Continuous  Intensity (log10)            NaN
# ...                            ...                ...            ...
# lysopc_22:6             Continuous  Intensity (log10)            NaN
# lysope_16:0             Continuous  Intensity (log10)            NaN
# lysope_18:0             Continuous  Intensity (log10)            NaN
# lysope_18:1             Continuous  Intensity (log10)            NaN
# lysope_18:2             Continuous  Intensity (log10)            NaN
#
#                        item_type array cohorts data_type       debut  \
# tabular_field_name
# collection_date              NaN   NaN     NaN       NaN         NaN
# collection_timestamp         NaN   NaN     NaN       NaN         NaN
# timezone                     NaN   NaN     NaN       NaN         NaN
# 22:6_cholesteryl_ester      Data    No     10K   Tabular  2019-02-19
# acca_c10:0                  Data    No     10K   Tabular  2019-02-19
# ...                          ...   ...     ...       ...         ...
# lysopc_22:6                 Data    No     10K   Tabular  2019-02-19
# lysope_16:0                 Data    No     10K   Tabular  2019-02-19
# lysope_18:0                 Data    No     10K   Tabular  2019-02-19
# lysope_18:1                 Data    No     10K   Tabular  2019-02-19
# lysope_18:2                 Data    No     10K   Tabular  2019-02-19
#
#                                           pandas_dtype
# tabular_field_name
# collection_date                         datetime64[ns]
# collection_timestamp    datetime64[ns, Asia/Jerusalem]
# timezone                                        string
# 22:6_cholesteryl_ester                           float
# acca_c10:0                                       float
# ...                                                ...
# lysopc_22:6                                      float
# lysope_16:0                                      float
# lysope_18:0                                      float
# lysope_18:1                                      float
# lysope_18:2                                      float
#
# [200 rows x 13 columns]
