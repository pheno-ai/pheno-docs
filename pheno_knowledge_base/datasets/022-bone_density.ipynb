# %% [raw]
# ---
# output-file: 022-bone_density.html
# title: 022-bone_density
# ---

# %% [markdown]
# # Bone size, mineral and density (DXA) dataset
#
# Bone density was profiled based on DXA imaging, and includes measurements of mineral content in different parts of a variety of skeletal components.
#
# DXA (dual-energy x-ray absorptiometry) imaging is a method used to measure bone density and mineral content. A DXA scan uses a low dose of ionizing radiation to produce a detailed image of the body, specifically the bones. The scan is then analyzed by a software to determine the bone mineral density (BMD) and bone mineral content (BMC) in different parts of the body. This method is considered to be one of the most accurate methods for measuring bone density, as it is able to provide detailed information about the distribution of bone mineral content in different bony structures of the body skeleton. The spine and hip are most commonly measured because that is where most osteoporotic fractures occur. DXA imaging is commonly used for assessing the risk of osteoporosis, a condition characterized by low bone density and increased risk of fractures, and for monitoring the effects of treatments for the condition.
#
# ### Data availability:
# The information is stored in 1 parquet file: `bone_density.parquet`

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('bone_density')
dl
# Out:
# DataLoader for bone_density with
# 289 fields
# 2 tables: ['bone_density', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                                                                   field_string  \
# tabular_field_name
# collection_date                                   Collection date (YYYY-MM-DD)
# timezone                                                              Timezone
# collection_timestamp                                      Collection timestamp
# body_arm_left_area                                          Body arm left area
# body_arm_left_bmc                           Body arm left bone mineral content
# body_arm_left_bmd                           Body arm left bone mineral density
# body_arm_right_area                                        Body arm right area
# body_arm_right_bmc                         Body arm right bone mineral content
# body_arm_right_bmd                         Body arm right bone mineral density
# body_arms_area                                                  Body arms area
# body_arms_bmc                                   Body arms bone mineral content
# body_arms_bmd                                   Body arms bone mineral density
# body_dose                                                            Body dose
# body_head_area                                                  Body head area
# body_head_bmc                                   Body head bone mineral content
# body_head_bmd                                   Body head bone mineral density
# body_leg_left_area                                          Body leg left area
# body_leg_left_bmc                           Body leg left bone mineral content
# body_leg_left_bmd                           Body leg left bone mineral density
# body_leg_right_area                                        Body leg right area
# body_leg_right_bmc                         Body leg right bone mineral content
# body_leg_right_bmd                         Body leg right bone mineral density
# body_legs_area                                                  Body legs area
# body_legs_bmc                                   Body legs bone mineral content
# body_legs_bmd                                   Body legs bone mineral density
# body_pelvis_area                                              Body pelvis area
# body_pelvis_bmc                               Body pelvis bone mineral content
# body_pelvis_bmd                               Body pelvis bone mineral density
# body_ribs_area                                                  Body ribs area
# body_ribs_bmc                                   Body ribs bone mineral content
# body_ribs_bmd                                   Body ribs bone mineral density
# body_spine_area                                                Body spine area
# body_spine_bmc                                 Body spine bone mineral content
# body_spine_bmd                                 Body spine bone mineral density
# body_total_area                                                Body total area
# body_total_bmc                                 Body total bone mineral content
# body_total_bmd                                 Body total bone mineral density
# body_total_left_area                                      Body total left area
# body_total_left_bmc                       Body total left bone mineral content
# body_total_left_bmd                       Body total left bone mineral density
# body_total_right_area                                    Body total right area
# body_total_right_bmc                     Body total right bone mineral content
# body_total_right_bmd                     Body total right bone mineral density
# body_trunk_area                                                Body trunk area
# body_trunk_bmc                                 Body trunk bone mineral content
# body_trunk_bmd                                 Body trunk bone mineral density
# body_trunk_left_area                                      Body trunk left area
# body_trunk_left_bmc                       Body trunk left bone mineral content
# body_trunk_left_bmd                       Body trunk left bone mineral density
# body_trunk_right_area                                    Body trunk right area
# body_trunk_right_bmc                     Body trunk right bone mineral content
# body_trunk_right_bmd                     Body trunk right bone mineral density
# femur_left_lower_neck_area                          Femur left lower neck area
# femur_left_lower_neck_bmc           Femur left lower neck bone mineral content
# femur_left_lower_neck_bmd           Femur left lower neck bone mineral density
# femur_left_neck_am_percent                 Femur left neck age-matched percent
# femur_left_neck_area                                      Femur left neck area
# femur_left_neck_bmc                       Femur left neck bone mineral content
# femur_left_neck_bmd                       Femur left neck bone mineral density
# femur_left_neck_t_score                                Femur left neck t-score
# femur_left_neck_ya_percent                 Femur left neck young-adult percent
# femur_left_neck_z_score                                Femur left neck z-score
# femur_left_shaft_area                                    Femur left shaft area
# femur_left_shaft_bmc                     Femur left shaft bone mineral content
# femur_left_shaft_bmd                     Femur left shaft bone mineral density
# femur_left_total_am_percent               Femur left total age-matched percent
# femur_left_total_area                                    Femur left total area
# femur_left_total_bmc                     Femur left total bone mineral content
# femur_left_total_bmd                     Femur left total bone mineral density
# femur_left_total_t_score                              Femur left total t-score
# femur_left_total_ya_percent               Femur left total young-adult percent
# femur_left_total_z_score                              Femur left total z-score
# femur_left_troch_am_percent               Femur left troch age-matched percent
# femur_left_troch_area                                    Femur left troch area
# femur_left_troch_bmc                     Femur left troch bone mineral content
# femur_left_troch_bmd                     Femur left troch bone mineral density
# femur_left_troch_t_score                              Femur left troch t-score
# femur_left_troch_ya_percent               Femur left troch young-adult percent
# femur_left_troch_z_score                              Femur left troch z-score
# femur_left_upper_neck_am_percent     Femur left upper neck age-matched percent
# femur_left_upper_neck_area                          Femur left upper neck area
# femur_left_upper_neck_bmc           Femur left upper neck bone mineral content
# femur_left_upper_neck_bmd           Femur left upper neck bone mineral density
# femur_left_upper_neck_t_score                    Femur left upper neck t-score
# femur_left_upper_neck_ya_percent     Femur left upper neck young-adult percent
# femur_left_upper_neck_z_score                    Femur left upper neck z-score
# femur_left_wards_am_percent               Femur left wards age-matched percent
# femur_left_wards_area                                    Femur left wards area
# femur_left_wards_bmc                     Femur left wards bone mineral content
# femur_left_wards_bmd                     Femur left wards bone mineral density
# femur_left_wards_t_score                              Femur left wards t-score
# femur_left_wards_ya_percent               Femur left wards young-adult percent
# femur_left_wards_z_score                              Femur left wards z-score
# femur_lower_neck_diff_area                          Femur lower neck diff area
# femur_lower_neck_diff_bmc           Femur lower neck diff bone mineral content
# femur_lower_neck_diff_bmd           Femur lower neck diff bone mineral density
# femur_lower_neck_mean_area                          Femur lower neck mean area
# femur_lower_neck_mean_bmc           Femur lower neck mean bone mineral content
# femur_lower_neck_mean_bmd           Femur lower neck mean bone mineral density
# femur_neck_diff_area                                      Femur neck diff area
# femur_neck_diff_bmc                       Femur neck diff bone mineral content
# femur_neck_diff_bmd                       Femur neck diff bone mineral density
# femur_neck_mean_am_percent                 Femur neck mean age-matched percent
# femur_neck_mean_area                                      Femur neck mean area
# femur_neck_mean_bmc                       Femur neck mean bone mineral content
# femur_neck_mean_bmd                       Femur neck mean bone mineral density
# femur_neck_mean_t_score                                Femur neck mean t-score
# femur_neck_mean_ya_percent                 Femur neck mean young-adult percent
# femur_neck_mean_z_score                                Femur neck mean z-score
# femur_right_lower_neck_area                        Femur right lower neck area
# femur_right_lower_neck_bmc         Femur right lower neck bone mineral content
# femur_right_lower_neck_bmd         Femur right lower neck bone mineral density
# femur_right_neck_am_percent               Femur right neck age-matched percent
# femur_right_neck_area                                    Femur right neck area
# femur_right_neck_bmc                     Femur right neck bone mineral content
# femur_right_neck_bmd                     Femur right neck bone mineral density
# femur_right_neck_t_score                              Femur right neck t-score
# femur_right_neck_ya_percent               Femur right neck young-adult percent
# femur_right_neck_z_score                              Femur right neck z-score
# femur_right_shaft_area                                  Femur right shaft area
# femur_right_shaft_bmc                   Femur right shaft bone mineral content
# femur_right_shaft_bmd                   Femur right shaft bone mineral density
# femur_right_total_am_percent             Femur right total age-matched percent
# femur_right_total_area                                  Femur right total area
# femur_right_total_bmc                   Femur right total bone mineral content
# femur_right_total_bmd                   Femur right total bone mineral density
# femur_right_total_t_score                            Femur right total t-score
# femur_right_total_ya_percent             Femur right total young-adult percent
# femur_right_total_z_score                            Femur right total z-score
# femur_right_troch_am_percent             Femur right troch age-matched percent
# femur_right_troch_area                                  Femur right troch area
# femur_right_troch_bmc                   Femur right troch bone mineral content
# femur_right_troch_bmd                   Femur right troch bone mineral density
# femur_right_troch_t_score                            Femur right troch t-score
# femur_right_troch_ya_percent             Femur right troch young-adult percent
# femur_right_troch_z_score                            Femur right troch z-score
# femur_right_upper_neck_am_percent   Femur right upper neck age-matched percent
# femur_right_upper_neck_area                        Femur right upper neck area
# femur_right_upper_neck_bmc         Femur right upper neck bone mineral content
# femur_right_upper_neck_bmd         Femur right upper neck bone mineral density
# femur_right_upper_neck_t_score                  Femur right upper neck t-score
# femur_right_upper_neck_ya_percent   Femur right upper neck young-adult percent
# femur_right_upper_neck_z_score                  Femur right upper neck z-score
# femur_right_wards_am_percent             Femur right wards age-matched percent
# femur_right_wards_area                                  Femur right wards area
# femur_right_wards_bmc                   Femur right wards bone mineral content
# femur_right_wards_bmd                   Femur right wards bone mineral density
# femur_right_wards_t_score                            Femur right wards t-score
# femur_right_wards_ya_percent             Femur right wards young-adult percent
# femur_right_wards_z_score                            Femur right wards z-score
# femur_shaft_diff_area                                    Femur shaft diff area
# femur_shaft_diff_bmc                     Femur shaft diff bone mineral content
# femur_shaft_diff_bmd                     Femur shaft diff bone mineral density
# femur_shaft_mean_area                                    Femur shaft mean area
# femur_shaft_mean_bmc                     Femur shaft mean bone mineral content
# femur_shaft_mean_bmd                     Femur shaft mean bone mineral density
# femur_total_diff_area                                    Femur total diff area
# femur_total_diff_bmc                     Femur total diff bone mineral content
# femur_total_diff_bmd                     Femur total diff bone mineral density
# femur_total_mean_am_percent               Femur total mean age-matched percent
# femur_total_mean_area                                    Femur total mean area
# femur_total_mean_bmc                     Femur total mean bone mineral content
# femur_total_mean_bmd                     Femur total mean bone mineral density
# femur_total_mean_t_score                              Femur total mean t-score
# femur_total_mean_ya_percent               Femur total mean young-adult percent
# femur_total_mean_z_score                              Femur total mean z-score
# femur_troch_diff_area                                    Femur troch diff area
# femur_troch_diff_bmc                     Femur troch diff bone mineral content
# femur_troch_diff_bmd                     Femur troch diff bone mineral density
# femur_troch_mean_am_percent               Femur troch mean age-matched percent
# femur_troch_mean_area                                    Femur troch mean area
# femur_troch_mean_bmc                     Femur troch mean bone mineral content
# femur_troch_mean_bmd                     Femur troch mean bone mineral density
# femur_troch_mean_t_score                              Femur troch mean t-score
# femur_troch_mean_ya_percent               Femur troch mean young-adult percent
# femur_troch_mean_z_score                              Femur troch mean z-score
# femur_upper_neck_diff_area                          Femur upper neck diff area
# femur_upper_neck_diff_bmc           Femur upper neck diff bone mineral content
# femur_upper_neck_diff_bmd           Femur upper neck diff bone mineral density
# femur_upper_neck_mean_am_percent     Femur upper neck mean age-matched percent
# femur_upper_neck_mean_area                          Femur upper neck mean area
# femur_upper_neck_mean_bmc           Femur upper neck mean bone mineral content
# femur_upper_neck_mean_bmd           Femur upper neck mean bone mineral density
# femur_upper_neck_mean_t_score                    Femur upper neck mean t-score
# femur_upper_neck_mean_ya_percent     Femur upper neck mean young-adult percent
# femur_upper_neck_mean_z_score                    Femur upper neck mean z-score
# femur_wards_diff_area                                    Femur wards diff area
# femur_wards_diff_bmc                     Femur wards diff bone mineral content
# femur_wards_diff_bmd                     Femur wards diff bone mineral density
# femur_wards_mean_am_percent               Femur wards mean age-matched percent
# femur_wards_mean_area                                    Femur wards mean area
# femur_wards_mean_bmc                     Femur wards mean bone mineral content
# femur_wards_mean_bmd                     Femur wards mean bone mineral density
# femur_wards_mean_t_score                              Femur wards mean t-score
# femur_wards_mean_ya_percent               Femur wards mean young-adult percent
# femur_wards_mean_z_score                              Femur wards mean z-score
# spine_dose                                                          Spine dose
# spine_l1_am_percent                               Spine l1 age-matched percent
# spine_l1_area                                                    Spine l1 area
# spine_l1_average_height                                Spine l1 average height
# spine_l1_average_width                                  Spine l1 average width
# spine_l1_bmc                                     Spine l1 bone mineral content
# spine_l1_bmd                                     Spine l1 bone mineral density
# spine_l1_l2_am_percent                         Spine l1 l2 age-matched percent
# spine_l1_l2_area                                              Spine l1 l2 area
# spine_l1_l2_average_height                          Spine l1 l2 average height
# spine_l1_l2_average_width                            Spine l1 l2 average width
# spine_l1_l2_bmc                               Spine l1 l2 bone mineral content
# spine_l1_l2_bmd                               Spine l1 l2 bone mineral density
# spine_l1_l2_t_score                                        Spine l1 l2 t-score
# spine_l1_l2_ya_percent                         Spine l1 l2 young-adult percent
# spine_l1_l2_z_score                                        Spine l1 l2 z-score
# spine_l1_l3_am_percent                         Spine l1 l3 age-matched percent
# spine_l1_l3_area                                              Spine l1 l3 area
# spine_l1_l3_average_height                          Spine l1 l3 average height
# spine_l1_l3_average_width                            Spine l1 l3 average width
# spine_l1_l3_bmc                               Spine l1 l3 bone mineral content
# spine_l1_l3_bmd                               Spine l1 l3 bone mineral density
# spine_l1_l3_t_score                                        Spine l1 l3 t-score
# spine_l1_l3_ya_percent                         Spine l1 l3 young-adult percent
# spine_l1_l3_z_score                                        Spine l1 l3 z-score
# spine_l1_l4_am_percent                         Spine l1 l4 age-matched percent
# spine_l1_l4_area                                              Spine l1 l4 area
# spine_l1_l4_average_height                          Spine l1 l4 average height
# spine_l1_l4_average_width                            Spine l1 l4 average width
# spine_l1_l4_bmc                               Spine l1 l4 bone mineral content
# spine_l1_l4_bmd                               Spine l1 l4 bone mineral density
# spine_l1_l4_t_score                                        Spine l1 l4 t-score
# spine_l1_l4_ya_percent                         Spine l1 l4 young-adult percent
# spine_l1_l4_z_score                                        Spine l1 l4 z-score
# spine_l1_t_score                                              Spine l1 t-score
# spine_l1_ya_percent                               Spine l1 young-adult percent
# spine_l1_z_score                                              Spine l1 z-score
# spine_l2_am_percent                               Spine l2 age-matched percent
# spine_l2_area                                                    Spine l2 area
# spine_l2_average_height                                Spine l2 average height
# spine_l2_average_width                                  Spine l2 average width
# spine_l2_bmc                                     Spine l2 bone mineral content
# spine_l2_bmd                                     Spine l2 bone mineral density
# spine_l2_l3_am_percent                         Spine l2 l3 age-matched percent
# spine_l2_l3_area                                              Spine l2 l3 area
# spine_l2_l3_average_height                          Spine l2 l3 average height
# spine_l2_l3_average_width                            Spine l2 l3 average width
# spine_l2_l3_bmc                               Spine l2 l3 bone mineral content
# spine_l2_l3_bmd                               Spine l2 l3 bone mineral density
# spine_l2_l3_t_score                                        Spine l2 l3 t-score
# spine_l2_l3_ya_percent                         Spine l2 l3 young-adult percent
# spine_l2_l3_z_score                                        Spine l2 l3 z-score
# spine_l2_l4_am_percent                         Spine l2 l4 age-matched percent
# spine_l2_l4_area                                              Spine l2 l4 area
# spine_l2_l4_average_height                          Spine l2 l4 average height
# spine_l2_l4_average_width                            Spine l2 l4 average width
# spine_l2_l4_bmc                               Spine l2 l4 bone mineral content
# spine_l2_l4_bmd                               Spine l2 l4 bone mineral density
# spine_l2_l4_t_score                                        Spine l2 l4 t-score
# spine_l2_l4_ya_percent                         Spine l2 l4 young-adult percent
# spine_l2_l4_z_score                                        Spine l2 l4 z-score
# spine_l2_t_score                                              Spine l2 t-score
# spine_l2_ya_percent                               Spine l2 young-adult percent
# spine_l2_z_score                                              Spine l2 z-score
# spine_l3_am_percent                               Spine l3 age-matched percent
# spine_l3_area                                                    Spine l3 area
# spine_l3_average_height                                Spine l3 average height
# spine_l3_average_width                                  Spine l3 average width
# spine_l3_bmc                                     Spine l3 bone mineral content
# spine_l3_bmd                                     Spine l3 bone mineral density
# spine_l3_l4_am_percent                         Spine l3 l4 age-matched percent
# spine_l3_l4_area                                              Spine l3 l4 area
# spine_l3_l4_average_height                          Spine l3 l4 average height
# spine_l3_l4_average_width                            Spine l3 l4 average width
# spine_l3_l4_bmc                               Spine l3 l4 bone mineral content
# spine_l3_l4_bmd                               Spine l3 l4 bone mineral density
# spine_l3_l4_t_score                                        Spine l3 l4 t-score
# spine_l3_l4_ya_percent                         Spine l3 l4 young-adult percent
# spine_l3_l4_z_score                                        Spine l3 l4 z-score
# spine_l3_t_score                                              Spine l3 t-score
# spine_l3_ya_percent                               Spine l3 young-adult percent
# spine_l3_z_score                                              Spine l3 z-score
# spine_l4_am_percent                               Spine l4 age-matched percent
# spine_l4_area                                                    Spine l4 area
# spine_l4_average_height                                Spine l4 average height
# spine_l4_average_width                                  Spine l4 average width
# spine_l4_bmc                                     Spine l4 bone mineral content
# spine_l4_bmd                                     Spine l4 bone mineral density
# spine_l4_t_score                                              Spine l4 t-score
# spine_l4_ya_percent                               Spine l4 young-adult percent
# spine_l4_z_score                                              Spine l4 z-score
#
#                                                                   description_string  \
# tabular_field_name
# collection_date                                         Collection date (YYYY-MM-DD)
# timezone                                                                    Timezone
# collection_timestamp                                            Collection timestamp
# body_arm_left_area                                                Body left arm area
# body_arm_left_bmc                                 Body left arm bone mineral content
# body_arm_left_bmd                                 Body left arm bone mineral density
# body_arm_right_area                                              Body right arm area
# body_arm_right_bmc                               Body right arm bone mineral content
# body_arm_right_bmd                               Body right arm bone mineral density
# body_arms_area                                                        Body arms area
# body_arms_bmc                                         Body arms bone mineral content
# body_arms_bmd                                         Body arms bone mineral density
# body_dose                                                                  Body dose
# body_head_area                                                        Body head area
# body_head_bmc                                         Body head bone mineral content
# body_head_bmd                                         Body head bone mineral density
# body_leg_left_area                                                Body left leg area
# body_leg_left_bmc                                 Body left leg bone mineral content
# body_leg_left_bmd                                 Body left leg bone mineral density
# body_leg_right_area                                              Body right leg area
# body_leg_right_bmc                               Body right leg bone mineral content
# body_leg_right_bmd                               Body right leg bone mineral density
# body_legs_area                                                        Body legs area
# body_legs_bmc                                         Body legs bone mineral content
# body_legs_bmd                                         Body legs bone mineral density
# body_pelvis_area                                                    Body pelvis area
# body_pelvis_bmc                                     Body pelvis bone mineral content
# body_pelvis_bmd                                     Body pelvis bone mineral density
# body_ribs_area                                                        Body ribs area
# body_ribs_bmc                                         Body ribs bone mineral content
# body_ribs_bmd                                         Body ribs bone mineral density
# body_spine_area                                                      Body spine area
# body_spine_bmc                                       Body spine bone mineral content
# body_spine_bmd                                       Body spine bone mineral density
# body_total_area                                                      Body total area
# body_total_bmc                                       Body total bone mineral content
# body_total_bmd                                       Body total bone mineral density
# body_total_left_area                                            Body total left area
# body_total_left_bmc                             Body total left bone mineral content
# body_total_left_bmd                             Body total left bone mineral density
# body_total_right_area                                          Body total right area
# body_total_right_bmc                           Body total right bone mineral content
# body_total_right_bmd                           Body total right bone mineral density
# body_trunk_area                                                      Body trunk area
# body_trunk_bmc                                       Body trunk bone mineral content
# body_trunk_bmd                                       Body trunk bone mineral density
# body_trunk_left_area                                            Body left trunk area
# body_trunk_left_bmc                             Body left trunk bone mineral content
# body_trunk_left_bmd                             Body left trunk bone mineral density
# body_trunk_right_area                                          Body right trunk area
# body_trunk_right_bmc                           Body right trunk bone mineral content
# body_trunk_right_bmd                           Body right trunk bone mineral density
# femur_left_lower_neck_area                                Femur left lower neck area
# femur_left_lower_neck_bmc                 Femur left lower neck bone mineral content
# femur_left_lower_neck_bmd                 Femur left lower neck bone mineral density
# femur_left_neck_am_percent                       Femur left neck age-matched percent
# femur_left_neck_area                                            Femur left neck area
# femur_left_neck_bmc                             Femur left neck bone mineral content
# femur_left_neck_bmd                             Femur left neck bone mineral density
# femur_left_neck_t_score                                      Femur left neck t-score
# femur_left_neck_ya_percent                       Femur left neck young-adult percent
# femur_left_neck_z_score                                      Femur left neck z-score
# femur_left_shaft_area                                          Femur left shaft area
# femur_left_shaft_bmc                           Femur left shaft bone mineral content
# femur_left_shaft_bmd                           Femur left shaft bone mineral density
# femur_left_total_am_percent                     Femur left total age-matched percent
# femur_left_total_area                                          Femur left total area
# femur_left_total_bmc                           Femur left total bone mineral content
# femur_left_total_bmd                           Femur left total bone mineral density
# femur_left_total_t_score                                    Femur left total t-score
# femur_left_total_ya_percent                     Femur left total young-adult percent
# femur_left_total_z_score                                    Femur left total z-score
# femur_left_troch_am_percent                Femur left trochanter age-matched percent
# femur_left_troch_area                                     Femur left trochanter area
# femur_left_troch_bmc                      Femur left trochanter bone mineral content
# femur_left_troch_bmd                      Femur left trochanter bone mineral density
# femur_left_troch_t_score                               Femur left trochanter t-score
# femur_left_troch_ya_percent                Femur left trochanter young-adult percent
# femur_left_troch_z_score                               Femur left trochanter z-score
# femur_left_upper_neck_am_percent           Femur left upper neck age-matched percent
# femur_left_upper_neck_area                                Femur left upper neck area
# femur_left_upper_neck_bmc                 Femur left upper neck bone mineral content
# femur_left_upper_neck_bmd                 Femur left upper neck bone mineral density
# femur_left_upper_neck_t_score                          Femur left upper neck t-score
# femur_left_upper_neck_ya_percent           Femur left upper neck young-adult percent
# femur_left_upper_neck_z_score                          Femur left upper neck z-score
# femur_left_wards_am_percent                     Femur left wards age-matched percent
# femur_left_wards_area                                          Femur left wards area
# femur_left_wards_bmc                           Femur left wards bone mineral content
# femur_left_wards_bmd                           Femur left wards bone mineral density
# femur_left_wards_t_score                                    Femur left wards t-score
# femur_left_wards_ya_percent                     Femur left wards young-adult percent
# femur_left_wards_z_score                                    Femur left wards z-score
# femur_lower_neck_diff_area         Femur difference in lower neck area between sides
# femur_lower_neck_diff_bmc          Femur difference in lower neck bone mineral co...
# femur_lower_neck_diff_bmd          Femur difference in lower neck bone mineral de...
# femur_lower_neck_mean_area                                Femur lower neck mean area
# femur_lower_neck_mean_bmc                 Femur lower neck mean bone mineral content
# femur_lower_neck_mean_bmd                 Femur lower neck mean bone mineral density
# femur_neck_diff_area                     Femur difference in neck area between sides
# femur_neck_diff_bmc                Femur difference in neck bone mineral content ...
# femur_neck_diff_bmd                Femur difference in neck bone mineral density ...
# femur_neck_mean_am_percent                       Femur neck mean age-matched percent
# femur_neck_mean_area                                            Femur neck mean area
# femur_neck_mean_bmc                             Femur neck mean bone mineral content
# femur_neck_mean_bmd                             Femur neck mean bone mineral density
# femur_neck_mean_t_score                                      Femur neck mean t-score
# femur_neck_mean_ya_percent                       Femur neck mean young-adult percent
# femur_neck_mean_z_score                                      Femur neck mean z-score
# femur_right_lower_neck_area                              Femur right lower neck area
# femur_right_lower_neck_bmc               Femur right lower neck bone mineral content
# femur_right_lower_neck_bmd               Femur right lower neck bone mineral density
# femur_right_neck_am_percent                     Femur right neck age-matched percent
# femur_right_neck_area                                          Femur right neck area
# femur_right_neck_bmc                           Femur right neck bone mineral content
# femur_right_neck_bmd                           Femur right neck bone mineral density
# femur_right_neck_t_score                                    Femur right neck t-score
# femur_right_neck_ya_percent                     Femur right neck young-adult percent
# femur_right_neck_z_score                                    Femur right neck z-score
# femur_right_shaft_area                                        Femur right shaft area
# femur_right_shaft_bmc                         Femur right shaft bone mineral content
# femur_right_shaft_bmd                         Femur right shaft bone mineral density
# femur_right_total_am_percent                   Femur right total age-matched percent
# femur_right_total_area                                        Femur right total area
# femur_right_total_bmc                         Femur right total bone mineral content
# femur_right_total_bmd                         Femur right total bone mineral density
# femur_right_total_t_score                                  Femur right total t-score
# femur_right_total_ya_percent                   Femur right total young-adult percent
# femur_right_total_z_score                                  Femur right total z-score
# femur_right_troch_am_percent              Femur right trochanter age-matched percent
# femur_right_troch_area                                   Femur right trochanter area
# femur_right_troch_bmc                    Femur right trochanter bone mineral content
# femur_right_troch_bmd                    Femur right trochanter bone mineral density
# femur_right_troch_t_score                             Femur right trochanter t-score
# femur_right_troch_ya_percent              Femur right trochanter young-adult percent
# femur_right_troch_z_score                             Femur right trochanter z-score
# femur_right_upper_neck_am_percent         Femur right upper neck age-matched percent
# femur_right_upper_neck_area                              Femur right upper neck area
# femur_right_upper_neck_bmc               Femur right upper neck bone mineral content
# femur_right_upper_neck_bmd               Femur right upper neck bone mineral density
# femur_right_upper_neck_t_score                        Femur right upper neck t-score
# femur_right_upper_neck_ya_percent         Femur right upper neck young-adult percent
# femur_right_upper_neck_z_score                        Femur right upper neck z-score
# femur_right_wards_am_percent          Femur right wards triangel age-matched percent
# femur_right_wards_area                               Femur right wards triangel area
# femur_right_wards_bmc                Femur right wards triangel bone mineral content
# femur_right_wards_bmd                Femur right wards triangel bone mineral density
# femur_right_wards_t_score                         Femur right wards triangel t-score
# femur_right_wards_ya_percent          Femur right wards triangel young-adult percent
# femur_right_wards_z_score                         Femur right wards triangel z-score
# femur_shaft_diff_area                   Femur difference in shaft area between sides
# femur_shaft_diff_bmc               Femur difference in shaft bone mineral content...
# femur_shaft_diff_bmd                           Femur shaft diff bone mineral density
# femur_shaft_mean_area                                          Femur shaft mean area
# femur_shaft_mean_bmc                           Femur shaft mean bone mineral content
# femur_shaft_mean_bmd                           Femur shaft mean bone mineral density
# femur_total_diff_area                   Femur difference in total area between sides
# femur_total_diff_bmc                  Femur difference in total bone mineral content
# femur_total_diff_bmd                     Femur difference total bone mineral density
# femur_total_mean_am_percent                     Femur total mean age-matched percent
# femur_total_mean_area                                          Femur total mean area
# femur_total_mean_bmc                           Femur total mean bone mineral content
# femur_total_mean_bmd                           Femur total mean bone mineral density
# femur_total_mean_t_score                                    Femur total mean t-score
# femur_total_mean_ya_percent                     Femur total mean young-adult percent
# femur_total_mean_z_score                                    Femur total mean z-score
# femur_troch_diff_area                   Femur difference in troch area between sides
# femur_troch_diff_bmc               Femur difference in troch bone mineral content...
# femur_troch_diff_bmd               Femur difference in troch bone mineral density...
# femur_troch_mean_am_percent                Femur trochanter mean age-matched percent
# femur_troch_mean_area                                     Femur trochanter mean area
# femur_troch_mean_bmc                      Femur trochanter mean bone mineral content
# femur_troch_mean_bmd                      Femur trochanter mean bone mineral density
# femur_troch_mean_t_score                               Femur trochanter mean t-score
# femur_troch_mean_ya_percent                Femur trochanter mean young-adult percent
# femur_troch_mean_z_score                               Femur trochanter mean z-score
# femur_upper_neck_diff_area                                Femur upper neck diff area
# femur_upper_neck_diff_bmc          Femur difference in upper neck bone mineral co...
# femur_upper_neck_diff_bmd          Femur difference in upper neck bone mineral de...
# femur_upper_neck_mean_am_percent           Femur upper neck mean age-matched percent
# femur_upper_neck_mean_area                                Femur upper neck mean area
# femur_upper_neck_mean_bmc                 Femur upper neck mean bone mineral content
# femur_upper_neck_mean_bmd                 Femur upper neck mean bone mineral density
# femur_upper_neck_mean_t_score                          Femur upper neck mean t-score
# femur_upper_neck_mean_ya_percent           Femur upper neck mean young-adult percent
# femur_upper_neck_mean_z_score                          Femur upper neck mean z-score
# femur_wards_diff_area              Femur difference in wards triangel area betwee...
# femur_wards_diff_bmc               Femur difference in wards triangel bone minera...
# femur_wards_diff_bmd               Femur difference in wards triangel bone minera...
# femur_wards_mean_am_percent            Femur wards triangel mean age-matched percent
# femur_wards_mean_area                                 Femur wards triangel mean area
# femur_wards_mean_bmc                  Femur wards triangel mean bone mineral content
# femur_wards_mean_bmd                  Femur wards triangel mean bone mineral density
# femur_wards_mean_t_score                           Femur wards triangel mean t-score
# femur_wards_mean_ya_percent            Femur wards triangel mean young-adult percent
# femur_wards_mean_z_score                           Femur wards triangel mean z-score
# spine_dose                                                      Spine radiation dose
# spine_l1_am_percent                                     Spine l1 age-matched percent
# spine_l1_area                                                          Spine l1 area
# spine_l1_average_height                                      Spine l1 average height
# spine_l1_average_width                                        Spine l1 average width
# spine_l1_bmc                                           Spine l1 bone mineral content
# spine_l1_bmd                                           Spine l1 bone mineral density
# spine_l1_l2_am_percent                               Spine l1 l2 age-matched percent
# spine_l1_l2_area                                                    Spine l1 l2 area
# spine_l1_l2_average_height                                Spine l1 l2 average height
# spine_l1_l2_average_width                                  Spine l1 l2 average width
# spine_l1_l2_bmc                                     Spine l1 l2 bone mineral content
# spine_l1_l2_bmd                                     Spine l1 l2 bone mineral density
# spine_l1_l2_t_score                                              Spine l1 l2 t-score
# spine_l1_l2_ya_percent                               Spine l1 l2 young-adult percent
# spine_l1_l2_z_score                                              Spine l1 l2 z-score
# spine_l1_l3_am_percent                               Spine l1 l3 age-matched percent
# spine_l1_l3_area                                                    Spine l1 l3 area
# spine_l1_l3_average_height                                Spine l1 l3 average height
# spine_l1_l3_average_width                                  Spine l1 l3 average width
# spine_l1_l3_bmc                                     Spine l1 l3 bone mineral content
# spine_l1_l3_bmd                                     Spine l1 l3 bone mineral density
# spine_l1_l3_t_score                                              Spine l1 l3 t-score
# spine_l1_l3_ya_percent                               Spine l1 l3 young-adult percent
# spine_l1_l3_z_score                                              Spine l1 l3 z-score
# spine_l1_l4_am_percent                               Spine l1 l4 age-matched percent
# spine_l1_l4_area                                                    Spine l1 l4 area
# spine_l1_l4_average_height                                Spine l1 l4 average height
# spine_l1_l4_average_width                                  Spine l1 l4 average width
# spine_l1_l4_bmc                                     Spine l1 l4 bone mineral content
# spine_l1_l4_bmd                                     Spine l1 l4 bone mineral density
# spine_l1_l4_t_score                                              Spine l1 l4 t-score
# spine_l1_l4_ya_percent                               Spine l1 l4 young-adult percent
# spine_l1_l4_z_score                                              Spine l1 l4 z-score
# spine_l1_t_score                                                    Spine l1 t-score
# spine_l1_ya_percent                                     Spine l1 young-adult percent
# spine_l1_z_score                                                    Spine l1 z-score
# spine_l2_am_percent                                     Spine l2 age-matched percent
# spine_l2_area                                                          Spine l2 area
# spine_l2_average_height                                      Spine l2 average height
# spine_l2_average_width                                        Spine l2 average width
# spine_l2_bmc                                           Spine l2 bone mineral content
# spine_l2_bmd                                           Spine l2 bone mineral density
# spine_l2_l3_am_percent                               Spine l2 l3 age-matched percent
# spine_l2_l3_area                                                    Spine l2 l3 area
# spine_l2_l3_average_height                                Spine l2 l3 average height
# spine_l2_l3_average_width                                  Spine l2 l3 average width
# spine_l2_l3_bmc                                     Spine l2 l3 bone mineral content
# spine_l2_l3_bmd                                     Spine l2 l3 bone mineral density
# spine_l2_l3_t_score                                              Spine l2 l3 t-score
# spine_l2_l3_ya_percent                               Spine l2 l3 young-adult percent
# spine_l2_l3_z_score                                              Spine l2 l3 z-score
# spine_l2_l4_am_percent                               Spine l2 l4 age-matched percent
# spine_l2_l4_area                                                    Spine l2 l4 area
# spine_l2_l4_average_height                                Spine l2 l4 average height
# spine_l2_l4_average_width                                  Spine l2 l4 average width
# spine_l2_l4_bmc                                     Spine l2 l4 bone mineral content
# spine_l2_l4_bmd                                     Spine l2 l4 bone mineral density
# spine_l2_l4_t_score                                              Spine l2 l4 t-score
# spine_l2_l4_ya_percent                               Spine l2 l4 young-adult percent
# spine_l2_l4_z_score                                              Spine l2 l4 z-score
# spine_l2_t_score                                                    Spine l2 t-score
# spine_l2_ya_percent                                     Spine l2 young-adult percent
# spine_l2_z_score                                                    Spine l2 z-score
# spine_l3_am_percent                                     Spine l3 age-matched percent
# spine_l3_area                                                          Spine l3 area
# spine_l3_average_height                                      Spine l3 average height
# spine_l3_average_width                                        Spine l3 average width
# spine_l3_bmc                                           Spine l3 bone mineral content
# spine_l3_bmd                                           Spine l3 bone mineral density
# spine_l3_l4_am_percent                               Spine l3 l4 age-matched percent
# spine_l3_l4_area                                                    Spine l3 l4 area
# spine_l3_l4_average_height                                Spine l3 l4 average height
# spine_l3_l4_average_width                                  Spine l3 l4 average width
# spine_l3_l4_bmc                                     Spine l3 l4 bone mineral content
# spine_l3_l4_bmd                                     Spine l3 l4 bone mineral density
# spine_l3_l4_t_score                                              Spine l3 l4 t-score
# spine_l3_l4_ya_percent                               Spine l3 l4 young-adult percent
# ...
# spine_l4_bmd                       2020-06-09                           float
# spine_l4_t_score                   2020-06-09                           float
# spine_l4_ya_percent                2020-06-09                           float
# spine_l4_z_score                   2020-06-09                           float
#
#                                    parent_dataframe
# tabular_field_name
# collection_date                                 NaN
# timezone                                        NaN
# collection_timestamp                            NaN
# body_arm_left_area                              NaN
# body_arm_left_bmc                               NaN
# body_arm_left_bmd                               NaN
# body_arm_right_area                             NaN
# body_arm_right_bmc                              NaN
# body_arm_right_bmd                              NaN
# body_arms_area                                  NaN
# body_arms_bmc                                   NaN
# body_arms_bmd                                   NaN
# body_dose                                       NaN
# body_head_area                                  NaN
# body_head_bmc                                   NaN
# body_head_bmd                                   NaN
# body_leg_left_area                              NaN
# body_leg_left_bmc                               NaN
# body_leg_left_bmd                               NaN
# body_leg_right_area                             NaN
# body_leg_right_bmc                              NaN
# body_leg_right_bmd                              NaN
# body_legs_area                                  NaN
# body_legs_bmc                                   NaN
# body_legs_bmd                                   NaN
# body_pelvis_area                                NaN
# body_pelvis_bmc                                 NaN
# body_pelvis_bmd                                 NaN
# body_ribs_area                                  NaN
# body_ribs_bmc                                   NaN
# body_ribs_bmd                                   NaN
# body_spine_area                                 NaN
# body_spine_bmc                                  NaN
# body_spine_bmd                                  NaN
# body_total_area                                 NaN
# body_total_bmc                                  NaN
# body_total_bmd                                  NaN
# body_total_left_area                            NaN
# body_total_left_bmc                             NaN
# body_total_left_bmd                             NaN
# body_total_right_area                           NaN
# body_total_right_bmc                            NaN
# body_total_right_bmd                            NaN
# body_trunk_area                                 NaN
# body_trunk_bmc                                  NaN
# body_trunk_bmd                                  NaN
# body_trunk_left_area                            NaN
# body_trunk_left_bmc                             NaN
# body_trunk_left_bmd                             NaN
# body_trunk_right_area                           NaN
# body_trunk_right_bmc                            NaN
# body_trunk_right_bmd                            NaN
# femur_left_lower_neck_area                      NaN
# femur_left_lower_neck_bmc                       NaN
# femur_left_lower_neck_bmd                       NaN
# femur_left_neck_am_percent                      NaN
# femur_left_neck_area                            NaN
# femur_left_neck_bmc                             NaN
# femur_left_neck_bmd                             NaN
# femur_left_neck_t_score                         NaN
# femur_left_neck_ya_percent                      NaN
# femur_left_neck_z_score                         NaN
# femur_left_shaft_area                           NaN
# femur_left_shaft_bmc                            NaN
# femur_left_shaft_bmd                            NaN
# femur_left_total_am_percent                     NaN
# femur_left_total_area                           NaN
# femur_left_total_bmc                            NaN
# femur_left_total_bmd                            NaN
# femur_left_total_t_score                        NaN
# femur_left_total_ya_percent                     NaN
# femur_left_total_z_score                        NaN
# femur_left_troch_am_percent                     NaN
# femur_left_troch_area                           NaN
# femur_left_troch_bmc                            NaN
# femur_left_troch_bmd                            NaN
# femur_left_troch_t_score                        NaN
# femur_left_troch_ya_percent                     NaN
# femur_left_troch_z_score                        NaN
# femur_left_upper_neck_am_percent                NaN
# femur_left_upper_neck_area                      NaN
# femur_left_upper_neck_bmc                       NaN
# femur_left_upper_neck_bmd                       NaN
# femur_left_upper_neck_t_score                   NaN
# femur_left_upper_neck_ya_percent                NaN
# femur_left_upper_neck_z_score                   NaN
# femur_left_wards_am_percent                     NaN
# femur_left_wards_area                           NaN
# femur_left_wards_bmc                            NaN
# femur_left_wards_bmd                            NaN
# femur_left_wards_t_score                        NaN
# femur_left_wards_ya_percent                     NaN
# femur_left_wards_z_score                        NaN
# femur_lower_neck_diff_area                      NaN
# femur_lower_neck_diff_bmc                       NaN
# femur_lower_neck_diff_bmd                       NaN
# femur_lower_neck_mean_area                      NaN
# femur_lower_neck_mean_bmc                       NaN
# femur_lower_neck_mean_bmd                       NaN
# femur_neck_diff_area                            NaN
# femur_neck_diff_bmc                             NaN
# femur_neck_diff_bmd                             NaN
# femur_neck_mean_am_percent                      NaN
# femur_neck_mean_area                            NaN
# femur_neck_mean_bmc                             NaN
# femur_neck_mean_bmd                             NaN
# femur_neck_mean_t_score                         NaN
# femur_neck_mean_ya_percent                      NaN
# femur_neck_mean_z_score                         NaN
# femur_right_lower_neck_area                     NaN
# femur_right_lower_neck_bmc                      NaN
# femur_right_lower_neck_bmd                      NaN
# femur_right_neck_am_percent                     NaN
# femur_right_neck_area                           NaN
# femur_right_neck_bmc                            NaN
# femur_right_neck_bmd                            NaN
# femur_right_neck_t_score                        NaN
# femur_right_neck_ya_percent                     NaN
# femur_right_neck_z_score                        NaN
# femur_right_shaft_area                          NaN
# femur_right_shaft_bmc                           NaN
# femur_right_shaft_bmd                           NaN
# femur_right_total_am_percent                    NaN
# femur_right_total_area                          NaN
# femur_right_total_bmc                           NaN
# femur_right_total_bmd                           NaN
# femur_right_total_t_score                       NaN
# femur_right_total_ya_percent                    NaN
# femur_right_total_z_score                       NaN
# femur_right_troch_am_percent                    NaN
# femur_right_troch_area                          NaN
# femur_right_troch_bmc                           NaN
# femur_right_troch_bmd                           NaN
# femur_right_troch_t_score                       NaN
# femur_right_troch_ya_percent                    NaN
# femur_right_troch_z_score                       NaN
# femur_right_upper_neck_am_percent               NaN
# femur_right_upper_neck_area                     NaN
# femur_right_upper_neck_bmc                      NaN
# femur_right_upper_neck_bmd                      NaN
# femur_right_upper_neck_t_score                  NaN
# femur_right_upper_neck_ya_percent               NaN
# femur_right_upper_neck_z_score                  NaN
# femur_right_wards_am_percent                    NaN
# femur_right_wards_area                          NaN
# femur_right_wards_bmc                           NaN
# femur_right_wards_bmd                           NaN
# femur_right_wards_t_score                       NaN
# femur_right_wards_ya_percent                    NaN
# femur_right_wards_z_score                       NaN
# femur_shaft_diff_area                           NaN
# femur_shaft_diff_bmc                            NaN
# femur_shaft_diff_bmd                            NaN
# femur_shaft_mean_area                           NaN
# femur_shaft_mean_bmc                            NaN
# femur_shaft_mean_bmd                            NaN
# femur_total_diff_area                           NaN
# femur_total_diff_bmc                            NaN
# femur_total_diff_bmd                            NaN
# femur_total_mean_am_percent                     NaN
# femur_total_mean_area                           NaN
# femur_total_mean_bmc                            NaN
# femur_total_mean_bmd                            NaN
# femur_total_mean_t_score                        NaN
# femur_total_mean_ya_percent                     NaN
# femur_total_mean_z_score                        NaN
# femur_troch_diff_area                           NaN
# femur_troch_diff_bmc                            NaN
# femur_troch_diff_bmd                            NaN
# femur_troch_mean_am_percent                     NaN
# femur_troch_mean_area                           NaN
# femur_troch_mean_bmc                            NaN
# femur_troch_mean_bmd                            NaN
# femur_troch_mean_t_score                        NaN
# femur_troch_mean_ya_percent                     NaN
# femur_troch_mean_z_score                        NaN
# femur_upper_neck_diff_area                      NaN
# femur_upper_neck_diff_bmc                       NaN
# femur_upper_neck_diff_bmd                       NaN
# femur_upper_neck_mean_am_percent                NaN
# femur_upper_neck_mean_area                      NaN
# femur_upper_neck_mean_bmc                       NaN
# femur_upper_neck_mean_bmd                       NaN
# femur_upper_neck_mean_t_score                   NaN
# femur_upper_neck_mean_ya_percent                NaN
# femur_upper_neck_mean_z_score                   NaN
# femur_wards_diff_area                           NaN
# femur_wards_diff_bmc                            NaN
# femur_wards_diff_bmd                            NaN
# femur_wards_mean_am_percent                     NaN
# femur_wards_mean_area                           NaN
# femur_wards_mean_bmc                            NaN
# femur_wards_mean_bmd                            NaN
# femur_wards_mean_t_score                        NaN
# femur_wards_mean_ya_percent                     NaN
# femur_wards_mean_z_score                        NaN
# spine_dose                                      NaN
# spine_l1_am_percent                             NaN
# spine_l1_area                                   NaN
# spine_l1_average_height                         NaN
# spine_l1_average_width                          NaN
# spine_l1_bmc                                    NaN
# spine_l1_bmd                                    NaN
# spine_l1_l2_am_percent                          NaN
# spine_l1_l2_area                                NaN
# spine_l1_l2_average_height                      NaN
# spine_l1_l2_average_width                       NaN
# spine_l1_l2_bmc                                 NaN
# spine_l1_l2_bmd                                 NaN
# spine_l1_l2_t_score                             NaN
# spine_l1_l2_ya_percent                          NaN
# spine_l1_l2_z_score                             NaN
# spine_l1_l3_am_percent                          NaN
# spine_l1_l3_area                                NaN
# spine_l1_l3_average_height                      NaN
# spine_l1_l3_average_width                       NaN
# spine_l1_l3_bmc                                 NaN
# spine_l1_l3_bmd                                 NaN
# spine_l1_l3_t_score                             NaN
# spine_l1_l3_ya_percent                          NaN
# spine_l1_l3_z_score                             NaN
# spine_l1_l4_am_percent                          NaN
# spine_l1_l4_area                                NaN
# spine_l1_l4_average_height                      NaN
# spine_l1_l4_average_width                       NaN
# spine_l1_l4_bmc                                 NaN
# spine_l1_l4_bmd                                 NaN
# spine_l1_l4_t_score                             NaN
# spine_l1_l4_ya_percent                          NaN
# spine_l1_l4_z_score                             NaN
# spine_l1_t_score                                NaN
# spine_l1_ya_percent                             NaN
# spine_l1_z_score                                NaN
# spine_l2_am_percent                             NaN
# spine_l2_area                                   NaN
# spine_l2_average_height                         NaN
# spine_l2_average_width                          NaN
# spine_l2_bmc                                    NaN
# spine_l2_bmd                                    NaN
# spine_l2_l3_am_percent                          NaN
# spine_l2_l3_area                                NaN
# spine_l2_l3_average_height                      NaN
# spine_l2_l3_average_width                       NaN
# spine_l2_l3_bmc                                 NaN
# spine_l2_l3_bmd                                 NaN
# spine_l2_l3_t_score                             NaN
# spine_l2_l3_ya_percent                          NaN
# spine_l2_l3_z_score                             NaN
# spine_l2_l4_am_percent                          NaN
# spine_l2_l4_area                                NaN
# spine_l2_l4_average_height                      NaN
# spine_l2_l4_average_width                       NaN
# spine_l2_l4_bmc                                 NaN
# spine_l2_l4_bmd                                 NaN
# spine_l2_l4_t_score                             NaN
# spine_l2_l4_ya_percent                          NaN
# spine_l2_l4_z_score                             NaN
# spine_l2_t_score                                NaN
# spine_l2_ya_percent                             NaN
# spine_l2_z_score                                NaN
# spine_l3_am_percent                             NaN
# spine_l3_area                                   NaN
# spine_l3_average_height                         NaN
# spine_l3_average_width                          NaN
# spine_l3_bmc                                    NaN
# spine_l3_bmd                                    NaN
# spine_l3_l4_am_percent                          NaN
# spine_l3_l4_area                                NaN
# spine_l3_l4_average_height                      NaN
# spine_l3_l4_average_width                       NaN
# spine_l3_l4_bmc                                 NaN
# spine_l3_l4_bmd                                 NaN
# spine_l3_l4_t_score                             NaN
# spine_l3_l4_ya_percent                          NaN
# spine_l3_l4_z_score                             NaN
# spine_l3_t_score                                NaN
# spine_l3_ya_percent                             NaN
# spine_l3_z_score                                NaN
# spine_l4_am_percent                             NaN
# spine_l4_area                                   NaN
# spine_l4_average_height                         NaN
# spine_l4_average_width                          NaN
# spine_l4_bmc                                    NaN
# spine_l4_bmd                                    NaN
# spine_l4_t_score                                NaN
# spine_l4_ya_percent                             NaN
# spine_l4_z_score                                NaN
