# %% [raw]
# ---
# output-file: 001-events.html
# title: 001-events
# ---

# %% [markdown]
# # Events dataset
#
# Events Informations of the Human Phenotype Project study participants including birth month and year, sex and visits information.
#
# ### Data availability:
#
# - events.parquet - also contains information regarding participant visits and calls

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('events')
dl
# Out:
# DataLoader for events with
# 10 fields
# 1 tables: ['events']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                                          field_string  \
# tabular_field_name
# month_of_birth                         Month of birth
# year_of_birth                           Year of birth
# sex                                               Sex
# research_stage_type               Research stage type
# visit_center                             Visit center
# research_stage_timestamp  Timestamp of research stage
# research_stage_date            Date of research stage
# age_at_research_stage           Age at research stage
# study_id                                     Study ID
# timezone                                     Timezone
#
#                                                          description_string  \
# tabular_field_name
# month_of_birth                                               Month of birth
# year_of_birth                                                 Year of birth
# sex                                                                     Sex
# research_stage_type                          The type of the research stage
# visit_center                              The name of the assessment center
# research_stage_timestamp  The timestamp of the research stage. For examp...
# research_stage_date       The date of the research stage. For example, i...
# age_at_research_stage     The age of the participant during the research...
# study_id                                               The study identifier
# timezone                                                           Timezone
#
#                               relative_location              value_type  \
# tabular_field_name
# month_of_birth            events/events.parquet                 Integer
# year_of_birth             events/events.parquet                 Integer
# sex                       events/events.parquet    Categorical (single)
# research_stage_type       events/events.parquet  Categorical (multiple)
# visit_center              events/events.parquet  Categorical (multiple)
# research_stage_timestamp  events/events.parquet                    Date
# research_stage_date       events/events.parquet                    Date
# age_at_research_stage     events/events.parquet                 Integer
# study_id                  events/events.parquet  Categorical (multiple)
# timezone                  events/events.parquet                    Date
#
#                           units  sampling_rate item_type array cohorts  \
# tabular_field_name
# month_of_birth              NaN            NaN      Data    No     10K
# year_of_birth               NaN            NaN      Data    No     10K
# sex                         NaN            NaN      Data    No     10K
# research_stage_type         NaN            NaN      Data    No     10K
# visit_center                NaN            NaN      Data    No     10K
# research_stage_timestamp    NaN            NaN      Data    No     10K
# research_stage_date         NaN            NaN      Data    No     10K
# age_at_research_stage       NaN            NaN      Data    No     10K
# study_id                    NaN            NaN      Data    No     10K
# timezone                    NaN            NaN      Data    No     10K
#
#                          data_type       debut  \
# tabular_field_name
# month_of_birth             Tabular  2019-01-01
# year_of_birth              Tabular  2019-01-01
# sex                        Tabular  2019-01-01
# research_stage_type        Tabular  2019-01-01
# visit_center               Tabular  2019-01-01
# research_stage_timestamp   Tabular  2019-01-01
# research_stage_date        Tabular  2019-01-01
# age_at_research_stage      Tabular  2019-01-01
# study_id                   Tabular  2019-01-01
# timezone                   Tabular  2019-01-01
#
#                                             pandas_dtype  parent_dataframe  \
# tabular_field_name
# month_of_birth                                       int               NaN
# year_of_birth                                        int               NaN
# sex                                                  int               NaN
# research_stage_type                                  int               NaN
# visit_center                                         int               NaN
# research_stage_timestamp  datetime64[ns, Asia/Jerusalem]               NaN
# research_stage_date                       datetime64[ns]               NaN
# age_at_research_stage                              float               NaN
# study_id                                             int               NaN
# timezone                                          string               NaN
#
#                           data_coding
# tabular_field_name
# month_of_birth                    NaN
# year_of_birth                     NaN
# sex                               9.0
# research_stage_type            1001.0
# visit_center                    999.0
# research_stage_timestamp          NaN
# research_stage_date               NaN
# age_at_research_stage             NaN
# study_id                       1000.0
# timezone                          NaN
