# %% [raw]
# ---
# output-file: 015-ecg.html
# title: 015-ecg
# ---

# %% [markdown]
# # ECG dataset
# An electrocardiogram (ECG) is a simple test that can be used to check your heart's rhythm and electrical activity. Sensors attached to the skin are used to detect the electrical signals produced by the heart each time it beats.
#
# A resting 12-lead ECG is recorded at each visit for participants. The record length is 10 seconds and the sample rate is 1000Hz. We collect both the raw waveform ECG signal from all leads and tabular data. The tabular data are features which have been extracted automatically by the machine from the raw data such as the P wave duration.
#
# ### Data availability:
# The information is stored in 2 tabular parquet files: `ecg.parquet`, `ecg_qc.parquet`, which contain tabular features and QC checks on the raw ECG waveform data. Mutiple time series parquet files contain the raw and processed ECG waveform data

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('ecg')
dl
# Out:
# DataLoader for ecg with
# 165 fields
# 3 tables: ['ecg', 'ecg_qc', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                                                                          field_string  \
# tabular_field_name
# collection_date                                          Collection date (YYYY-MM-DD)
# timezone                                                                     Timezone
# collection_timestamp                                             Collection timestamp
# MDC_ECG_LEAD_I                                                             ECG lead I
# MDC_ECG_LEAD_II                                                           ECG lead II
# MDC_ECG_LEAD_III                                                         ECG lead III
# MDC_ECG_LEAD_aVR                                                         ECG lead aVR
# MDC_ECG_LEAD_aVL                                                         ECG lead aVL
# MDC_ECG_LEAD_aVF                                                         ECG lead aVF
# MDC_ECG_LEAD_V1                                                           ECG lead V1
# MDC_ECG_LEAD_V2                                                           ECG lead V2
# MDC_ECG_LEAD_V3                                                           ECG lead V3
# MDC_ECG_LEAD_V4                                                           ECG lead V4
# MDC_ECG_LEAD_V5                                                           ECG lead V5
# MDC_ECG_LEAD_V6                                                           ECG lead V6
# MDC_ECG_LEAD_I_clean                                                       ECG lead I
# MDC_ECG_LEAD_II_clean                                                     ECG lead II
# MDC_ECG_LEAD_III_clean                                                   ECG lead III
# MDC_ECG_LEAD_aVR_clean                                                   ECG lead aVR
# MDC_ECG_LEAD_aVL_clean                                                   ECG lead aVL
# MDC_ECG_LEAD_aVF_clean                                                   ECG lead aVF
# MDC_ECG_LEAD_V1_clean                                                     ECG lead V1
# MDC_ECG_LEAD_V2_clean                                                     ECG lead V2
# MDC_ECG_LEAD_V3_clean                                                     ECG lead V3
# MDC_ECG_LEAD_V4_clean                                                     ECG lead V4
# MDC_ECG_LEAD_V5_clean                                                     ECG lead V5
# MDC_ECG_LEAD_V6_clean                                                     ECG lead V6
# raw_ecg_time_series                                    Raw ECG times series file path
# processed_ecg_time_series                        Processed ECG times series file path
# raw_ecg_time_series_wide                 Raw ECG times series (wide format) file path
# processed_ecg_time_series_wide      Processed ECG times series (wide format) file ...
# hr_bpm                                                                     Heart rate
# p_ms                                                                 P wave duration
# pr_ms                                                                     PR interval
# qrs_ms                                                                   QRS duration
# qt_ms                                                                     QT interval
# qtc_ms                                                                   QTc interval
# conclusion                                           ECG machine generated conclusion
# p_axis                                                                         P axis
# t_axis                                                                         T axis
# qrs_axis                                                                     QRS axis
# r_r_ms                                                                    RR interval
# j_mv_aVF                                               Amplitude of J wave (aVF lead)
# j_mv_aVL                                               Amplitude of J wave (aVL lead)
# j_mv_aVR                                               Amplitude of J wave (aVR lead)
# j_mv_I                                                   Amplitude of J wave (I lead)
# j_mv_II                                                 Amplitude of J wave (II lead)
# j_mv_III                                               Amplitude of J wave (III lead)
# j_mv_V1                                                 Amplitude of J wave (V1 lead)
# j_mv_V2                                                 Amplitude of J wave (V2 lead)
# j_mv_V3                                                 Amplitude of J wave (V3 lead)
# j_mv_V4                                                 Amplitude of J wave (V4 lead)
# j_mv_V5                                                 Amplitude of J wave (V5 lead)
# j_mv_V6                                                 Amplitude of J wave (V6 lead)
# p_mv_aVF                                               Amplitude of P wave (aVF lead)
# p_mv_aVL                                               Amplitude of P wave (aVL lead)
# p_mv_I                                                   Amplitude of P wave (I lead)
# p_mv_II                                                 Amplitude of P wave (II lead)
# p_mv_III                                               Amplitude of P wave (III lead)
# p_mv_V1                                                 Amplitude of P wave (V1 lead)
# p_mv_V2                                                 Amplitude of P wave (V2 lead)
# p_mv_V3                                                 Amplitude of P wave (V3 lead)
# p_mv_V4                                                 Amplitude of P wave (V4 lead)
# p_mv_V5                                                 Amplitude of P wave (V5 lead)
# p_mv_V6                                                 Amplitude of P wave (V6 lead)
# r_ms_aVF                                                   R wave duration (aVF lead)
# r_ms_aVL                                                   R wave duration (aVL lead)
# r_ms_aVR                                                   R wave duration (aVR lead)
# r_ms_I                                                       R wave duration (I lead)
# r_ms_II                                                     R wave duration (II lead)
# r_ms_III                                                   R wave duration (III lead)
# r_ms_V1                                                     R wave duration (V1 lead)
# r_ms_V2                                                     R wave duration (V2 lead)
# r_ms_V3                                                     R wave duration (V3 lead)
# r_ms_V4                                                     R wave duration (V4 lead)
# r_ms_V5                                                     R wave duration (V5 lead)
# r_ms_V6                                                     R wave duration (V6 lead)
# r_mv_aVF                                               Amplitude of R wave (aVF lead)
# r_mv_aVL                                               Amplitude of R wave (aVL lead)
# r_mv_aVR                                               Amplitude of R wave (aVR lead)
# r_mv_I                                                   Amplitude of R wave (I lead)
# r_mv_II                                                 Amplitude of R wave (II lead)
# r_mv_III                                               Amplitude of R wave (III lead)
# r_mv_V1                                                 Amplitude of R wave (V1 lead)
# r_mv_V2                                                 Amplitude of R wave (V2 lead)
# r_mv_V3                                                 Amplitude of R wave (V3 lead)
# r_mv_V4                                                 Amplitude of R wave (V4 lead)
# r_mv_V5                                                 Amplitude of R wave (V5 lead)
# r_mv_V6                                                 Amplitude of R wave (V6 lead)
# s_mv_aVF                                               Amplitude of S wave (aVF lead)
# s_mv_aVL                                               Amplitude of S wave (aVL lead)
# s_mv_aVR                                               Amplitude of S wave (aVR lead)
# s_mv_I                                                   Amplitude of S wave (I lead)
# s_mv_II                                                 Amplitude of S wave (II lead)
# s_mv_III                                               Amplitude of S wave (III lead)
# s_mv_V1                                                 Amplitude of S wave (V1 lead)
# s_mv_V2                                                 Amplitude of S wave (V2 lead)
# s_mv_V3                                                 Amplitude of S wave (V3 lead)
# s_mv_V4                                                 Amplitude of S wave (V4 lead)
# s_mv_V5                                                 Amplitude of S wave (V5 lead)
# s_mv_V6                                                 Amplitude of S wave (V6 lead)
# st_mv_aVF                                                     ST elevation (aVF lead)
# st_mv_aVL                                                     ST elevation (aVL lead)
# st_mv_aVR                                                     ST elevation (aVR lead)
# st_mv_I                                                         ST elevation (I lead)
# st_mv_II                                                       ST elevation (II lead)
# st_mv_III                                                     ST elevation (III lead)
# st_mv_V1                                                       ST elevation (V1 lead)
# st_mv_V2                                                       ST elevation (V2 lead)
# st_mv_V3                                                       ST elevation (V3 lead)
# st_mv_V4                                                       ST elevation (V4 lead)
# st_mv_V5                                                       ST elevation (V5 lead)
# st_mv_V6                                                       ST elevation (V6 lead)
# t_mv_aVF                                               Amplitude of T wave (aVF lead)
# t_mv_aVL                                               Amplitude of T wave (aVL lead)
# t_mv_aVR                                               Amplitude of T wave (aVR lead)
# t_mv_I                                                   Amplitude of T wave (I lead)
# t_mv_II                                                 Amplitude of T wave (II lead)
# t_mv_III                                               Amplitude of T wave (III lead)
# t_mv_V1                                                 Amplitude of T wave (V1 lead)
# t_mv_V2                                                 Amplitude of T wave (V2 lead)
# t_mv_V3                                                 Amplitude of T wave (V3 lead)
# t_mv_V4                                                 Amplitude of T wave (V4 lead)
# t_mv_V5                                                 Amplitude of T wave (V5 lead)
# t_mv_V6                                                 Amplitude of T wave (V6 lead)
# non_confirmed_diagnosis                               ECG machine generated diagnosis
# qrs                                                                   QRS information
# st_t                                                             ST segment diagnosis
# MDC_ECG_LEAD_I__stationary_check                Stationarity check for specified lead
# MDC_ECG_LEAD_II__stationary_check               Stationarity check for specified lead
# MDC_ECG_LEAD_III__stationary_check              Stationarity check for specified lead
# MDC_ECG_LEAD_aVR__stationary_check              Stationarity check for specified lead
# MDC_ECG_LEAD_aVL__stationary_check              Stationarity check for specified lead
# MDC_ECG_LEAD_aVF__stationary_check              Stationarity check for specified lead
# MDC_ECG_LEAD_V1__stationary_check               Stationarity check for specified lead
# MDC_ECG_LEAD_V2__stationary_check               Stationarity check for specified lead
# MDC_ECG_LEAD_V3__stationary_check               Stationarity check for specified lead
# MDC_ECG_LEAD_V4__stationary_check               Stationarity check for specified lead
# MDC_ECG_LEAD_V5__stationary_check               Stationarity check for specified lead
# MDC_ECG_LEAD_V6__heart_rate_check                 Heart rate check for specified lead
# MDC_ECG_LEAD_I__heart_rate_check                  Heart rate check for specified lead
# MDC_ECG_LEAD_II__heart_rate_check                 Heart rate check for specified lead
# MDC_ECG_LEAD_III__heart_rate_check                Heart rate check for specified lead
# MDC_ECG_LEAD_aVR__heart_rate_check                Heart rate check for specified lead
# MDC_ECG_LEAD_aVL__heart_rate_check                Heart rate check for specified lead
# MDC_ECG_LEAD_aVF__heart_rate_check                Heart rate check for specified lead
# MDC_ECG_LEAD_V1__heart_rate_check                 Heart rate check for specified lead
# MDC_ECG_LEAD_V2__heart_rate_check                 Heart rate check for specified lead
# MDC_ECG_LEAD_V3__heart_rate_check                 Heart rate check for specified lead
# MDC_ECG_LEAD_V4__heart_rate_check                 Heart rate check for specified lead
# MDC_ECG_LEAD_V5__heart_rate_check                 Heart rate check for specified lead
# MDC_ECG_LEAD_V6__heart_rate_check                 Heart rate check for specified lead
# MDC_ECG_LEAD_I__SNR_check                                SNR check for specified lead
# MDC_ECG_LEAD_II__SNR_check                               SNR check for specified lead
# MDC_ECG_LEAD_III__SNR_check                              SNR check for specified lead
# MDC_ECG_LEAD_aVR__SNR_check                              SNR check for specified lead
# MDC_ECG_LEAD_aVL__SNR_check                              SNR check for specified lead
# MDC_ECG_LEAD_aVF__SNR_check                              SNR check for specified lead
# MDC_ECG_LEAD_V1__SNR_check                               SNR check for specified lead
# MDC_ECG_LEAD_V2__SNR_check                               SNR check for specified lead
# MDC_ECG_LEAD_V3__SNR_check                               SNR check for specified lead
# MDC_ECG_LEAD_V4__SNR_check                               SNR check for specified lead
# MDC_ECG_LEAD_V5__SNR_check                               SNR check for specified lead
# MDC_ECG_LEAD_V6__SNR_check                               SNR check for specified lead
# MDC_ECG_LEAD_I__SNR                          Signal to noise ratio for specified lead
# MDC_ECG_LEAD_II__SNR                         Signal to noise ratio for specified lead
# MDC_ECG_LEAD_III__SNR                        Signal to noise ratio for specified lead
# MDC_ECG_LEAD_aVR__SNR                        Signal to noise ratio for specified lead
# MDC_ECG_LEAD_aVL__SNR                        Signal to noise ratio for specified lead
# MDC_ECG_LEAD_aVF__SNR                        Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V1__SNR                         Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V2__SNR                         Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V3__SNR                         Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V4__SNR                         Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V5__SNR                         Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V6__SNR                         Signal to noise ratio for specified lead
# MDC_ECG_LEAD_I__ecg_quality                 Neurokit quality score for specified lead
# MDC_ECG_LEAD_II__ecg_quality                Neurokit quality score for specified lead
# MDC_ECG_LEAD_III__ecg_quality               Neurokit quality score for specified lead
# MDC_ECG_LEAD_aVR__ecg_quality               Neurokit quality score for specified lead
# MDC_ECG_LEAD_aVL__ecg_quality               Neurokit quality score for specified lead
# MDC_ECG_LEAD_aVF__ecg_quality               Neurokit quality score for specified lead
# MDC_ECG_LEAD_V1__ecg_quality                Neurokit quality score for specified lead
# MDC_ECG_LEAD_V2__ecg_quality                Neurokit quality score for specified lead
# MDC_ECG_LEAD_V3__ecg_quality                Neurokit quality score for specified lead
# MDC_ECG_LEAD_V4__ecg_quality                Neurokit quality score for specified lead
# MDC_ECG_LEAD_V5__ecg_quality                Neurokit quality score for specified lead
# MDC_ECG_LEAD_V6__ecg_quality                Neurokit quality score for specified lead
#
#                                                                    description_string  \
# tabular_field_name
# collection_date                                          Collection date (YYYY-MM-DD)
# timezone                                               Timezone for timestamp columns
# collection_timestamp                                             Collection timestamp
# MDC_ECG_LEAD_I                                     Raw ECG signal for specificed lead
# MDC_ECG_LEAD_II                                    Raw ECG signal for specificed lead
# MDC_ECG_LEAD_III                                   Raw ECG signal for specificed lead
# MDC_ECG_LEAD_aVR                                   Raw ECG signal for specificed lead
# MDC_ECG_LEAD_aVL                                   Raw ECG signal for specificed lead
# MDC_ECG_LEAD_aVF                                   Raw ECG signal for specificed lead
# MDC_ECG_LEAD_V1                                    Raw ECG signal for specificed lead
# MDC_ECG_LEAD_V2                                    Raw ECG signal for specificed lead
# MDC_ECG_LEAD_V3                                    Raw ECG signal for specificed lead
# MDC_ECG_LEAD_V4                                    Raw ECG signal for specificed lead
# MDC_ECG_LEAD_V5                                    Raw ECG signal for specificed lead
# MDC_ECG_LEAD_V6                                    Raw ECG signal for specificed lead
# MDC_ECG_LEAD_I_clean                              Clean ECG signal for specified lead
# MDC_ECG_LEAD_II_clean                             Clean ECG signal for specified lead
# MDC_ECG_LEAD_III_clean                            Clean ECG signal for specified lead
# MDC_ECG_LEAD_aVR_clean                            Clean ECG signal for specified lead
# MDC_ECG_LEAD_aVL_clean                            Clean ECG signal for specified lead
# MDC_ECG_LEAD_aVF_clean                            Clean ECG signal for specified lead
# MDC_ECG_LEAD_V1_clean                             Clean ECG signal for specified lead
# MDC_ECG_LEAD_V2_clean                             Clean ECG signal for specified lead
# MDC_ECG_LEAD_V3_clean                             Clean ECG signal for specified lead
# MDC_ECG_LEAD_V4_clean                             Clean ECG signal for specified lead
# MDC_ECG_LEAD_V5_clean                             Clean ECG signal for specified lead
# MDC_ECG_LEAD_V6_clean                             Clean ECG signal for specified lead
# raw_ecg_time_series                               S3 reference to raw ECG time series
# processed_ecg_time_series                   S3 reference to processed ECG time series
# raw_ecg_time_series_wide              S3 reference to raw ECG time series wide format
# processed_ecg_time_series_wide      S3 reference to processed ECG time series wide...
# hr_bpm                                                                     Heart rate
# p_ms                                                                 P wave duration
# pr_ms                                                                     PR interval
# qrs_ms                                                                   QRS duration
# qt_ms                                                                     QT interval
# qtc_ms                                                                   QTc interval
# conclusion                                           ECG machine generated conclusion
# p_axis                                                                         P axis
# t_axis                                                                         T axis
# qrs_axis                                                                     QRS axis
# r_r_ms                                                                    RR interval
# j_mv_aVF                                               Amplitude of J wave (aVF lead)
# j_mv_aVL                                               Amplitude of J wave (aVL lead)
# j_mv_aVR                                               Amplitude of J wave (aVR lead)
# j_mv_I                                                   Amplitude of J wave (I lead)
# j_mv_II                                                 Amplitude of J wave (II lead)
# j_mv_III                                               Amplitude of J wave (III lead)
# j_mv_V1                                                 Amplitude of J wave (V1 lead)
# j_mv_V2                                                 Amplitude of J wave (V2 lead)
# j_mv_V3                                                 Amplitude of J wave (V3 lead)
# j_mv_V4                                                 Amplitude of J wave (V4 lead)
# j_mv_V5                                                 Amplitude of J wave (V5 lead)
# j_mv_V6                                                 Amplitude of J wave (V6 lead)
# p_mv_aVF                                               Amplitude of P wave (aVF lead)
# p_mv_aVL                                               Amplitude of P wave (aVL lead)
# p_mv_I                                                   Amplitude of P wave (I lead)
# p_mv_II                                                 Amplitude of P wave (II lead)
# p_mv_III                                               Amplitude of P wave (III lead)
# p_mv_V1                                                 Amplitude of P wave (V1 lead)
# p_mv_V2                                                 Amplitude of P wave (V2 lead)
# p_mv_V3                                                 Amplitude of P wave (V3 lead)
# p_mv_V4                                                 Amplitude of P wave (V4 lead)
# p_mv_V5                                                 Amplitude of P wave (V5 lead)
# p_mv_V6                                                 Amplitude of P wave (V6 lead)
# r_ms_aVF                                                   R wave duration (aVF lead)
# r_ms_aVL                                                   R wave duration (aVL lead)
# r_ms_aVR                                                   R wave duration (aVR lead)
# r_ms_I                                                       R wave duration (I lead)
# r_ms_II                                                     R wave duration (II lead)
# r_ms_III                                                   R wave duration (III lead)
# r_ms_V1                                                     R wave duration (V1 lead)
# r_ms_V2                                                     R wave duration (V2 lead)
# r_ms_V3                                                     R wave duration (V3 lead)
# r_ms_V4                                                     R wave duration (V4 lead)
# r_ms_V5                                                     R wave duration (V5 lead)
# r_ms_V6                                                     R wave duration (V6 lead)
# r_mv_aVF                                               Amplitude of R wave (aVF lead)
# r_mv_aVL                                               Amplitude of R wave (aVL lead)
# r_mv_aVR                                               Amplitude of R wave (aVR lead)
# r_mv_I                                                   Amplitude of R wave (I lead)
# r_mv_II                                                 Amplitude of R wave (II lead)
# r_mv_III                                               Amplitude of R wave (III lead)
# r_mv_V1                                                 Amplitude of R wave (V1 lead)
# r_mv_V2                                                 Amplitude of R wave (V2 lead)
# r_mv_V3                                                 Amplitude of R wave (V3 lead)
# r_mv_V4                                                 Amplitude of R wave (V4 lead)
# r_mv_V5                                                 Amplitude of R wave (V5 lead)
# r_mv_V6                                                 Amplitude of R wave (V6 lead)
# s_mv_aVF                                               Amplitude of S wave (aVF lead)
# s_mv_aVL                                               Amplitude of S wave (aVL lead)
# s_mv_aVR                                               Amplitude of S wave (aVR lead)
# s_mv_I                                                   Amplitude of S wave (I lead)
# s_mv_II                                                 Amplitude of S wave (II lead)
# s_mv_III                                               Amplitude of S wave (III lead)
# s_mv_V1                                                 Amplitude of S wave (V1 lead)
# s_mv_V2                                                 Amplitude of S wave (V2 lead)
# s_mv_V3                                                 Amplitude of S wave (V3 lead)
# s_mv_V4                                                 Amplitude of S wave (V4 lead)
# s_mv_V5                                                 Amplitude of S wave (V5 lead)
# s_mv_V6                                                 Amplitude of S wave (V6 lead)
# st_mv_aVF                                                     ST elevation (aVF lead)
# st_mv_aVL                                                     ST elevation (aVL lead)
# st_mv_aVR                                                     ST elevation (aVR lead)
# st_mv_I                                                         ST elevation (I lead)
# st_mv_II                                                       ST elevation (II lead)
# st_mv_III                                                     ST elevation (III lead)
# st_mv_V1                                                       ST elevation (V1 lead)
# st_mv_V2                                                       ST elevation (V2 lead)
# st_mv_V3                                                       ST elevation (V3 lead)
# st_mv_V4                                                       ST elevation (V4 lead)
# st_mv_V5                                                       ST elevation (V5 lead)
# st_mv_V6                                                       ST elevation (V6 lead)
# t_mv_aVF                                               Amplitude of T wave (aVF lead)
# t_mv_aVL                                               Amplitude of T wave (aVL lead)
# t_mv_aVR                                               Amplitude of T wave (aVR lead)
# t_mv_I                                                   Amplitude of T wave (I lead)
# t_mv_II                                                 Amplitude of T wave (II lead)
# t_mv_III                                               Amplitude of T wave (III lead)
# t_mv_V1                                                 Amplitude of T wave (V1 lead)
# t_mv_V2                                                 Amplitude of T wave (V2 lead)
# t_mv_V3                                                 Amplitude of T wave (V3 lead)
# t_mv_V4                                                 Amplitude of T wave (V4 lead)
# t_mv_V5                                                 Amplitude of T wave (V5 lead)
# t_mv_V6                                                 Amplitude of T wave (V6 lead)
# non_confirmed_diagnosis                               ECG machine generated diagnosis
# qrs                                                                   QRS information
# st_t                                                             ST segment diagnosis
# MDC_ECG_LEAD_I__stationary_check                Stationarity check for specified lead
# MDC_ECG_LEAD_II__stationary_check               Stationarity check for specified lead
# MDC_ECG_LEAD_III__stationary_check              Stationarity check for specified lead
# MDC_ECG_LEAD_aVR__stationary_check              Stationarity check for specified lead
# MDC_ECG_LEAD_aVL__stationary_check              Stationarity check for specified lead
# MDC_ECG_LEAD_aVF__stationary_check              Stationarity check for specified lead
# MDC_ECG_LEAD_V1__stationary_check               Stationarity check for specified lead
# MDC_ECG_LEAD_V2__stationary_check               Stationarity check for specified lead
# MDC_ECG_LEAD_V3__stationary_check               Stationarity check for specified lead
# MDC_ECG_LEAD_V4__stationary_check               Stationarity check for specified lead
# MDC_ECG_LEAD_V5__stationary_check               Stationarity check for specified lead
# MDC_ECG_LEAD_V6__heart_rate_check                 Heart rate check for specified lead
# MDC_ECG_LEAD_I__heart_rate_check                  Heart rate check for specified lead
# MDC_ECG_LEAD_II__heart_rate_check                 Heart rate check for specified lead
# MDC_ECG_LEAD_III__heart_rate_check                Heart rate check for specified lead
# MDC_ECG_LEAD_aVR__heart_rate_check                Heart rate check for specified lead
# MDC_ECG_LEAD_aVL__heart_rate_check                Heart rate check for specified lead
# MDC_ECG_LEAD_aVF__heart_rate_check                Heart rate check for specified lead
# MDC_ECG_LEAD_V1__heart_rate_check                 Heart rate check for specified lead
# MDC_ECG_LEAD_V2__heart_rate_check                 Heart rate check for specified lead
# MDC_ECG_LEAD_V3__heart_rate_check                 Heart rate check for specified lead
# MDC_ECG_LEAD_V4__heart_rate_check                 Heart rate check for specified lead
# MDC_ECG_LEAD_V5__heart_rate_check                 Heart rate check for specified lead
# MDC_ECG_LEAD_V6__heart_rate_check                 Heart rate check for specified lead
# MDC_ECG_LEAD_I__SNR_check                                SNR check for specified lead
# MDC_ECG_LEAD_II__SNR_check                               SNR check for specified lead
# MDC_ECG_LEAD_III__SNR_check                              SNR check for specified lead
# MDC_ECG_LEAD_aVR__SNR_check                              SNR check for specified lead
# MDC_ECG_LEAD_aVL__SNR_check                              SNR check for specified lead
# MDC_ECG_LEAD_aVF__SNR_check                              SNR check for specified lead
# MDC_ECG_LEAD_V1__SNR_check                               SNR check for specified lead
# MDC_ECG_LEAD_V2__SNR_check                               SNR check for specified lead
# MDC_ECG_LEAD_V3__SNR_check                               SNR check for specified lead
# MDC_ECG_LEAD_V4__SNR_check                               SNR check for specified lead
# MDC_ECG_LEAD_V5__SNR_check                               SNR check for specified lead
# MDC_ECG_LEAD_V6__SNR_check                               SNR check for specified lead
# MDC_ECG_LEAD_I__SNR                          Signal to noise ratio for specified lead
# MDC_ECG_LEAD_II__SNR                         Signal to noise ratio for specified lead
# MDC_ECG_LEAD_III__SNR                        Signal to noise ratio for specified lead
# MDC_ECG_LEAD_aVR__SNR                        Signal to noise ratio for specified lead
# MDC_ECG_LEAD_aVL__SNR                        Signal to noise ratio for specified lead
# MDC_ECG_LEAD_aVF__SNR                        Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V1__SNR                         Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V2__SNR                         Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V3__SNR                         Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V4__SNR                         Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V5__SNR                         Signal to noise ratio for specified lead
# MDC_ECG_LEAD_V6__SNR                         Signal to noise ratio for specified lead
# MDC_ECG_LEAD_I__ecg_quality                 Neurokit quality score for specified lead
# MDC_ECG_LEAD_II__ecg_quality                Neurokit quality score for specified lead
# MDC_ECG_LEAD_III__ecg_quality               Neurokit quality score for specified lead
# MDC_ECG_LEAD_aVR__ecg_quality               Neurokit quality score for specified lead
# MDC_ECG_LEAD_aVL__ecg_quality               Neurokit quality score for specified lead
# MDC_ECG_LEAD_aVF__ecg_quality               Neurokit quality score for specified lead
# MDC_ECG_LEAD_V1__ecg_quality                Neurokit quality score for specified lead
# MDC_ECG_LEAD_V2__ecg_quality                Neurokit quality score for specified lead
# MDC_ECG_LEAD_V3__ecg_quality                Neurokit quality score for specified lead
# MDC_ECG_LEAD_V4__ecg_quality                Neurokit quality score for specified lead
# MDC_ECG_LEAD_V5__ecg_quality                Neurokit quality score for specified lead
# MDC_ECG_LEAD_V6__ecg_quality                Neurokit quality score for specified lead
#
#                                      relative_location             value_type  \
# tabular_field_name
# collection_date                        ecg/ecg.parquet                   Date
# timezone                               ecg/ecg.parquet   Categorical (single)
# collection_timestamp                   ecg/ecg.parquet   Categorical (single)
# MDC_ECG_LEAD_I                                     NaN  Time series (metrics)
# MDC_ECG_LEAD_II                                    NaN  Time series (metrics)
# MDC_ECG_LEAD_III                                   NaN  Time series (metrics)
# MDC_ECG_LEAD_aVR                                   NaN  Time series (metrics)
# MDC_ECG_LEAD_aVL                                   NaN  Time series (metrics)
# MDC_ECG_LEAD_aVF                                   NaN  Time series (metrics)
# MDC_ECG_LEAD_V1                                    NaN  Time series (metrics)
# MDC_ECG_LEAD_V2                                    NaN  Time series (metrics)
# MDC_ECG_LEAD_V3                                    NaN  Time series (metrics)
# MDC_ECG_LEAD_V4                                    NaN  Time series (metrics)
# MDC_ECG_LEAD_V5                                    NaN  Time series (metrics)
# MDC_ECG_LEAD_V6                                    NaN  Time series (metrics)
# MDC_ECG_LEAD_I_clean                               NaN  Time series (metrics)
# MDC_ECG_LEAD_II_clean                              NaN  Time series (metrics)
# MDC_ECG_LEAD_III_clean                             NaN  Time series (metrics)
# MDC_ECG_LEAD_aVR_clean                             NaN  Time series (metrics)
# MDC_ECG_LEAD_aVL_clean                             NaN  Time series (metrics)
# MDC_ECG_LEAD_aVF_clean                             NaN  Time series (metrics)
# MDC_ECG_LEAD_V1_clean                              NaN  Time series (metrics)
# MDC_ECG_LEAD_V2_clean                              NaN  Time series (metrics)
# MDC_ECG_LEAD_V3_clean                              NaN  Time series (metrics)
# MDC_ECG_LEAD_V4_clean                              NaN  Time series (metrics)
# MDC_ECG_LEAD_V5_clean                              NaN  Time series (metrics)
# MDC_ECG_LEAD_V6_clean                              NaN  Time series (metrics)
# raw_ecg_time_series                    ecg/ecg.parquet                  Text
# processed_ecg_time_series              ecg/ecg.parquet                  Text
# raw_ecg_time_series_wide               ecg/ecg.parquet                  Text
# processed_ecg_time_series_wide         ecg/ecg.parquet                  Text
# hr_bpm                                 ecg/ecg.parquet                Integer
# p_ms                                   ecg/ecg.parquet                Integer
# pr_ms                                  ecg/ecg.parquet                Integer
# qrs_ms                                 ecg/ecg.parquet                Integer
# qt_ms                                  ecg/ecg.parquet                Integer
# qtc_ms                                 ecg/ecg.parquet                Integer
# conclusion                             ecg/ecg.parquet   Categorical (single)
# p_axis                                 ecg/ecg.parquet                Integer
# t_axis                                 ecg/ecg.parquet                Integer
# qrs_axis                               ecg/ecg.parquet                Integer
# r_r_ms                                 ecg/ecg.parquet                Integer
# j_mv_aVF                               ecg/ecg.parquet             Continuous
# j_mv_aVL                               ecg/ecg.parquet             Continuous
# j_mv_aVR                               ecg/ecg.parquet             Continuous
# j_mv_I                                 ecg/ecg.parquet             Continuous
# j_mv_II                                ecg/ecg.parquet             Continuous
# j_mv_III                               ecg/ecg.parquet             Continuous
# j_mv_V1                                ecg/ecg.parquet             Continuous
# j_mv_V2                                ecg/ecg.parquet             Continuous
# j_mv_V3                                ecg/ecg.parquet             Continuous
# j_mv_V4                                ecg/ecg.parquet             Continuous
# j_mv_V5                                ecg/ecg.parquet             Continuous
# j_mv_V6                                ecg/ecg.parquet             Continuous
# p_mv_aVF                               ecg/ecg.parquet             Continuous
# p_mv_aVL                               ecg/ecg.parquet             Continuous
# p_mv_I                                 ecg/ecg.parquet             Continuous
# p_mv_II                                ecg/ecg.parquet             Continuous
# p_mv_III                               ecg/ecg.parquet             Continuous
# p_mv_V1                                ecg/ecg.parquet             Continuous
# p_mv_V2                                ecg/ecg.parquet             Continuous
# p_mv_V3                                ecg/ecg.parquet             Continuous
# p_mv_V4                                ecg/ecg.parquet             Continuous
# p_mv_V5                                ecg/ecg.parquet             Continuous
# p_mv_V6                                ecg/ecg.parquet             Continuous
# r_ms_aVF                               ecg/ecg.parquet                Integer
# r_ms_aVL                               ecg/ecg.parquet                Integer
# r_ms_aVR                               ecg/ecg.parquet                Integer
# r_ms_I                                 ecg/ecg.parquet                Integer
# r_ms_II                                ecg/ecg.parquet                Integer
# r_ms_III                               ecg/ecg.parquet                Integer
# r_ms_V1                                ecg/ecg.parquet                Integer
# r_ms_V2                                ecg/ecg.parquet                Integer
# r_ms_V3                                ecg/ecg.parquet                Integer
# r_ms_V4                                ecg/ecg.parquet                Integer
# r_ms_V5                                ecg/ecg.parquet                Integer
# r_ms_V6                                ecg/ecg.parquet                Integer
# r_mv_aVF                               ecg/ecg.parquet             Continuous
# r_mv_aVL                               ecg/ecg.parquet             Continuous
# r_mv_aVR                               ecg/ecg.parquet             Continuous
# r_mv_I                                 ecg/ecg.parquet             Continuous
# r_mv_II                                ecg/ecg.parquet             Continuous
# r_mv_III                               ecg/ecg.parquet             Continuous
# r_mv_V1                                ecg/ecg.parquet             Continuous
# r_mv_V2                                ecg/ecg.parquet             Continuous
# r_mv_V3                                ecg/ecg.parquet             Continuous
# r_mv_V4                                ecg/ecg.parquet             Continuous
# r_mv_V5                                ecg/ecg.parquet             Continuous
# r_mv_V6                                ecg/ecg.parquet             Continuous
# s_mv_aVF                               ecg/ecg.parquet             Continuous
# s_mv_aVL                               ecg/ecg.parquet             Continuous
# s_mv_aVR                               ecg/ecg.parquet             Continuous
# s_mv_I                                 ecg/ecg.parquet             Continuous
# s_mv_II                                ecg/ecg.parquet             Continuous
# s_mv_III                               ecg/ecg.parquet             Continuous
# s_mv_V1                                ecg/ecg.parquet             Continuous
# s_mv_V2                                ecg/ecg.parquet             Continuous
# s_mv_V3                                ecg/ecg.parquet             Continuous
# s_mv_V4                                ecg/ecg.parquet             Continuous
# s_mv_V5                                ecg/ecg.parquet             Continuous
# s_mv_V6                                ecg/ecg.parquet             Continuous
# st_mv_aVF                              ecg/ecg.parquet             Continuous
# st_mv_aVL                              ecg/ecg.parquet             Continuous
# st_mv_aVR                              ecg/ecg.parquet             Continuous
# st_mv_I                                ecg/ecg.parquet             Continuous
# st_mv_II                               ecg/ecg.parquet             Continuous
# st_mv_III                              ecg/ecg.parquet             Continuous
# st_mv_V1                               ecg/ecg.parquet             Continuous
# st_mv_V2                               ecg/ecg.parquet             Continuous
# st_mv_V3                               ecg/ecg.parquet             Continuous
# st_mv_V4                               ecg/ecg.parquet             Continuous
# st_mv_V5                               ecg/ecg.parquet             Continuous
# st_mv_V6                               ecg/ecg.parquet             Continuous
# t_mv_aVF                               ecg/ecg.parquet             Continuous
# t_mv_aVL                               ecg/ecg.parquet             Continuous
# t_mv_aVR                               ecg/ecg.parquet             Continuous
# t_mv_I                                 ecg/ecg.parquet             Continuous
# t_mv_II                                ecg/ecg.parquet             Continuous
# t_mv_III                               ecg/ecg.parquet             Continuous
# t_mv_V1                                ecg/ecg.parquet             Continuous
# t_mv_V2                                ecg/ecg.parquet             Continuous
# t_mv_V3                                ecg/ecg.parquet             Continuous
# t_mv_V4                                ecg/ecg.parquet             Continuous
# t_mv_V5                                ecg/ecg.parquet             Continuous
# t_mv_V6                                ecg/ecg.parquet             Continuous
# non_confirmed_diagnosis                ecg/ecg.parquet   Categorical (single)
# qrs                                    ecg/ecg.parquet   Categorical (single)
# st_t                                   ecg/ecg.parquet   Categorical (single)
# MDC_ECG_LEAD_I__stationary_check    ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_II__stationary_check   ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_III__stationary_check  ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_aVR__stationary_check  ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_aVL__stationary_check  ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_aVF__stationary_check  ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V1__stationary_check   ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V2__stationary_check   ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V3__stationary_check   ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V4__stationary_check   ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V5__stationary_check   ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V6__heart_rate_check   ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_I__heart_rate_check    ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_II__heart_rate_check   ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_III__heart_rate_check  ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_aVR__heart_rate_check  ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_aVL__heart_rate_check  ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_aVF__heart_rate_check  ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V1__heart_rate_check   ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V2__heart_rate_check   ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V3__heart_rate_check   ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V4__heart_rate_check   ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V5__heart_rate_check   ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V6__heart_rate_check   ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_I__SNR_check           ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_II__SNR_check          ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_III__SNR_check         ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_aVR__SNR_check         ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_aVL__SNR_check         ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_aVF__SNR_check         ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V1__SNR_check          ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V2__SNR_check          ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V3__SNR_check          ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V4__SNR_check          ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V5__SNR_check          ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V6__SNR_check          ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_I__SNR                 ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_II__SNR                ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_III__SNR               ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_aVR__SNR               ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_aVL__SNR               ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_aVF__SNR               ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V1__SNR                ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V2__SNR                ecg/ecg_qc.parquet             Continuous
# MDC_ECG_LEAD_V3__SNR                ecg/ecg_qc.parquet             Continuous
# ...
# MDC_ECG_LEAD_V1__stationary_check                            float
# MDC_ECG_LEAD_V2__stationary_check                            float
# MDC_ECG_LEAD_V3__stationary_check                            float
# MDC_ECG_LEAD_V4__stationary_check                            float
# MDC_ECG_LEAD_V5__stationary_check                            float
# MDC_ECG_LEAD_V6__heart_rate_check                            float
# MDC_ECG_LEAD_I__heart_rate_check                             float
# MDC_ECG_LEAD_II__heart_rate_check                            float
# MDC_ECG_LEAD_III__heart_rate_check                           float
# MDC_ECG_LEAD_aVR__heart_rate_check                           float
# MDC_ECG_LEAD_aVL__heart_rate_check                           float
# MDC_ECG_LEAD_aVF__heart_rate_check                           float
# MDC_ECG_LEAD_V1__heart_rate_check                            float
# MDC_ECG_LEAD_V2__heart_rate_check                            float
# MDC_ECG_LEAD_V3__heart_rate_check                            float
# MDC_ECG_LEAD_V4__heart_rate_check                            float
# MDC_ECG_LEAD_V5__heart_rate_check                            float
# MDC_ECG_LEAD_V6__heart_rate_check                            float
# MDC_ECG_LEAD_I__SNR_check                                    float
# MDC_ECG_LEAD_II__SNR_check                                   float
# MDC_ECG_LEAD_III__SNR_check                                  float
# MDC_ECG_LEAD_aVR__SNR_check                                  float
# MDC_ECG_LEAD_aVL__SNR_check                                  float
# MDC_ECG_LEAD_aVF__SNR_check                                  float
# MDC_ECG_LEAD_V1__SNR_check                                   float
# MDC_ECG_LEAD_V2__SNR_check                                   float
# MDC_ECG_LEAD_V3__SNR_check                                   float
# MDC_ECG_LEAD_V4__SNR_check                                   float
# MDC_ECG_LEAD_V5__SNR_check                                   float
# MDC_ECG_LEAD_V6__SNR_check                                   float
# MDC_ECG_LEAD_I__SNR                                          float
# MDC_ECG_LEAD_II__SNR                                         float
# MDC_ECG_LEAD_III__SNR                                        float
# MDC_ECG_LEAD_aVR__SNR                                        float
# MDC_ECG_LEAD_aVL__SNR                                        float
# MDC_ECG_LEAD_aVF__SNR                                        float
# MDC_ECG_LEAD_V1__SNR                                         float
# MDC_ECG_LEAD_V2__SNR                                         float
# MDC_ECG_LEAD_V3__SNR                                         float
# MDC_ECG_LEAD_V4__SNR                                         float
# MDC_ECG_LEAD_V5__SNR                                         float
# MDC_ECG_LEAD_V6__SNR                                         float
# MDC_ECG_LEAD_I__ecg_quality                               category
# MDC_ECG_LEAD_II__ecg_quality                              category
# MDC_ECG_LEAD_III__ecg_quality                             category
# MDC_ECG_LEAD_aVR__ecg_quality                             category
# MDC_ECG_LEAD_aVL__ecg_quality                             category
# MDC_ECG_LEAD_aVF__ecg_quality                             category
# MDC_ECG_LEAD_V1__ecg_quality                              category
# MDC_ECG_LEAD_V2__ecg_quality                              category
# MDC_ECG_LEAD_V3__ecg_quality                              category
# MDC_ECG_LEAD_V4__ecg_quality                              category
# MDC_ECG_LEAD_V5__ecg_quality                              category
# MDC_ECG_LEAD_V6__ecg_quality                              category
#
#                                              parent_dataframe
# tabular_field_name
# collection_date                                           NaN
# timezone                                                  NaN
# collection_timestamp                                      NaN
# MDC_ECG_LEAD_I                            raw_ecg_time_series
# MDC_ECG_LEAD_II                           raw_ecg_time_series
# MDC_ECG_LEAD_III                          raw_ecg_time_series
# MDC_ECG_LEAD_aVR                          raw_ecg_time_series
# MDC_ECG_LEAD_aVL                          raw_ecg_time_series
# MDC_ECG_LEAD_aVF                          raw_ecg_time_series
# MDC_ECG_LEAD_V1                           raw_ecg_time_series
# MDC_ECG_LEAD_V2                           raw_ecg_time_series
# MDC_ECG_LEAD_V3                           raw_ecg_time_series
# MDC_ECG_LEAD_V4                           raw_ecg_time_series
# MDC_ECG_LEAD_V5                           raw_ecg_time_series
# MDC_ECG_LEAD_V6                           raw_ecg_time_series
# MDC_ECG_LEAD_I_clean                processed_ecg_time_series
# MDC_ECG_LEAD_II_clean               processed_ecg_time_series
# MDC_ECG_LEAD_III_clean              processed_ecg_time_series
# MDC_ECG_LEAD_aVR_clean              processed_ecg_time_series
# MDC_ECG_LEAD_aVL_clean              processed_ecg_time_series
# MDC_ECG_LEAD_aVF_clean              processed_ecg_time_series
# MDC_ECG_LEAD_V1_clean               processed_ecg_time_series
# MDC_ECG_LEAD_V2_clean               processed_ecg_time_series
# MDC_ECG_LEAD_V3_clean               processed_ecg_time_series
# MDC_ECG_LEAD_V4_clean               processed_ecg_time_series
# MDC_ECG_LEAD_V5_clean               processed_ecg_time_series
# MDC_ECG_LEAD_V6_clean               processed_ecg_time_series
# raw_ecg_time_series                                       NaN
# processed_ecg_time_series                                 NaN
# raw_ecg_time_series_wide                                  NaN
# processed_ecg_time_series_wide                            NaN
# hr_bpm                                                    NaN
# p_ms                                                      NaN
# pr_ms                                                     NaN
# qrs_ms                                                    NaN
# qt_ms                                                     NaN
# qtc_ms                                                    NaN
# conclusion                                                NaN
# p_axis                                                    NaN
# t_axis                                                    NaN
# qrs_axis                                                  NaN
# r_r_ms                                                    NaN
# j_mv_aVF                                                  NaN
# j_mv_aVL                                                  NaN
# j_mv_aVR                                                  NaN
# j_mv_I                                                    NaN
# j_mv_II                                                   NaN
# j_mv_III                                                  NaN
# j_mv_V1                                                   NaN
# j_mv_V2                                                   NaN
# j_mv_V3                                                   NaN
# j_mv_V4                                                   NaN
# j_mv_V5                                                   NaN
# j_mv_V6                                                   NaN
# p_mv_aVF                                                  NaN
# p_mv_aVL                                                  NaN
# p_mv_I                                                    NaN
# p_mv_II                                                   NaN
# p_mv_III                                                  NaN
# p_mv_V1                                                   NaN
# p_mv_V2                                                   NaN
# p_mv_V3                                                   NaN
# p_mv_V4                                                   NaN
# p_mv_V5                                                   NaN
# p_mv_V6                                                   NaN
# r_ms_aVF                                                  NaN
# r_ms_aVL                                                  NaN
# r_ms_aVR                                                  NaN
# r_ms_I                                                    NaN
# r_ms_II                                                   NaN
# r_ms_III                                                  NaN
# r_ms_V1                                                   NaN
# r_ms_V2                                                   NaN
# r_ms_V3                                                   NaN
# r_ms_V4                                                   NaN
# r_ms_V5                                                   NaN
# r_ms_V6                                                   NaN
# r_mv_aVF                                                  NaN
# r_mv_aVL                                                  NaN
# r_mv_aVR                                                  NaN
# r_mv_I                                                    NaN
# r_mv_II                                                   NaN
# r_mv_III                                                  NaN
# r_mv_V1                                                   NaN
# r_mv_V2                                                   NaN
# r_mv_V3                                                   NaN
# r_mv_V4                                                   NaN
# r_mv_V5                                                   NaN
# r_mv_V6                                                   NaN
# s_mv_aVF                                                  NaN
# s_mv_aVL                                                  NaN
# s_mv_aVR                                                  NaN
# s_mv_I                                                    NaN
# s_mv_II                                                   NaN
# s_mv_III                                                  NaN
# s_mv_V1                                                   NaN
# s_mv_V2                                                   NaN
# s_mv_V3                                                   NaN
# s_mv_V4                                                   NaN
# s_mv_V5                                                   NaN
# s_mv_V6                                                   NaN
# st_mv_aVF                                                 NaN
# st_mv_aVL                                                 NaN
# st_mv_aVR                                                 NaN
# st_mv_I                                                   NaN
# st_mv_II                                                  NaN
# st_mv_III                                                 NaN
# st_mv_V1                                                  NaN
# st_mv_V2                                                  NaN
# st_mv_V3                                                  NaN
# st_mv_V4                                                  NaN
# st_mv_V5                                                  NaN
# st_mv_V6                                                  NaN
# t_mv_aVF                                                  NaN
# t_mv_aVL                                                  NaN
# t_mv_aVR                                                  NaN
# t_mv_I                                                    NaN
# t_mv_II                                                   NaN
# t_mv_III                                                  NaN
# t_mv_V1                                                   NaN
# t_mv_V2                                                   NaN
# t_mv_V3                                                   NaN
# t_mv_V4                                                   NaN
# t_mv_V5                                                   NaN
# t_mv_V6                                                   NaN
# non_confirmed_diagnosis                                   NaN
# qrs                                                       NaN
# st_t                                                      NaN
# MDC_ECG_LEAD_I__stationary_check                          NaN
# MDC_ECG_LEAD_II__stationary_check                         NaN
# MDC_ECG_LEAD_III__stationary_check                        NaN
# MDC_ECG_LEAD_aVR__stationary_check                        NaN
# MDC_ECG_LEAD_aVL__stationary_check                        NaN
# MDC_ECG_LEAD_aVF__stationary_check                        NaN
# MDC_ECG_LEAD_V1__stationary_check                         NaN
# MDC_ECG_LEAD_V2__stationary_check                         NaN
# MDC_ECG_LEAD_V3__stationary_check                         NaN
# MDC_ECG_LEAD_V4__stationary_check                         NaN
# MDC_ECG_LEAD_V5__stationary_check                         NaN
# MDC_ECG_LEAD_V6__heart_rate_check                         NaN
# MDC_ECG_LEAD_I__heart_rate_check                          NaN
# MDC_ECG_LEAD_II__heart_rate_check                         NaN
# MDC_ECG_LEAD_III__heart_rate_check                        NaN
# MDC_ECG_LEAD_aVR__heart_rate_check                        NaN
# MDC_ECG_LEAD_aVL__heart_rate_check                        NaN
# MDC_ECG_LEAD_aVF__heart_rate_check                        NaN
# MDC_ECG_LEAD_V1__heart_rate_check                         NaN
# MDC_ECG_LEAD_V2__heart_rate_check                         NaN
# MDC_ECG_LEAD_V3__heart_rate_check                         NaN
# MDC_ECG_LEAD_V4__heart_rate_check                         NaN
# MDC_ECG_LEAD_V5__heart_rate_check                         NaN
# MDC_ECG_LEAD_V6__heart_rate_check                         NaN
# MDC_ECG_LEAD_I__SNR_check                                 NaN
# MDC_ECG_LEAD_II__SNR_check                                NaN
# MDC_ECG_LEAD_III__SNR_check                               NaN
# MDC_ECG_LEAD_aVR__SNR_check                               NaN
# MDC_ECG_LEAD_aVL__SNR_check                               NaN
# MDC_ECG_LEAD_aVF__SNR_check                               NaN
# MDC_ECG_LEAD_V1__SNR_check                                NaN
# MDC_ECG_LEAD_V2__SNR_check                                NaN
# MDC_ECG_LEAD_V3__SNR_check                                NaN
# MDC_ECG_LEAD_V4__SNR_check                                NaN
# MDC_ECG_LEAD_V5__SNR_check                                NaN
# MDC_ECG_LEAD_V6__SNR_check                                NaN
# MDC_ECG_LEAD_I__SNR                                       NaN
# MDC_ECG_LEAD_II__SNR                                      NaN
# MDC_ECG_LEAD_III__SNR                                     NaN
# MDC_ECG_LEAD_aVR__SNR                                     NaN
# MDC_ECG_LEAD_aVL__SNR                                     NaN
# MDC_ECG_LEAD_aVF__SNR                                     NaN
# MDC_ECG_LEAD_V1__SNR                                      NaN
# MDC_ECG_LEAD_V2__SNR                                      NaN
# MDC_ECG_LEAD_V3__SNR                                      NaN
# MDC_ECG_LEAD_V4__SNR                                      NaN
# MDC_ECG_LEAD_V5__SNR                                      NaN
# MDC_ECG_LEAD_V6__SNR                                      NaN
# MDC_ECG_LEAD_I__ecg_quality                               NaN
# MDC_ECG_LEAD_II__ecg_quality                              NaN
# MDC_ECG_LEAD_III__ecg_quality                             NaN
# MDC_ECG_LEAD_aVR__ecg_quality                             NaN
# MDC_ECG_LEAD_aVL__ecg_quality                             NaN
# MDC_ECG_LEAD_aVF__ecg_quality                             NaN
# MDC_ECG_LEAD_V1__ecg_quality                              NaN
# MDC_ECG_LEAD_V2__ecg_quality                              NaN
# MDC_ECG_LEAD_V3__ecg_quality                              NaN
# MDC_ECG_LEAD_V4__ecg_quality                              NaN
# MDC_ECG_LEAD_V5__ecg_quality                              NaN
# MDC_ECG_LEAD_V6__ecg_quality                              NaN
