# %% [raw]
# ---
# output-file: 018-medications.html
# title: 018-medications
# ---

# %% [markdown]
# # Medications
#
# The medication information collection in the Human Phenotype Project study is based on self reporting of medications usage via online and smartphone applications and collection by staff members by telephone or face-to-face interviews during follow-up.
#
# Self-report is when the participant reports the use of medication to the researcher.
# Having accurate and complete data on medication usage is essential to understanding the true impact of these medications on individuals' health.
#
# ### Data availability:
# During registration (sign up) to the study, participants are asked to report their regular medications online(autofill), selecting from a predefined drop-down list.
# The information is stored in 1 parquet file: `medications.parquet`

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('medications')
dl
# Out:
# DataLoader for medications with
# 12 fields
# 2 tables: ['medications', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                                 field_string  \
# tabular_field_name
# collection_timestamp         Collection time
# collection_date              Collection date
# timezone                            Timezone
# medication                   Medication name
# start_month                      Start month
# start_year                        Start year
# ahfs_code                          AHFS code
# atc_code                            ATC code
# medication_heb        Medication hebrew name
# medication_mapping        Medication mapping
#
#                                         description_string  \
# tabular_field_name
# collection_timestamp                       Collection time
# collection_date                            Collection date
# timezone                                          Timezone
# medication                                 Medication name
# start_month               Start month of medication taking
# start_year                 Start year of medication taking
# ahfs_code             AHFS code mapping to medication name
# atc_code               ATC code mapping to medication name
# medication_heb                      Medication hebrew name
# medication_mapping                    Mapping to ATC codes
#
#                                     relative_location  value_type  units  \
# tabular_field_name
# collection_timestamp  medications/medications.parquet         NaN    NaN
# collection_date       medications/medications.parquet         NaN    NaN
# timezone              medications/medications.parquet         NaN    NaN
# medication            medications/medications.parquet         NaN    NaN
# start_month           medications/medications.parquet         NaN    NaN
# start_year            medications/medications.parquet         NaN    NaN
# ahfs_code             medications/medications.parquet         NaN    NaN
# atc_code              medications/medications.parquet         NaN    NaN
# medication_heb        medications/medications.parquet         NaN    NaN
# medication_mapping    medications/medications.parquet         NaN    NaN
#
#                       sampling_rate item_type  array  cohorts  data_type  \
# tabular_field_name
# collection_timestamp            NaN      Data    NaN      NaN        NaN
# collection_date                 NaN      Data    NaN      NaN        NaN
# timezone                        NaN      Data    NaN      NaN        NaN
# medication                      NaN      Data    NaN      NaN        NaN
# start_month                     NaN      Data    NaN      NaN        NaN
# start_year                      NaN      Data    NaN      NaN        NaN
# ahfs_code                       NaN      Data    NaN      NaN        NaN
# atc_code                        NaN      Data    NaN      NaN        NaN
# medication_heb                  NaN      Data    NaN      NaN        NaN
# medication_mapping              NaN      Bulk    NaN      NaN        NaN
#
#                       debut                    pandas_dtype  parent_dataframe
# tabular_field_name
# collection_timestamp    NaN  datetime64[ns, Asia/Jerusalem]               NaN
# collection_date         NaN                  datetime64[ns]               NaN
# timezone                NaN                          string               NaN
# medication              NaN                          string               NaN
# start_month             NaN                         float64               NaN
# start_year              NaN                         float64               NaN
# ahfs_code               NaN                          string               NaN
# atc_code                NaN                          string               NaN
# medication_heb          NaN                          string               NaN
# medication_mapping      NaN                          string               NaN
