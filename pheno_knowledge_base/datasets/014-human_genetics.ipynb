# %% [raw]
# ---
# output-file: 014-human_genetics.html
# title: 014-human_genetics
# ---

# %% [markdown]
# # Human genetics (Gencove)
#
# The Human Phenotype Project collects genomic variation data on all its participants. The genomic data together with the Human Phenotype Project  deep-phenotypes allows to investigate the progression of disease, and to explore personalized treatments. We genotype millions of positions by low-pass sequencing combined with imputation using gencove platform technologies. Genotype imputation is a process of statistically inferring unobserved genotypes using known haplotypes in a population. The performance of Gencove genotype imputation is very high ( accuracy > 98% ) (Wasik et al. 2021).
#
# ### Data availability:
# The information is stored in a number of statistics parquet files:<br>
# - `human_genetics.parquet`: sample metadata, including QC statistics, paths to PLINK variant files (raw and post-QC), and principal components (PCs).<br>
# - `variants_qc.parquet`: variant QC statistics.<br>
# - `relationship/relationship_ibs.txt`: IBS calculated by PLINK for pairs of participants.<br>
# - `relationship/relationship_king.tsv`: King kinship coefficients for pairs of participants.<br>
# - `pca/pca.parquet`: a PLINK file containing  principal components.<br>
# - `pca/pca_loadings.tsv`: a PLINK file containing principal component loadings calculated.<br>

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('human_genetics')
dl
# Out:
# DataLoader for human_genetics with
# 190 fields
# 3 tables: ['human_genetics', 'pca', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                                                                                field_string  \
# tabular_field_name
# collection_date                                                             Collection date
# version                                                                     Gencove version
# gencove_fastq_r1                                                                   R1_FASTQ
# gencove_fastq_r2                                                                   R2_FASTQ
# gencove_bam                                                                             BAM
# gencove_bai                                                                     BAM indices
# gencove_vcf                                            Imputation Variant Call Format (VCF)
# genecov_qc_bases                                                            Bases sequenced
# genecov_qc_bases_dedup                                                   Deduplicated bases
# gencove_qc_bases_dedup_mapped                                    Deduplicated bases aligned
# genecov_qc_effective_coverage                                            Effective coverage
# genecov_qc_fraction_contamination                                         DNA contamination
# genecov_qc_snps                                                                SNPs covered
# genecov_qc_format_passed                                       Passed FASTQ format validity
# genecov_qc_r1_eq_r2_passed                                          Passed paired-end count
# genecov_qc_r1_r2_ids_match_passed                                   Passed paired-end match
# genecov_qc_bases_passed                                              Passed Bases sequenced
# genecov_qc_bases_dedup_passed                                     Passed Deduplicated bases
# genecov_qc_bases_dedup_mapped_passed                      Passed Deduplicated bases aligned
# genecov_qc_effective_coverage_passed                              Passed Effective coverage
# genecov_qc_fraction_contamination_passed                           Passed DNA contamination
# genecov_qc_snps_passed                                                  Passed SNPs covered
# heterozygosity_proportion                                         Heterozygosity proportion
# pass_het_check                                             Passed Heterozygosity proportion
# sample_qc_gp_pass_rate                                     Genotype Probabilities pass rate
# sample_qc_gp_pass_check                                       Passed Genotype Probabilities
# genetic_sex                                                                         DNA sex
# chr_x_proportion                                    Proportion of alignment to chromosome X
# chr_y_proportion                                    Proportion of alignment to chromosome Y
# sample_qc_gender_match_check                                            Passed gender check
# variants_qc_parquet                                                      Variants QC report
# relatives                                                 Relatives based on IBD estimation
# relationship_king_tsv                                                    KING kingship file
# relationship_ibs_txt                                                         PLINK IBS file
# chr_1_raw_bed                             PLINK BED file for the Raw genotype data for chr1
# chr_1_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr1
# chr_1_raw_bim                             PLINK BIM file for the Raw genotype data for chr1
# chr_2_raw_bed                             PLINK BED file for the Raw genotype data for chr2
# chr_2_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr2
# chr_2_raw_bim                             PLINK BIM file for the Raw genotype data for chr2
# chr_3_raw_bed                             PLINK BED file for the Raw genotype data for chr3
# chr_3_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr3
# chr_3_raw_bim                             PLINK BIM file for the Raw genotype data for chr3
# chr_4_raw_bed                             PLINK BED file for the Raw genotype data for chr4
# chr_4_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr4
# chr_4_raw_bim                             PLINK BIM file for the Raw genotype data for chr4
# chr_5_raw_bed                             PLINK BED file for the Raw genotype data for chr5
# chr_5_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr5
# chr_5_raw_bim                             PLINK BIM file for the Raw genotype data for chr5
# chr_6_raw_bed                             PLINK BED file for the Raw genotype data for chr6
# chr_6_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr6
# chr_6_raw_bim                             PLINK BIM file for the Raw genotype data for chr6
# chr_7_raw_bed                             PLINK BED file for the Raw genotype data for chr7
# chr_7_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr7
# chr_7_raw_bim                             PLINK BIM file for the Raw genotype data for chr7
# chr_8_raw_bed                             PLINK BED file for the Raw genotype data for chr8
# chr_8_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr8
# chr_8_raw_bim                             PLINK BIM file for the Raw genotype data for chr8
# chr_9_raw_bed                             PLINK BED file for the Raw genotype data for chr9
# chr_9_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr9
# chr_9_raw_bim                             PLINK BIM file for the Raw genotype data for chr9
# chr_10_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_10_raw_fam                               PLINK FAM file accompanying Raw .bed for chr10
# chr_10_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_11_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_11_raw_fam                               PLINK FAM file accompanying Raw .bed for chr11
# chr_11_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_12_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_12_raw_fam                               PLINK FAM file accompanying Raw .bed for chr12
# chr_12_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_13_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_13_raw_fam                               PLINK FAM file accompanying Raw .bed for chr13
# chr_13_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_14_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_14_raw_fam                               PLINK FAM file accompanying Raw .bed for chr14
# chr_14_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_15_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_15_raw_fam                               PLINK FAM file accompanying Raw .bed for chr15
# chr_15_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_16_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_16_raw_fam                               PLINK FAM file accompanying Raw .bed for chr16
# chr_16_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_17_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_17_raw_fam                               PLINK FAM file accompanying Raw .bed for chr17
# chr_17_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_18_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_18_raw_fam                               PLINK FAM file accompanying Raw .bed for chr18
# chr_18_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_19_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_19_raw_fam                               PLINK FAM file accompanying Raw .bed for chr19
# chr_19_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_20_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_20_raw_fam                               PLINK FAM file accompanying Raw .bed for chr20
# chr_20_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_21_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_21_raw_fam                               PLINK FAM file accompanying Raw .bed for chr21
# chr_21_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_22_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_22_raw_fam                               PLINK FAM file accompanying Raw .bed for chr22
# chr_22_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_1_postqc_bed                          PLINK BED file for post QC genotype data for chr1
# chr_1_postqc_fam                               PLINK FAM file accompanying QC .bed for chr1
# chr_1_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_2_postqc_bed                          PLINK BED file for post QC genotype data for chr2
# chr_2_postqc_fam                               PLINK FAM file accompanying QC .bed for chr2
# chr_2_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_3_postqc_bed                          PLINK BED file for post QC genotype data for chr3
# chr_3_postqc_fam                               PLINK FAM file accompanying QC .bed for chr3
# chr_3_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_4_postqc_bed                          PLINK BED file for post QC genotype data for chr4
# chr_4_postqc_fam                               PLINK FAM file accompanying QC .bed for chr4
# chr_4_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_5_postqc_bed                          PLINK BED file for post QC genotype data for chr5
# chr_5_postqc_fam                               PLINK FAM file accompanying QC .bed for chr5
# chr_5_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_6_postqc_bed                          PLINK BED file for post QC genotype data for chr6
# chr_6_postqc_fam                               PLINK FAM file accompanying QC .bed for chr6
# chr_6_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_7_postqc_bed                          PLINK BED file for post QC genotype data for chr7
# chr_7_postqc_fam                               PLINK FAM file accompanying QC .bed for chr7
# chr_7_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_8_postqc_bed                          PLINK BED file for post QC genotype data for chr8
# chr_8_postqc_fam                               PLINK FAM file accompanying QC .bed for chr8
# chr_8_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_9_postqc_bed                          PLINK BED file for post QC genotype data for chr9
# chr_9_postqc_fam                               PLINK FAM file accompanying QC .bed for chr9
# chr_9_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_10_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_10_postqc_fam                             PLINK FAM file accompanying QC .bed for chr10
# chr_10_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_11_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_11_postqc_fam                             PLINK FAM file accompanying QC .bed for chr11
# chr_11_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_12_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_12_postqc_fam                             PLINK FAM file accompanying QC .bed for chr12
# chr_12_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_13_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_13_postqc_fam                             PLINK FAM file accompanying QC .bed for chr13
# chr_13_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_14_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_14_postqc_fam                             PLINK FAM file accompanying QC .bed for chr14
# chr_14_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_15_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_15_postqc_fam                             PLINK FAM file accompanying QC .bed for chr15
# chr_15_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_16_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_16_postqc_fam                             PLINK FAM file accompanying QC .bed for chr16
# chr_16_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_17_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_17_postqc_fam                             PLINK FAM file accompanying QC .bed for chr17
# chr_17_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_18_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_18_postqc_fam                             PLINK FAM file accompanying QC .bed for chr18
# chr_18_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_19_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_19_postqc_fam                             PLINK FAM file accompanying QC .bed for chr19
# chr_19_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_20_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_20_postqc_fam                             PLINK FAM file accompanying QC .bed for chr20
# chr_20_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_21_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_21_postqc_fam                             PLINK FAM file accompanying QC .bed for chr21
# chr_21_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_22_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_22_postqc_fam                             PLINK FAM file accompanying QC .bed for chr22
# chr_22_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# pc1                                                                   Principal component 1
# pc2                                                                   Principal component 2
# pc3                                                                   Principal component 3
# pc4                                                                   Principal component 4
# pc5                                                                   Principal component 5
# pc6                                                                   Principal component 6
# pc7                                                                   Principal component 7
# pc8                                                                   Principal component 8
# pc9                                                                   Principal component 9
# pc10                                                                 Principal component 10
# pc11                                                                 Principal component 11
# pc12                                                                 Principal component 12
# pc13                                                                 Principal component 13
# pc14                                                                 Principal component 14
# pc15                                                                 Principal component 15
# pc16                                                                 Principal component 16
# pc17                                                                 Principal component 17
# pc18                                                                 Principal component 18
# pc19                                                                 Principal component 19
# pc20                                                                 Principal component 20
# used_in_pca_calculation                            Included in principal component analysis
# pca_loadings_tsv                                           Principal component loading file
#
#                                                                          description_string  \
# tabular_field_name
# collection_date                           The date of downloading Gencove results from t...
# version                                                          Gencove API version 1 or 2
# gencove_fastq_r1                          Per sample FASTQ file, a text file that contai...
# gencove_fastq_r2                          Per sample FASTQ file, a text file that contai...
# gencove_bam                               Per sample Binary Alignment Map (BAM) file for...
# gencove_bai                                                 Per sample indices for BAM file
# gencove_vcf                               Per sample VCF, a text file storing imputed ge...
# genecov_qc_bases                          number of total bases sequenced. from genecov ...
# genecov_qc_bases_dedup                    number of deduplicated bases. from genecov qc ...
# gencove_qc_bases_dedup_mapped             number of deduplicated bases that have aligned...
# genecov_qc_effective_coverage                      effective coverage. from genecov qc file
# genecov_qc_fraction_contamination         contamination by DNA from another sample of th...
# genecov_qc_snps                           number of variants in reference panel that are...
# genecov_qc_format_passed                  Indicates proper formatting of the input FASTQ...
# genecov_qc_r1_eq_r2_passed                Indicates number of bases in R1 file equal to ...
# genecov_qc_r1_r2_ids_match_passed         Indicates R1 read identifiers match R2 read id...
# genecov_qc_bases_passed                   Indicates number of total bases sequenced grea...
# genecov_qc_bases_dedup_passed             Indicates number of deduplicated bases greater...
# genecov_qc_bases_dedup_mapped_passed      Indicates number of deduplicated bases aligned...
# genecov_qc_effective_coverage_passed      Indicates effective coverage greater than 0. f...
# genecov_qc_fraction_contamination_passed  Indicates contamination by DNA less than 0.06....
# genecov_qc_snps_passed                    Indicates number of variants covered by at lea...
# heterozygosity_proportion                 Estimated heterozygosity proportion across a s...
# pass_het_check                            Indicates heterozygosity proportion is less th...
# sample_qc_gp_pass_rate                    Proportion of genotypes with maximum GP greate...
# sample_qc_gp_pass_check                   Indicates proportion of GP greater than 0.9 is...
# genetic_sex                               Sex as determined by the percentage of read-al...
# chr_x_proportion                                percentage of reads aligned to chromosome X
# chr_y_proportion                                percentage of reads aligned to chromosome Y
# sample_qc_gender_match_check              Indicates inferred_gender and submitted_gender...
# variants_qc_parquet                                                  QC report for each SNP
# relatives                                 List of second and first degree relatives acco...
# relationship_king_tsv                     KING kinship coefficient matrix for pairs of p...
# relationship_ibs_txt                      PLINK IBS coefficient matrix for paris of part...
# chr_1_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_1_raw_fam                             PLINK sample information file accompanying a ....
# chr_1_raw_bim                             PLINK variant information file (per chromosome...
# chr_2_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_2_raw_fam                             PLINK sample information file accompanying a ....
# chr_2_raw_bim                             PLINK variant information file (per chromosome...
# chr_3_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_3_raw_fam                             PLINK sample information file accompanying a ....
# chr_3_raw_bim                             PLINK variant information file (per chromosome...
# chr_4_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_4_raw_fam                             PLINK sample information file accompanying a ....
# chr_4_raw_bim                             PLINK variant information file (per chromosome...
# chr_5_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_5_raw_fam                             PLINK sample information file accompanying a ....
# chr_5_raw_bim                             PLINK variant information file (per chromosome...
# chr_6_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_6_raw_fam                             PLINK sample information file accompanying a ....
# chr_6_raw_bim                             PLINK variant information file (per chromosome...
# chr_7_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_7_raw_fam                             PLINK sample information file accompanying a ....
# chr_7_raw_bim                             PLINK variant information file (per chromosome...
# chr_8_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_8_raw_fam                             PLINK sample information file accompanying a ....
# chr_8_raw_bim                             PLINK variant information file (per chromosome...
# chr_9_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_9_raw_fam                             PLINK sample information file accompanying a ....
# chr_9_raw_bim                             PLINK variant information file (per chromosome...
# chr_10_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_10_raw_fam                            PLINK sample information file accompanying a ....
# chr_10_raw_bim                            PLINK variant information file (per chromosome...
# chr_11_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_11_raw_fam                            PLINK sample information file accompanying a ....
# chr_11_raw_bim                            PLINK variant information file (per chromosome...
# chr_12_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_12_raw_fam                            PLINK sample information file accompanying a ....
# chr_12_raw_bim                            PLINK variant information file (per chromosome...
# chr_13_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_13_raw_fam                            PLINK sample information file accompanying a ....
# chr_13_raw_bim                            PLINK variant information file (per chromosome...
# chr_14_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_14_raw_fam                            PLINK sample information file accompanying a ....
# chr_14_raw_bim                            PLINK variant information file (per chromosome...
# chr_15_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_15_raw_fam                            PLINK sample information file accompanying a ....
# chr_15_raw_bim                            PLINK variant information file (per chromosome...
# chr_16_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_16_raw_fam                            PLINK sample information file accompanying a ....
# chr_16_raw_bim                            PLINK variant information file (per chromosome...
# chr_17_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_17_raw_fam                            PLINK sample information file accompanying a ....
# chr_17_raw_bim                            PLINK variant information file (per chromosome...
# chr_18_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_18_raw_fam                            PLINK sample information file accompanying a ....
# chr_18_raw_bim                            PLINK variant information file (per chromosome...
# chr_19_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_19_raw_fam                            PLINK sample information file accompanying a ....
# chr_19_raw_bim                            PLINK variant information file (per chromosome...
# chr_20_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_20_raw_fam                            PLINK sample information file accompanying a ....
# chr_20_raw_bim                            PLINK variant information file (per chromosome...
# chr_21_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_21_raw_fam                            PLINK sample information file accompanying a ....
# chr_21_raw_bim                            PLINK variant information file (per chromosome...
# chr_22_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_22_raw_fam                            PLINK sample information file accompanying a ....
# chr_22_raw_bim                            PLINK variant information file (per chromosome...
# chr_1_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_1_postqc_fam                          PLINK sample information file accompanying a ....
# chr_1_postqc_bim                          PLINK variant information file (per chromosome...
# chr_2_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_2_postqc_fam                          PLINK sample information file accompanying a ....
# chr_2_postqc_bim                          PLINK variant information file (per chromosome...
# chr_3_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_3_postqc_fam                          PLINK sample information file accompanying a ....
# chr_3_postqc_bim                          PLINK variant information file (per chromosome...
# chr_4_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_4_postqc_fam                          PLINK sample information file accompanying a ....
# chr_4_postqc_bim                          PLINK variant information file (per chromosome...
# chr_5_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_5_postqc_fam                          PLINK sample information file accompanying a ....
# chr_5_postqc_bim                          PLINK variant information file (per chromosome...
# chr_6_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_6_postqc_fam                          PLINK sample information file accompanying a ....
# chr_6_postqc_bim                          PLINK variant information file (per chromosome...
# chr_7_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_7_postqc_fam                          PLINK sample information file accompanying a ....
# chr_7_postqc_bim                          PLINK variant information file (per chromosome...
# chr_8_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_8_postqc_fam                          PLINK sample information file accompanying a ....
# chr_8_postqc_bim                          PLINK variant information file (per chromosome...
# chr_9_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_9_postqc_fam                          PLINK sample information file accompanying a ....
# chr_9_postqc_bim                          PLINK variant information file (per chromosome...
# chr_10_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_10_postqc_fam                         PLINK sample information file accompanying a ....
# chr_10_postqc_bim                         PLINK variant information file (per chromosome...
# chr_11_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_11_postqc_fam                         PLINK sample information file accompanying a ....
# chr_11_postqc_bim                         PLINK variant information file (per chromosome...
# chr_12_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_12_postqc_fam                         PLINK sample information file accompanying a ....
# chr_12_postqc_bim                         PLINK variant information file (per chromosome...
# chr_13_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_13_postqc_fam                         PLINK sample information file accompanying a ....
# chr_13_postqc_bim                         PLINK variant information file (per chromosome...
# chr_14_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_14_postqc_fam                         PLINK sample information file accompanying a ....
# chr_14_postqc_bim                         PLINK variant information file (per chromosome...
# chr_15_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_15_postqc_fam                         PLINK sample information file accompanying a ....
# chr_15_postqc_bim                         PLINK variant information file (per chromosome...
# chr_16_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_16_postqc_fam                         PLINK sample information file accompanying a ....
# chr_16_postqc_bim                         PLINK variant information file (per chromosome...
# chr_17_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_17_postqc_fam                         PLINK sample information file accompanying a ....
# chr_17_postqc_bim                         PLINK variant information file (per chromosome...
# chr_18_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_18_postqc_fam                         PLINK sample information file accompanying a ....
# chr_18_postqc_bim                         PLINK variant information file (per chromosome...
# chr_19_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_19_postqc_fam                         PLINK sample information file accompanying a ....
# chr_19_postqc_bim                         PLINK variant information file (per chromosome...
# chr_20_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_20_postqc_fam                         PLINK sample information file accompanying a ....
# chr_20_postqc_bim                         PLINK variant information file (per chromosome...
# chr_21_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_21_postqc_fam                         PLINK sample information file accompanying a ....
# chr_21_postqc_bim                         PLINK variant information file (per chromosome...
# chr_22_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_22_postqc_fam                         PLINK sample information file accompanying a ....
# chr_22_postqc_bim                         PLINK variant information file (per chromosome...
# pc1                                               Score for projected principal component 1
# pc2                                               Score for projected principal component 2
# pc3                                               Score for projected principal component 3
# pc4                                               Score for projected principal component 4
# pc5                                               Score for projected principal component 5
# pc6                                               Score for projected principal component 6
# pc7                                               Score for projected principal component 7
# pc8                                               Score for projected principal component 8
# pc9                                               Score for projected principal component 9
# pc10                                             Score for projected principal component 10
# pc11                                             Score for projected principal component 11
# pc12                                             Score for projected principal component 12
# pc13                                             Score for projected principal component 13
# pc14                                             Score for projected principal component 14
# pc15                                             Score for projected principal component 15
# pc16                                             Score for projected principal component 16
# pc17                                             Score for projected principal component 17
# pc18                                             Score for projected principal component 18
# pc19                                             Score for projected principal component 19
# pc20                                             Score for projected principal component 20
# used_in_pca_calculation                   Indicates samples was in the input for princip...
# pca_loadings_tsv                                           Principal component loading file
#
#                                                               relative_location  \
# tabular_field_name
# collection_date                           human_genetics/human_genetics.parquet
# version                                   human_genetics/human_genetics.parquet
# gencove_fastq_r1                          human_genetics/human_genetics.parquet
# gencove_fastq_r2                          human_genetics/human_genetics.parquet
# gencove_bam                               human_genetics/human_genetics.parquet
# gencove_bai                               human_genetics/human_genetics.parquet
# gencove_vcf                               human_genetics/human_genetics.parquet
# genecov_qc_bases                          human_genetics/human_genetics.parquet
# genecov_qc_bases_dedup                    human_genetics/human_genetics.parquet
# gencove_qc_bases_dedup_mapped             human_genetics/human_genetics.parquet
# genecov_qc_effective_coverage             human_genetics/human_genetics.parquet
# genecov_qc_fraction_contamination         human_genetics/human_genetics.parquet
# genecov_qc_snps                           human_genetics/human_genetics.parquet
# genecov_qc_format_passed                  human_genetics/human_genetics.parquet
# genecov_qc_r1_eq_r2_passed                human_genetics/human_genetics.parquet
# genecov_qc_r1_r2_ids_match_passed         human_genetics/human_genetics.parquet
# genecov_qc_bases_passed                   human_genetics/human_genetics.parquet
# genecov_qc_bases_dedup_passed             human_genetics/human_genetics.parquet
# genecov_qc_bases_dedup_mapped_passed      human_genetics/human_genetics.parquet
# genecov_qc_effective_coverage_passed      human_genetics/human_genetics.parquet
# genecov_qc_fraction_contamination_passed  human_genetics/human_genetics.parquet
# genecov_qc_snps_passed                    human_genetics/human_genetics.parquet
# heterozygosity_proportion                 human_genetics/human_genetics.parquet
# pass_het_check                            human_genetics/human_genetics.parquet
# sample_qc_gp_pass_rate                    human_genetics/human_genetics.parquet
# sample_qc_gp_pass_check                   human_genetics/human_genetics.parquet
# genetic_sex                               human_genetics/human_genetics.parquet
# chr_x_proportion                          human_genetics/human_genetics.parquet
# chr_y_proportion                          human_genetics/human_genetics.parquet
# sample_qc_gender_match_check              human_genetics/human_genetics.parquet
# variants_qc_parquet                       human_genetics/human_genetics.parquet
# relatives                                 human_genetics/human_genetics.parquet
# relationship_king_tsv                     human_genetics/human_genetics.parquet
# relationship_ibs_txt                      human_genetics/human_genetics.parquet
# chr_1_raw_bed                             human_genetics/human_genetics.parquet
# chr_1_raw_fam                             human_genetics/human_genetics.parquet
# chr_1_raw_bim                             human_genetics/human_genetics.parquet
# chr_2_raw_bed                             human_genetics/human_genetics.parquet
# chr_2_raw_fam                             human_genetics/human_genetics.parquet
# chr_2_raw_bim                             human_genetics/human_genetics.parquet
# chr_3_raw_bed                             human_genetics/human_genetics.parquet
# chr_3_raw_fam                             human_genetics/human_genetics.parquet
# chr_3_raw_bim                             human_genetics/human_genetics.parquet
# chr_4_raw_bed                             human_genetics/human_genetics.parquet
# chr_4_raw_fam                             human_genetics/human_genetics.parquet
# chr_4_raw_bim                             human_genetics/human_genetics.parquet
# chr_5_raw_bed                             human_genetics/human_genetics.parquet
# chr_5_raw_fam                             human_genetics/human_genetics.parquet
# chr_5_raw_bim                             human_genetics/human_genetics.parquet
# chr_6_raw_bed                             human_genetics/human_genetics.parquet
# chr_6_raw_fam                             human_genetics/human_genetics.parquet
# chr_6_raw_bim                             human_genetics/human_genetics.parquet
# chr_7_raw_bed                             human_genetics/human_genetics.parquet
# chr_7_raw_fam                             human_genetics/human_genetics.parquet
# chr_7_raw_bim                             human_genetics/human_genetics.parquet
# chr_8_raw_bed                             human_genetics/human_genetics.parquet
# chr_8_raw_fam                             human_genetics/human_genetics.parquet
# chr_8_raw_bim                             human_genetics/human_genetics.parquet
# chr_9_raw_bed                             human_genetics/human_genetics.parquet
# chr_9_raw_fam                             human_genetics/human_genetics.parquet
# chr_9_raw_bim                             human_genetics/human_genetics.parquet
# chr_10_raw_bed                            human_genetics/human_genetics.parquet
# chr_10_raw_fam                            human_genetics/human_genetics.parquet
# chr_10_raw_bim                            human_genetics/human_genetics.parquet
# chr_11_raw_bed                            human_genetics/human_genetics.parquet
# chr_11_raw_fam                            human_genetics/human_genetics.parquet
# chr_11_raw_bim                            human_genetics/human_genetics.parquet
# chr_12_raw_bed                            human_genetics/human_genetics.parquet
# chr_12_raw_fam                            human_genetics/human_genetics.parquet
# chr_12_raw_bim                            human_genetics/human_genetics.parquet
# chr_13_raw_bed                            human_genetics/human_genetics.parquet
# chr_13_raw_fam                            human_genetics/human_genetics.parquet
# chr_13_raw_bim                            human_genetics/human_genetics.parquet
# chr_14_raw_bed                            human_genetics/human_genetics.parquet
# chr_14_raw_fam                            human_genetics/human_genetics.parquet
# chr_14_raw_bim                            human_genetics/human_genetics.parquet
# chr_15_raw_bed                            human_genetics/human_genetics.parquet
# chr_15_raw_fam                            human_genetics/human_genetics.parquet
# chr_15_raw_bim                            human_genetics/human_genetics.parquet
# chr_16_raw_bed                            human_genetics/human_genetics.parquet
# chr_16_raw_fam                            human_genetics/human_genetics.parquet
# chr_16_raw_bim                            human_genetics/human_genetics.parquet
# chr_17_raw_bed                            human_genetics/human_genetics.parquet
# chr_17_raw_fam                            human_genetics/human_genetics.parquet
# chr_17_raw_bim                            human_genetics/human_genetics.parquet
# chr_18_raw_bed                            human_genetics/human_genetics.parquet
# chr_18_raw_fam                            human_genetics/human_genetics.parquet
# chr_18_raw_bim                            human_genetics/human_genetics.parquet
# chr_19_raw_bed                            human_genetics/human_genetics.parquet
# chr_19_raw_fam                            human_genetics/human_genetics.parquet
# chr_19_raw_bim                            human_genetics/human_genetics.parquet
# chr_20_raw_bed                            human_genetics/human_genetics.parquet
# chr_20_raw_fam                            human_genetics/human_genetics.parquet
# chr_20_raw_bim                            human_genetics/human_genetics.parquet
# chr_21_raw_bed                            human_genetics/human_genetics.parquet
# chr_21_raw_fam                            human_genetics/human_genetics.parquet
# chr_21_raw_bim                            human_genetics/human_genetics.parquet
# chr_22_raw_bed                            human_genetics/human_genetics.parquet
# chr_22_raw_fam                            human_genetics/human_genetics.parquet
# chr_22_raw_bim                            human_genetics/human_genetics.parquet
# chr_1_postqc_bed                          human_genetics/human_genetics.parquet
# chr_1_postqc_fam                          human_genetics/human_genetics.parquet
# chr_1_postqc_bim                          human_genetics/human_genetics.parquet
# chr_2_postqc_bed                          human_genetics/human_genetics.parquet
# chr_2_postqc_fam                          human_genetics/human_genetics.parquet
# chr_2_postqc_bim                          human_genetics/human_genetics.parquet
# chr_3_postqc_bed                          human_genetics/human_genetics.parquet
# chr_3_postqc_fam                          human_genetics/human_genetics.parquet
# chr_3_postqc_bim                          human_genetics/human_genetics.parquet
# chr_4_postqc_bed                          human_genetics/human_genetics.parquet
# chr_4_postqc_fam                          human_genetics/human_genetics.parquet
# chr_4_postqc_bim                          human_genetics/human_genetics.parquet
# chr_5_postqc_bed                          human_genetics/human_genetics.parquet
# chr_5_postqc_fam                          human_genetics/human_genetics.parquet
# chr_5_postqc_bim                          human_genetics/human_genetics.parquet
# chr_6_postqc_bed                          human_genetics/human_genetics.parquet
# chr_6_postqc_fam                          human_genetics/human_genetics.parquet
# chr_6_postqc_bim                          human_genetics/human_genetics.parquet
# chr_7_postqc_bed                          human_genetics/human_genetics.parquet
# chr_7_postqc_fam                          human_genetics/human_genetics.parquet
# chr_7_postqc_bim                          human_genetics/human_genetics.parquet
# chr_8_postqc_bed                          human_genetics/human_genetics.parquet
# chr_8_postqc_fam                          human_genetics/human_genetics.parquet
# chr_8_postqc_bim                          human_genetics/human_genetics.parquet
# chr_9_postqc_bed                          human_genetics/human_genetics.parquet
# chr_9_postqc_fam                          human_genetics/human_genetics.parquet
# chr_9_postqc_bim                          human_genetics/human_genetics.parquet
# chr_10_postqc_bed                         human_genetics/human_genetics.parquet
# chr_10_postqc_fam                         human_genetics/human_genetics.parquet
# chr_10_postqc_bim                         human_genetics/human_genetics.parquet
# chr_11_postqc_bed                         human_genetics/human_genetics.parquet
# chr_11_postqc_fam                         human_genetics/human_genetics.parquet
# chr_11_postqc_bim                         human_genetics/human_genetics.parquet
# chr_12_postqc_bed                         human_genetics/human_genetics.parquet
# chr_12_postqc_fam                         human_genetics/human_genetics.parquet
# chr_12_postqc_bim                         human_genetics/human_genetics.parquet
# chr_13_postqc_bed                         human_genetics/human_genetics.parquet
# chr_13_postqc_fam                         human_genetics/human_genetics.parquet
# chr_13_postqc_bim                         human_genetics/human_genetics.parquet
# chr_14_postqc_bed                         human_genetics/human_genetics.parquet
# chr_14_postqc_fam                         human_genetics/human_genetics.parquet
# ...
# chr_21_postqc_bed                           NaN        category
# chr_21_postqc_fam                           NaN        category
# chr_21_postqc_bim                           NaN        category
# chr_22_postqc_bed                           NaN        category
# chr_22_postqc_fam                           NaN        category
# chr_22_postqc_bim                           NaN        category
# pc1                                         NaN           float
# pc2                                         NaN           float
# pc3                                         NaN           float
# pc4                                         NaN           float
# pc5                                         NaN           float
# pc6                                         NaN           float
# pc7                                         NaN           float
# pc8                                         NaN           float
# pc9                                         NaN           float
# pc10                                        NaN           float
# pc11                                        NaN           float
# pc12                                        NaN           float
# pc13                                        NaN           float
# pc14                                        NaN           float
# pc15                                        NaN           float
# pc16                                        NaN           float
# pc17                                        NaN           float
# pc18                                        NaN           float
# pc19                                        NaN           float
# pc20                                        NaN           float
# used_in_pca_calculation                     NaN            bool
# pca_loadings_tsv                            NaN        category
#
#                                           parent_dataframe  data_coding
# tabular_field_name
# collection_date                                        NaN          NaN
# version                                                NaN          NaN
# gencove_fastq_r1                                       NaN          NaN
# gencove_fastq_r2                                       NaN          NaN
# gencove_bam                                            NaN          NaN
# gencove_bai                                            NaN          NaN
# gencove_vcf                                            NaN          NaN
# genecov_qc_bases                                       NaN          NaN
# genecov_qc_bases_dedup                                 NaN          NaN
# gencove_qc_bases_dedup_mapped                          NaN          NaN
# genecov_qc_effective_coverage                          NaN          NaN
# genecov_qc_fraction_contamination                      NaN          NaN
# genecov_qc_snps                                        NaN          NaN
# genecov_qc_format_passed                               NaN          NaN
# genecov_qc_r1_eq_r2_passed                             NaN          NaN
# genecov_qc_r1_r2_ids_match_passed                      NaN          NaN
# genecov_qc_bases_passed                                NaN          NaN
# genecov_qc_bases_dedup_passed                          NaN          NaN
# genecov_qc_bases_dedup_mapped_passed                   NaN          NaN
# genecov_qc_effective_coverage_passed                   NaN          NaN
# genecov_qc_fraction_contamination_passed               NaN          NaN
# genecov_qc_snps_passed                                 NaN          NaN
# heterozygosity_proportion                              NaN          NaN
# pass_het_check                                         NaN          NaN
# sample_qc_gp_pass_rate                                 NaN          NaN
# sample_qc_gp_pass_check                                NaN          NaN
# genetic_sex                                            NaN          NaN
# chr_x_proportion                                       NaN          NaN
# chr_y_proportion                                       NaN          NaN
# sample_qc_gender_match_check                           NaN          NaN
# variants_qc_parquet                                    NaN          NaN
# relatives                                              NaN          NaN
# relationship_king_tsv                                  NaN          NaN
# relationship_ibs_txt                                   NaN          NaN
# chr_1_raw_bed                                          NaN          NaN
# chr_1_raw_fam                                          NaN          NaN
# chr_1_raw_bim                                          NaN          NaN
# chr_2_raw_bed                                          NaN          NaN
# chr_2_raw_fam                                          NaN          NaN
# chr_2_raw_bim                                          NaN          NaN
# chr_3_raw_bed                                          NaN          NaN
# chr_3_raw_fam                                          NaN          NaN
# chr_3_raw_bim                                          NaN          NaN
# chr_4_raw_bed                                          NaN          NaN
# chr_4_raw_fam                                          NaN          NaN
# chr_4_raw_bim                                          NaN          NaN
# chr_5_raw_bed                                          NaN          NaN
# chr_5_raw_fam                                          NaN          NaN
# chr_5_raw_bim                                          NaN          NaN
# chr_6_raw_bed                                          NaN          NaN
# chr_6_raw_fam                                          NaN          NaN
# chr_6_raw_bim                                          NaN          NaN
# chr_7_raw_bed                                          NaN          NaN
# chr_7_raw_fam                                          NaN          NaN
# chr_7_raw_bim                                          NaN          NaN
# chr_8_raw_bed                                          NaN          NaN
# chr_8_raw_fam                                          NaN          NaN
# chr_8_raw_bim                                          NaN          NaN
# chr_9_raw_bed                                          NaN          NaN
# chr_9_raw_fam                                          NaN          NaN
# chr_9_raw_bim                                          NaN          NaN
# chr_10_raw_bed                                         NaN          NaN
# chr_10_raw_fam                                         NaN          NaN
# chr_10_raw_bim                                         NaN          NaN
# chr_11_raw_bed                                         NaN          NaN
# chr_11_raw_fam                                         NaN          NaN
# chr_11_raw_bim                                         NaN          NaN
# chr_12_raw_bed                                         NaN          NaN
# chr_12_raw_fam                                         NaN          NaN
# chr_12_raw_bim                                         NaN          NaN
# chr_13_raw_bed                                         NaN          NaN
# chr_13_raw_fam                                         NaN          NaN
# chr_13_raw_bim                                         NaN          NaN
# chr_14_raw_bed                                         NaN          NaN
# chr_14_raw_fam                                         NaN          NaN
# chr_14_raw_bim                                         NaN          NaN
# chr_15_raw_bed                                         NaN          NaN
# chr_15_raw_fam                                         NaN          NaN
# chr_15_raw_bim                                         NaN          NaN
# chr_16_raw_bed                                         NaN          NaN
# chr_16_raw_fam                                         NaN          NaN
# chr_16_raw_bim                                         NaN          NaN
# chr_17_raw_bed                                         NaN          NaN
# chr_17_raw_fam                                         NaN          NaN
# chr_17_raw_bim                                         NaN          NaN
# chr_18_raw_bed                                         NaN          NaN
# chr_18_raw_fam                                         NaN          NaN
# chr_18_raw_bim                                         NaN          NaN
# chr_19_raw_bed                                         NaN          NaN
# chr_19_raw_fam                                         NaN          NaN
# chr_19_raw_bim                                         NaN          NaN
# chr_20_raw_bed                                         NaN          NaN
# chr_20_raw_fam                                         NaN          NaN
# chr_20_raw_bim                                         NaN          NaN
# chr_21_raw_bed                                         NaN          NaN
# chr_21_raw_fam                                         NaN          NaN
# chr_21_raw_bim                                         NaN          NaN
# chr_22_raw_bed                                         NaN          NaN
# chr_22_raw_fam                                         NaN          NaN
# chr_22_raw_bim                                         NaN          NaN
# chr_1_postqc_bed                                       NaN          NaN
# chr_1_postqc_fam                                       NaN          NaN
# chr_1_postqc_bim                                       NaN          NaN
# chr_2_postqc_bed                                       NaN          NaN
# chr_2_postqc_fam                                       NaN          NaN
# chr_2_postqc_bim                                       NaN          NaN
# chr_3_postqc_bed                                       NaN          NaN
# chr_3_postqc_fam                                       NaN          NaN
# chr_3_postqc_bim                                       NaN          NaN
# chr_4_postqc_bed                                       NaN          NaN
# chr_4_postqc_fam                                       NaN          NaN
# chr_4_postqc_bim                                       NaN          NaN
# chr_5_postqc_bed                                       NaN          NaN
# chr_5_postqc_fam                                       NaN          NaN
# chr_5_postqc_bim                                       NaN          NaN
# chr_6_postqc_bed                                       NaN          NaN
# chr_6_postqc_fam                                       NaN          NaN
# chr_6_postqc_bim                                       NaN          NaN
# chr_7_postqc_bed                                       NaN          NaN
# chr_7_postqc_fam                                       NaN          NaN
# chr_7_postqc_bim                                       NaN          NaN
# chr_8_postqc_bed                                       NaN          NaN
# chr_8_postqc_fam                                       NaN          NaN
# chr_8_postqc_bim                                       NaN          NaN
# chr_9_postqc_bed                                       NaN          NaN
# chr_9_postqc_fam                                       NaN          NaN
# chr_9_postqc_bim                                       NaN          NaN
# chr_10_postqc_bed                                      NaN          NaN
# chr_10_postqc_fam                                      NaN          NaN
# chr_10_postqc_bim                                      NaN          NaN
# chr_11_postqc_bed                                      NaN          NaN
# chr_11_postqc_fam                                      NaN          NaN
# chr_11_postqc_bim                                      NaN          NaN
# chr_12_postqc_bed                                      NaN          NaN
# chr_12_postqc_fam                                      NaN          NaN
# chr_12_postqc_bim                                      NaN          NaN
# chr_13_postqc_bed                                      NaN          NaN
# chr_13_postqc_fam                                      NaN          NaN
# chr_13_postqc_bim                                      NaN          NaN
# chr_14_postqc_bed                                      NaN          NaN
# chr_14_postqc_fam                                      NaN          NaN
# chr_14_postqc_bim                                      NaN          NaN
# chr_15_postqc_bed                                      NaN          NaN
# chr_15_postqc_fam                                      NaN          NaN
# chr_15_postqc_bim                                      NaN          NaN
# chr_16_postqc_bed                                      NaN          NaN
# chr_16_postqc_fam                                      NaN          NaN
# chr_16_postqc_bim                                      NaN          NaN
# chr_17_postqc_bed                                      NaN          NaN
# chr_17_postqc_fam                                      NaN          NaN
# chr_17_postqc_bim                                      NaN          NaN
# chr_18_postqc_bed                                      NaN          NaN
# chr_18_postqc_fam                                      NaN          NaN
# chr_18_postqc_bim                                      NaN          NaN
# chr_19_postqc_bed                                      NaN          NaN
# chr_19_postqc_fam                                      NaN          NaN
# chr_19_postqc_bim                                      NaN          NaN
# chr_20_postqc_bed                                      NaN          NaN
# chr_20_postqc_fam                                      NaN          NaN
# chr_20_postqc_bim                                      NaN          NaN
# chr_21_postqc_bed                                      NaN          NaN
# chr_21_postqc_fam                                      NaN          NaN
# chr_21_postqc_bim                                      NaN          NaN
# chr_22_postqc_bed                                      NaN          NaN
# chr_22_postqc_fam                                      NaN          NaN
# chr_22_postqc_bim                                      NaN          NaN
# pc1                                                    NaN          NaN
# pc2                                                    NaN          NaN
# pc3                                                    NaN          NaN
# pc4                                                    NaN          NaN
# pc5                                                    NaN          NaN
# pc6                                                    NaN          NaN
# pc7                                                    NaN          NaN
# pc8                                                    NaN          NaN
# pc9                                                    NaN          NaN
# pc10                                                   NaN          NaN
# pc11                                                   NaN          NaN
# pc12                                                   NaN          NaN
# pc13                                                   NaN          NaN
# pc14                                                   NaN          NaN
# pc15                                                   NaN          NaN
# pc16                                                   NaN          NaN
# pc17                                                   NaN          NaN
# pc18                                                   NaN          NaN
# pc19                                                   NaN          NaN
# pc20                                                   NaN          NaN
# used_in_pca_calculation                                NaN          NaN
# pca_loadings_tsv                                       NaN          NaN
