# %% [raw]
# ---
# output-file: 007-blood_pressure.html
# title: 007-blood_pressure
# ---

# %% [markdown]
# # Blood pressure dataset
# Blood pressure is the measurement of the force exerted against the walls of the arteries as blood flows through them. Blood pressure is recorded as two values: systolic pressure (the pressure when the heart beats) and diastolic pressure (the pressure when the heart is at rest between beats).
#
# Blood pressure measurement can be performed in a variety of settings, including hospitals, clinics, and even at home, using an automated or manual sphygmomanometer. Blood pressure measurement can be used to monitor the effectiveness of treatment interventions, such as lifestyle changes. The goal of treatment is to achieve and maintain target blood pressure levels, which are generally lower for individuals at higher risk for cardiovascular disease.
#
# Blood pressure is measured using an OMRON Blood Pressure Monitor HEM-RML31 device and an appropriately sized cuff. Multiple blood pressure readings are done during the visit. For each blood pressure reading, three measurements are taken: systolic pressure, diastolic pressure, and average heart rate. The participant is asked to avoid caffeine, exercise and smoking at least 30 minutes before the measurement. The measurement is taken on the left arm if possible.
#
# ### Data availability:
# The information is stored in 1 parquet file: `blood_pressure.parquet`

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('blood_pressure')
dl
# Out:
# DataLoader for blood_pressure with
# 22 fields
# 2 tables: ['blood_pressure', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                                                                                  field_string  \
# tabular_field_name
# collection_date                                                  Collection date (YYYY-MM-DD)
# collection_timestamp                                                     Collection timestamp
# timezone                                                                             Timezone
# lying_blood_pressure_diastolic                                Lying diastolic blood pressure
# lying_blood_pressure_pulse_rate                               Lying blood pressure pulse rate
# lying_blood_pressure_systolic                                  Lying systolic blood pressure
# sitting_blood_pressure_diastolic                            Sitting diastolic blood pressure
# sitting_blood_pressure_pulse_rate                           Sitting blood pressure pulse rate
# sitting_blood_pressure_systolic                              Sitting systolic blood pressure
# standing_one_min_blood_pressure_diastolic       Standing one minute diastolic blood pressure
# standing_one_min_blood_pressure_pulse_rate      Standing one minute blood pressure pulse rate
# standing_one_min_blood_pressure_systolic         Standing one minute systolic blood pressure
# standing_three_min_blood_pressure_diastolic   Standing three minute diastolic blood pressure
# standing_three_min_blood_pressure_pulse_rate  Standing three minute blood pressure pulse rate
# standing_three_min_blood_pressure_systolic     Standing three minute systolic blood pressure
# blood_pressure_hand                                                       Blood pressure hand
# sitting_second_blood_pressure_diastolic              Sitting second diastolic blood pressure
# sitting_second_blood_pressure_pulse_rate             Sitting second blood pressure pulse rate
# sitting_second_blood_pressure_systolic                Sitting second systolic blood pressure
# dizziness                                                            Dizzness after standing
#
#                                                                              description_string  \
# tabular_field_name
# collection_date                                                    Collection date (YYYY-MM-DD)
# collection_timestamp                                                       Collection timestamp
# timezone                                                                               Timezone
# lying_blood_pressure_diastolic                             Lying diastolic blood pressure value
# lying_blood_pressure_pulse_rate                                 Lying blood pressure pulse rate
# lying_blood_pressure_systolic                               Lying systolic blood pressure value
# sitting_blood_pressure_diastolic                         Sitting diastolic blood pressure value
# sitting_blood_pressure_pulse_rate                             Sitting blood pressure pulse rate
# sitting_blood_pressure_systolic                           Sitting systolic blood pressure value
# standing_one_min_blood_pressure_diastolic     Standing one minute diastolic blood pressure v...
# standing_one_min_blood_pressure_pulse_rate        Standing one minute blood pressure pulse rate
# standing_one_min_blood_pressure_systolic      Standing one minute systolic blood pressure value
# standing_three_min_blood_pressure_diastolic   Standing three minute diastolic blood pressure...
# standing_three_min_blood_pressure_pulse_rate    Standing three minute blood pressure pulse rate
# standing_three_min_blood_pressure_systolic    Standing three minute systolic blood pressure ...
# blood_pressure_hand                                  Hand used to peform blood pressure reading
# sitting_second_blood_pressure_diastolic       A second diastolic blood pressure value readin...
# sitting_second_blood_pressure_pulse_rate      Pulse rate of a second blood pressure reading ...
# sitting_second_blood_pressure_systolic        A second systolic blood pressure value reading...
# dizziness                                     Self reported dizziness once a person stands u...
#
#                                                                   relative_location  \
# tabular_field_name
# collection_date                               blood_pressure/blood_pressure.parquet
# collection_timestamp                          blood_pressure/blood_pressure.parquet
# timezone                                      blood_pressure/blood_pressure.parquet
# lying_blood_pressure_diastolic                blood_pressure/blood_pressure.parquet
# lying_blood_pressure_pulse_rate               blood_pressure/blood_pressure.parquet
# lying_blood_pressure_systolic                 blood_pressure/blood_pressure.parquet
# sitting_blood_pressure_diastolic              blood_pressure/blood_pressure.parquet
# sitting_blood_pressure_pulse_rate             blood_pressure/blood_pressure.parquet
# sitting_blood_pressure_systolic               blood_pressure/blood_pressure.parquet
# standing_one_min_blood_pressure_diastolic     blood_pressure/blood_pressure.parquet
# standing_one_min_blood_pressure_pulse_rate    blood_pressure/blood_pressure.parquet
# standing_one_min_blood_pressure_systolic      blood_pressure/blood_pressure.parquet
# standing_three_min_blood_pressure_diastolic   blood_pressure/blood_pressure.parquet
# standing_three_min_blood_pressure_pulse_rate  blood_pressure/blood_pressure.parquet
# standing_three_min_blood_pressure_systolic    blood_pressure/blood_pressure.parquet
# blood_pressure_hand                           blood_pressure/blood_pressure.parquet
# sitting_second_blood_pressure_diastolic       blood_pressure/blood_pressure.parquet
# sitting_second_blood_pressure_pulse_rate      blood_pressure/blood_pressure.parquet
# sitting_second_blood_pressure_systolic        blood_pressure/blood_pressure.parquet
# dizziness                                     blood_pressure/blood_pressure.parquet
#
#                                                          value_type units  \
# tabular_field_name
# collection_date                                                Time  Time
# collection_timestamp                                           Time  Time
# timezone                                                 Continuous   NaN
# lying_blood_pressure_diastolic                           Continuous  mmHg
# lying_blood_pressure_pulse_rate                          Continuous   bpm
# lying_blood_pressure_systolic                            Continuous  mmHg
# sitting_blood_pressure_diastolic                         Continuous  mmHg
# sitting_blood_pressure_pulse_rate                        Continuous   bpm
# sitting_blood_pressure_systolic                          Continuous  mmHg
# standing_one_min_blood_pressure_diastolic                Continuous  mmHg
# standing_one_min_blood_pressure_pulse_rate               Continuous   bpm
# standing_one_min_blood_pressure_systolic                 Continuous  mmHg
# standing_three_min_blood_pressure_diastolic              Continuous  mmHg
# standing_three_min_blood_pressure_pulse_rate             Continuous   bpm
# standing_three_min_blood_pressure_systolic               Continuous  mmHg
# blood_pressure_hand                           Categorical (single)    NaN
# sitting_second_blood_pressure_diastolic                  Continuous  mmHg
# sitting_second_blood_pressure_pulse_rate                 Continuous   bpm
# sitting_second_blood_pressure_systolic                   Continuous  mmHg
# dizziness                                     Categorical (single)    NaN
#
#                                               sampling_rate item_type   array  \
# tabular_field_name
# collection_date                                         NaN      Data  Single
# collection_timestamp                                    NaN      Data  Single
# timezone                                                NaN      Data  Single
# lying_blood_pressure_diastolic                          NaN      Data  Single
# lying_blood_pressure_pulse_rate                         NaN      Data  Single
# lying_blood_pressure_systolic                           NaN      Data  Single
# sitting_blood_pressure_diastolic                        NaN      Data  Single
# sitting_blood_pressure_pulse_rate                       NaN      Data  Single
# sitting_blood_pressure_systolic                         NaN      Data  Single
# standing_one_min_blood_pressure_diastolic               NaN      Data  Single
# standing_one_min_blood_pressure_pulse_rate              NaN      Data  Single
# standing_one_min_blood_pressure_systolic                NaN      Data  Single
# standing_three_min_blood_pressure_diastolic             NaN      Data  Single
# standing_three_min_blood_pressure_pulse_rate            NaN      Data  Single
# standing_three_min_blood_pressure_systolic              NaN      Data  Single
# blood_pressure_hand                                     NaN      Data  Single
# sitting_second_blood_pressure_diastolic                 NaN      Data  Single
# sitting_second_blood_pressure_pulse_rate                NaN      Data  Single
# sitting_second_blood_pressure_systolic                  NaN      Data  Single
# dizziness                                               NaN      Data  Single
#
#                                              cohorts data_type       debut  \
# tabular_field_name
# collection_date                                  10K   Tabular  2019-01-29
# collection_timestamp                             10K   Tabular  2019-01-29
# timezone                                         10K   Tabular  2019-01-29
# lying_blood_pressure_diastolic                   10K   Tabular  2019-01-29
# lying_blood_pressure_pulse_rate                  10K   Tabular  2019-01-29
# lying_blood_pressure_systolic                    10K   Tabular  2019-01-29
# sitting_blood_pressure_diastolic                 10K   Tabular  2019-01-29
# sitting_blood_pressure_pulse_rate                10K   Tabular  2019-01-29
# sitting_blood_pressure_systolic                  10K   Tabular  2019-01-29
# standing_one_min_blood_pressure_diastolic        10K   Tabular  2019-01-29
# standing_one_min_blood_pressure_pulse_rate       10K   Tabular  2019-01-29
# standing_one_min_blood_pressure_systolic         10K   Tabular  2019-01-29
# standing_three_min_blood_pressure_diastolic      10K   Tabular  2019-01-29
# standing_three_min_blood_pressure_pulse_rate     10K   Tabular  2019-01-29
# standing_three_min_blood_pressure_systolic       10K   Tabular  2019-01-29
# blood_pressure_hand                              10K   Tabular  2022-06-12
# sitting_second_blood_pressure_diastolic          10K   Tabular  2022-06-12
# sitting_second_blood_pressure_pulse_rate         10K   Tabular  2022-06-12
# sitting_second_blood_pressure_systolic           10K   Tabular  2022-06-12
# dizziness                                        10K   Tabular  2019-01-29
#
#                                                                 pandas_dtype  \
# tabular_field_name
# collection_date                                               datetime64[ns]
# collection_timestamp                          datetime64[ns, Asia/Jerusalem]
# timezone                                                              string
# lying_blood_pressure_diastolic                                         float
# lying_blood_pressure_pulse_rate                                        float
# lying_blood_pressure_systolic                                          float
# sitting_blood_pressure_diastolic                                       float
# sitting_blood_pressure_pulse_rate                                      float
# sitting_blood_pressure_systolic                                        float
# standing_one_min_blood_pressure_diastolic                              float
# standing_one_min_blood_pressure_pulse_rate                             float
# standing_one_min_blood_pressure_systolic                               float
# standing_three_min_blood_pressure_diastolic                            float
# standing_three_min_blood_pressure_pulse_rate                           float
# standing_three_min_blood_pressure_systolic                             float
# blood_pressure_hand                                                 category
# sitting_second_blood_pressure_diastolic                                float
# sitting_second_blood_pressure_pulse_rate                               float
# sitting_second_blood_pressure_systolic                                 float
# dizziness                                                             string
#
#                                               parent_dataframe
# tabular_field_name
# collection_date                                            NaN
# collection_timestamp                                       NaN
# timezone                                                   NaN
# lying_blood_pressure_diastolic                             NaN
# lying_blood_pressure_pulse_rate                            NaN
# lying_blood_pressure_systolic                              NaN
# sitting_blood_pressure_diastolic                           NaN
# sitting_blood_pressure_pulse_rate                          NaN
# sitting_blood_pressure_systolic                            NaN
# standing_one_min_blood_pressure_diastolic                  NaN
# standing_one_min_blood_pressure_pulse_rate                 NaN
# standing_one_min_blood_pressure_systolic                   NaN
# standing_three_min_blood_pressure_diastolic                NaN
# standing_three_min_blood_pressure_pulse_rate               NaN
# standing_three_min_blood_pressure_systolic                 NaN
# blood_pressure_hand                                        NaN
# sitting_second_blood_pressure_diastolic                    NaN
# sitting_second_blood_pressure_pulse_rate                   NaN
# sitting_second_blood_pressure_systolic                     NaN
# dizziness                                                  NaN
