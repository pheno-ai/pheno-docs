# %% [raw]
# ---
# output-file: 017-cgm.html
# title: 017-cgm
# ---

# %% [markdown]
# # CGM dataset
#
# Continuous Glucose Monitoring (CGM) measures glucose levels in a continuous manner.  <br>
# This measure provides information on blood glucose control and glucose variability and could be used to monitor patients with diabetes.
#
# Each 14-day continuous measure is termed a single CGM-connection.
#
# Using the glucose measured in the CGM connection, we can calculate summary features (which was done using the iglu package) summarizing information on glucose control and variability. <br>
# These were calculated for the entire CGM connection as well as for daily segments of the data.
#
# The actual glucose measures are stored in multiple parquet files, each file holds the glucose measures for a single CGM connection. <br>
#
# ### Data availability:
# The metadata and summary features are stored in 3 main statistics parquet files: `cgm.parquet`, `iglu.parquet`, `iglu_daily.parquet`.

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('cgm')
dl
# Out:
# DataLoader for cgm with
# 98 fields
# 4 tables: ['cgm', 'iglu', 'iglu_daily', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                                                                     field_string  \
# tabular_field_name
# connection_id                                                       ConnectionID
# cgm_time_series                                                   CGM timeseries
# glucose                                                                  Glucose
# collection_timestamp                                        Collection timestamp
# cgm_first_date                                                    CGM first date
# cgm_last_date                                                      CGM last date
# cgm_device_type                                                  CGM Device type
# cgm_datapoints_lost_in_qc                              CGM datapoints lost in QC
# percentage_of_cgm_datapoints_lost_in_qc  Percentage of CGM datapoints lost in QC
# number_of_cgm_days_available                        Number of CGM days available
# number_of_cgm_datapoints_available            Number of CGM datapoints available
# timezone                                                                Timezone
# cgm_1st_quartile                                                    1st quantile
# cgm_3rd_quartile                                                    3rd quantile
# cgm_above_140                                                        % above 140
# cgm_above_180                                                        % above 180
# cgm_above_250                                                        % above 250
# cgm_below_54                                                          % below 54
# cgm_below_70                                                          % below 70
# cgm_in_range_63_140                                            % in range 63-140
# cgm_in_range_70_180                                            % in range 70-180
# cgm_adrr                                                                    ADRR
# cgm_auc                                                                      AUC
# cgm_cogi                                                                    COGI
# cgm_conga                                                                  Conga
# cgm_cv                                                                        CV
# cgm_cv_measures_mean                                                      CVmean
# cgm_cv_measures_sd                                                          CVsd
# cgm_ea1c                                                                    eA1C
# cgm_gmi                                                                      GMI
# cgm_grade                                                                  GRADE
# cgm_grade_eugly                                                      GRADE eugly
# cgm_grade_hyper                                                      GRADE hyper
# cgm_grade_hypo                                                        GRADE hypo
# cgm_gvp                                                                      GVP
# cgm_hbgi                                                                    HBGI
# cgm_hyper_index                                                      Hyper index
# cgm_hypo_index                                                        Hypo index
# cgm_igc                                                                      IGC
# cgm_iqr                                                                      IQR
# cgm_j_index                                                              J-index
# cgm_lbgi                                                                    LBGI
# cgm_m_value                                                              M value
# cgm_mad                                                                      MAD
# cgm_mag                                                                      MAG
# cgm_mage                                                                    MAGE
# cgm_min_                                                                     Min
# cgm_max_                                                                     Max
# cgm_mean                                                                    Mean
# cgm_median                                                                Median
# cgm_modd                                                                    MODD
# cgm_range                                                                  Range
# cgm_sd                                                                        SD
# cgm_sd_roc                                                                SD.Roc
# cgm_sdb                                                                      SDb
# cgm_sdbdm                                                                  SDbdm
# cgm_sddm                                                                    SDdm
# cgm_sdhhmm                                                                SDhhmm
# cgm_sdw                                                                      SDw
# cgm_sdwsh                                                                  SDwsh
# collection_date                                                             Date
# connection_day                                                    Connection day
# cgm_daily_1st_quartile                                        Daily 1st quartile
# cgm_daily_3rd_quartile                                        Daily 3rd quartile
# cgm_daily_above_140                                            Daily % above 140
# cgm_daily_above_180                                            Daily % above 180
# cgm_daily_above_250                                            Daily % above 250
# cgm_daily_below_54                                              Daily % below 54
# cgm_daily_below_70                                              Daily % below 70
# cgm_daily_in_range_63_140                                Daily % in range 63-140
# cgm_daily_in_range_70_180                                Daily % in range 70-180
# cgm_daily_adrr                                                        Daily ADRR
# cgm_daily_auc                                                          Daily AUC
# cgm_daily_cogi                                                        Daily COGI
# cgm_daily_cv                                                            Daily CV
# cgm_daily_ea1c                                                        Daily eA1C
# cgm_daily_gmi                                                          Daily GMI
# cgm_daily_grade                                                      Daily GRADE
# cgm_daily_grade_eugly                                          Daily GRADE_eugly
# cgm_daily_grade_hyper                                          Daily GRADE_hyper
# cgm_daily_grade_hypo                                            Daily GRADE_hypo
# cgm_daily_gvp                                                          Daily GVP
# cgm_daily_hbgi                                                        Daily HBGI
# cgm_daily_hyper_index                                          Daily Hyper index
# cgm_daily_hypo_index                                            Daily Hypo index
# cgm_daily_igc                                                          Daily IGC
# cgm_daily_iqr                                                          Daily IQR
# cgm_daily_j_index                                                  Daily J_index
# cgm_daily_lbgi                                                        Daily LBGI
# cgm_daily_m_value                                                  Daily M value
# cgm_daily_mad                                                          Daily MAD
# cgm_daily_mag                                                          Daily MAG
# cgm_daily_mage                                                        Daily MAGE
# cgm_daily_min                                                          Daily Min
# cgm_daily_max                                                          Daily Max
# cgm_daily_mean                                                        Daily Mean
# cgm_daily_median                                                    Daily Median
# cgm_daily_range                                                      Daily Range
# cgm_daily_sd                                                            Daily SD
# cgm_daily_sd_roc                                                    Daily SD.Roc
# cgm_daily_sdwsh                                                      Daily SDwsh
# timezone                                                                Timezone
#
#                                                                         description_string  \
# tabular_field_name
# connection_id                                                     CGM device connection id
# cgm_time_series                          Name of the file containing the participants' ...
# glucose                                                        cgm temporal glucose values
# collection_timestamp                             CGM connection first data point timestamp
# cgm_first_date                                                   CGM connection first date
# cgm_last_date                                                     CGM connection last date
# cgm_device_type                                                            CGM Device type
# cgm_datapoints_lost_in_qc                              Number of CGM datapoints lost in QC
# percentage_of_cgm_datapoints_lost_in_qc                                                NaN
# number_of_cgm_days_available               Number of CGM days available for the connection
# number_of_cgm_datapoints_available       Number of CGM datapoints available for the con...
# timezone                                                           TImezone of measurement
# cgm_1st_quartile                                     First quantile of all glucose values.
# cgm_3rd_quartile                                     Third quantile of all glucose values.
# cgm_above_140                            Percent of glucose measures that were larger t...
# cgm_above_180                            Percent of glucose measures that were larger t...
# cgm_above_250                            Percent of glucose measures that were larger t...
# cgm_below_54                             Percent of glucose measures that were lower th...
# cgm_below_70                             Percent of glucose measures that were lower th...
# cgm_in_range_63_140                      Percent of glucose measures that were in a spe...
# cgm_in_range_70_180                      Percent of glucose measures that were in a spe...
# cgm_adrr                                 Average daily risk range (ADRR) is a variabili...
# cgm_auc                                  Hourly average AUC. This measure integrates, t...
# cgm_cogi                                 Continuous Glucose Monitoring Index (COGI). CO...
# cgm_conga                                Continuous Overall Net Glycemic Action (CONGA)...
# cgm_cv                                   Coefficient of variation of all glucose values.\n
# cgm_cv_measures_mean                                                Mean of all daily CVs.
# cgm_cv_measures_sd                                   Standard deviations of all daily CVs.
# cgm_ea1c                                 A linear transformation of the mean glucose va...
# cgm_gmi                                  A linear transformation of the mean glucose va...
# cgm_grade                                Glycaemic Risk Assessment Diabetes Equation (G...
# cgm_grade_eugly                          Percentage of the GRADE score that is attribut...
# cgm_grade_hyper                          Percentage of the GRADE score that is attribut...
# cgm_grade_hypo                           Percentage of the GRADE score that is attribut...
# cgm_gvp                                  Glucose Variability Percentage (GVP), which is...
# cgm_hbgi                                                   High Blood Glucose Index (HBGI)
# cgm_hyper_index                          This is a weighted average of hyperglycemic va...
# cgm_hypo_index                           This is a weighted average of hypoglycemic val...
# cgm_igc                                  Index of Glycemic Control (IGC), a sum of the ...
# cgm_iqr                                  Interquartile range (IQR), calculated as the d...
# cgm_j_index                              This index was designed to stress the importan...
# cgm_lbgi                                                    Low Blood Glucose Index (LBGI)
# cgm_m_value                              The M-value is an index aimed to describe the ...
# cgm_mad                                  Median Absolute Deviation (MAD). This is a mea...
# cgm_mag                                  Mean Absolute Glucose (MAG). This is a measure...
# cgm_mage                                 Mean Amplitude of Glycemic Excursions (MAGE), ...
# cgm_min_                                                    Minimum of all glucose values.
# cgm_max_                                                    Maximum of all glucose values.
# cgm_mean                                                       Mean of all glucose values.
# cgm_median                                                   Median of all glucose values.
# cgm_modd                                 Mean difference between glucose values obtaine...
# cgm_range                                Difference between the maximum and minimum glu...
# cgm_sd                                           Standard deviation of all glucose values.
# cgm_sd_roc                               Standard deviation of all the rate of change (...
# cgm_sdb                                  SD between days, within time points. Mean valu...
# cgm_sdbdm                                SD between days, within time points, corrected...
# cgm_sddm                                 Horizontal SD. SD of the mean glucose values, ...
# cgm_sdhhmm                               SD between time points. Standard deviation of ...
# cgm_sdw                                  Vertical SD within days. Average value of the ...
# cgm_sdwsh                                SD within series. Taking hour-long intervals t...
# collection_date                          Date of the daily CGM data used to calculate t...
# connection_day                                                   Day of the CGM connection
# cgm_daily_1st_quartile                             First quantile of daily glucose values.
# cgm_daily_3rd_quartile                             Third quantile of daily glucose values.
# cgm_daily_above_140                      Percent of daily glucose measures that were la...
# cgm_daily_above_180                      Percent of daily glucose measures that were la...
# cgm_daily_above_250                      Percent of daily glucose measures that were la...
# cgm_daily_below_54                       Percent of daily glucose measures that were lo...
# cgm_daily_below_70                       Percent of daily glucose measures that were lo...
# cgm_daily_in_range_63_140                Percent of daily glucose measures that were in...
# cgm_daily_in_range_70_180                Percent of daily glucose measures that were in...
# cgm_daily_adrr                           Average daily risk range (ADRR) is a variabili...
# cgm_daily_auc                            Hourly average AUC. This measure integrates, t...
# cgm_daily_cogi                           Continuous Glucose Monitoring Index (COGI). CO...
# cgm_daily_cv                             Coefficient of variation of daily glucose values.
# cgm_daily_ea1c                           A linear transformation of the mean glucose va...
# cgm_daily_gmi                            A linear transformation of the mean glucose va...
# cgm_daily_grade                          Glycaemic Risk Assessment Diabetes Equation (G...
# cgm_daily_grade_eugly                    Percentage of the GRADE score that is attribut...
# cgm_daily_grade_hyper                    Percentage of the GRADE score that is attribut...
# cgm_daily_grade_hypo                     Percentage of the GRADE score that is attribut...
# cgm_daily_gvp                            Glucose Variability Percentage (GVP), which is...
# cgm_daily_hbgi                                             High Blood Glucose Index (HBGI)
# cgm_daily_hyper_index                    This is a weighted average of hyperglycemic va...
# cgm_daily_hypo_index                     This is a weighted average of hypoglycemic val...
# cgm_daily_igc                            Index of Glycemic Control (IGC), a sum of the ...
# cgm_daily_iqr                            Interquartile range (IQR), calculated as the d...
# cgm_daily_j_index                        This index was designed to stress the importan...
# cgm_daily_lbgi                                              Low Blood Glucose Index (LBGI)
# cgm_daily_m_value                        The M-value is an index aimed to describe the ...
# cgm_daily_mad                            Median Absolute Deviation (MAD). This is a mea...
# cgm_daily_mag                            Mean Absolute Glucose (MAG). This is a measure...
# cgm_daily_mage                           Mean Amplitude of Glycemic Excursions (MAGE), ...
# cgm_daily_min                                               Minimum of all glucose values.
# cgm_daily_max                                               Maximum of all glucose values.
# cgm_daily_mean                                                 Mean of all glucose values.
# cgm_daily_median                                             Median of all glucose values.
# cgm_daily_range                          Difference between the maximum and minimum glu...
# cgm_daily_sd                                     Standard deviation of all glucose values.
# cgm_daily_sd_roc                         Standard deviation of all the rate of change (...
# cgm_daily_sdwsh                          SD within series. Taking hour-long intervals t...
# timezone                                                           TImezone of measurement
#
#                                               relative_location  \
# tabular_field_name
# connection_id                                   cgm/cgm.parquet
# cgm_time_series                                 cgm/cgm.parquet
# glucose                                                     NaN
# collection_timestamp                            cgm/cgm.parquet
# cgm_first_date                                  cgm/cgm.parquet
# cgm_last_date                                   cgm/cgm.parquet
# cgm_device_type                                 cgm/cgm.parquet
# cgm_datapoints_lost_in_qc                       cgm/cgm.parquet
# percentage_of_cgm_datapoints_lost_in_qc         cgm/cgm.parquet
# number_of_cgm_days_available                    cgm/cgm.parquet
# number_of_cgm_datapoints_available              cgm/cgm.parquet
# timezone                                        cgm/cgm.parquet
# cgm_1st_quartile                               cgm/iglu.parquet
# cgm_3rd_quartile                               cgm/iglu.parquet
# cgm_above_140                                  cgm/iglu.parquet
# cgm_above_180                                  cgm/iglu.parquet
# cgm_above_250                                  cgm/iglu.parquet
# cgm_below_54                                   cgm/iglu.parquet
# cgm_below_70                                   cgm/iglu.parquet
# cgm_in_range_63_140                            cgm/iglu.parquet
# cgm_in_range_70_180                            cgm/iglu.parquet
# cgm_adrr                                       cgm/iglu.parquet
# cgm_auc                                        cgm/iglu.parquet
# cgm_cogi                                       cgm/iglu.parquet
# cgm_conga                                      cgm/iglu.parquet
# cgm_cv                                         cgm/iglu.parquet
# cgm_cv_measures_mean                           cgm/iglu.parquet
# cgm_cv_measures_sd                             cgm/iglu.parquet
# cgm_ea1c                                       cgm/iglu.parquet
# cgm_gmi                                        cgm/iglu.parquet
# cgm_grade                                      cgm/iglu.parquet
# cgm_grade_eugly                                cgm/iglu.parquet
# cgm_grade_hyper                                cgm/iglu.parquet
# cgm_grade_hypo                                 cgm/iglu.parquet
# cgm_gvp                                        cgm/iglu.parquet
# cgm_hbgi                                       cgm/iglu.parquet
# cgm_hyper_index                                cgm/iglu.parquet
# cgm_hypo_index                                 cgm/iglu.parquet
# cgm_igc                                        cgm/iglu.parquet
# cgm_iqr                                        cgm/iglu.parquet
# cgm_j_index                                    cgm/iglu.parquet
# cgm_lbgi                                       cgm/iglu.parquet
# cgm_m_value                                    cgm/iglu.parquet
# cgm_mad                                        cgm/iglu.parquet
# cgm_mag                                        cgm/iglu.parquet
# cgm_mage                                       cgm/iglu.parquet
# cgm_min_                                       cgm/iglu.parquet
# cgm_max_                                       cgm/iglu.parquet
# cgm_mean                                       cgm/iglu.parquet
# cgm_median                                     cgm/iglu.parquet
# cgm_modd                                       cgm/iglu.parquet
# cgm_range                                      cgm/iglu.parquet
# cgm_sd                                         cgm/iglu.parquet
# cgm_sd_roc                                     cgm/iglu.parquet
# cgm_sdb                                        cgm/iglu.parquet
# cgm_sdbdm                                      cgm/iglu.parquet
# cgm_sddm                                       cgm/iglu.parquet
# cgm_sdhhmm                                     cgm/iglu.parquet
# cgm_sdw                                        cgm/iglu.parquet
# cgm_sdwsh                                      cgm/iglu.parquet
# collection_date                          cgm/iglu_daily.parquet
# connection_day                           cgm/iglu_daily.parquet
# cgm_daily_1st_quartile                   cgm/iglu_daily.parquet
# cgm_daily_3rd_quartile                   cgm/iglu_daily.parquet
# cgm_daily_above_140                      cgm/iglu_daily.parquet
# cgm_daily_above_180                      cgm/iglu_daily.parquet
# cgm_daily_above_250                      cgm/iglu_daily.parquet
# cgm_daily_below_54                       cgm/iglu_daily.parquet
# cgm_daily_below_70                       cgm/iglu_daily.parquet
# cgm_daily_in_range_63_140                cgm/iglu_daily.parquet
# cgm_daily_in_range_70_180                cgm/iglu_daily.parquet
# cgm_daily_adrr                           cgm/iglu_daily.parquet
# cgm_daily_auc                            cgm/iglu_daily.parquet
# cgm_daily_cogi                           cgm/iglu_daily.parquet
# cgm_daily_cv                             cgm/iglu_daily.parquet
# cgm_daily_ea1c                           cgm/iglu_daily.parquet
# cgm_daily_gmi                            cgm/iglu_daily.parquet
# cgm_daily_grade                          cgm/iglu_daily.parquet
# cgm_daily_grade_eugly                    cgm/iglu_daily.parquet
# cgm_daily_grade_hyper                    cgm/iglu_daily.parquet
# cgm_daily_grade_hypo                     cgm/iglu_daily.parquet
# cgm_daily_gvp                            cgm/iglu_daily.parquet
# cgm_daily_hbgi                           cgm/iglu_daily.parquet
# cgm_daily_hyper_index                    cgm/iglu_daily.parquet
# cgm_daily_hypo_index                     cgm/iglu_daily.parquet
# cgm_daily_igc                            cgm/iglu_daily.parquet
# cgm_daily_iqr                            cgm/iglu_daily.parquet
# cgm_daily_j_index                        cgm/iglu_daily.parquet
# cgm_daily_lbgi                           cgm/iglu_daily.parquet
# cgm_daily_m_value                        cgm/iglu_daily.parquet
# cgm_daily_mad                            cgm/iglu_daily.parquet
# cgm_daily_mag                            cgm/iglu_daily.parquet
# cgm_daily_mage                           cgm/iglu_daily.parquet
# cgm_daily_min                            cgm/iglu_daily.parquet
# cgm_daily_max                            cgm/iglu_daily.parquet
# cgm_daily_mean                           cgm/iglu_daily.parquet
# cgm_daily_median                         cgm/iglu_daily.parquet
# cgm_daily_range                          cgm/iglu_daily.parquet
# cgm_daily_sd                             cgm/iglu_daily.parquet
# cgm_daily_sd_roc                         cgm/iglu_daily.parquet
# cgm_daily_sdwsh                          cgm/iglu_daily.parquet
# timezone                                 cgm/iglu_daily.parquet
#
#                                                      value_type    units  \
# tabular_field_name
# connection_id                                              Text     Text
# cgm_time_series                                            Text      NaN
# glucose                                  Series data, continous    mg/dl
# collection_timestamp                                       Time     Time
# cgm_first_date                                             Time     Time
# cgm_last_date                                              Time     Time
# cgm_device_type                          Categorical (multiple)     Text
# cgm_datapoints_lost_in_qc                               Integer      NaN
# percentage_of_cgm_datapoints_lost_in_qc                     NaN      NaN
# number_of_cgm_days_available                            Integer  integer
# number_of_cgm_datapoints_available                      Integer  integer
# timezone                                                   Text     Text
# cgm_1st_quartile                                     Continuous    mg/dl
# cgm_3rd_quartile                                     Continuous    mg/dl
# cgm_above_140                                        Continuous        %
# cgm_above_180                                        Continuous        %
# cgm_above_250                                        Continuous        %
# cgm_below_54                                         Continuous        %
# cgm_below_70                                         Continuous        %
# cgm_in_range_63_140                                  Continuous        %
# cgm_in_range_70_180                                  Continuous        %
# cgm_adrr                                             Continuous      NaN
# cgm_auc                                              Continuous  mg/dl*h
# cgm_cogi                                             Continuous      NaN
# cgm_conga                                            Continuous      NaN
# cgm_cv                                               Continuous      NaN
# cgm_cv_measures_mean                                 Continuous      NaN
# cgm_cv_measures_sd                                   Continuous      NaN
# cgm_ea1c                                             Continuous    mg/dl
# cgm_gmi                                              Continuous    mg/dl
# cgm_grade                                            Continuous      NaN
# cgm_grade_eugly                                      Continuous      NaN
# cgm_grade_hyper                                      Continuous      NaN
# cgm_grade_hypo                                       Continuous      NaN
# cgm_gvp                                              Continuous      NaN
# cgm_hbgi                                             Continuous      NaN
# cgm_hyper_index                                      Continuous      NaN
# cgm_hypo_index                                       Continuous      NaN
# cgm_igc                                              Continuous      NaN
# cgm_iqr                                              Continuous    mg/dl
# cgm_j_index                                          Continuous      NaN
# cgm_lbgi                                             Continuous      NaN
# cgm_m_value                                          Continuous      NaN
# cgm_mad                                              Continuous    mg/dl
# cgm_mag                                              Continuous    mg/dl
# cgm_mage                                             Continuous    mg/dl
# cgm_min_                                             Continuous    mg/dl
# cgm_max_                                             Continuous    mg/dl
# cgm_mean                                             Continuous    mg/dl
# cgm_median                                           Continuous    mg/dl
# cgm_modd                                             Continuous    mg/dl
# cgm_range                                            Continuous    mg/dl
# cgm_sd                                               Continuous    mg/dl
# cgm_sd_roc                                           Continuous      NaN
# cgm_sdb                                              Continuous    mg/dl
# cgm_sdbdm                                            Continuous    mg/dl
# cgm_sddm                                             Continuous    mg/dl
# cgm_sdhhmm                                           Continuous    mg/dl
# cgm_sdw                                              Continuous    mg/dl
# cgm_sdwsh                                            Continuous    mg/dl
# collection_date                                            Time     Time
# connection_day                                          Integer  integer
# cgm_daily_1st_quartile                               Continuous    mg/dl
# cgm_daily_3rd_quartile                               Continuous    mg/dl
# cgm_daily_above_140                                  Continuous        %
# cgm_daily_above_180                                  Continuous        %
# cgm_daily_above_250                                  Continuous        %
# cgm_daily_below_54                                   Continuous        %
# cgm_daily_below_70                                   Continuous        %
# cgm_daily_in_range_63_140                            Continuous        %
# cgm_daily_in_range_70_180                            Continuous        %
# cgm_daily_adrr                                       Continuous      NaN
# cgm_daily_auc                                        Continuous  mg/dl*h
# cgm_daily_cogi                                       Continuous      NaN
# cgm_daily_cv                                         Continuous      NaN
# cgm_daily_ea1c                                       Continuous    mg/dl
# cgm_daily_gmi                                        Continuous    mg/dl
# cgm_daily_grade                                      Continuous      NaN
# cgm_daily_grade_eugly                                Continuous      NaN
# cgm_daily_grade_hyper                                Continuous      NaN
# cgm_daily_grade_hypo                                 Continuous      NaN
# cgm_daily_gvp                                        Continuous      NaN
# cgm_daily_hbgi                                       Continuous      NaN
# cgm_daily_hyper_index                                Continuous      NaN
# cgm_daily_hypo_index                                 Continuous      NaN
# cgm_daily_igc                                        Continuous      NaN
# cgm_daily_iqr                                        Continuous    mg/dl
# cgm_daily_j_index                                    Continuous      NaN
# cgm_daily_lbgi                                       Continuous      NaN
# cgm_daily_m_value                                    Continuous      NaN
# cgm_daily_mad                                        Continuous    mg/dl
# cgm_daily_mag                                        Continuous    mg/dl
# cgm_daily_mage                                       Continuous    mg/dl
# cgm_daily_min                                        Continuous    mg/dl
# cgm_daily_max                                        Continuous    mg/dl
# cgm_daily_mean                                       Continuous    mg/dl
# cgm_daily_median                                     Continuous    mg/dl
# cgm_daily_range                                      Continuous    mg/dl
# cgm_daily_sd                                         Continuous    mg/dl
# cgm_daily_sd_roc                                     Continuous      NaN
# cgm_daily_sdwsh                                      Continuous    mg/dl
# timezone                                                   Text      NaN
#
#                                         sampling_rate item_type     array  \
# tabular_field_name
# connection_id                                     NaN      Data    Single
# cgm_time_series                                   NaN      Bulk    Single
# glucose                                         15min      Data    Single
# collection_timestamp                              NaN      Data    Single
# cgm_first_date                                    NaN      Data    Single
# cgm_last_date                                     NaN      Data    Single
# cgm_device_type                                   NaN      Data    Single
# cgm_datapoints_lost_in_qc                         NaN      Data    Single
# percentage_of_cgm_datapoints_lost_in_qc           NaN       NaN       NaN
# number_of_cgm_days_available                      NaN      Data    Single
# number_of_cgm_datapoints_available                NaN      Data    Single
# timezone                                          NaN      Data    Single
# cgm_1st_quartile                                  NaN      Data    Single
# cgm_3rd_quartile                                  NaN      Data    Single
# cgm_above_140                                     NaN      Data    Single
# cgm_above_180                                     NaN      Data    Single
# cgm_above_250                                     NaN      Data    Single
# cgm_below_54                                      NaN      Data    Single
# cgm_below_70                                      NaN      Data    Single
# cgm_in_range_63_140                               NaN      Data    Single
# cgm_in_range_70_180                               NaN      Data    Single
# cgm_adrr                                          NaN      Data    Single
# cgm_auc                                           NaN      Data    Single
# cgm_cogi                                          NaN      Data    Single
# cgm_conga                                         NaN      Data    Single
# cgm_cv                                            NaN      Data    Single
# cgm_cv_measures_mean                              NaN      Data    Single
# cgm_cv_measures_sd                                NaN      Data    Single
# cgm_ea1c                                          NaN      Data    Single
# cgm_gmi                                           NaN      Data    Single
# cgm_grade                                         NaN      Data    Single
# cgm_grade_eugly                                   NaN      Data    Single
# cgm_grade_hyper                                   NaN      Data    Single
# cgm_grade_hypo                                    NaN      Data    Single
# cgm_gvp                                           NaN      Data    Single
# cgm_hbgi                                          NaN      Data    Single
# cgm_hyper_index                                   NaN      Data    Single
# cgm_hypo_index                                    NaN      Data    Single
# cgm_igc                                           NaN      Data    Single
# cgm_iqr                                           NaN      Data    Single
# cgm_j_index                                       NaN      Data    Single
# cgm_lbgi                                          NaN      Data    Single
# cgm_m_value                                       NaN      Data    Single
# cgm_mad                                           NaN      Data    Single
# cgm_mag                                           NaN      Data    Single
# cgm_mage                                          NaN      Data    Single
# cgm_min_                                          NaN      Data    Single
# cgm_max_                                          NaN      Data    Single
# cgm_mean                                          NaN      Data    Single
# cgm_median                                        NaN      Data    Single
# cgm_modd                                          NaN      Data    Single
# cgm_range                                         NaN      Data    Single
# cgm_sd                                            NaN      Data    Single
# cgm_sd_roc                                        NaN      Data    Single
# cgm_sdb                                           NaN      Data    Single
# cgm_sdbdm                                         NaN      Data    Single
# cgm_sddm                                          NaN      Data    Single
# cgm_sdhhmm                                        NaN      Data    Single
# cgm_sdw                                           NaN      Data    Single
# cgm_sdwsh                                         NaN      Data    Single
# collection_date                                   NaN      Data  Multiple
# connection_day                                    NaN      Data    Single
# cgm_daily_1st_quartile                            NaN      Data  Multiple
# cgm_daily_3rd_quartile                            NaN      Data  Multiple
# cgm_daily_above_140                               NaN      Data  Multiple
# cgm_daily_above_180                               NaN      Data  Multiple
# cgm_daily_above_250                               NaN      Data  Multiple
# cgm_daily_below_54                                NaN      Data  Multiple
# cgm_daily_below_70                                NaN      Data  Multiple
# cgm_daily_in_range_63_140                         NaN      Data  Multiple
# cgm_daily_in_range_70_180                         NaN      Data  Multiple
# cgm_daily_adrr                                    NaN      Data  Multiple
# cgm_daily_auc                                     NaN      Data  Multiple
# cgm_daily_cogi                                    NaN      Data  Multiple
# cgm_daily_cv                                      NaN      Data  Multiple
# cgm_daily_ea1c                                    NaN      Data  Multiple
# cgm_daily_gmi                                     NaN      Data  Multiple
# cgm_daily_grade                                   NaN      Data  Multiple
# cgm_daily_grade_eugly                             NaN      Data  Multiple
# cgm_daily_grade_hyper                             NaN      Data  Multiple
# cgm_daily_grade_hypo                              NaN      Data  Multiple
# cgm_daily_gvp                                     NaN      Data  Multiple
# cgm_daily_hbgi                                    NaN      Data  Multiple
# cgm_daily_hyper_index                             NaN      Data  Multiple
# cgm_daily_hypo_index                              NaN      Data  Multiple
# cgm_daily_igc                                     NaN      Data  Multiple
# cgm_daily_iqr                                     NaN      Data  Multiple
# cgm_daily_j_index                                 NaN      Data  Multiple
# cgm_daily_lbgi                                    NaN      Data  Multiple
# cgm_daily_m_value                                 NaN      Data  Multiple
# cgm_daily_mad                                     NaN      Data  Multiple
# cgm_daily_mag                                     NaN      Data  Multiple
# cgm_daily_mage                                    NaN      Data  Multiple
# cgm_daily_min                                     NaN      Data  Multiple
# cgm_daily_max                                     NaN      Data  Multiple
# cgm_daily_mean                                    NaN      Data  Multiple
# cgm_daily_median                                  NaN      Data  Multiple
# cgm_daily_range                                   NaN      Data  Multiple
# cgm_daily_sd                                      NaN      Data  Multiple
# cgm_daily_sd_roc                                  NaN      Data  Multiple
# cgm_daily_sdwsh                                   NaN      Data  Multiple
# timezone                                          NaN      Data    Single
#
#                                         cohorts    data_type       debut  \
# tabular_field_name
# connection_id                               10K      tabular  2018-12-27
# cgm_time_series                             10K         text  2018-12-27
# glucose                                     10K  time series  2018-12-27
# collection_timestamp                        10K      tabular  2018-12-27
# cgm_first_date                              10K      tabular  2018-12-27
# cgm_last_date                               10K      tabular  2018-12-27
# cgm_device_type                             10K      tabular  2018-12-27
# cgm_datapoints_lost_in_qc                   10K      tabular  2018-12-27
# percentage_of_cgm_datapoints_lost_in_qc     NaN          NaN         NaN
# number_of_cgm_days_available                10K      tabular  2018-12-27
# number_of_cgm_datapoints_available          10K      tabular  2018-12-27
# timezone                                    10K      tabular  2018-12-27
# cgm_1st_quartile                            10K      tabular  2018-12-27
# cgm_3rd_quartile                            10K      tabular  2018-12-27
# cgm_above_140                               10K      tabular  2018-12-27
# cgm_above_180                               10K      tabular  2018-12-27
# cgm_above_250                               10K      tabular  2018-12-27
# cgm_below_54                                10K      tabular  2018-12-27
# cgm_below_70                                10K      tabular  2018-12-27
# cgm_in_range_63_140                         10K      tabular  2018-12-27
# cgm_in_range_70_180                         10K      tabular  2018-12-27
# cgm_adrr                                    10K      tabular  2018-12-27
# cgm_auc                                     10K      tabular  2018-12-27
# cgm_cogi                                    10K      tabular  2018-12-27
# cgm_conga                                   10K      tabular  2018-12-27
# cgm_cv                                      10K      tabular  2018-12-27
# cgm_cv_measures_mean                        10K      tabular  2018-12-27
# cgm_cv_measures_sd                          10K      tabular  2018-12-27
# cgm_ea1c                                    10K      tabular  2018-12-27
# cgm_gmi                                     10K      tabular  2018-12-27
# cgm_grade                                   10K      tabular  2018-12-27
# cgm_grade_eugly                             10K      tabular  2018-12-27
# cgm_grade_hyper                             10K      tabular  2018-12-27
# cgm_grade_hypo                              10K      tabular  2018-12-27
# cgm_gvp                                     10K      tabular  2018-12-27
# cgm_hbgi                                    10K      tabular  2018-12-27
# cgm_hyper_index                             10K      tabular  2018-12-27
# cgm_hypo_index                              10K      tabular  2018-12-27
# cgm_igc                                     10K      tabular  2018-12-27
# cgm_iqr                                     10K      tabular  2018-12-27
# cgm_j_index                                 10K      tabular  2018-12-27
# cgm_lbgi                                    10K      tabular  2018-12-27
# cgm_m_value                                 10K      tabular  2018-12-27
# cgm_mad                                     10K      tabular  2018-12-27
# cgm_mag                                     10K      tabular  2018-12-27
# cgm_mage                                    10K      tabular  2018-12-27
# cgm_min_                                    10K      tabular  2018-12-27
# cgm_max_                                    10K      tabular  2018-12-27
# cgm_mean                                    10K      tabular  2018-12-27
# cgm_median                                  10K      tabular  2018-12-27
# cgm_modd                                    10K      tabular  2018-12-27
# cgm_range                                   10K      tabular  2018-12-27
# cgm_sd                                      10K      tabular  2018-12-27
# cgm_sd_roc                                  10K      tabular  2018-12-27
# cgm_sdb                                     10K      tabular  2018-12-27
# cgm_sdbdm                                   10K      tabular  2018-12-27
# cgm_sddm                                    10K      tabular  2018-12-27
# cgm_sdhhmm                                  10K      tabular  2018-12-27
# cgm_sdw                                     10K      tabular  2018-12-27
# cgm_sdwsh                                   10K      tabular  2018-12-27
# collection_date                             10K      tabular  2018-12-27
# connection_day                              10K      tabular  2018-12-27
# cgm_daily_1st_quartile                      10K      tabular  2018-12-27
# cgm_daily_3rd_quartile                      10K      tabular  2018-12-27
# cgm_daily_above_140                         10K      tabular  2018-12-27
# cgm_daily_above_180                         10K      tabular  2018-12-27
# cgm_daily_above_250                         10K      tabular  2018-12-27
# cgm_daily_below_54                          10K      tabular  2018-12-27
# cgm_daily_below_70                          10K      tabular  2018-12-27
# cgm_daily_in_range_63_140                   10K      tabular  2018-12-27
# cgm_daily_in_range_70_180                   10K      tabular  2018-12-27
# cgm_daily_adrr                              10K      tabular  2018-12-27
# cgm_daily_auc                               10K      tabular  2018-12-27
# cgm_daily_cogi                              10K      tabular  2018-12-27
# cgm_daily_cv                                10K      tabular  2018-12-27
# cgm_daily_ea1c                              10K      tabular  2018-12-27
# cgm_daily_gmi                               10K      tabular  2018-12-27
# cgm_daily_grade                             10K      tabular  2018-12-27
# cgm_daily_grade_eugly                       10K      tabular  2018-12-27
# cgm_daily_grade_hyper                       10K      tabular  2018-12-27
# cgm_daily_grade_hypo                        10K      tabular  2018-12-27
# cgm_daily_gvp                               10K      tabular  2018-12-27
# cgm_daily_hbgi                              10K      tabular  2018-12-27
# cgm_daily_hyper_index                       10K      tabular  2018-12-27
# cgm_daily_hypo_index                        10K      tabular  2018-12-27
# cgm_daily_igc                               10K      tabular  2018-12-27
# cgm_daily_iqr                               10K      tabular  2018-12-27
# cgm_daily_j_index                           10K      tabular  2018-12-27
# cgm_daily_lbgi                              10K      tabular  2018-12-27
# cgm_daily_m_value                           10K      tabular  2018-12-27
# cgm_daily_mad                               10K      tabular  2018-12-27
# cgm_daily_mag                               10K      tabular  2018-12-27
# cgm_daily_mage                              10K      tabular  2018-12-27
# cgm_daily_min                               10K      tabular  2018-12-27
# cgm_daily_max                               10K      tabular  2018-12-27
# cgm_daily_mean                              10K      tabular  2018-12-27
# cgm_daily_median                            10K      tabular  2018-12-27
# cgm_daily_range                             10K      tabular  2018-12-27
# cgm_daily_sd                                10K      tabular  2018-12-27
# cgm_daily_sd_roc                            10K      tabular  2018-12-27
# cgm_daily_sdwsh                             10K      tabular  2018-12-27
# timezone                                    10K      tabular  2018-12-27
#
#                                                            pandas_dtype  \
# tabular_field_name
# connection_id                                                       int
# cgm_time_series                                                  string
# glucose                                                           float
# collection_timestamp                     datetime64[ns, Asia/Jerusalem]
# cgm_first_date                           datetime64[ns, Asia/Jerusalem]
# cgm_last_date                            datetime64[ns, Asia/Jerusalem]
# cgm_device_type                                                category
# cgm_datapoints_lost_in_qc                                           int
# percentage_of_cgm_datapoints_lost_in_qc                           float
# number_of_cgm_days_available                                        int
# number_of_cgm_datapoints_available                                  int
# timezone                                                         string
# cgm_1st_quartile                                                  float
# cgm_3rd_quartile                                                  float
# cgm_above_140                                                     float
# cgm_above_180                                                     float
# cgm_above_250                                                     float
# cgm_below_54                                                      float
# cgm_below_70                                                      float
# cgm_in_range_63_140                                               float
# cgm_in_range_70_180                                               float
# cgm_adrr                                                          float
# cgm_auc                                                           float
# cgm_cogi                                                          float
# cgm_conga                                                         float
# cgm_cv                                                            float
# cgm_cv_measures_mean                                              float
# cgm_cv_measures_sd                                                float
# cgm_ea1c                                                          float
# cgm_gmi                                                           float
# cgm_grade                                                         float
# cgm_grade_eugly                                                   float
# cgm_grade_hyper                                                   float
# cgm_grade_hypo                                                    float
# cgm_gvp                                                           float
# cgm_hbgi                                                          float
# cgm_hyper_index                                                   float
# cgm_hypo_index                                                    float
# cgm_igc                                                           float
# cgm_iqr                                                           float
# cgm_j_index                                                       float
# cgm_lbgi                                                          float
# cgm_m_value                                                       float
# cgm_mad                                                           float
# cgm_mag                                                           float
# cgm_mage                                                          float
# cgm_min_                                                          float
# cgm_max_                                                          float
# cgm_mean                                                          float
# cgm_median                                                        float
# cgm_modd                                                          float
# cgm_range                                                         float
# cgm_sd                                                            float
# cgm_sd_roc                                                        float
# cgm_sdb                                                           float
# cgm_sdbdm                                                         float
# cgm_sddm                                                          float
# cgm_sdhhmm                                                        float
# cgm_sdw                                                           float
# cgm_sdwsh                                                         float
# collection_date                          datetime64[ns, Asia/Jerusalem]
# connection_day                                                      int
# cgm_daily_1st_quartile                                            float
# cgm_daily_3rd_quartile                                            float
# cgm_daily_above_140                                               float
# cgm_daily_above_180                                               float
# cgm_daily_above_250                                               float
# cgm_daily_below_54                                                float
# cgm_daily_below_70                                                float
# cgm_daily_in_range_63_140                                         float
# cgm_daily_in_range_70_180                                         float
# cgm_daily_adrr                                                    float
# cgm_daily_auc                                                     float
# cgm_daily_cogi                                                    float
# cgm_daily_cv                                                      float
# cgm_daily_ea1c                                                    float
# cgm_daily_gmi                                                     float
# cgm_daily_grade                                                   float
# cgm_daily_grade_eugly                                             float
# cgm_daily_grade_hyper                                             float
# cgm_daily_grade_hypo                                              float
# cgm_daily_gvp                                                     float
# cgm_daily_hbgi                                                    float
# cgm_daily_hyper_index                                             float
# cgm_daily_hypo_index                                              float
# cgm_daily_igc                                                     float
# cgm_daily_iqr                                                     float
# cgm_daily_j_index                                                 float
# cgm_daily_lbgi                                                    float
# cgm_daily_m_value                                                 float
# cgm_daily_mad                                                     float
# cgm_daily_mag                                                     float
# cgm_daily_mage                                                    float
# cgm_daily_min                                                     float
# cgm_daily_max                                                     float
# cgm_daily_mean                                                    float
# cgm_daily_median                                                  float
# cgm_daily_range                                                   float
# cgm_daily_sd                                                      float
# cgm_daily_sd_roc                                                  float
# cgm_daily_sdwsh                                                   float
# timezone                                                         string
#
#                                         parent_dataframe
# tabular_field_name
# connection_id                                        NaN
# cgm_time_series                                      NaN
# glucose                                  cgm_time_series
# collection_timestamp                                 NaN
# cgm_first_date                                       NaN
# cgm_last_date                                        NaN
# cgm_device_type                                      NaN
# cgm_datapoints_lost_in_qc                            NaN
# percentage_of_cgm_datapoints_lost_in_qc              NaN
# number_of_cgm_days_available                         NaN
# number_of_cgm_datapoints_available                   NaN
# timezone                                             NaN
# cgm_1st_quartile                                     NaN
# cgm_3rd_quartile                                     NaN
# cgm_above_140                                        NaN
# cgm_above_180                                        NaN
# cgm_above_250                                        NaN
# cgm_below_54                                         NaN
# cgm_below_70                                         NaN
# cgm_in_range_63_140                                  NaN
# cgm_in_range_70_180                                  NaN
# cgm_adrr                                             NaN
# cgm_auc                                              NaN
# cgm_cogi                                             NaN
# cgm_conga                                            NaN
# cgm_cv                                               NaN
# cgm_cv_measures_mean                                 NaN
# cgm_cv_measures_sd                                   NaN
# cgm_ea1c                                             NaN
# cgm_gmi                                              NaN
# cgm_grade                                            NaN
# cgm_grade_eugly                                      NaN
# cgm_grade_hyper                                      NaN
# cgm_grade_hypo                                       NaN
# cgm_gvp                                              NaN
# cgm_hbgi                                             NaN
# cgm_hyper_index                                      NaN
# cgm_hypo_index                                       NaN
# cgm_igc                                              NaN
# cgm_iqr                                              NaN
# cgm_j_index                                          NaN
# cgm_lbgi                                             NaN
# cgm_m_value                                          NaN
# cgm_mad                                              NaN
# cgm_mag                                              NaN
# cgm_mage                                             NaN
# cgm_min_                                             NaN
# cgm_max_                                             NaN
# cgm_mean                                             NaN
# cgm_median                                           NaN
# cgm_modd                                             NaN
# cgm_range                                            NaN
# cgm_sd                                               NaN
# cgm_sd_roc                                           NaN
# cgm_sdb                                              NaN
# cgm_sdbdm                                            NaN
# cgm_sddm                                             NaN
# cgm_sdhhmm                                           NaN
# cgm_sdw                                              NaN
# cgm_sdwsh                                            NaN
# collection_date                                      NaN
# connection_day                                       NaN
# cgm_daily_1st_quartile                               NaN
# cgm_daily_3rd_quartile                               NaN
# cgm_daily_above_140                                  NaN
# cgm_daily_above_180                                  NaN
# cgm_daily_above_250                                  NaN
# cgm_daily_below_54                                   NaN
# cgm_daily_below_70                                   NaN
# cgm_daily_in_range_63_140                            NaN
# cgm_daily_in_range_70_180                            NaN
# cgm_daily_adrr                                       NaN
# cgm_daily_auc                                        NaN
# cgm_daily_cogi                                       NaN
# cgm_daily_cv                                         NaN
# cgm_daily_ea1c                                       NaN
# cgm_daily_gmi                                        NaN
# cgm_daily_grade                                      NaN
# cgm_daily_grade_eugly                                NaN
# cgm_daily_grade_hyper                                NaN
# cgm_daily_grade_hypo                                 NaN
# cgm_daily_gvp                                        NaN
# cgm_daily_hbgi                                       NaN
# cgm_daily_hyper_index                                NaN
# cgm_daily_hypo_index                                 NaN
# cgm_daily_igc                                        NaN
# cgm_daily_iqr                                        NaN
# cgm_daily_j_index                                    NaN
# cgm_daily_lbgi                                       NaN
# cgm_daily_m_value                                    NaN
# cgm_daily_mad                                        NaN
# cgm_daily_mag                                        NaN
# cgm_daily_mage                                       NaN
# cgm_daily_min                                        NaN
# cgm_daily_max                                        NaN
# cgm_daily_mean                                       NaN
# cgm_daily_median                                     NaN
# cgm_daily_range                                      NaN
# cgm_daily_sd                                         NaN
# cgm_daily_sd_roc                                     NaN
# cgm_daily_sdwsh                                      NaN
# timezone                                             NaN
