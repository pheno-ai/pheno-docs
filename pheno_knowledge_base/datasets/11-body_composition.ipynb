# %% [raw]
# ---
# output-file: 11-body_composition.html
# title: 11-body_composition
# ---

# %% [markdown]
# # Body composition (DXA) dataset
#
# Body composition was profiled based on DXA (dual-energy x-ray absorptiometry) imaging, and includes measurements of fat and lean mass for the legs, arms, trunk, gynoid, and android, as well as measurements of total scan visceral adipose tissue (VAT) and subcutaneous adipose tissue (SAT) area, mass and volume are included.
#
# DXA (dual-energy x-ray absorptiometry) is a medical imaging technique that is used to measure body composition, specifically the amounts of bone, fat, and lean muscle tissue in the body. A DXA scan uses a low dose of ionizing radiation to produce a detailed image of the body, which is then analyzed by a software to determine the body composition. This method is considered to be one of the most accurate methods for measuring body composition, as it is able to distinguish between different types of tissue and provide detailed information about the distribution of fat and muscle in the body. DXA imaging is commonly used for assessing bone density and for monitoring changes in body composition over time, such as during weight loss, muscle building programs or for assessment of sarcopenia.
#
# ### Data availability:
# The information is stored in 1 parquet file: `body_composition.parquet`

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('body_composition', unique_index=True)
dl
# Out:
# DataLoader for body_composition with
# 157 fields
# 2 tables: ['body_composition', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                                                                   field_string  \
# tabular_field_name
# collection_date                                   Collection date (YYYY-MM-DD)
# timezone                                                              Timezone
# collection_timestamp                                      Collection timestamp
# body_comp_android_bone_mass                 Body composition android bone mass
# body_comp_android_fat_free_mass         Body composition android fat free mass
# ...                                                                        ...
# total_scan_sat_mass                Total scan subcutaneous adipose tissue mass
# total_scan_sat_volume            Total scan subcutaneous adipose tissue volume
# total_scan_vat_area                    Total scan visceral adipose tissue area
# total_scan_vat_mass                    Total scan visceral adipose tissue mass
# total_scan_vat_volume                Total scan visceral adipose tissue volume
#
#                                                                 description_string  \
# tabular_field_name
# collection_date                                       Collection date (YYYY-MM-DD)
# timezone                                                                  Timezone
# collection_timestamp                                          Collection timestamp
# body_comp_android_bone_mass                     Body composition android bone mass
# body_comp_android_fat_free_mass             Body composition android fat free mass
# ...                                                                            ...
# total_scan_sat_mass              Total scan subcutaneous adipose tissue (SAT) mass
# total_scan_sat_volume            Total scan subcutaneous adipose tissue (SAT) v...
# total_scan_vat_area                  Total scan visceral adipose tissue (VAT) area
# total_scan_vat_mass                  Total scan visceral adipose tissue (VAT) mass
# total_scan_vat_volume              Total scan visceral adipose tissue (VAT) volume
#
#                                  parent_dataframe  \
# tabular_field_name
# collection_date                               NaN
# timezone                                      NaN
# collection_timestamp                          NaN
# body_comp_android_bone_mass                   NaN
# body_comp_android_fat_free_mass               NaN
# ...                                           ...
# total_scan_sat_mass                           NaN
# total_scan_sat_volume                         NaN
# total_scan_vat_area                           NaN
# total_scan_vat_mass                           NaN
# total_scan_vat_volume                         NaN
#
#                                                           relative_location  \
# tabular_field_name
# collection_date                  /body_composition/body_composition.parquet
# timezone                         /body_composition/body_composition.parquet
# collection_timestamp             /body_composition/body_composition.parquet
# body_comp_android_bone_mass      /body_composition/body_composition.parquet
# body_comp_android_fat_free_mass  /body_composition/body_composition.parquet
# ...                                                                     ...
# total_scan_sat_mass              /body_composition/body_composition.parquet
# total_scan_sat_volume            /body_composition/body_composition.parquet
# total_scan_vat_area              /body_composition/body_composition.parquet
# total_scan_vat_mass              /body_composition/body_composition.parquet
# total_scan_vat_volume            /body_composition/body_composition.parquet
#
#                                  value_type units  sampling_rate item_type  \
# tabular_field_name
# collection_date                         NaN  Time            NaN       NaN
# timezone                                NaN   NaN            NaN       NaN
# collection_timestamp                   Date  Time            NaN      Data
# body_comp_android_bone_mass      Continuous  gram            NaN      Data
# body_comp_android_fat_free_mass  Continuous  gram            NaN      Data
# ...                                     ...   ...            ...       ...
# total_scan_sat_mass              Continuous  gram            NaN      Data
# total_scan_sat_volume            Continuous  cm^3            NaN      Data
# total_scan_vat_area              Continuous  cm^2            NaN      Data
# total_scan_vat_mass              Continuous  gram            NaN      Data
# total_scan_vat_volume            Continuous  cm^3            NaN      Data
#
#                                   array cohorts data_type       debut  \
# tabular_field_name
# collection_date                     NaN     NaN       NaN         NaN
# timezone                            NaN     NaN       NaN         NaN
# collection_timestamp             Single     10K   tabular  2020-06-09
# body_comp_android_bone_mass      Single     10K   tabular  2020-06-09
# body_comp_android_fat_free_mass  Single     10K   tabular  2020-06-09
# ...                                 ...     ...       ...         ...
# total_scan_sat_mass              Single     10K   tabular  2020-06-09
# total_scan_sat_volume            Single     10K   tabular  2020-06-09
# total_scan_vat_area              Single     10K   tabular  2020-06-09
# total_scan_vat_mass              Single     10K   tabular  2020-06-09
# total_scan_vat_volume            Single     10K   tabular  2020-06-09
#
#                                                    pandas_dtype
# tabular_field_name
# collection_date                                  datetime64[ns]
# timezone                                                 string
# collection_timestamp             datetime64[ns, Asia/Jerusalem]
# body_comp_android_bone_mass                               float
# body_comp_android_fat_free_mass                           float
# ...                                                         ...
# total_scan_sat_mass                                       float
# total_scan_sat_volume                                     float
# total_scan_vat_area                                       float
# total_scan_vat_mass                                       float
# total_scan_vat_volume                                     float
#
# [155 rows x 13 columns]
