# %% [raw]
# ---
# output-file: 041-ukbb_followup_questionnaire.html
# title: 041-ukbb_followup_questionnaire
# ---

# %% [markdown]
# # UKBB Followup Questionnaire
#
# This lifestyle questionnaire is an adaptation of the UK Biobank touch screen questionnaire.
# The full version is sent to the participants via email and is completed online by them in the Zoho platform, prior or after the baseline visit. The short, followup, questionnaire version is filled by the participants in followup visits.
# Questions asked are related to the participant’s lifestyle and demographics, physical activity, use of cellular phone, diet and eating habits, sleep, smoking and alcohol consumption, family and medical history. The short follow-up version contains only part of the baseline survey, and includes two additional sections; 11 questions from the Minnesota Living With Heart failure questionnaire
# Some of the questions have been adapted to account for cultural differences in Israel compared to the UK.
#
# ### Data availability:
# The information is stored in 2 parquet files: `ukbb_followup_questionnaire.parquet` and `ukbb_mapping.parquet`

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('ukbb_followup_questionnaire')
dl
# Out:
# DataLoader for ukbb_followup_questionnaire with
# 196 fields
# 2 tables: ['ukbb_followup_questionnaire', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                                                                                          field_string  \
# tabular_field_name
# collection_timestamp                                                             Collection timestamp
# collection_date                                                                       Collection date
# timezone                                                                                      Timezon
# study_family_member                                          Family member participates in this study
# study_family_member_participant_id                                       Family member participant ID
# study_family_member_relationship                                 Family member degree of relationship
# study_household_member                                    Household member participates in this study
# study_household_member_participant_id_phone                                                       NaN
# domestic_household_type                                                Type of accommodation lived in
# domestic_household_years                                            Length of time at current address
# domestic_household_people_number                                        Number of people in household
# domestic_household_people_relationship              How are people in household related to partici...
# domestic_household_car_number                                         Number of vehicles in household
# domestic_household_income                                    Average total household income after tax
# domestic_job_status                                                         Current employment status
# domestic_job_years                                                 Years employed in main current job
# domestic_job_months                                               Months employed in main current job
# domestic_job_hours_daily                                           Length of working day for main job
# domestic_job_office_days                            Frequency of travelling from home to job workp...
# domestic_job_transport                                  Transport type for commuting to job workplace
# domestic_job_distance                                       \nDistance between home and job workplace
# domestic_job_walking_standing                                 Job involves mainly walking or standing
# domestic_job_manual_physical                               Job involves heavy manual or physical work
# domestic_job_shifts                                                           Job involves shift work
# domestic_job_night_shift                                                Job involves night shift work
# activity_walking_10min_days_weekly                             Number of days/week walked 10+ minutes
# activity_walking_minutes_daily                                                      Duration of walks
# activity_maderate_days_weekly                       Number of days/week of moderate physical activ...
# activity_moderate_minutes_daily                                         Duration of moderate activity
# activity_vigorous_days_weekly                       Number of days/week of vigorous physical activ...
# activity_vigorous_minutes_daily                                         Duration of vigorous activity
# activity_walking_pace                                                              Usual walking pace
# activity_staires_daily                                    Frequency of stair climbing in last 4 weeks
# activity_transport_types                                     Types of transport used (excluding work)
# activity_physical_types                                    Types of physical activity in last 4 weeks
# activity_walking_pleasure_monthly                   Frequency of walking for pleasure in last 4 weeks
# activity_walking_pleasure_duration                                      Duration walking for pleasure
# activity_other_monthly                                   Frequency of other exercises in last 4 weeks
# activity_other_duration                                                   Duration of other exercises
# activity_strenuous_monthly                              Frequency of strenuous sports in last 4 weeks
# activity_strenuous_duration                                              Duration of strenuous sports
# activity_diy_light_monthly                                                 Frequency of mild exercise
# activity_diy_light_duration                                                 Duration of mild exercise
# activity_diy_heavy_monthly                                                 Frequency of high exercise
# activity_diy_heavy_duration                                                 Duration of high exercise
# activity_social_visit_frequency                                     Frequency of friend/family visits
# activity_social_weekly                                                      Leisure/social activities
# activity_outdoors_summer_daily                                          Time spend outdoors in summer
# activity_outdoors_winter_daily                                          Time spent outdoors in winter
# activity_indoors_tv_daily                                         Time spent watching television (TV)
# activiy_indoors_pc_daily                                                    Time spent using computer
# activity_driving_daily                                                             Time spent driving
# activity_driving_fast_frequency                                Drive faster than motorway speed limit
# sleep_hours_daily                                                                      Sleep duration
# sleep_waking_morning_easy                                                       Getting up in morning
# sleep_chronotype                                                  Morning/evening person (chronotype)
# sleep_nap                                                                              Nap during day
# sleep_insomnia                                                               Sleeplessness / insomnia
# sleep_snoring                                                                                 Snoring
# sleep_daytime                                                               Daytime dozing / sleeping
# smoking_current_status                                                        Current tobacco smoking
# smoking_past_frequency                                                           Past tobacco smoking
# smoking_total_above_100                                Light smokers, at least 100 smokes in lifetime
# smoking_current_age_start_choice                               Age started smoking in current smokers
# smoking_current_age_start_number                               Age started smoking in current smokers
# smoking_tobacco_type_present                                         Type of tobacco currently smoked
# smoking_current_cigar_past_status                       Previously smoked cigarettes on most/all days
# smoking_current_cigar_past_choice                   Number of cigarettes previously smoked daily (...
# smoking_current_cigar_past_number                   Number of cigarettes previously smoked daily (...
# smoking_current_cigar_age_stop_choice               Age stopped smoking cigarettes (current cigar/...
# smoking_current_cigar_age_stop_number               Age stopped smoking cigarettes (current cigar/...
# smoking_current_choice                              Number of cigarettes currently smoked daily (c...
# smoking_current_number                              Number of cigarettes currently smoked daily (c...
# smoking_current_time_after_wake                                   Time from waking to first cigarette
# smoking_current_difficulty_to_avoid_one_day                          Difficulty not smoking for 1 day
# smoking_stop_tried                                                         Ever tried to stop smoking
# smoking_stop_wish                                                               Wants to stop smoking
# smoking_present_vs_past                                         Smoking compared to 10 years previous
# smoking_reduced_why                                                               Why reduced smoking
# smoking_former_age_start_choice                                 Age started smoking in former smokers
# smoking_former_age_start_number                                 Age started smoking in former smokers
# smoking_former_tobacco_type                                         Type of tobacco previously smoked
# smoking_present_choice_dup                          Number of cigarettes currently smoked daily (c...
# smoking_present_number_dup                          Number of cigarettes currently smoked daily (c...
# smoking_former_age_stop_choice                                                    Age stopped smoking
# smoking_former_age_stop_number                                                    Age stopped smoking
# smoking_former_stop_6_month                                        Ever stopped smoking for 6+ months
# smoking_former_stop_why                             Why did you stop smoking? (You can select more...
# smoking_former_stop_attempts_choice                      Number of unsuccessful stop-smoking attempts
# smoking_former_stop_attempts_number                      Number of unsuccessful stop-smoking attempts
# smoking_former_start_again                                             Likelihood of resuming smoking
# smoking_exposure_home                                                    Smoking/smokers in household
# smoking_exposure_home_hours_choice                                  Exposure to tobacco smoke at home
# smoking_exposure_home_hours_number                                  Exposure to tobacco smoke at home
# smoking_exposure_outside_choice                                Exposure to tobacco smoke outside home
# smoking_exposure_outside_hours                                 Exposure to tobacco smoke outside home
# extra_domestic_past_pets                                                                          NaN
# extra_domestic_current_pets                                                                       NaN
# extra_domestic_current_pets_type                                                                  NaN
# extra_domestic_residence_area_type                                                                NaN
# face_current_aging                                                                      Facial ageing
# family_history_father_alive                                                        Father still alive
# family_history_father_age_passing                                               Father's age at death
# family_history_past_father_illness                                                Illnesses of father
# family_history_past_father_illness                                                Illnesses of father
# family_history_mother_alive                                                        Mother still alive
# family_history_mother_age_passing                                               Mother's age at death
# family_history_past_mother_illness                                                Illnesses of mother
# family_history_past_mother_illness                                                Illnesses of mother
# family_history_past_siblings_illness                                            Illnesses of siblings
# family_history_past_siblings_illness                                            Illnesses of siblings
# family_history_number_older_siblings                                         Number of older siblings
# family_history_non_accidental_death                      Non-accidental death in close genetic family
# health_mental_current_mood_swings_frequency                                               Mood swings
# health_mental_current_miserable                                                         Miserableness
# health_mental_current_irritable                                                          Irritability
# health_mental_current_sensitive                                           Sensitivity / hurt feelings
# health_mental_current_fed_up                                                          Fed-up feelings
# health_mental_current_nervous                                                        Nervous feelings
# health_mental_current_worrier                                              Worrier / anxious feelings
# health_mental_current_tense                                                   Tense / 'highly strung'
# health_mental_current_worry_after_embarassment                     Worry too long after embarrassment
# health_mental_current_nerves                                                     Suffer from 'nerves'
# health_mental_current_lonely                                                    Loneliness, isolation
# health_mental_current_guilt                                                           Guilty feelings
# health_mental_current_risk_taker                                                          Risk taking
# health_mental_current_happiness                                                             Happiness
# health_mental_current_satifaction_work                                          Work/job satisfaction
# health_mental_current_satifaction_health                                          Health satisfaction
# health_mental_current_satifaction_family_relations                   Family relationship satisfaction
# health_mental_current_satifaction_friends_relat...                           Friendships satisfaction
# health_mental_current_satifaction_financial                          Financial situation satisfaction
# health_mental_past_two_week_depression_frequency          Frequency of depressed mood in last 2 weeks
# health_mental_past_two_week_disinterest_frequency   Frequency of unenthusiasm / disinterest in las...
# health_mental_past_two_week_restless_frequency      Frequency of tenseness / restlessness in last ...
# health_mental_past_two_week_tired_frequency         Frequency of tiredness / lethargy in last 2 weeks
# health_mental_past_doctor                           Seen doctor (GP) for nerves, anxiety, tension ...
# mental_halth_past_psychiatrist                      Seen a psychiatrist for nerves, anxiety, tensi...
# health_mental_past_depression_week                                    Ever depressed for a whole week
# health_mental_past_depression_longest                                    Longest period of depression
# health_mental_past_depression_episodes_numebr                           Number of depression episodes
# health_mental_past_disinterest_week                 Ever unenthusiastic/disinterested for a whole ...
# health_mental_past_disinterest_longest                   Longest period of unenthusiasm / disinterest
# health_mental_past_disinterest_episodes_numebr        Number of unenthusiastic/disinterested episodes
# health_mental_past_manic_two_days                                         Ever manic/hyper for 2 days
# health_mental_past_irritable_two_days                  Ever highly irritable/argumentative for 2 days
# health_mental_past_manic_symptoms                                                Manic/hyper symptoms
# health_mental_past_manic_irritable_longest                  Length of longest manic/irritable episode
# health_mental_past_manic_irritable_problems                      Severity of manic/irritable episodes
# health_mental_current_able_to_confide                                                 Able to confide
# health_mental_past_two_years_event                  Illness, injury, bereavement, stress in last 2...
# health_general_rating                                                           Overall health rating
# health_eyes_glasses_contacts                                          Wears glasses or contact lenses
# health_eyes_glasses_contacts_start_age                  Age started wearing glasses or contact lenses
# health_eyes_glasses_contacts_reason                                 Reason for glasses/contact lenses
# skin_current_sunscreen_use                                                   Use of sun/uv protection
# health_mouth_problems                                                     Mouth/teeth dental problems
# health_general_past_year_falling                                               Falls in the last year
# health_general_past_year_weight_change                         Weight change compared with 1 year ago
# health_breathing_past_year_wheezing                     Wheeze or whistling in the chest in last year
# health_breathing_shortness_breath_walking                 Shortness of breath walking on level ground
# health_male_current_balding_pattern                                              Hair/balding pattern
# mlhfq_rest_during_day                                                                             NaN
# mlhfq_difficulty_walking                                                                          NaN
# mlhfq_difficulty_house_work                                                                       NaN
# mlhfq_rarely_leave_house                                                                          NaN
# mlhfq_rarely_socialize                                                                            NaN
# mlhfq_difficulty_working                                                                          NaN
# mlhfq_difficulty_maintining_hobbies                                                               NaN
# mlhfq_difficulty_intercourse                                                                      NaN
# mlhfq_fatigue                                                                                     NaN
# mlhfq_liability                                                                                   NaN
# mlhfq_medical_state_concers                                                                       NaN
# extra_health_females_first_mestural_cycle_age                                                     NaN
# extra_health_females_current_mestural_cycle                                                       NaN
# extra_health_females_last_mestural_cycle_age                                                      NaN
# extra_health_females_past_mestural_cycle_regular                                                  NaN
# extra_health_females_current_mestural_cycle_reg...                                                NaN
# extra_health_females_current_avg_mestural_cycle...                                                NaN
# extra_health_females_current_avg_mestural_cycle...                                                NaN
# extra_health_females_current_avg_tampons_per_day                                                  NaN
# extra_health_females_current_bleeding_between_m...                                                NaN
# extra_health_females_current_mestural_cycle_pains                                                 NaN
# extra_health_females_current_mestural_cycle_sym...                                                NaN
# extra_health_females_current_birth_control                                                        NaN
# extra_health_females_current_birth_control_type                                                   NaN
# extra_health_females_current_manopause_symptoms                                                   NaN
# extra_health_females_first_hot_flash_age                                                          NaN
# extra_health_females_first_vaginal_dryness_age                                                    NaN
# extra_health_females_first_dicreased_libido_age                                                   NaN
# extra_health_females_first_mood_changes_age                                                       NaN
# extra_health_females_first_skin_dryness_age                                                       NaN
# extra_health_females_current_hrt                                                                  NaN
# extra_health_females_current_hrt_type                                                             NaN
# extra_health_females_past_recurring_uti                                                           NaN
# extra_health_females_past_uti_antibiotics                                                         NaN
# ukbb_mapping                                                                 UKBB survey code mapping
#
#                                                                                    description_string  \
# tabular_field_name
# collection_timestamp                                                                              NaN
# collection_date                                                                                   NaN
# timezone                                                                      TImezone of measurement
# study_family_member                                 Is a member of your family a participant in th...
# study_family_member_participant_id                                      What is their participant ID?
# study_family_member_relationship                       What is your degree of relationship with them?
# study_household_member                              Does anyone in your household participate in t...
# study_household_member_participant_id_phone                                                       NaN
# domestic_household_type                                    What type of accommodation do you live in?
# domestic_household_years                            How many years have you lived at your current ...
# domestic_household_people_number                    Including yourself, how many people are living...
# domestic_household_people_relationship              How are the other people who live with you rel...
# domestic_household_car_number                       How many cars or vans are owned, or available ...
# domestic_household_income                           What is the average total income after tax rec...
# domestic_job_status                                 Which of the following describes your current ...
# domestic_job_years                                  How many years have you worked in your current...
# domestic_job_months                                 How many months have you worked in your curren...
# domestic_job_hours_daily                            In a typical DAY, how many hours do you spend ...
# domestic_job_office_days                            How many days a WEEK do you travel from home t...
# domestic_job_transport                              What types of transport do you use to get to a...
# domestic_job_distance                               About how many km is it between your home and ...
# domestic_job_walking_standing                       Does your work involve walking or standing for...
# domestic_job_manual_physical                        Does your work involve heavy manual or physica...
# domestic_job_shifts                                                Does your work involve shift work?
# domestic_job_night_shift                                         Does your work involve night shifts?
# activity_walking_10min_days_weekly                  In a typical WEEK, on how many days did you wa...
# activity_walking_minutes_daily                      How many minutes did you usually spend walking...
# activity_maderate_days_weekly                       In a typical WEEK, on how many days did you do...
# activity_moderate_minutes_daily                     How many minutes did you usually spend doing m...
# activity_vigorous_days_weekly                       In a typical WEEK, how many days did you do 10...
# activity_vigorous_minutes_daily                     How many minutes did you usually spend doing v...
# activity_walking_pace                                 How would you describe your usual walking pace?
# activity_staires_daily                              At home, during the last 4 weeks, about how ma...
# activity_transport_types                            In the last 4 weeks, which forms of transport ...
# activity_physical_types                             In the last 4 weeks did you spend any time doi...
# activity_walking_pleasure_monthly                   How many times in the last 4 weeks did you go ...
# activity_walking_pleasure_duration                  Each time you went walking for pleasure, about...
# activity_other_monthly                              How many times in the last 4 weeks did you do ...
# activity_other_duration                             Each time you did other exercises such as swim...
# activity_strenuous_monthly                          How many times in the last 4 weeks did you do ...
# activity_strenuous_duration                         Each time you did strenuous sports, about how ...
# activity_diy_light_monthly                          How many times in the last 4 weeks did you do ...
# activity_diy_light_duration                         Each time you did light DIY, about how long di...
# activity_diy_heavy_monthly                          How many times in the last 4 weeks did you do ...
# activity_diy_heavy_duration                         Each time you did heavy DIY, about how long di...
# activity_social_visit_frequency                     How often do you visit friends or family or ha...
# activity_social_weekly                              Which of the following do you attend once a we...
# activity_outdoors_summer_daily                      In a typical DAY in summer, how many hours do ...
# activity_outdoors_winter_daily                      In a typical DAY in winter, how many hours do ...
# activity_indoors_tv_daily                           In a typical DAY, how many hours do you spend ...
# activiy_indoors_pc_daily                            In a typical DAY, how many hours do you spend ...
# activity_driving_daily                              In a typical DAY, how many hours do you spend ...
# activity_driving_fast_frequency                     How often do you drive faster than the speed l...
# sleep_hours_daily                                   About how many hours sleep do you get in every...
# sleep_waking_morning_easy                           On an average day, how easy do you find gettin...
# sleep_chronotype                                                      Do you consider yourself to be?
# sleep_nap                                                           Do you have a nap during the day?
# sleep_insomnia                                      Do you have trouble falling asleep at night or...
# sleep_snoring                                       Does your partner or a close relative or frien...
# sleep_daytime                                       How likely are you to doze off or fall asleep ...
# smoking_current_status                                                      Do you smoke tobacco now?
# smoking_past_frequency                                In the past, how often have you smoked tobacco?
# smoking_total_above_100                             In your lifetime, have you smoked a total of a...
# smoking_current_age_start_choice                    How old were you when you first started smokin...
# smoking_current_age_start_number                    How old were you when you first started smokin...
# smoking_tobacco_type_present                                What type of tobacco do you mainly smoke?
# smoking_current_cigar_past_status                   Did you previously smoke cigarettes on most or...
# smoking_current_cigar_past_choice                   About how many cigarettes did you smoke on ave...
# smoking_current_cigar_past_number                   About how many cigarettes did you smoke on ave...
# smoking_current_cigar_age_stop_choice               How old were you when you last smoked cigarett...
# smoking_current_cigar_age_stop_number               How old were you when you last smoked cigarett...
# smoking_current_choice                              About how many cigarettes do you smoke on aver...
# smoking_current_number                              About how many cigarettes do you smoke on aver...
# smoking_current_time_after_wake                     How soon after waking do you smoke your first ...
# smoking_current_difficulty_to_avoid_one_day         How easy or difficult would you find it to go ...
# smoking_stop_tried                                                 Have you tried to give up smoking?
# smoking_stop_wish                                                        Do you want to stop smoking?
# smoking_present_vs_past                                      Compared to 10 years ago do you smoke...
# smoking_reduced_why                                 Why did you reduce your smoking? (You can sele...
# smoking_former_age_start_choice                     How old were you when you first started smokin...
# smoking_former_age_start_number                     How old were you when you first started smokin...
# smoking_former_tobacco_type                               What type of tobacco did you usually smoke?
# smoking_present_choice_dup                          About how many cigarettes did you smoke on ave...
# smoking_present_number_dup                          About how many cigarettes did you smoke on ave...
# smoking_former_age_stop_choice                      How old were you when you last smoked on most ...
# smoking_former_age_stop_number                      How old were you when you last smoked on most ...
# smoking_former_stop_6_month                         In the time that you smoked, did you ever stop...
# smoking_former_stop_why                             Why did you stop smoking? (You can select more...
# smoking_former_stop_attempts_choice                 How many times did you try to give up smoking ...
# smoking_former_stop_attempts_number                 How many times did you try to give up smoking ...
# smoking_former_start_again                                  Do you think you may start smoking again?
# smoking_exposure_home                                            Does anyone in your household smoke?
# smoking_exposure_home_hours_choice                  At home, about how many hours per WEEK are you...
# smoking_exposure_home_hours_number                  At home, about how many hours per WEEK are you...
# smoking_exposure_outside_choice                     Outside of your home, about how many hours per...
# smoking_exposure_outside_hours                      Outside of your home, about how many hours per...
# extra_domestic_past_pets                                                                          NaN
# extra_domestic_current_pets                                                                       NaN
# extra_domestic_current_pets_type                                                                  NaN
# extra_domestic_residence_area_type                                                                NaN
# face_current_aging                                                       Do people say that you look:
# family_history_father_alive                                               Is your father still alive?
# family_history_father_age_passing                                      What was his age when he died?
# family_history_past_father_illness                  Has/did your father ever suffer from? (You can...
# family_history_past_father_illness                  Has/did your father ever suffer from? (You can...
# family_history_mother_alive                                               Is your mother still alive?
# family_history_mother_age_passing                                     What was her age when she died?
# family_history_past_mother_illness                  Has/did your mother ever suffer from? (You can...
# family_history_past_mother_illness                  Has/did your mother ever suffer from? (You can...
# family_history_past_siblings_illness                Have any of your brothers or sisters suffered ...
# family_history_past_siblings_illness                Have any or your brothers or sisters suffered ...
# family_history_number_older_siblings                How many OLDER brothers/sisters do you have? (...
# family_history_non_accidental_death                 Have any of your mother, father, brothers or s...
# health_mental_current_mood_swings_frequency                      Does your mood often go up and down?
# health_mental_current_miserable                      Do you ever feel 'just miserable' for no reason?
# health_mental_current_irritable                                          Are you an irritable person?
# health_mental_current_sensitive                                        Are your feelings easily hurt?
# health_mental_current_fed_up                                              Do you often feel 'fed-up'?
# health_mental_current_nervous                               Would you call yourself a nervous person?
# health_mental_current_worrier                                                      Are you a worrier?
# health_mental_current_tense                         Would you call yourself tense or 'highly strung'?
# health_mental_current_worry_after_embarassment      Do you worry too long after an embarrassing ex...
# health_mental_current_nerves                                             Do you suffer from 'nerves'?
# health_mental_current_lonely                                                Do you often feel lonely?
# health_mental_current_guilt                              Are you often troubled by feelings of guilt?
# health_mental_current_risk_taker                    Would you describe yourself as someone who tak...
# health_mental_current_happiness                                         In general how happy are you?
# health_mental_current_satifaction_work              In general how satisfied are you with the WORK...
# health_mental_current_satifaction_health            In general how satisfied are you with your HEA...
# health_mental_current_satifaction_family_relations  In general how satisfied are you with your FAM...
# health_mental_current_satifaction_friends_relat...  In general how satisfied are you with your FRI...
# health_mental_current_satifaction_financial         In general how satisfied are you with your FIN...
# health_mental_past_two_week_depression_frequency    Over the past two weeks, how often have you fe...
# health_mental_past_two_week_disinterest_frequency   Over the past two weeks, how often have you ha...
# health_mental_past_two_week_restless_frequency      Over the past two weeks, how often have you fe...
# health_mental_past_two_week_tired_frequency         Over the past two weeks, how often have you fe...
# health_mental_past_doctor                           Have you ever seen a general practitioner (GP)...
# mental_halth_past_psychiatrist                      Have you ever seen a psychiatrist for nerves, ...
# health_mental_past_depression_week                  Looking back over your life, have you ever had...
# health_mental_past_depression_longest               How many weeks was the longest period when you...
# health_mental_past_depression_episodes_numebr       How many periods have you had when you were fe...
# health_mental_past_disinterest_week                 Have you ever had a time when you were uninter...
# health_mental_past_disinterest_longest              How many weeks was the longest period when you...
# health_mental_past_disinterest_episodes_numebr      How many periods have you had when you were un...
# health_mental_past_manic_two_days                   Have you ever had a period of time lasting at ...
# health_mental_past_irritable_two_days               Have you ever had a period of time lasting at ...
# health_mental_past_manic_symptoms                   Please try to remember a period when you were ...
# health_mental_past_manic_irritable_longest          What is the longest time period that these "hi...
# health_mental_past_manic_irritable_problems         How much of a problem have these "high" or "ir...
# health_mental_current_able_to_confide               How often are you able to confide in someone c...
# health_mental_past_two_years_event                  In the last 2 years have you experienced any o...
# health_general_rating                               In general how would you rate your overall hea...
# health_eyes_glasses_contacts                        Do you wear glasses or contact lenses to corre...
# health_eyes_glasses_contacts_start_age              What age did you first start to wear glasses o...
# health_eyes_glasses_contacts_reason                 Why were you prescribed glasses/contacts? (You...
# skin_current_sunscreen_use                          Do you wear sun protection (e.g. sunscreen lot...
# health_mouth_problems                               Do you have any of the following? (You can sel...
# health_general_past_year_falling                             In the last year have you had any falls?
# health_general_past_year_weight_change              Compared with one year ago, has your weight ch...
# health_breathing_past_year_wheezing                 In the last year have you ever had wheeze or w...
# health_breathing_shortness_breath_walking           Do you get short of breath walking with people...
# health_male_current_balding_pattern                 Which of the following best describes your hai...
# mlhfq_rest_during_day                                                                             NaN
# mlhfq_difficulty_walking                                                                          NaN
# mlhfq_difficulty_house_work                                                                       NaN
# mlhfq_rarely_leave_house                                                                          NaN
# mlhfq_rarely_socialize                                                                            NaN
# mlhfq_difficulty_working                                                                          NaN
# mlhfq_difficulty_maintining_hobbies                                                               NaN
# mlhfq_difficulty_intercourse                                                                      NaN
# mlhfq_fatigue                                                                                     NaN
# mlhfq_liability                                                                                   NaN
# mlhfq_medical_state_concers                                                                       NaN
# extra_health_females_first_mestural_cycle_age                                                     NaN
# extra_health_females_current_mestural_cycle                                                       NaN
# extra_health_females_last_mestural_cycle_age                                                      NaN
# extra_health_females_past_mestural_cycle_regular                                                  NaN
# extra_health_females_current_mestural_cycle_reg...                                                NaN
# extra_health_females_current_avg_mestural_cycle...                                                NaN
# extra_health_females_current_avg_mestural_cycle...                                                NaN
# extra_health_females_current_avg_tampons_per_day                                                  NaN
# extra_health_females_current_bleeding_between_m...                                                NaN
# extra_health_females_current_mestural_cycle_pains                                                 NaN
# extra_health_females_current_mestural_cycle_sym...                                                NaN
# extra_health_females_current_birth_control                                                        NaN
# extra_health_females_current_birth_control_type                                                   NaN
# extra_health_females_current_manopause_symptoms                                                   NaN
# extra_health_females_first_hot_flash_age                                                          NaN
# extra_health_females_first_vaginal_dryness_age                                                    NaN
# extra_health_females_first_dicreased_libido_age                                                   NaN
# extra_health_females_first_mood_changes_age                                                       NaN
# extra_health_females_first_skin_dryness_age                                                       NaN
# extra_health_females_current_hrt                                                                  NaN
# extra_health_females_current_hrt_type                                                             NaN
# extra_health_females_past_recurring_uti                                                           NaN
# extra_health_females_past_uti_antibiotics                                                         NaN
# ukbb_mapping                                        Mappings of survey codes to English and Hebrew...
#
#                                                                                     relative_location  \
# tabular_field_name
# collection_timestamp                                ukbb_followup_questionnaire/ukbb_followup_ques...
# collection_date                                     ukbb_followup_questionnaire/ukbb_followup_ques...
# timezone                                            ukbb_followup_questionnaire/ukbb_followup_ques...
# study_family_member                                 ukbb_followup_questionnaire/ukbb_followup_ques...
# study_family_member_participant_id                  ukbb_followup_questionnaire/ukbb_followup_ques...
# study_family_member_relationship                    ukbb_followup_questionnaire/ukbb_followup_ques...
# study_household_member                              ukbb_followup_questionnaire/ukbb_followup_ques...
# study_household_member_participant_id_phone         ukbb_followup_questionnaire/ukbb_followup_ques...
# domestic_household_type                             ukbb_followup_questionnaire/ukbb_followup_ques...
# domestic_household_years                            ukbb_followup_questionnaire/ukbb_followup_ques...
# domestic_household_people_number                    ukbb_followup_questionnaire/ukbb_followup_ques...
# domestic_household_people_relationship              ukbb_followup_questionnaire/ukbb_followup_ques...
# domestic_household_car_number                       ukbb_followup_questionnaire/ukbb_followup_ques...
# domestic_household_income                           ukbb_followup_questionnaire/ukbb_followup_ques...
# domestic_job_status                                 ukbb_followup_questionnaire/ukbb_followup_ques...
# domestic_job_years                                  ukbb_followup_questionnaire/ukbb_followup_ques...
# domestic_job_months                                 ukbb_followup_questionnaire/ukbb_followup_ques...
# domestic_job_hours_daily                            ukbb_followup_questionnaire/ukbb_followup_ques...
# domestic_job_office_days                            ukbb_followup_questionnaire/ukbb_followup_ques...
# domestic_job_transport                              ukbb_followup_questionnaire/ukbb_followup_ques...
# domestic_job_distance                               ukbb_followup_questionnaire/ukbb_followup_ques...
# domestic_job_walking_standing                       ukbb_followup_questionnaire/ukbb_followup_ques...
# domestic_job_manual_physical                        ukbb_followup_questionnaire/ukbb_followup_ques...
# domestic_job_shifts                                 ukbb_followup_questionnaire/ukbb_followup_ques...
# domestic_job_night_shift                            ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_walking_10min_days_weekly                  ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_walking_minutes_daily                      ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_maderate_days_weekly                       ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_moderate_minutes_daily                     ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_vigorous_days_weekly                       ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_vigorous_minutes_daily                     ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_walking_pace                               ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_staires_daily                              ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_transport_types                            ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_physical_types                             ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_walking_pleasure_monthly                   ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_walking_pleasure_duration                  ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_other_monthly                              ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_other_duration                             ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_strenuous_monthly                          ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_strenuous_duration                         ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_diy_light_monthly                          ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_diy_light_duration                         ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_diy_heavy_monthly                          ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_diy_heavy_duration                         ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_social_visit_frequency                     ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_social_weekly                              ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_outdoors_summer_daily                      ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_outdoors_winter_daily                      ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_indoors_tv_daily                           ukbb_followup_questionnaire/ukbb_followup_ques...
# activiy_indoors_pc_daily                            ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_driving_daily                              ukbb_followup_questionnaire/ukbb_followup_ques...
# activity_driving_fast_frequency                     ukbb_followup_questionnaire/ukbb_followup_ques...
# sleep_hours_daily                                   ukbb_followup_questionnaire/ukbb_followup_ques...
# sleep_waking_morning_easy                           ukbb_followup_questionnaire/ukbb_followup_ques...
# sleep_chronotype                                    ukbb_followup_questionnaire/ukbb_followup_ques...
# sleep_nap                                           ukbb_followup_questionnaire/ukbb_followup_ques...
# ...
# skin_current_sunscreen_use                                       NaN
# health_mouth_problems                                            NaN
# health_general_past_year_falling                                 NaN
# health_general_past_year_weight_change                           NaN
# health_breathing_past_year_wheezing                              NaN
# health_breathing_shortness_breath_walking                        NaN
# health_male_current_balding_pattern                              NaN
# mlhfq_rest_during_day                                            NaN
# mlhfq_difficulty_walking                                         NaN
# mlhfq_difficulty_house_work                                      NaN
# mlhfq_rarely_leave_house                                         NaN
# mlhfq_rarely_socialize                                           NaN
# mlhfq_difficulty_working                                         NaN
# mlhfq_difficulty_maintining_hobbies                              NaN
# mlhfq_difficulty_intercourse                                     NaN
# mlhfq_fatigue                                                    NaN
# mlhfq_liability                                                  NaN
# mlhfq_medical_state_concers                                      NaN
# extra_health_females_first_mestural_cycle_age                    NaN
# extra_health_females_current_mestural_cycle                      NaN
# extra_health_females_last_mestural_cycle_age                     NaN
# extra_health_females_past_mestural_cycle_regular                 NaN
# extra_health_females_current_mestural_cycle_reg...               NaN
# extra_health_females_current_avg_mestural_cycle...               NaN
# extra_health_females_current_avg_mestural_cycle...               NaN
# extra_health_females_current_avg_tampons_per_day                 NaN
# extra_health_females_current_bleeding_between_m...               NaN
# extra_health_females_current_mestural_cycle_pains                NaN
# extra_health_females_current_mestural_cycle_sym...               NaN
# extra_health_females_current_birth_control                       NaN
# extra_health_females_current_birth_control_type                  NaN
# extra_health_females_current_manopause_symptoms                  NaN
# extra_health_females_first_hot_flash_age                         NaN
# extra_health_females_first_vaginal_dryness_age                   NaN
# extra_health_females_first_dicreased_libido_age                  NaN
# extra_health_females_first_mood_changes_age                      NaN
# extra_health_females_first_skin_dryness_age                      NaN
# extra_health_females_current_hrt                                 NaN
# extra_health_females_current_hrt_type                            NaN
# extra_health_females_past_recurring_uti                          NaN
# extra_health_females_past_uti_antibiotics                        NaN
# ukbb_mapping                                                     NaN
#
#                                                    data_coding
# tabular_field_name
# collection_timestamp                                       NaN
# collection_date                                            NaN
# timezone                                                   NaN
# study_family_member                                          7
# study_family_member_participant_id                         NaN
# study_family_member_relationship                       P100200
# study_household_member                                       7
# study_household_member_participant_id_phone                NaN
# domestic_household_type                                 100286
# domestic_household_years                                   NaN
# domestic_household_people_number                           NaN
# domestic_household_people_relationship                 P100292
# domestic_household_car_number                           100293
# domestic_household_income                              P100294
# domestic_job_status                                    P100295
# domestic_job_years                                         NaN
# domestic_job_months                                        NaN
# domestic_job_hours_daily                                   NaN
# domestic_job_office_days                                   NaN
# domestic_job_transport                                 P100299
# domestic_job_distance                                      NaN
# domestic_job_walking_standing                           100301
# domestic_job_manual_physical                            100301
# domestic_job_shifts                                     100301
# domestic_job_night_shift                                100301
# activity_walking_10min_days_weekly                         NaN
# activity_walking_minutes_daily                             NaN
# activity_maderate_days_weekly                              NaN
# activity_moderate_minutes_daily                            NaN
# activity_vigorous_days_weekly                              NaN
# activity_vigorous_minutes_daily                            NaN
# activity_walking_pace                                  P100313
# activity_staires_daily                                  100314
# activity_transport_types                                100299
# activity_physical_types                                 100316
# activity_walking_pleasure_monthly                      P100317
# activity_walking_pleasure_duration                      100318
# activity_other_monthly                                  100317
# activity_other_duration                                 100318
# activity_strenuous_monthly                              100317
# activity_strenuous_duration                             100318
# activity_diy_light_monthly                              100317
# activity_diy_light_duration                             100318
# activity_diy_heavy_monthly                              100317
# activity_diy_heavy_duration                             100318
# activity_social_visit_frequency                         100327
# activity_social_weekly                                  100328
# activity_outdoors_summer_daily                             NaN
# activity_outdoors_winter_daily                             NaN
# activity_indoors_tv_daily                                  NaN
# activiy_indoors_pc_daily                                   NaN
# activity_driving_daily                                     NaN
# activity_driving_fast_frequency                         100334
# sleep_hours_daily                                          NaN
# sleep_waking_morning_easy                               100341
# sleep_chronotype                                        100342
# sleep_nap                                               100343
# sleep_insomnia                                          100343
# sleep_snoring                                           100345
# sleep_daytime                                          P100346
# smoking_current_status                                  100347
# smoking_past_frequency                                  100348
# smoking_total_above_100                                 100349
# smoking_current_age_start_choice                       P100291
# smoking_current_age_start_number                           NaN
# smoking_tobacco_type_present                            100351
# smoking_current_cigar_past_status                       100352
# smoking_current_cigar_past_choice                      P100353
# smoking_current_cigar_past_number                          NaN
# smoking_current_cigar_age_stop_choice                  P100291
# smoking_current_cigar_age_stop_number                      NaN
# smoking_current_choice                                 P100355
# smoking_current_number                                     NaN
# smoking_current_time_after_wake                         100356
# smoking_current_difficulty_to_avoid_one_day             100357
# smoking_stop_tried                                     P100358
# smoking_stop_wish                                       100359
# smoking_present_vs_past                                 100360
# smoking_reduced_why                                     100361
# smoking_former_age_start_choice                        P100291
# smoking_former_age_start_number                            NaN
# smoking_former_tobacco_type                             100351
# smoking_present_choice_dup                             P100355
# smoking_present_number_dup                                 NaN
# smoking_former_age_stop_choice                         P100291
# smoking_former_age_stop_number                             NaN
# smoking_former_stop_6_month                             100349
# smoking_former_stop_why                                 100361
# smoking_former_stop_attempts_choice                  P100291_1
# smoking_former_stop_attempts_number                        NaN
# smoking_former_start_again                              100369
# smoking_exposure_home                                   100370
# smoking_exposure_home_hours_choice                   P100291_1
# smoking_exposure_home_hours_number                         NaN
# smoking_exposure_outside_choice                      P100291_1
# smoking_exposure_outside_hours                             NaN
# extra_domestic_past_pets                                     7
# extra_domestic_current_pets                                  7
# extra_domestic_current_pets_type                          UKB9
# extra_domestic_residence_area_type                       UKB10
# face_current_aging                                      100435
# family_history_father_alive                             100349
# family_history_father_age_passing                          NaN
# family_history_past_father_illness                        1010
# family_history_past_father_illness                        1010
# family_history_mother_alive                             100349
# family_history_mother_age_passing                          NaN
# family_history_past_mother_illness                        1010
# family_history_past_mother_illness                        1010
# family_history_past_siblings_illness                      1010
# family_history_past_siblings_illness                      1010
# family_history_number_older_siblings                       NaN
# family_history_non_accidental_death                     100349
# health_mental_current_mood_swings_frequency             100349
# health_mental_current_miserable                         100349
# health_mental_current_irritable                         100349
# health_mental_current_sensitive                         100349
# health_mental_current_fed_up                            100349
# health_mental_current_nervous                           100349
# health_mental_current_worrier                           100349
# health_mental_current_tense                             100349
# health_mental_current_worry_after_embarassment          100349
# health_mental_current_nerves                            100349
# health_mental_current_lonely                            100349
# health_mental_current_guilt                             100349
# health_mental_current_risk_taker                        100349
# health_mental_current_happiness                        P100478
# health_mental_current_satifaction_work                  100479
# health_mental_current_satifaction_health                100478
# health_mental_current_satifaction_family_relations      100478
# health_mental_current_satifaction_friends_relat...      100478
# health_mental_current_satifaction_financial             100478
# health_mental_past_two_week_depression_frequency        100484
# health_mental_past_two_week_disinterest_frequency       100484
# health_mental_past_two_week_restless_frequency          100484
# health_mental_past_two_week_tired_frequency             100484
# health_mental_past_doctor                               100349
# mental_halth_past_psychiatrist                          100349
# health_mental_past_depression_week                      100349
# health_mental_past_depression_longest                      NaN
# health_mental_past_depression_episodes_numebr              NaN
# health_mental_past_disinterest_week                     100349
# health_mental_past_disinterest_longest                     NaN
# health_mental_past_disinterest_episodes_numebr             NaN
# health_mental_past_manic_two_days                       100349
# health_mental_past_irritable_two_days                   100349
# health_mental_past_manic_symptoms                       100498
# health_mental_past_manic_irritable_longest              100499
# health_mental_past_manic_irritable_problems             100500
# health_mental_current_able_to_confide                   100501
# health_mental_past_two_years_event                      100502
# health_general_rating                                   100508
# health_eyes_glasses_contacts                            100349
# health_eyes_glasses_contacts_start_age                     NaN
# health_eyes_glasses_contacts_reason                     100514
# skin_current_sunscreen_use                              100536
# health_mouth_problems                                   100538
# health_general_past_year_falling                        100539
# health_general_past_year_weight_change                  100540
# health_breathing_past_year_wheezing                     100349
# health_breathing_shortness_breath_walking               100349
# health_male_current_balding_pattern                     100572
# mlhfq_rest_during_day                                      NaN
# mlhfq_difficulty_walking                                   NaN
# mlhfq_difficulty_house_work                                NaN
# mlhfq_rarely_leave_house                                   NaN
# mlhfq_rarely_socialize                                     NaN
# mlhfq_difficulty_working                                   NaN
# mlhfq_difficulty_maintining_hobbies                        NaN
# mlhfq_difficulty_intercourse                               NaN
# mlhfq_fatigue                                              NaN
# mlhfq_liability                                            NaN
# mlhfq_medical_state_concers                                NaN
# extra_health_females_first_mestural_cycle_age              NaN
# extra_health_females_current_mestural_cycle                  7
# extra_health_females_last_mestural_cycle_age               NaN
# extra_health_females_past_mestural_cycle_regular        100349
# extra_health_females_current_mestural_cycle_reg...      100349
# extra_health_females_current_avg_mestural_cycle...         NaN
# extra_health_females_current_avg_mestural_cycle...         NaN
# extra_health_females_current_avg_tampons_per_day           NaN
# extra_health_females_current_bleeding_between_m...      100349
# extra_health_females_current_mestural_cycle_pains        UKB13
# extra_health_females_current_mestural_cycle_sym...       UKB14
# extra_health_females_current_birth_control                   7
# extra_health_females_current_birth_control_type          UKB15
# extra_health_females_current_manopause_symptoms          UKB16
# extra_health_females_first_hot_flash_age                   NaN
# extra_health_females_first_vaginal_dryness_age             NaN
# extra_health_females_first_dicreased_libido_age            NaN
# extra_health_females_first_mood_changes_age                NaN
# extra_health_females_first_skin_dryness_age                NaN
# extra_health_females_current_hrt                             7
# extra_health_females_current_hrt_type                      NaN
# extra_health_females_past_recurring_uti                      7
# extra_health_females_past_uti_antibiotics                    7
# ukbb_mapping                                               NaN
