# %% [raw]
# ---
# output-file: 18-medications.html
# title: 18-medications
# ---

# %% [markdown]
# # Medications dataset
# ### Description
#
# The medication information collection in the Human Phenotype Project study is based on self reporting of medications usage via online and smartphone applications and collection by staff members by telephone or face-to-face interviews during follow-up.
#
#
# Self-report is when the participant reports the use of medication to the researcher.
# Having accurate and complete data on medication usage is essential to understanding the true impact of these medications on individuals' health.
#
# ### Data sources
#
# Currently, there are several origins for the medication data:
# 1. During registration (sign up) to the study, participants are asked to report their regular medications online(autofill), selecting from a predefined drop-down list.
# 2. Participants can log the medications taken and the consumption time using a dedicated mobile app ”Project 10k”. They requested to log during the two weeks period following each visit.
# 3. On follow up stages calls or visits to the clinical testing center - ​​participants are asked to report about any new medications they take or stopped taking and provide the month and year of when each medication was given or stopped. A staff member fills the  medications from a predefined dropdown list.
#
#
# ### Data availability:
# The information is stored in 1 parquet file: `medications.parquet`

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('medications')
dl
# Out:
# DataLoader for medications with
# 12 fields
# 2 tables: ['medications', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                          field_string                    description_string  \
# tabular_field_name
# collection_timestamp  Collection time                       Collection time
# collection_date       Collection date                       Collection date
# timezone                     Timezone                              Timezone
# medication            Medication name                       Medication name
# start_month               Start month      Start month of medication taking
# start_year                 Start year       Start year of medication taking
# ahfs_code                   AHFS code  AHFS code mapping to medication name
# atc_code                     ATC code   ATC code mapping to medication name
#
#                       parent_dataframe                 relative_location  \
# tabular_field_name
# collection_timestamp               NaN  /medications/medications.parquet
# collection_date                    NaN  /medications/medications.parquet
# timezone                           NaN  /medications/medications.parquet
# medication                         NaN  /medications/medications.parquet
# start_month                        NaN  /medications/medications.parquet
# start_year                         NaN  /medications/medications.parquet
# ahfs_code                          NaN  /medications/medications.parquet
# atc_code                           NaN  /medications/medications.parquet
#
#                       value_type  units  sampling_rate  item_type  array  \
# tabular_field_name
# collection_timestamp         NaN    NaN            NaN        NaN    NaN
# collection_date              NaN    NaN            NaN        NaN    NaN
# timezone                     NaN    NaN            NaN        NaN    NaN
# medication                   NaN    NaN            NaN        NaN    NaN
# start_month                  NaN    NaN            NaN        NaN    NaN
# start_year                   NaN    NaN            NaN        NaN    NaN
# ahfs_code                    NaN    NaN            NaN        NaN    NaN
# atc_code                     NaN    NaN            NaN        NaN    NaN
#
#                       cohorts  data_type  debut  \
# tabular_field_name
# collection_timestamp      NaN        NaN    NaN
# collection_date           NaN        NaN    NaN
# timezone                  NaN        NaN    NaN
# medication                NaN        NaN    NaN
# start_month               NaN        NaN    NaN
# start_year                NaN        NaN    NaN
# ahfs_code                 NaN        NaN    NaN
# atc_code                  NaN        NaN    NaN
#
#                                         pandas_dtype
# tabular_field_name
# collection_timestamp  datetime64[ns, Asia/Jerusalem]
# collection_date                       datetime64[ns]
# timezone                                      string
# medication                                    string
# start_month                                  float64
# start_year                                   float64
# ahfs_code                                     string
# atc_code                                      string
