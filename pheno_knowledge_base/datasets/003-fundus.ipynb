# %% [raw]
# ---
# output-file: 003-fundus.html
# title: 003-fundus
# ---

# %% [markdown]
# # Fundus images dataset
#
# Fundus imaging allows for the visualization of the interior surface of the eye, known as the fundus; and used to examine structures such as the optic disc, retina, and retinal microvasculature. This procedure is commonly used to diagnose and monitor a variety of eye diseases.
#
# Fundus imaging is a type of medical imaging technique that is used to obtain detailed, high-resolution images of the back of the eye, including the retina, the optic nerve, and the macula, an oval-shaped area in the center of the retina used for central vision (Figure 1). These images can provide important information about the health of the eye and can be used to diagnose and monitor a variety of eye diseases and conditions.
#
# One of the key features that can be seen in fundus images is the retinal microvasculature, which refers to the network of small blood vessels that supply blood to the retina. The appearance and structure of the retinal microvasculature can provide information about the health of the eye and can be used to diagnose and monitor a variety of conditions.
#
# In addition, the information provided by fundus imaging can also be used in research to better understand the underlying mechanisms of various eye conditions and as a non-invasive tool for visualization of the general microvascular circulation health and a direct view to part of the central nervous system. As such, the fundus image can serve as a window to systemic health.
#
# The Human Phenotype Project (HPP) performs fundus imaging on each participant's eyes to produce image files. To process and enhance the data, an open source software pipeline: AutoMorph: Automated Retinal Vascular Morphology Quantification via a Deep Learning Pipeline (Zhou 2022), that combines several different deep learning models is used. Specifically for the following steps:
# (1) Image pre-processing.
# (2) Image quality grading.
# (3) Anatomical segmentation (binary vessel segmentation, artery/vein segmentation, and optic disc segmentation).
# (4) Various morphological feature measurements such as vessel caliber, tortuosity density, fractal dimension etc. These features were calculated separately for segmented veins and arteries, and also as a combined feature.
# The current pipeline does not include automatic identification or clinical interpretation of eye abnormalities such as age-macular degeneration (AMD) or edema, glaucoma signs, microaneurysms etc’ that can be derived from the fundus image.
#
# ### Data availability:
# - All tabular information is stored in a main parquet file: `fundus.parquet`
# - Image files including segmentations are stored in subfolders and mapped in the main parqet file.

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
dl = PhenoLoader('fundus')
dl
# Out:
# DataLoader for fundus with
# 76 fields
# 3 tables: ['fundus', 'microvasculature', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
dl.dict
# Out:
#                                                                                          field_string  \
# tabular_field_name
# fundus_image_left                                                                 Fundus image (left)
# fundus_image_right                                                               Fundus image (right)
# collection_date                                                          Collection date (YYYY-MM-DD)
# timezone                                                                                     Timezone
# collection_timestamp                                                             Collection timestamp
# device_software_version                                                              Software version
# image_view_type_left                                                    Fundus image view type (left)
# image_view_type_right                                                  Fundus image view type (right)
# preprocessing_centre_width_left                                     preprocessing centre width (left)
# preprocessing_centre_height_left                                   preprocessing centre height (left)
# preprocessing_radius_left                                          preprocessing circle radius (left)
# preprocessing_scale_resolution_left                             preprocessing scale resolution (left)
# preprocessing_centre_width_right                                    preprocessing centre width (left)
# preprocessing_centre_height_right                                  preprocessing centre height (left)
# preprocessing_radius_right                                         preprocessing circle radius (left)
# preprocessing_scale_resolution_right                            preprocessing scale resolution (left)
# fundus_image_quality_prediction_right                         Fundus image quality prediction (right)
# fundus_image_quality_good_score_right                         Fundus image quality good score (right)
# fundus_image_quality_usable_score_right                     Fundus image quality usable score (right)
# fundus_image_quality_bad_score_right                           Fundus image quality bad score (right)
# fundus_image_quality_sd_good_right                               Fundus image quality SD good (right)
# fundus_image_quality_sd_usable_right                           Fundus image quality SD usable (right)
# fundus_image_quality_sd_bad_right                                 Fundus image quality SD bad (right)
# fundus_image_quality_prediction_left                          Fundus image quality prediction (right)
# fundus_image_quality_good_score_left                          Fundus image quality good score (right)
# fundus_image_quality_usable_score_left                      Fundus image quality usable score (right)
# fundus_image_quality_bad_score_left                            Fundus image quality bad score (right)
# fundus_image_quality_sd_good_left                                 Fundus image quality SD good (left)
# fundus_image_quality_sd_usable_left                             Fundus image quality SD usable (left)
# fundus_image_quality_sd_bad_left                                   Fundus image quality SD bad (left)
# fundus_image_binary_artery_segmentation_left           Fundus image binary artery segmentation (left)
# fundus_image_binary_artery_segmentation_right         Fundus image binary artery segmentation (right)
# fundus_image_binary_vein_segmentation_left               Fundus image binary vein segmentation (left)
# fundus_image_binary_vein_segmentation_right             Fundus image binary vein segmentation (right)
# fundus_image_binary_artery_and_vein_classificat...  Fundus image binary artery and vein classifica...
# fundus_image_binary_artery_and_vein_classificat...  Fundus image binary artery and vein classifica...
# fundus_image_binary_vessel_segmentation_left           Fundus image binary vessel segmentation (left)
# fundus_image_binary_vessel_segmentation_right         Fundus image binary vessel segmentation (right)
# fractal_dimension_left                                                       Fractal dimension (left)
# vessel_density_left                                                             Vessel density (left)
# average_width_left                                                               Average width (left)
# distance_tortuosity_left                                                   Distance tortuosity (left)
# squared_curvature_tortuosity_left                                 Squared curvature tortuosity (left)
# tortuosity_density_left                                                     Tortuosity density (left)
# artery_fractal_dimension_left                                         Artery fractal dimension (left)
# artery_vessel_density_left                                               Artery vessel density (left)
# artery_average_width_left                                                 Artery average width (left)
# artery_distance_tortuosity_left                                     Artery distance tortuosity (left)
# artery_squared_curvature_tortuosity_left                   Artery squared curvature tortuosity (left)
# artery_tortuosity_density_left                                       Artery tortuosity density (left)
# vein_fractal_dimension_left                                             Vein fractal dimension (left)
# vein_vessel_density_left                                                   Vein vessel density (left)
# vein_average_width_left                                                     Vein average width (left)
# vein_distance_tortuosity_left                                         Vein distance tortuosity (left)
# vein_squared_curvature_tortuosity_left                       Vein squared curvature tortuosity (left)
# vein_tortuosity_density_left                                           Vein tortuosity density (left)
# fractal_dimension_right                                                     Fractal dimension (right)
# vessel_density_right                                                           Vessel density (right)
# average_width_right                                                             Average width (right)
# distance_tortuosity_right                                                 Distance tortuosity (right)
# squared_curvature_tortuosity_right                               Squared curvature tortuosity (right)
# tortuosity_density_right                                                   Tortuosity density (right)
# artery_fractal_dimension_right                                       Artery fractal dimension (right)
# artery_vessel_density_right                                             Artery vessel density (right)
# artery_average_width_right                                               Artery average width (right)
# artery_distance_tortuosity_right                                   Artery distance tortuosity (right)
# artery_squared_curvature_tortuosity_right                 Artery squared curvature tortuosity (right)
# artery_tortuosity_density_right                                     Artery tortuosity density (right)
# vein_fractal_dimension_right                                           Vein fractal dimension (right)
# vein_vessel_density_right                                                 Vein vessel density (right)
# vein_average_width_right                                                   Vein average width (right)
# vein_distance_tortuosity_right                                       Vein distance tortuosity (right)
# vein_squared_curvature_tortuosity_right                     Vein squared curvature tortuosity (right)
# vein_tortuosity_density_right                                         Vein tortuosity density (right)
#
#                                                                                    description_string  \
# tabular_field_name
# fundus_image_left                                                                 Fundus image (left)
# fundus_image_right                                                               Fundus image (right)
# collection_date                                                          Collection date (YYYY-MM-DD)
# timezone                                                               Timezone for timestamp columns
# collection_timestamp                                                             Collection timestamp
# device_software_version                                                       Device software Version
# image_view_type_left                                                     Nasal or central view (left)
# image_view_type_right                                                   Nasal or central view (right)
# preprocessing_centre_width_left                                     preprocessing centre width (left)
# preprocessing_centre_height_left                                   preprocessing centre height (left)
# preprocessing_radius_left                                          preprocessing circle radius (left)
# preprocessing_scale_resolution_left                             preprocessing scale resolution (left)
# preprocessing_centre_width_right                                   preprocessing centre width (right)
# preprocessing_centre_height_right                                 preprocessing centre height (right)
# preprocessing_radius_right                                        preprocessing circle radius (right)
# preprocessing_scale_resolution_right                           preprocessing scale resolution (right)
# fundus_image_quality_prediction_right                         Fundus image quality prediction (right)
# fundus_image_quality_good_score_right                         Fundus image quality good score (right)
# fundus_image_quality_usable_score_right                     Fundus image quality usable score (right)
# fundus_image_quality_bad_score_right                           Fundus image quality bad score (right)
# fundus_image_quality_sd_good_right                               Fundus image quality SD good (right)
# fundus_image_quality_sd_usable_right                           Fundus image quality SD usable (right)
# fundus_image_quality_sd_bad_right                                 Fundus image quality SD bad (right)
# fundus_image_quality_prediction_left                          Fundus image quality prediction (right)
# fundus_image_quality_good_score_left                          Fundus image quality good score (right)
# fundus_image_quality_usable_score_left                      Fundus image quality usable score (right)
# fundus_image_quality_bad_score_left                            Fundus image quality bad score (right)
# fundus_image_quality_sd_good_left                                 Fundus image quality SD good (left)
# fundus_image_quality_sd_usable_left                             Fundus image quality SD usable (left)
# fundus_image_quality_sd_bad_left                                   Fundus image quality SD bad (left)
# fundus_image_binary_artery_segmentation_left           Fundus image binary artery segmentation (left)
# fundus_image_binary_artery_segmentation_right         Fundus image binary artery segmentation (right)
# fundus_image_binary_vein_segmentation_left               Fundus image binary vein segmentation (left)
# fundus_image_binary_vein_segmentation_right             Fundus image binary vein segmentation (right)
# fundus_image_binary_artery_and_vein_classificat...  Fundus image binary artery and vein classifica...
# fundus_image_binary_artery_and_vein_classificat...  Fundus image binary artery and vein classifica...
# fundus_image_binary_vessel_segmentation_left           Fundus image binary vessel segmentation (left)
# fundus_image_binary_vessel_segmentation_right         Fundus image binary vessel segmentation (right)
# fractal_dimension_left                                                       Fractal dimension (left)
# vessel_density_left                                                             Vessel density (left)
# average_width_left                                                               Average width (left)
# distance_tortuosity_left                                                   Distance tortuosity (left)
# squared_curvature_tortuosity_left                                 Squared curvature tortuosity (left)
# tortuosity_density_left                                                     Tortuosity density (left)
# artery_fractal_dimension_left                                         Artery fractal dimension (left)
# artery_vessel_density_left                                               Artery vessel density (left)
# artery_average_width_left                                                 Artery average width (left)
# artery_distance_tortuosity_left                                     Artery distance tortuosity (left)
# artery_squared_curvature_tortuosity_left                   Artery squared curvature tortuosity (left)
# artery_tortuosity_density_left                                       Artery tortuosity density (left)
# vein_fractal_dimension_left                                             Vein fractal dimension (left)
# vein_vessel_density_left                                                   Vein vessel density (left)
# vein_average_width_left                                                     Vein average width (left)
# vein_distance_tortuosity_left                                         Vein distance tortuosity (left)
# vein_squared_curvature_tortuosity_left                       Vein squared curvature tortuosity (left)
# vein_tortuosity_density_left                                           Vein tortuosity density (left)
# fractal_dimension_right                                                     Fractal dimension (right)
# vessel_density_right                                                           Vessel density (right)
# average_width_right                                                             Average width (right)
# distance_tortuosity_right                                                 Distance tortuosity (right)
# squared_curvature_tortuosity_right                               Squared curvature tortuosity (right)
# tortuosity_density_right                                                   Tortuosity density (right)
# artery_fractal_dimension_right                                       Artery fractal dimension (right)
# artery_vessel_density_right                                             Artery vessel density (right)
# artery_average_width_right                                               Artery average width (right)
# artery_distance_tortuosity_right                                   Artery distance tortuosity (right)
# artery_squared_curvature_tortuosity_right                 Artery squared curvature tortuosity (right)
# artery_tortuosity_density_right                                     Artery tortuosity density (right)
# vein_fractal_dimension_right                                           Vein fractal dimension (right)
# vein_vessel_density_right                                                 Vein vessel density (right)
# vein_average_width_right                                                   Vein average width (right)
# vein_distance_tortuosity_right                                       Vein distance tortuosity (right)
# vein_squared_curvature_tortuosity_right                     Vein squared curvature tortuosity (right)
# vein_tortuosity_density_right                                         Vein tortuosity density (right)
#
#                                                                   relative_location  \
# tabular_field_name
# fundus_image_left                                             fundus/fundus.parquet
# fundus_image_right                                            fundus/fundus.parquet
# collection_date                                               fundus/fundus.parquet
# timezone                                                      fundus/fundus.parquet
# collection_timestamp                                          fundus/fundus.parquet
# device_software_version                                       fundus/fundus.parquet
# image_view_type_left                                          fundus/fundus.parquet
# image_view_type_right                                         fundus/fundus.parquet
# preprocessing_centre_width_left                               fundus/fundus.parquet
# preprocessing_centre_height_left                              fundus/fundus.parquet
# preprocessing_radius_left                                     fundus/fundus.parquet
# preprocessing_scale_resolution_left                           fundus/fundus.parquet
# preprocessing_centre_width_right                              fundus/fundus.parquet
# preprocessing_centre_height_right                             fundus/fundus.parquet
# preprocessing_radius_right                                    fundus/fundus.parquet
# preprocessing_scale_resolution_right                          fundus/fundus.parquet
# fundus_image_quality_prediction_right                         fundus/fundus.parquet
# fundus_image_quality_good_score_right                         fundus/fundus.parquet
# fundus_image_quality_usable_score_right                       fundus/fundus.parquet
# fundus_image_quality_bad_score_right                          fundus/fundus.parquet
# fundus_image_quality_sd_good_right                            fundus/fundus.parquet
# fundus_image_quality_sd_usable_right                          fundus/fundus.parquet
# fundus_image_quality_sd_bad_right                             fundus/fundus.parquet
# fundus_image_quality_prediction_left                          fundus/fundus.parquet
# fundus_image_quality_good_score_left                          fundus/fundus.parquet
# fundus_image_quality_usable_score_left                        fundus/fundus.parquet
# fundus_image_quality_bad_score_left                           fundus/fundus.parquet
# fundus_image_quality_sd_good_left                             fundus/fundus.parquet
# fundus_image_quality_sd_usable_left                           fundus/fundus.parquet
# fundus_image_quality_sd_bad_left                              fundus/fundus.parquet
# fundus_image_binary_artery_segmentation_left        fundus/microvasculature.parquet
# fundus_image_binary_artery_segmentation_right       fundus/microvasculature.parquet
# fundus_image_binary_vein_segmentation_left          fundus/microvasculature.parquet
# fundus_image_binary_vein_segmentation_right         fundus/microvasculature.parquet
# fundus_image_binary_artery_and_vein_classificat...  fundus/microvasculature.parquet
# fundus_image_binary_artery_and_vein_classificat...  fundus/microvasculature.parquet
# fundus_image_binary_vessel_segmentation_left        fundus/microvasculature.parquet
# fundus_image_binary_vessel_segmentation_right       fundus/microvasculature.parquet
# fractal_dimension_left                              fundus/microvasculature.parquet
# vessel_density_left                                 fundus/microvasculature.parquet
# average_width_left                                  fundus/microvasculature.parquet
# distance_tortuosity_left                            fundus/microvasculature.parquet
# squared_curvature_tortuosity_left                   fundus/microvasculature.parquet
# tortuosity_density_left                             fundus/microvasculature.parquet
# artery_fractal_dimension_left                       fundus/microvasculature.parquet
# artery_vessel_density_left                          fundus/microvasculature.parquet
# artery_average_width_left                           fundus/microvasculature.parquet
# artery_distance_tortuosity_left                     fundus/microvasculature.parquet
# artery_squared_curvature_tortuosity_left            fundus/microvasculature.parquet
# artery_tortuosity_density_left                      fundus/microvasculature.parquet
# vein_fractal_dimension_left                         fundus/microvasculature.parquet
# vein_vessel_density_left                            fundus/microvasculature.parquet
# vein_average_width_left                             fundus/microvasculature.parquet
# vein_distance_tortuosity_left                       fundus/microvasculature.parquet
# vein_squared_curvature_tortuosity_left              fundus/microvasculature.parquet
# vein_tortuosity_density_left                        fundus/microvasculature.parquet
# fractal_dimension_right                             fundus/microvasculature.parquet
# vessel_density_right                                fundus/microvasculature.parquet
# average_width_right                                 fundus/microvasculature.parquet
# distance_tortuosity_right                           fundus/microvasculature.parquet
# squared_curvature_tortuosity_right                  fundus/microvasculature.parquet
# tortuosity_density_right                            fundus/microvasculature.parquet
# artery_fractal_dimension_right                      fundus/microvasculature.parquet
# artery_vessel_density_right                         fundus/microvasculature.parquet
# artery_average_width_right                          fundus/microvasculature.parquet
# artery_distance_tortuosity_right                    fundus/microvasculature.parquet
# artery_squared_curvature_tortuosity_right           fundus/microvasculature.parquet
# artery_tortuosity_density_right                     fundus/microvasculature.parquet
# vein_fractal_dimension_right                        fundus/microvasculature.parquet
# vein_vessel_density_right                           fundus/microvasculature.parquet
# vein_average_width_right                            fundus/microvasculature.parquet
# vein_distance_tortuosity_right                      fundus/microvasculature.parquet
# vein_squared_curvature_tortuosity_right             fundus/microvasculature.parquet
# vein_tortuosity_density_right                       fundus/microvasculature.parquet
#
#                                                                 value_type  \
# tabular_field_name
# fundus_image_left                                                    Text
# fundus_image_right                                                   Text
# collection_date                                                       Date
# timezone                                                               NaN
# collection_timestamp                                                   NaN
# device_software_version                                                NaN
# image_view_type_left                                Categorical (multiple)
# image_view_type_right                               Categorical (multiple)
# preprocessing_centre_width_left                                 Continuous
# preprocessing_centre_height_left                                Continuous
# preprocessing_radius_left                                       Continuous
# preprocessing_scale_resolution_left                             Continuous
# preprocessing_centre_width_right                                Continuous
# preprocessing_centre_height_right                               Continuous
# preprocessing_radius_right                                      Continuous
# preprocessing_scale_resolution_right                            Continuous
# fundus_image_quality_prediction_right                           Continuous
# fundus_image_quality_good_score_right                           Continuous
# fundus_image_quality_usable_score_right                         Continuous
# fundus_image_quality_bad_score_right                            Continuous
# fundus_image_quality_sd_good_right                              Continuous
# fundus_image_quality_sd_usable_right                            Continuous
# fundus_image_quality_sd_bad_right                               Continuous
# fundus_image_quality_prediction_left                            Continuous
# fundus_image_quality_good_score_left                            Continuous
# fundus_image_quality_usable_score_left                          Continuous
# fundus_image_quality_bad_score_left                             Continuous
# fundus_image_quality_sd_good_left                               Continuous
# fundus_image_quality_sd_usable_left                             Continuous
# fundus_image_quality_sd_bad_left                                Continuous
# fundus_image_binary_artery_segmentation_left                         Text
# fundus_image_binary_artery_segmentation_right                        Text
# fundus_image_binary_vein_segmentation_left                           Text
# fundus_image_binary_vein_segmentation_right                          Text
# fundus_image_binary_artery_and_vein_classificat...                   Text
# fundus_image_binary_artery_and_vein_classificat...                   Text
# fundus_image_binary_vessel_segmentation_left                         Text
# fundus_image_binary_vessel_segmentation_right                        Text
# fractal_dimension_left                                          Continuous
# vessel_density_left                                             Continuous
# average_width_left                                              Continuous
# distance_tortuosity_left                                        Continuous
# squared_curvature_tortuosity_left                               Continuous
# tortuosity_density_left                                         Continuous
# artery_fractal_dimension_left                                   Continuous
# artery_vessel_density_left                                      Continuous
# artery_average_width_left                                       Continuous
# artery_distance_tortuosity_left                                 Continuous
# artery_squared_curvature_tortuosity_left                        Continuous
# artery_tortuosity_density_left                                  Continuous
# vein_fractal_dimension_left                                     Continuous
# vein_vessel_density_left                                        Continuous
# vein_average_width_left                                         Continuous
# vein_distance_tortuosity_left                                   Continuous
# vein_squared_curvature_tortuosity_left                          Continuous
# vein_tortuosity_density_left                                    Continuous
# fractal_dimension_right                                         Continuous
# vessel_density_right                                            Continuous
# average_width_right                                             Continuous
# distance_tortuosity_right                                       Continuous
# squared_curvature_tortuosity_right                              Continuous
# tortuosity_density_right                                        Continuous
# artery_fractal_dimension_right                                  Continuous
# artery_vessel_density_right                                     Continuous
# artery_average_width_right                                      Continuous
# artery_distance_tortuosity_right                                Continuous
# artery_squared_curvature_tortuosity_right                       Continuous
# artery_tortuosity_density_right                                 Continuous
# vein_fractal_dimension_right                                    Continuous
# vein_vessel_density_right                                       Continuous
# vein_average_width_right                                        Continuous
# vein_distance_tortuosity_right                                  Continuous
# vein_squared_curvature_tortuosity_right                         Continuous
# vein_tortuosity_density_right                                   Continuous
#
#                                                           units  \
# tabular_field_name
# fundus_image_left                                           NaN
# fundus_image_right                                          NaN
# collection_date                                            Time
# timezone                                                    NaN
# collection_timestamp                                       Time
# device_software_version                                     NaN
# image_view_type_left                                       Text
# image_view_type_right                                      Text
# preprocessing_centre_width_left                         Boolean
# preprocessing_centre_height_left                        Boolean
# preprocessing_radius_left                               Boolean
# preprocessing_scale_resolution_left                     Boolean
# preprocessing_centre_width_right                        Boolean
# preprocessing_centre_height_right                       Boolean
# preprocessing_radius_right                              Boolean
# preprocessing_scale_resolution_right                    Boolean
# fundus_image_quality_prediction_right                   Boolean
# fundus_image_quality_good_score_right               Probability
# fundus_image_quality_usable_score_right             Probability
# fundus_image_quality_bad_score_right                Probability
# fundus_image_quality_sd_good_right                  Probability
# fundus_image_quality_sd_usable_right                Probability
# fundus_image_quality_sd_bad_right                   Probability
# fundus_image_quality_prediction_left                    Boolean
# fundus_image_quality_good_score_left                Probability
# fundus_image_quality_usable_score_left              Probability
# fundus_image_quality_bad_score_left                 Probability
# fundus_image_quality_sd_good_left                   Probability
# fundus_image_quality_sd_usable_left                 Probability
# fundus_image_quality_sd_bad_left                    Probability
# fundus_image_binary_artery_segmentation_left                NaN
# fundus_image_binary_artery_segmentation_right               NaN
# fundus_image_binary_vein_segmentation_left                  NaN
# fundus_image_binary_vein_segmentation_right                 NaN
# fundus_image_binary_artery_and_vein_classificat...          NaN
# fundus_image_binary_artery_and_vein_classificat...          NaN
# fundus_image_binary_vessel_segmentation_left                NaN
# fundus_image_binary_vessel_segmentation_right               NaN
# fractal_dimension_left                                      NaN
# vessel_density_left                                     density
# average_width_left                                       pixels
# distance_tortuosity_left                                    NaN
# squared_curvature_tortuosity_left                           NaN
# tortuosity_density_left                                 density
# artery_fractal_dimension_left                               NaN
# artery_vessel_density_left                              density
# artery_average_width_left                                pixels
# artery_distance_tortuosity_left                             NaN
# artery_squared_curvature_tortuosity_left                    NaN
# artery_tortuosity_density_left                          density
# vein_fractal_dimension_left                                 NaN
# vein_vessel_density_left                                density
# vein_average_width_left                                  pixels
# vein_distance_tortuosity_left                               NaN
# vein_squared_curvature_tortuosity_left                      NaN
# vein_tortuosity_density_left                            density
# fractal_dimension_right                                     NaN
# vessel_density_right                                    density
# average_width_right                                      pixels
# distance_tortuosity_right                                   NaN
# squared_curvature_tortuosity_right                          NaN
# tortuosity_density_right                                density
# artery_fractal_dimension_right                              NaN
# artery_vessel_density_right                             density
# artery_average_width_right                               pixels
# artery_distance_tortuosity_right                            NaN
# artery_squared_curvature_tortuosity_right                   NaN
# artery_tortuosity_density_right                         density
# vein_fractal_dimension_right                                NaN
# vein_vessel_density_right                               density
# vein_average_width_right                                 pixels
# vein_distance_tortuosity_right                              NaN
# vein_squared_curvature_tortuosity_right                     NaN
# vein_tortuosity_density_right                           density
#
#                                                     sampling_rate item_type  \
# tabular_field_name
# fundus_image_left                                             NaN      Bulk
# fundus_image_right                                            NaN      Bulk
# collection_date                                               NaN      Data
# timezone                                                      NaN       NaN
# collection_timestamp                                          NaN      Data
# device_software_version                                       NaN      Data
# image_view_type_left                                          NaN      Data
# image_view_type_right                                         NaN      Data
# preprocessing_centre_width_left                               NaN      Data
# preprocessing_centre_height_left                              NaN      Data
# preprocessing_radius_left                                     NaN      Data
# preprocessing_scale_resolution_left                           NaN      Data
# preprocessing_centre_width_right                              NaN      Data
# preprocessing_centre_height_right                             NaN      Data
# preprocessing_radius_right                                    NaN      Data
# preprocessing_scale_resolution_right                          NaN      Data
# fundus_image_quality_prediction_right                         NaN      Data
# fundus_image_quality_good_score_right                         NaN      Data
# fundus_image_quality_usable_score_right                       NaN      Data
# fundus_image_quality_bad_score_right                          NaN      Data
# fundus_image_quality_sd_good_right                            NaN      Data
# fundus_image_quality_sd_usable_right                          NaN      Data
# fundus_image_quality_sd_bad_right                             NaN      Data
# fundus_image_quality_prediction_left                          NaN      Data
# fundus_image_quality_good_score_left                          NaN      Data
# fundus_image_quality_usable_score_left                        NaN      Data
# fundus_image_quality_bad_score_left                           NaN      Data
# fundus_image_quality_sd_good_left                             NaN      Data
# fundus_image_quality_sd_usable_left                           NaN      Data
# fundus_image_quality_sd_bad_left                              NaN      Data
# fundus_image_binary_artery_segmentation_left                  NaN      Bulk
# fundus_image_binary_artery_segmentation_right                 NaN      Bulk
# fundus_image_binary_vein_segmentation_left                    NaN      Bulk
# fundus_image_binary_vein_segmentation_right                   NaN      Bulk
# fundus_image_binary_artery_and_vein_classificat...            NaN      Bulk
# fundus_image_binary_artery_and_vein_classificat...            NaN      Bulk
# fundus_image_binary_vessel_segmentation_left                  NaN      Bulk
# fundus_image_binary_vessel_segmentation_right                 NaN      Bulk
# fractal_dimension_left                                        NaN      Data
# vessel_density_left                                           NaN      Data
# average_width_left                                            NaN      Data
# distance_tortuosity_left                                      NaN      Data
# squared_curvature_tortuosity_left                             NaN      Data
# tortuosity_density_left                                       NaN      Data
# artery_fractal_dimension_left                                 NaN      Data
# artery_vessel_density_left                                    NaN      Data
# artery_average_width_left                                     NaN      Data
# artery_distance_tortuosity_left                               NaN      Data
# artery_squared_curvature_tortuosity_left                      NaN      Data
# artery_tortuosity_density_left                                NaN      Data
# vein_fractal_dimension_left                                   NaN      Data
# vein_vessel_density_left                                      NaN      Data
# vein_average_width_left                                       NaN      Data
# vein_distance_tortuosity_left                                 NaN      Data
# vein_squared_curvature_tortuosity_left                        NaN      Data
# vein_tortuosity_density_left                                  NaN      Data
# fractal_dimension_right                                       NaN      Data
# vessel_density_right                                          NaN      Data
# average_width_right                                           NaN      Data
# distance_tortuosity_right                                     NaN      Data
# squared_curvature_tortuosity_right                            NaN      Data
# tortuosity_density_right                                      NaN      Data
# artery_fractal_dimension_right                                NaN      Data
# artery_vessel_density_right                                   NaN      Data
# artery_average_width_right                                    NaN      Data
# artery_distance_tortuosity_right                              NaN      Data
# artery_squared_curvature_tortuosity_right                     NaN      Data
# artery_tortuosity_density_right                               NaN      Data
# vein_fractal_dimension_right                                  NaN      Data
# vein_vessel_density_right                                     NaN      Data
# vein_average_width_right                                      NaN      Data
# vein_distance_tortuosity_right                                NaN      Data
# vein_squared_curvature_tortuosity_right                       NaN      Data
# vein_tortuosity_density_right                                 NaN      Data
#
#                                                      array cohorts data_type  \
# tabular_field_name
# fundus_image_left                                   Single     10K     image
# fundus_image_right                                  Single     10K     image
# collection_date                                     Single     10K   tabular
# timezone                                               NaN     NaN       NaN
# collection_timestamp                                Single     10K   tabular
# device_software_version                             Single     10K   tabular
# image_view_type_left                                Single     10K   tabular
# image_view_type_right                               Single     10K   tabular
# preprocessing_centre_width_left                     Single     10K   tabular
# preprocessing_centre_height_left                    Single     10K   tabular
# preprocessing_radius_left                           Single     10K   tabular
# preprocessing_scale_resolution_left                 Single     10K   tabular
# preprocessing_centre_width_right                    Single     10K   tabular
# preprocessing_centre_height_right                   Single     10K   tabular
# preprocessing_radius_right                          Single     10K   tabular
# preprocessing_scale_resolution_right                Single     10K   tabular
# fundus_image_quality_prediction_right               Single     10K   tabular
# fundus_image_quality_good_score_right               Single     10K   tabular
# fundus_image_quality_usable_score_right             Single     10K   tabular
# fundus_image_quality_bad_score_right                Single     10K   tabular
# fundus_image_quality_sd_good_right                  Single     10K   tabular
# fundus_image_quality_sd_usable_right                Single     10K   tabular
# fundus_image_quality_sd_bad_right                   Single     10K   tabular
# fundus_image_quality_prediction_left                Single     10K   tabular
# fundus_image_quality_good_score_left                Single     10K   tabular
# fundus_image_quality_usable_score_left              Single     10K   tabular
# fundus_image_quality_bad_score_left                 Single     10K   tabular
# fundus_image_quality_sd_good_left                   Single     10K   tabular
# fundus_image_quality_sd_usable_left                 Single     10K   tabular
# fundus_image_quality_sd_bad_left                    Single     10K   tabular
# fundus_image_binary_artery_segmentation_left        Single     10K     image
# fundus_image_binary_artery_segmentation_right       Single     10K     image
# fundus_image_binary_vein_segmentation_left          Single     10K     image
# fundus_image_binary_vein_segmentation_right         Single     10K     image
# fundus_image_binary_artery_and_vein_classificat...  Single     10K     image
# fundus_image_binary_artery_and_vein_classificat...  Single     10K     image
# fundus_image_binary_vessel_segmentation_left        Single     10K     image
# fundus_image_binary_vessel_segmentation_right       Single     10K     image
# fractal_dimension_left                              Single     10K   tabular
# vessel_density_left                                 Single     10K   tabular
# average_width_left                                  Single     10K   tabular
# distance_tortuosity_left                            Single     10K   tabular
# squared_curvature_tortuosity_left                   Single     10K   tabular
# tortuosity_density_left                             Single     10K   tabular
# artery_fractal_dimension_left                       Single     10K   tabular
# artery_vessel_density_left                          Single     10K   tabular
# artery_average_width_left                           Single     10K   tabular
# artery_distance_tortuosity_left                     Single     10K   tabular
# artery_squared_curvature_tortuosity_left            Single     10K   tabular
# artery_tortuosity_density_left                      Single     10K   tabular
# vein_fractal_dimension_left                         Single     10K   tabular
# vein_vessel_density_left                            Single     10K   tabular
# vein_average_width_left                             Single     10K   tabular
# vein_distance_tortuosity_left                       Single     10K   tabular
# vein_squared_curvature_tortuosity_left              Single     10K   tabular
# vein_tortuosity_density_left                        Single     10K   tabular
# fractal_dimension_right                             Single     10K   tabular
# vessel_density_right                                Single     10K   tabular
# average_width_right                                 Single     10K   tabular
# distance_tortuosity_right                           Single     10K   tabular
# squared_curvature_tortuosity_right                  Single     10K   tabular
# tortuosity_density_right                            Single     10K   tabular
# artery_fractal_dimension_right                      Single     10K   tabular
# artery_vessel_density_right                         Single     10K   tabular
# artery_average_width_right                          Single     10K   tabular
# artery_distance_tortuosity_right                    Single     10K   tabular
# artery_squared_curvature_tortuosity_right           Single     10K   tabular
# artery_tortuosity_density_right                     Single     10K   tabular
# vein_fractal_dimension_right                        Single     10K   tabular
# vein_vessel_density_right                           Single     10K   tabular
# vein_average_width_right                            Single     10K   tabular
# vein_distance_tortuosity_right                      Single     10K   tabular
# vein_squared_curvature_tortuosity_right             Single     10K   tabular
# vein_tortuosity_density_right                       Single     10K   tabular
#
#                                                          debut  \
# tabular_field_name
# fundus_image_left                                   2021-02-17
# fundus_image_right                                  2021-02-17
# collection_date                                     2021-02-17
# timezone                                            2021-02-17
# collection_timestamp                                2021-02-17
# device_software_version                             2021-02-17
# image_view_type_left                                2021-02-17
# image_view_type_right                               2021-02-17
# preprocessing_centre_width_left                     2021-02-17
# preprocessing_centre_height_left                    2021-02-17
# preprocessing_radius_left                           2021-02-17
# preprocessing_scale_resolution_left                 2021-02-17
# preprocessing_centre_width_right                    2021-02-17
# preprocessing_centre_height_right                   2021-02-17
# preprocessing_radius_right                          2021-02-17
# preprocessing_scale_resolution_right                2021-02-17
# fundus_image_quality_prediction_right               2021-02-17
# fundus_image_quality_good_score_right               2021-02-17
# fundus_image_quality_usable_score_right             2021-02-17
# fundus_image_quality_bad_score_right                2021-02-17
# fundus_image_quality_sd_good_right                  2021-02-17
# fundus_image_quality_sd_usable_right                2021-02-17
# fundus_image_quality_sd_bad_right                   2021-02-17
# fundus_image_quality_prediction_left                2021-02-17
# fundus_image_quality_good_score_left                2021-02-17
# fundus_image_quality_usable_score_left              2021-02-17
# fundus_image_quality_bad_score_left                 2021-02-17
# fundus_image_quality_sd_good_left                   2021-02-17
# fundus_image_quality_sd_usable_left                 2021-02-17
# fundus_image_quality_sd_bad_left                    2021-02-17
# fundus_image_binary_artery_segmentation_left        2021-02-17
# fundus_image_binary_artery_segmentation_right       2021-02-17
# fundus_image_binary_vein_segmentation_left          2021-02-17
# ...
# preprocessing_radius_left                                                    float
# preprocessing_scale_resolution_left                                          float
# preprocessing_centre_width_right                                             float
# preprocessing_centre_height_right                                            float
# preprocessing_radius_right                                                   float
# preprocessing_scale_resolution_right                                         float
# fundus_image_quality_prediction_right                                     category
# fundus_image_quality_good_score_right                                        float
# fundus_image_quality_usable_score_right                                      float
# fundus_image_quality_bad_score_right                                         float
# fundus_image_quality_sd_good_right                                           float
# fundus_image_quality_sd_usable_right                                         float
# fundus_image_quality_sd_bad_right                                            float
# fundus_image_quality_prediction_left                                      category
# fundus_image_quality_good_score_left                                         float
# fundus_image_quality_usable_score_left                                       float
# fundus_image_quality_bad_score_left                                          float
# fundus_image_quality_sd_good_left                                            float
# fundus_image_quality_sd_usable_left                                          float
# fundus_image_quality_sd_bad_left                                             float
# fundus_image_binary_artery_segmentation_left                                string
# fundus_image_binary_artery_segmentation_right                               string
# fundus_image_binary_vein_segmentation_left                                  string
# fundus_image_binary_vein_segmentation_right                                 string
# fundus_image_binary_artery_and_vein_classificat...                          string
# fundus_image_binary_artery_and_vein_classificat...                          string
# fundus_image_binary_vessel_segmentation_left                                string
# fundus_image_binary_vessel_segmentation_right                               string
# fractal_dimension_left                                                       float
# vessel_density_left                                                          float
# average_width_left                                                           float
# distance_tortuosity_left                                                     float
# squared_curvature_tortuosity_left                                            float
# tortuosity_density_left                                                      float
# artery_fractal_dimension_left                                                float
# artery_vessel_density_left                                                   float
# artery_average_width_left                                                    float
# artery_distance_tortuosity_left                                              float
# artery_squared_curvature_tortuosity_left                                     float
# artery_tortuosity_density_left                                               float
# vein_fractal_dimension_left                                                  float
# vein_vessel_density_left                                                     float
# vein_average_width_left                                                      float
# vein_distance_tortuosity_left                                                float
# vein_squared_curvature_tortuosity_left                                       float
# vein_tortuosity_density_left                                                 float
# fractal_dimension_right                                                      float
# vessel_density_right                                                         float
# average_width_right                                                          float
# distance_tortuosity_right                                                    float
# squared_curvature_tortuosity_right                                           float
# tortuosity_density_right                                                     float
# artery_fractal_dimension_right                                               float
# artery_vessel_density_right                                                  float
# artery_average_width_right                                                   float
# artery_distance_tortuosity_right                                             float
# artery_squared_curvature_tortuosity_right                                    float
# artery_tortuosity_density_right                                              float
# vein_fractal_dimension_right                                                 float
# vein_vessel_density_right                                                    float
# vein_average_width_right                                                     float
# vein_distance_tortuosity_right                                               float
# vein_squared_curvature_tortuosity_right                                      float
# vein_tortuosity_density_right                                                float
#
#                                                     parent_dataframe  \
# tabular_field_name
# fundus_image_left                                                NaN
# fundus_image_right                                               NaN
# collection_date                                                  NaN
# timezone                                                         NaN
# collection_timestamp                                             NaN
# device_software_version                                          NaN
# image_view_type_left                                             NaN
# image_view_type_right                                            NaN
# preprocessing_centre_width_left                                  NaN
# preprocessing_centre_height_left                                 NaN
# preprocessing_radius_left                                        NaN
# preprocessing_scale_resolution_left                              NaN
# preprocessing_centre_width_right                                 NaN
# preprocessing_centre_height_right                                NaN
# preprocessing_radius_right                                       NaN
# preprocessing_scale_resolution_right                             NaN
# fundus_image_quality_prediction_right                            NaN
# fundus_image_quality_good_score_right                            NaN
# fundus_image_quality_usable_score_right                          NaN
# fundus_image_quality_bad_score_right                             NaN
# fundus_image_quality_sd_good_right                               NaN
# fundus_image_quality_sd_usable_right                             NaN
# fundus_image_quality_sd_bad_right                                NaN
# fundus_image_quality_prediction_left                             NaN
# fundus_image_quality_good_score_left                             NaN
# fundus_image_quality_usable_score_left                           NaN
# fundus_image_quality_bad_score_left                              NaN
# fundus_image_quality_sd_good_left                                NaN
# fundus_image_quality_sd_usable_left                              NaN
# fundus_image_quality_sd_bad_left                                 NaN
# fundus_image_binary_artery_segmentation_left                     NaN
# fundus_image_binary_artery_segmentation_right                    NaN
# fundus_image_binary_vein_segmentation_left                       NaN
# fundus_image_binary_vein_segmentation_right                      NaN
# fundus_image_binary_artery_and_vein_classificat...               NaN
# fundus_image_binary_artery_and_vein_classificat...               NaN
# fundus_image_binary_vessel_segmentation_left                     NaN
# fundus_image_binary_vessel_segmentation_right                    NaN
# fractal_dimension_left                                           NaN
# vessel_density_left                                              NaN
# average_width_left                                               NaN
# distance_tortuosity_left                                         NaN
# squared_curvature_tortuosity_left                                NaN
# tortuosity_density_left                                          NaN
# artery_fractal_dimension_left                                    NaN
# artery_vessel_density_left                                       NaN
# artery_average_width_left                                        NaN
# artery_distance_tortuosity_left                                  NaN
# artery_squared_curvature_tortuosity_left                         NaN
# artery_tortuosity_density_left                                   NaN
# vein_fractal_dimension_left                                      NaN
# vein_vessel_density_left                                         NaN
# vein_average_width_left                                          NaN
# vein_distance_tortuosity_left                                    NaN
# vein_squared_curvature_tortuosity_left                           NaN
# vein_tortuosity_density_left                                     NaN
# fractal_dimension_right                                          NaN
# vessel_density_right                                             NaN
# average_width_right                                              NaN
# distance_tortuosity_right                                        NaN
# squared_curvature_tortuosity_right                               NaN
# tortuosity_density_right                                         NaN
# artery_fractal_dimension_right                                   NaN
# artery_vessel_density_right                                      NaN
# artery_average_width_right                                       NaN
# artery_distance_tortuosity_right                                 NaN
# artery_squared_curvature_tortuosity_right                        NaN
# artery_tortuosity_density_right                                  NaN
# vein_fractal_dimension_right                                     NaN
# vein_vessel_density_right                                        NaN
# vein_average_width_right                                         NaN
# vein_distance_tortuosity_right                                   NaN
# vein_squared_curvature_tortuosity_right                          NaN
# vein_tortuosity_density_right                                    NaN
#
#                                                    data_coding
# tabular_field_name
# fundus_image_left                                          NaN
# fundus_image_right                                         NaN
# collection_date                                            NaN
# timezone                                                   NaN
# collection_timestamp                                       NaN
# device_software_version                                    NaN
# image_view_type_left                                       NaN
# image_view_type_right                                      NaN
# preprocessing_centre_width_left                            NaN
# preprocessing_centre_height_left                           NaN
# preprocessing_radius_left                                  NaN
# preprocessing_scale_resolution_left                        NaN
# preprocessing_centre_width_right                           NaN
# preprocessing_centre_height_right                          NaN
# preprocessing_radius_right                                 NaN
# preprocessing_scale_resolution_right                       NaN
# fundus_image_quality_prediction_right                     F001
# fundus_image_quality_good_score_right                      NaN
# fundus_image_quality_usable_score_right                    NaN
# fundus_image_quality_bad_score_right                       NaN
# fundus_image_quality_sd_good_right                         NaN
# fundus_image_quality_sd_usable_right                       NaN
# fundus_image_quality_sd_bad_right                          NaN
# fundus_image_quality_prediction_left                      F001
# fundus_image_quality_good_score_left                       NaN
# fundus_image_quality_usable_score_left                     NaN
# fundus_image_quality_bad_score_left                        NaN
# fundus_image_quality_sd_good_left                          NaN
# fundus_image_quality_sd_usable_left                        NaN
# fundus_image_quality_sd_bad_left                           NaN
# fundus_image_binary_artery_segmentation_left               NaN
# fundus_image_binary_artery_segmentation_right              NaN
# fundus_image_binary_vein_segmentation_left                 NaN
# fundus_image_binary_vein_segmentation_right                NaN
# fundus_image_binary_artery_and_vein_classificat...         NaN
# fundus_image_binary_artery_and_vein_classificat...         NaN
# fundus_image_binary_vessel_segmentation_left               NaN
# fundus_image_binary_vessel_segmentation_right              NaN
# fractal_dimension_left                                     NaN
# vessel_density_left                                        NaN
# average_width_left                                         NaN
# distance_tortuosity_left                                   NaN
# squared_curvature_tortuosity_left                          NaN
# tortuosity_density_left                                    NaN
# artery_fractal_dimension_left                              NaN
# artery_vessel_density_left                                 NaN
# artery_average_width_left                                  NaN
# artery_distance_tortuosity_left                            NaN
# artery_squared_curvature_tortuosity_left                   NaN
# artery_tortuosity_density_left                             NaN
# vein_fractal_dimension_left                                NaN
# vein_vessel_density_left                                   NaN
# vein_average_width_left                                    NaN
# vein_distance_tortuosity_left                              NaN
# vein_squared_curvature_tortuosity_left                     NaN
# vein_tortuosity_density_left                               NaN
# fractal_dimension_right                                    NaN
# vessel_density_right                                       NaN
# average_width_right                                        NaN
# distance_tortuosity_right                                  NaN
# squared_curvature_tortuosity_right                         NaN
# tortuosity_density_right                                   NaN
# artery_fractal_dimension_right                             NaN
# artery_vessel_density_right                                NaN
# artery_average_width_right                                 NaN
# artery_distance_tortuosity_right                           NaN
# artery_squared_curvature_tortuosity_right                  NaN
# artery_tortuosity_density_right                            NaN
# vein_fractal_dimension_right                               NaN
# vein_vessel_density_right                                  NaN
# vein_average_width_right                                   NaN
# vein_distance_tortuosity_right                             NaN
# vein_squared_curvature_tortuosity_right                    NaN
# vein_tortuosity_density_right                              NaN
